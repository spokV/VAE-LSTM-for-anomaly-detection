# %%
from google.colab import drive
drive.mount('/content/drive')
global GIT_DIR
GIT_DIR='/content/drive/My\ Drive/afeka/y2/sem1/dl/code/LSTM-VAE/VAE-LSTM-for-anomaly-detection'
# %cd $GIT_DIR
# !ls

# %%
# %cd $GIT_DIR/codes/

# %%
import warnings

def fxn():
    warnings.warn("deprecated", DeprecationWarning)

with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    fxn()

# %%
# %tensorflow_version 1.x

# %%
import tensorflow as tf
import tensorflow_probability as tfp
import numpy as np
import matplotlib.pylab as plt
from matplotlib.pyplot import plot, ion, show, savefig, cla, figure
import random
import time

# %%
import os
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"   # see issue #152
os.environ["CUDA_VISIBLE_DEVICES"]="0"

import tensorflow as tf
from data_loader import DataGenerator
from models import VAEmodel, lstmKerasModel
from trainers import vaeTrainer

from utils import process_config, create_dirs, get_args

# %%
from tensorflow.python.client import device_lib

def get_available_gpus():
    local_device_protos = device_lib.list_local_devices()
    return [x.name for x in local_device_protos if x.device_type == 'GPU']

print(get_available_gpus())
# Out:
# []

# %%
# load VAE model
config = process_config('NAB_config.json')
# create the experiments dirs
create_dirs([config['result_dir'], config['checkpoint_dir']])
# create tensorflow session
sess = tf.Session(config=tf.ConfigProto(log_device_placement=True))
# create your data generator
data = DataGenerator(config)
# create a CNN model
model_vae = VAEmodel(config)
# create a CNN model
trainer_vae = vaeTrainer(sess, model_vae, data, config)
model_vae.load(sess)

# here you train your model
if config['TRAIN_VAE']:
    if config['num_epochs_vae'] > 0:
        trainer_vae.train()
# Out:
#  val sets:
# train: 602.6555, val: 416.2691
# Current sigma2: 0.0100000
# Already trained for 0.17562836805979412 min; Remaining 4.215080833435058 min.
# Saving model...
# Model saved.
# 2/49, test loss: -elbo: 379.1829, recons_loss_weighted: 699.4848, recons_loss_ls: 13.9897, KL_loss: 9.3043, sigma_regularisor: -55.2620, code_std_dev: [0.6934133  0.2523507  0.23782718 0.54637444 0.6586137  0.5506104 ]
# Loss on training and val sets:
# train: 517.4070, val: 338.9590
# Current sigma2: 0.0100000
# Already trained for 0.25584435860315957 min; Remaining 4.008228284782834 min.
# Saving model...
# Model saved.
# 3/49, test loss: -elbo: 361.4554, recons_loss_weighted: 663.9875, recons_loss_ls: 13.2798, KL_loss: 9.3255, sigma_regularisor: -55.2620, code_std_dev: [0.6665053  0.1452485  0.17453954 0.56851697 0.56604767 0.34429327]
# Loss on training and val sets:
# train: 484.1684, val: 389.8629
# Current sigma2: 0.0100000
# Already trained for 0.33929455280303955 min; Remaining 3.901887357234955 min.
# Saving model...
# Model saved.
# 4/49, test loss: -elbo: 330.7728, recons_loss_weighted: 594.9214, recons_loss_ls: 11.8984, KL_loss: 13.1759, sigma_regularisor: -55.2620, code_std_dev: [0.49307072 0.09177027 0.1927743  0.46755448 0.6182089  0.22185348]
# Loss on training and val sets:
# train: 459.4174, val: 314.3600
# Current sigma2: 0.0100000
# Already trained for 0.42202603816986084 min; Remaining 3.7982343435287476 min.
# Saving model...
# Model saved.
# 5/49, test loss: -elbo: 288.5818, recons_loss_weighted: 504.6754, recons_loss_ls: 10.0935, KL_loss: 16.1079, sigma_regularisor: -55.2620, code_std_dev: [0.48658663 0.08189087 0.15316246 0.25930706 0.37644023 0.13691168]
# Loss on training and val sets:
# train: 402.1874, val: 295.2873
# Current sigma2: 0.0100000
# Already trained for 0.5046582857767741 min; Remaining 3.700827429029677 min.
# Saving model...
# Model saved.
# 6/49, test loss: -elbo: 271.1517, recons_loss_weighted: 468.1929, recons_loss_ls: 9.3639, KL_loss: 16.9190, sigma_regularisor: -55.2620, code_std_dev: [0.48894316 0.07924788 0.11474541 0.30027226 0.26139355 0.11850617]
# Loss on training and val sets:
# train: 367.4716, val: 184.7159
# Current sigma2: 0.0100000
# Already trained for 0.5884069522221883 min; Remaining 3.614499849364871 min.
# Saving model...
# Model saved.
# 7/49, test loss: -elbo: 261.7180, recons_loss_weighted: 447.9350, recons_loss_ls: 8.9587, KL_loss: 17.6143, sigma_regularisor: -55.2620, code_std_dev: [0.39701208 0.1032837  0.08836551 0.25910762 0.26197442 0.09877972]
# Loss on training and val sets:
# train: 334.3618, val: 273.7657
# Current sigma2: 0.0100000
# Already trained for 0.6703321774800618 min; Remaining 3.519243931770325 min.
# Saving model...
# Model saved.
# 8/49, test loss: -elbo: 246.2985, recons_loss_weighted: 415.1499, recons_loss_ls: 8.3030, KL_loss: 18.5874, sigma_regularisor: -55.2620, code_std_dev: [0.26377487 0.07010141 0.14969985 0.21948236 0.24950816 0.0989324 ]
# Loss on training and val sets:
# train: 299.8344, val: 230.2273
# Current sigma2: 0.0100000
# Already trained for 0.7505102157592773 min; Remaining 3.4189909829033747 min.
# Saving model...
# Model saved.
# 9/49, test loss: -elbo: 225.0636, recons_loss_weighted: 371.0946, recons_loss_ls: 7.4219, KL_loss: 19.3801, sigma_regularisor: -55.2620, code_std_dev: [0.16812202 0.07896379 0.14760128 0.2237399  0.1953833  0.04977454]
# Loss on training and val sets:
# train: 271.9931, val: 235.8972
# Current sigma2: 0.0100000
# Already trained for 0.8318697214126587 min; Remaining 3.3274788856506348 min.
# Saving model...
# Model saved.
# 10/49, test loss: -elbo: 205.9095, recons_loss_weighted: 331.9183, recons_loss_ls: 6.6384, KL_loss: 19.8141, sigma_regularisor: -55.2620, code_std_dev: [0.18747415 0.09828696 0.16118483 0.17479044 0.15447184 0.09442313]
# Loss on training and val sets:
# train: 248.7089, val: 201.3018
# Current sigma2: 0.0100000
# Already trained for 0.9124747077624004 min; Remaining 3.23513760024851 min.
# Saving model...
# Model saved.
# 11/49, test loss: -elbo: 197.0797, recons_loss_weighted: 314.1968, recons_loss_ls: 6.2839, KL_loss: 19.8451, sigma_regularisor: -55.2620, code_std_dev: [0.1862932  0.12534338 0.17211616 0.14884734 0.16763474 0.09427476]
# Loss on training and val sets:
# train: 236.3023, val: 212.2270
# Current sigma2: 0.0100000
# Already trained for 0.9949622273445129 min; Remaining 3.150713719924291 min.
# Saving model...
# Model saved.
# 12/49, test loss: -elbo: 196.0004, recons_loss_weighted: 313.6407, recons_loss_ls: 6.2728, KL_loss: 19.0438, sigma_regularisor: -55.2620, code_std_dev: [0.2190413  0.14059138 0.1408702  0.20845376 0.17187689 0.15362982]
# Loss on training and val sets:
# train: 223.3494, val: 229.2658
# Current sigma2: 0.0100000
# Already trained for 1.0785764535268147 min; Remaining 3.069794521576319 min.
# Saving model...
# Model saved.
# 13/49, test loss: -elbo: 192.4379, recons_loss_weighted: 304.5956, recons_loss_ls: 6.0919, KL_loss: 20.0039, sigma_regularisor: -55.2620, code_std_dev: [0.19105643 0.11001195 0.15335628 0.15567198 0.16511525 0.11924312]
# Loss on training and val sets:
# train: 213.2437, val: 165.0062
# Current sigma2: 0.0100000
# Already trained for 1.1602335810661315 min; Remaining 2.9834577798843385 min.
# Saving model...
# Model saved.
# 14/49, test loss: -elbo: 186.3112, recons_loss_weighted: 290.9653, recons_loss_ls: 5.8193, KL_loss: 20.6923, sigma_regularisor: -55.2620, code_std_dev: [0.14997007 0.08119781 0.15996426 0.11587527 0.23509307 0.07707432]
# Loss on training and val sets:
# train: 202.5800, val: 184.8180
# Current sigma2: 0.0100000
# Already trained for 1.244137183825175 min; Remaining 2.9029867622587413 min.
# Saving model...
# Model saved.
# 15/49, test loss: -elbo: 183.2368, recons_loss_weighted: 284.7314, recons_loss_ls: 5.6946, KL_loss: 20.7349, sigma_regularisor: -55.2620, code_std_dev: [0.19765252 0.09994876 0.12197469 0.15225431 0.16260548 0.10445353]
# Loss on training and val sets:
# train: 192.9544, val: 182.7776
# Current sigma2: 0.0100000
# Already trained for 1.3340586423873901 min; Remaining 2.834874615073204 min.
# Saving model...
# Model saved.
# 16/49, test loss: -elbo: 178.9933, recons_loss_weighted: 276.0855, recons_loss_ls: 5.5217, KL_loss: 20.8143, sigma_regularisor: -55.2620, code_std_dev: [0.20794088 0.11091955 0.12970215 0.15733223 0.17031008 0.10355365]
# Loss on training and val sets:
# train: 185.3671, val: 156.2411
# Current sigma2: 0.0100000
# Already trained for 1.4197055339813232 min; Remaining 2.755898977728451 min.
# Saving model...
# Model saved.
# 17/49, test loss: -elbo: 176.5185, recons_loss_weighted: 269.6322, recons_loss_ls: 5.3926, KL_loss: 21.5662, sigma_regularisor: -55.2620, code_std_dev: [0.16116272 0.07755109 0.16964929 0.09814965 0.15368079 0.07031848]
# Loss on training and val sets:
# train: 179.6221, val: 196.3821
# Current sigma2: 0.0100000
# Already trained for 1.5067796111106873 min; Remaining 2.6787193086412215 min.
# Saving model...
# Model saved.
# 18/49, test loss: -elbo: 179.5931, recons_loss_weighted: 275.7489, recons_loss_ls: 5.5150, KL_loss: 21.5824, sigma_regularisor: -55.2620, code_std_dev: [0.20625937 0.06060417 0.13763307 0.16320138 0.18646093 0.09467581]
# Loss on training and val sets:
# train: 174.9532, val: 186.6638
# Current sigma2: 0.0100000
# Already trained for 1.5906481822331746 min; Remaining 2.5952680868014957 min.
# Saving model...
# Model saved.
# 19/49, test loss: -elbo: 174.7868, recons_loss_weighted: 265.9615, recons_loss_ls: 5.3192, KL_loss: 21.6698, sigma_regularisor: -55.2620, code_std_dev: [0.17404291 0.07317521 0.11006315 0.18050508 0.19876263 0.10191597]
# Loss on training and val sets:
# train: 167.4173, val: 174.7325
# Current sigma2: 0.0100000
# Already trained for 1.6724018772443137 min; Remaining 2.50860281586647 min.
# Saving model...
# Model saved.
# 20/49, test loss: -elbo: 174.9833, recons_loss_weighted: 267.2256, recons_loss_ls: 5.3445, KL_loss: 21.2343, sigma_regularisor: -55.2620, code_std_dev: [0.15243356 0.07929093 0.15757316 0.17046045 0.20131055 0.11737657]
# Loss on training and val sets:
# train: 162.2349, val: 203.9739
# Current sigma2: 0.0100000
# Already trained for 1.7543623050053914 min; Remaining 2.4226908021503024 min.
# Saving model...
# Model saved.
# 21/49, test loss: -elbo: 176.7875, recons_loss_weighted: 271.4735, recons_loss_ls: 5.4295, KL_loss: 20.9146, sigma_regularisor: -55.2620, code_std_dev: [0.18136258 0.09050999 0.14186275 0.19786145 0.19464628 0.13457572]
# Loss on training and val sets:
# train: 157.4612, val: 180.2745
# Current sigma2: 0.0100000
# Already trained for 1.8383309761683146 min; Remaining 2.339693969668764 min.
# Saving model...
# Model saved.
# 22/49, test loss: -elbo: 170.6324, recons_loss_weighted: 258.4410, recons_loss_ls: 5.1688, KL_loss: 21.2757, sigma_regularisor: -55.2620, code_std_dev: [0.14543703 0.07767557 0.13108148 0.19292031 0.20546772 0.14624465]
# Loss on training and val sets:
# train: 152.7808, val: 183.0444
# Current sigma2: 0.0100000
# Already trained for 1.928901163736979 min; Remaining 2.2643622356912365 min.
# Saving model...
# Model saved.
# 23/49, test loss: -elbo: 162.0144, recons_loss_weighted: 240.8684, recons_loss_ls: 4.8174, KL_loss: 21.4440, sigma_regularisor: -55.2620, code_std_dev: [0.15966968 0.09016621 0.08861466 0.18276337 0.21309191 0.11380377]
# Loss on training and val sets:
# train: 149.7068, val: 144.5955
# Current sigma2: 0.0100000
# Already trained for 2.016221304734548 min; Remaining 2.18423974679576 min.
# Saving model...
# Model saved.
# 24/49, test loss: -elbo: 164.1941, recons_loss_weighted: 246.2612, recons_loss_ls: 4.9252, KL_loss: 20.9274, sigma_regularisor: -55.2620, code_std_dev: [0.17208952 0.10848606 0.10701783 0.19941708 0.21986492 0.1187127 ]
# Loss on training and val sets:
# train: 146.7979, val: 191.0281
# Current sigma2: 0.0100000
# Already trained for 2.095545462767283 min; Remaining 2.095545462767283 min.
# Saving model...
# Model saved.
# 25/49, test loss: -elbo: 173.8362, recons_loss_weighted: 264.0322, recons_loss_ls: 5.2806, KL_loss: 21.6840, sigma_regularisor: -55.2620, code_std_dev: [0.13517337 0.11012966 0.16083077 0.12225151 0.19775006 0.1169151 ]
# Loss on training and val sets:
# train: 142.3462, val: 196.7833
# Current sigma2: 0.0100000
# Already trained for 2.1819809039433795 min; Remaining 2.014136219024658 min.
# Saving model...
# Model saved.
# 26/49, test loss: -elbo: 160.9594, recons_loss_weighted: 240.5297, recons_loss_ls: 4.8106, KL_loss: 20.5584, sigma_regularisor: -55.2620, code_std_dev: [0.20028189 0.11603151 0.166295   0.14589089 0.20173019 0.13219208]
# Loss on training and val sets:
# train: 138.6423, val: 152.3584
# Current sigma2: 0.0100000
# Already trained for 2.265252149105072 min; Remaining 1.9296592381265427 min.
# Saving model...
# Model saved.
# 27/49, test loss: -elbo: 160.7149, recons_loss_weighted: 240.4323, recons_loss_ls: 4.8086, KL_loss: 20.3626, sigma_regularisor: -55.2620, code_std_dev: [0.21462512 0.10089283 0.20822431 0.16123283 0.16041297 0.15651464]
# Loss on training and val sets:
# train: 135.0558, val: 155.1088
# Current sigma2: 0.0100000
# Already trained for 2.3495033343633014 min; Remaining 1.846038334142594 min.
# Saving model...
# Model saved.
# 28/49, test loss: -elbo: 171.0296, recons_loss_weighted: 259.4332, recons_loss_ls: 5.1887, KL_loss: 21.1769, sigma_regularisor: -55.2620, code_std_dev: [0.1615531  0.10654891 0.15185332 0.1286341  0.18836395 0.12279598]
# Loss on training and val sets:
# train: 132.6839, val: 158.8397
# Current sigma2: 0.0100000
# Already trained for 2.4325511932373045 min; Remaining 1.761502588206324 min.
# Saving model...
# Model saved.
# 29/49, test loss: -elbo: 160.1970, recons_loss_weighted: 238.0683, recons_loss_ls: 4.7614, KL_loss: 21.0266, sigma_regularisor: -55.2620, code_std_dev: [0.18099035 0.09883273 0.1678811  0.14981519 0.20982723 0.12134589]
# Loss on training and val sets:
# train: 131.4865, val: 161.3974
# Current sigma2: 0.0100000
# Already trained for 2.511982826391856 min; Remaining 1.6746552175945706 min.
# Saving model...
# Model saved.
# 30/49, test loss: -elbo: 162.6055, recons_loss_weighted: 244.2710, recons_loss_ls: 4.8854, KL_loss: 20.3338, sigma_regularisor: -55.2620, code_std_dev: [0.2091375  0.14742413 0.18894184 0.1433812  0.25810054 0.16562134]
# Loss on training and val sets:
# train: 127.2676, val: 179.2580
# Current sigma2: 0.0100000
# Already trained for 2.5940700451533 min; Remaining 1.5899138986423451 min.
# Saving model...
# Model saved.
# 31/49, test loss: -elbo: 157.7282, recons_loss_weighted: 232.4357, recons_loss_ls: 4.6487, KL_loss: 21.3742, sigma_regularisor: -55.2620, code_std_dev: [0.18127888 0.10902413 0.16491677 0.13059185 0.23005489 0.10310924]
# Loss on training and val sets:
# train: 126.5854, val: 133.1684
# Current sigma2: 0.0100000
# Already trained for 2.676596701145172 min; Remaining 1.5055856443941593 min.
# Saving model...
# Model saved.
# 32/49, test loss: -elbo: 158.9238, recons_loss_weighted: 235.4816, recons_loss_ls: 4.7096, KL_loss: 21.0468, sigma_regularisor: -55.2620, code_std_dev: [0.21593682 0.10921206 0.12308079 0.20529288 0.22645198 0.14143586]
# Loss on training and val sets:
# train: 123.7349, val: 154.5399
# Current sigma2: 0.0100000
# Already trained for 2.757834768295288 min; Remaining 1.4207027594248454 min.
# Saving model...
# Model saved.
# 33/49, test loss: -elbo: 165.8815, recons_loss_weighted: 248.8543, recons_loss_ls: 4.9771, KL_loss: 21.3181, sigma_regularisor: -55.2620, code_std_dev: [0.17010315 0.08106511 0.13144258 0.1879336  0.23951367 0.11437105]
# Loss on training and val sets:
# train: 121.7208, val: 156.8680
# Current sigma2: 0.0100000
# Already trained for 2.8391314427057903 min; Remaining 1.33606185539096 min.
# Saving model...
# Model saved.
# 34/49, test loss: -elbo: 160.7211, recons_loss_weighted: 239.4873, recons_loss_ls: 4.7897, KL_loss: 20.8413, sigma_regularisor: -55.2620, code_std_dev: [0.18348634 0.10147065 0.1545852  0.14499778 0.2699606  0.14112045]
# Loss on training and val sets:
# train: 120.4794, val: 170.5065
# Current sigma2: 0.0100000
# Already trained for 2.918751148382823 min; Remaining 1.250893349306924 min.
# Saving model...
# Model saved.
# 35/49, test loss: -elbo: 157.3061, recons_loss_weighted: 232.5646, recons_loss_ls: 4.6513, KL_loss: 20.8876, sigma_regularisor: -55.2620, code_std_dev: [0.17778672 0.10070748 0.1381328  0.18723898 0.24514392 0.12116025]
# Loss on training and val sets:
# train: 117.6922, val: 159.2934
# Current sigma2: 0.0100000
# Already trained for 3.00108345746994 min; Remaining 1.1670880112383102 min.
# Saving model...
# Model saved.
# 36/49, test loss: -elbo: 161.3035, recons_loss_weighted: 240.9107, recons_loss_ls: 4.8182, KL_loss: 20.7120, sigma_regularisor: -55.2620, code_std_dev: [0.19015984 0.12319081 0.13602954 0.18254264 0.25082004 0.15209569]
# Loss on training and val sets:
# train: 114.8424, val: 165.3553
# Current sigma2: 0.0100000
# Already trained for 3.084042982260386 min; Remaining 1.0835826694428383 min.
# Saving model...
# Model saved.
# 37/49, test loss: -elbo: 156.0596, recons_loss_weighted: 230.2924, recons_loss_ls: 4.6058, KL_loss: 20.7772, sigma_regularisor: -55.2620, code_std_dev: [0.19886678 0.08180983 0.11590935 0.23411971 0.31329605 0.15700075]
# Loss on training and val sets:
# train: 114.3850, val: 142.3546
# Current sigma2: 0.0100000
# Already trained for 3.165979071458181 min; Remaining 0.9997828646710044 min.
# Saving model...
# Model saved.
# 38/49, test loss: -elbo: 157.0529, recons_loss_weighted: 232.3567, recons_loss_ls: 4.6471, KL_loss: 20.7383, sigma_regularisor: -55.2620, code_std_dev: [0.18074426 0.11797693 0.13253336 0.19126353 0.24053615 0.13831764]
# Loss on training and val sets:
# train: 111.4955, val: 171.0158
# Current sigma2: 0.0100000
# Already trained for 3.252623903751373 min; Remaining 0.9174067420837206 min.
# Saving model...
# Model saved.
# 39/49, test loss: -elbo: 154.4993, recons_loss_weighted: 226.2975, recons_loss_ls: 4.5260, KL_loss: 21.2144, sigma_regularisor: -55.2620, code_std_dev: [0.16828714 0.09214525 0.14261316 0.16679294 0.2513682  0.11105967]
# Loss on training and val sets:
# train: 110.3406, val: 152.1855
# Current sigma2: 0.0100000
# Already trained for 3.333617349465688 min; Remaining 0.833404337366422 min.
# Saving model...
# Model saved.
# 40/49, test loss: -elbo: 155.3555, recons_loss_weighted: 229.2691, recons_loss_ls: 4.5854, KL_loss: 20.5848, sigma_regularisor: -55.2620, code_std_dev: [0.18053485 0.11027906 0.13184915 0.19736466 0.2569794  0.11536106]
# Loss on training and val sets:
# train: 107.9867, val: 160.2037
# Current sigma2: 0.0100000
# Already trained for 3.416504442691803 min; Remaining 0.7499643898591764 min.
# Saving model...
# Model saved.
# 41/49, test loss: -elbo: 150.7065, recons_loss_weighted: 218.7872, recons_loss_ls: 4.3757, KL_loss: 21.1767, sigma_regularisor: -55.2620, code_std_dev: [0.1861152  0.08365734 0.15364847 0.14855018 0.24108306 0.09676105]
# Loss on training and val sets:
# train: 107.9143, val: 153.1803
# Current sigma2: 0.0100000
# Already trained for 3.498529787858327 min; Remaining 0.666386626258729 min.
# Saving model...
# Model saved.
# 42/49, test loss: -elbo: 158.6288, recons_loss_weighted: 234.9662, recons_loss_ls: 4.6993, KL_loss: 21.0095, sigma_regularisor: -55.2620, code_std_dev: [0.16900045 0.12278026 0.12339702 0.1504734  0.2342566  0.13466018]
# Loss on training and val sets:
# train: 106.4506, val: 182.6852
# Current sigma2: 0.0100000
# Already trained for 3.5811827460924786 min; Remaining 0.5829832377359848 min.
# Saving model...
# Model saved.
# 43/49, test loss: -elbo: 153.7189, recons_loss_weighted: 226.0986, recons_loss_ls: 4.5220, KL_loss: 20.5334, sigma_regularisor: -55.2620, code_std_dev: [0.20275639 0.12499349 0.16070129 0.14265122 0.26000693 0.12233963]
# Loss on training and val sets:
# train: 105.2783, val: 132.8634
# Current sigma2: 0.0100000
# Already trained for 3.6659462809562684 min; Remaining 0.4999017655849457 min.
# Saving model...
# Model saved.
# 44/49, test loss: -elbo: 155.6264, recons_loss_weighted: 229.8019, recons_loss_ls: 4.5960, KL_loss: 20.5892, sigma_regularisor: -55.2620, code_std_dev: [0.21284805 0.0908023  0.17422423 0.14054647 0.25707322 0.13628544]
# Loss on training and val sets:
# train: 102.8787, val: 168.3973
# Current sigma2: 0.0100000
# Already trained for 3.745505400498708 min; Remaining 0.4161672667220787 min.
# Saving model...
# Model saved.
# 45/49, test loss: -elbo: 154.5402, recons_loss_weighted: 227.8225, recons_loss_ls: 4.5565, KL_loss: 20.4928, sigma_regularisor: -55.2620, code_std_dev: [0.19438723 0.10223492 0.1283356  0.19511312 0.23408958 0.16597399]
# Loss on training and val sets:
# train: 100.6091, val: 140.0918
# Current sigma2: 0.0100000
# Already trained for 3.8250277201334635 min; Remaining 0.33261110609856204 min.
# Saving model...
# Model saved.
# 46/49, test loss: -elbo: 151.3961, recons_loss_weighted: 222.2247, recons_loss_ls: 4.4445, KL_loss: 20.1476, sigma_regularisor: -55.2620, code_std_dev: [0.200625   0.09997494 0.14927717 0.18328388 0.2439852  0.13073565]
# Loss on training and val sets:
# train: 100.8502, val: 120.5385
# Current sigma2: 0.0100000
# Already trained for 3.9074378927548725 min; Remaining 0.2494109293247791 min.
# Saving model...
# Model saved.
# 47/49, test loss: -elbo: 153.7216, recons_loss_weighted: 225.9455, recons_loss_ls: 4.5189, KL_loss: 20.6126, sigma_regularisor: -55.2620, code_std_dev: [0.19887546 0.09920759 0.15643817 0.15007041 0.22179988 0.10824157]
# Loss on training and val sets:
# train: 100.9494, val: 129.9098
# Current sigma2: 0.0100000
# Already trained for 3.9894271969795225 min; Remaining 0.16622613320748011 min.
# Saving model...
# Model saved.
# 48/49, test loss: -elbo: 151.4267, recons_loss_weighted: 221.2135, recons_loss_ls: 4.4243, KL_loss: 20.6838, sigma_regularisor: -55.2620, code_std_dev: [0.1898669  0.08917221 0.13400249 0.18604183 0.26291782 0.12155752]
# Loss on training and val sets:
# train: 98.1590, val: 186.9083
# Current sigma2: 0.0100000
# Already trained for 4.077091022332509 min; Remaining 0.0832059392312757 min.
# Saving model...
# Model saved.
# 49/49, test loss: -elbo: 151.6632, recons_loss_weighted: 220.7334, recons_loss_ls: 4.4147, KL_loss: 21.1603, sigma_regularisor: -55.2620, code_std_dev: [0.18799356 0.07637746 0.13610083 0.16374147 0.21167797 0.11540032]
# Loss on training and val sets:
# train: 97.0493, val: 170.5506
# Current sigma2: 0.0100000
# Already trained for 4.157031504313151 min; Remaining 0.0 min.

# %%
# load LSTM model
lstm_model = lstmKerasModel(data)
lstm_model.produce_embeddings(config, model_vae, data, sess)
lstm_nn_model = lstm_model.create_lstm_model(config)
lstm_nn_model.summary()   # Display the model's architecture

# checkpoint path
checkpoint_path = config['checkpoint_dir_lstm'] + "cp.ckpt"
checkpoint_dir = os.path.dirname(checkpoint_path)
# Create a callback that saves the model's weights
cp_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path,
                                                 save_weights_only=True,
                                                 verbose=1)
# load weights if possible
lstm_model.load_model(lstm_nn_model, config, checkpoint_path)
# start training
if config['TRAIN_LSTM']:
    if config['num_epochs_lstm'] > 0:
        lstm_model.train(config, lstm_nn_model, cp_callback)

    # make a prediction on the test set using the trained model
    lstm_embedding = lstm_nn_model.predict(lstm_model.x_test, batch_size=config['batch_size_lstm'])
    print(lstm_embedding.shape)

    # visualise the first 10 test sequences
    for i in range(10):
        lstm_model.plot_lstm_embedding_prediction(i, config, model_vae, sess, data, lstm_embedding)
# Out:
# g model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-1-channels-trim-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 408us/sample - loss: 2.3053 - mean_squared_error: 2.3053 - val_loss: 2.0452 - val_mean_squared_error: 2.0452
# Epoch 56/100
# 608/746 [=======================>......] - ETA: 0s - loss: 2.2968 - mean_squared_error: 2.2968
# Epoch 00056: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-1-channels-trim-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 419us/sample - loss: 2.2982 - mean_squared_error: 2.2982 - val_loss: 2.0343 - val_mean_squared_error: 2.0343
# Epoch 57/100
# 640/746 [========================>.....] - ETA: 0s - loss: 2.2966 - mean_squared_error: 2.2966
# Epoch 00057: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-1-channels-trim-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 391us/sample - loss: 2.2909 - mean_squared_error: 2.2909 - val_loss: 2.0294 - val_mean_squared_error: 2.0294
# Epoch 58/100
# 640/746 [========================>.....] - ETA: 0s - loss: 2.2629 - mean_squared_error: 2.2629
# Epoch 00058: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-1-channels-trim-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 489us/sample - loss: 2.2854 - mean_squared_error: 2.2854 - val_loss: 2.0217 - val_mean_squared_error: 2.0217
# Epoch 59/100
# 736/746 [============================>.] - ETA: 0s - loss: 2.2446 - mean_squared_error: 2.2446
# Epoch 00059: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-1-channels-trim-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 361us/sample - loss: 2.2789 - mean_squared_error: 2.2789 - val_loss: 2.0170 - val_mean_squared_error: 2.0170
# Epoch 60/100
# 736/746 [============================>.] - ETA: 0s - loss: 2.2692 - mean_squared_error: 2.2692
# Epoch 00060: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-1-channels-trim-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 431us/sample - loss: 2.2725 - mean_squared_error: 2.2725 - val_loss: 2.0119 - val_mean_squared_error: 2.0119
# Epoch 61/100
# 704/746 [===========================>..] - ETA: 0s - loss: 2.2498 - mean_squared_error: 2.2498
# Epoch 00061: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-1-channels-trim-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 350us/sample - loss: 2.2662 - mean_squared_error: 2.2662 - val_loss: 2.0022 - val_mean_squared_error: 2.0022
# Epoch 62/100
# 640/746 [========================>.....] - ETA: 0s - loss: 2.2221 - mean_squared_error: 2.2221
# Epoch 00062: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-1-channels-trim-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 419us/sample - loss: 2.2591 - mean_squared_error: 2.2591 - val_loss: 1.9887 - val_mean_squared_error: 1.9887
# Epoch 63/100
# 736/746 [============================>.] - ETA: 0s - loss: 2.2658 - mean_squared_error: 2.2658
# Epoch 00063: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-1-channels-trim-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 448us/sample - loss: 2.2541 - mean_squared_error: 2.2541 - val_loss: 1.9835 - val_mean_squared_error: 1.9835
# Epoch 64/100
# 736/746 [============================>.] - ETA: 0s - loss: 2.2403 - mean_squared_error: 2.2403
# Epoch 00064: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-1-channels-trim-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 478us/sample - loss: 2.2491 - mean_squared_error: 2.2491 - val_loss: 1.9879 - val_mean_squared_error: 1.9879
# Epoch 65/100
# 704/746 [===========================>..] - ETA: 0s - loss: 2.2206 - mean_squared_error: 2.2206
# Epoch 00065: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-1-channels-trim-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 365us/sample - loss: 2.2438 - mean_squared_error: 2.2438 - val_loss: 1.9760 - val_mean_squared_error: 1.9760
# Epoch 66/100
# 704/746 [===========================>..] - ETA: 0s - loss: 2.2606 - mean_squared_error: 2.2606
# Epoch 00066: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-1-channels-trim-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 436us/sample - loss: 2.2382 - mean_squared_error: 2.2382 - val_loss: 1.9702 - val_mean_squared_error: 1.9702
# Epoch 67/100
# 640/746 [========================>.....] - ETA: 0s - loss: 2.2445 - mean_squared_error: 2.2445
# Epoch 00067: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-1-channels-trim-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 414us/sample - loss: 2.2329 - mean_squared_error: 2.2329 - val_loss: 1.9692 - val_mean_squared_error: 1.9692
# Epoch 68/100
# 640/746 [========================>.....] - ETA: 0s - loss: 2.2883 - mean_squared_error: 2.2883
# Epoch 00068: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-1-channels-trim-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 392us/sample - loss: 2.2273 - mean_squared_error: 2.2273 - val_loss: 1.9612 - val_mean_squared_error: 1.9612
# Epoch 69/100
# 608/746 [=======================>......] - ETA: 0s - loss: 2.2404 - mean_squared_error: 2.2404
# Epoch 00069: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-1-channels-trim-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 414us/sample - loss: 2.2224 - mean_squared_error: 2.2224 - val_loss: 1.9579 - val_mean_squared_error: 1.9579
# Epoch 70/100
# 736/746 [============================>.] - ETA: 0s - loss: 2.2057 - mean_squared_error: 2.2057
# Epoch 00070: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-1-channels-trim-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 439us/sample - loss: 2.2169 - mean_squared_error: 2.2169 - val_loss: 1.9533 - val_mean_squared_error: 1.9533
# Epoch 71/100
# 640/746 [========================>.....] - ETA: 0s - loss: 2.1713 - mean_squared_error: 2.1713
# Epoch 00071: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-1-channels-trim-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 376us/sample - loss: 2.2130 - mean_squared_error: 2.2130 - val_loss: 1.9488 - val_mean_squared_error: 1.9488
# Epoch 72/100
# 640/746 [========================>.....] - ETA: 0s - loss: 2.2075 - mean_squared_error: 2.2075
# Epoch 00072: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-1-channels-trim-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 317us/sample - loss: 2.2071 - mean_squared_error: 2.2071 - val_loss: 1.9436 - val_mean_squared_error: 1.9436
# Epoch 73/100
# 704/746 [===========================>..] - ETA: 0s - loss: 2.2195 - mean_squared_error: 2.2195
# Epoch 00073: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-1-channels-trim-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 380us/sample - loss: 2.2041 - mean_squared_error: 2.2041 - val_loss: 1.9409 - val_mean_squared_error: 1.9409
# Epoch 74/100
# 736/746 [============================>.] - ETA: 0s - loss: 2.1979 - mean_squared_error: 2.1979
# Epoch 00074: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-1-channels-trim-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 349us/sample - loss: 2.1989 - mean_squared_error: 2.1989 - val_loss: 1.9337 - val_mean_squared_error: 1.9337
# Epoch 75/100
# 640/746 [========================>.....] - ETA: 0s - loss: 2.1652 - mean_squared_error: 2.1652
# Epoch 00075: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-1-channels-trim-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 405us/sample - loss: 2.1936 - mean_squared_error: 2.1936 - val_loss: 1.9316 - val_mean_squared_error: 1.9316
# Epoch 76/100
# 736/746 [============================>.] - ETA: 0s - loss: 2.1911 - mean_squared_error: 2.1911
# Epoch 00076: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-1-channels-trim-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 407us/sample - loss: 2.1888 - mean_squared_error: 2.1888 - val_loss: 1.9280 - val_mean_squared_error: 1.9280
# Epoch 77/100
# 704/746 [===========================>..] - ETA: 0s - loss: 2.1933 - mean_squared_error: 2.1933
# Epoch 00077: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-1-channels-trim-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 391us/sample - loss: 2.1840 - mean_squared_error: 2.1840 - val_loss: 1.9224 - val_mean_squared_error: 1.9224
# Epoch 78/100
# 640/746 [========================>.....] - ETA: 0s - loss: 2.1020 - mean_squared_error: 2.1020
# Epoch 00078: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-1-channels-trim-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 376us/sample - loss: 2.1795 - mean_squared_error: 2.1795 - val_loss: 1.9187 - val_mean_squared_error: 1.9187
# Epoch 79/100
# 672/746 [==========================>...] - ETA: 0s - loss: 2.2155 - mean_squared_error: 2.2155
# Epoch 00079: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-1-channels-trim-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 465us/sample - loss: 2.1755 - mean_squared_error: 2.1755 - val_loss: 1.9138 - val_mean_squared_error: 1.9138
# Epoch 80/100
# 672/746 [==========================>...] - ETA: 0s - loss: 2.1852 - mean_squared_error: 2.1852
# Epoch 00080: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-1-channels-trim-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 398us/sample - loss: 2.1714 - mean_squared_error: 2.1714 - val_loss: 1.9108 - val_mean_squared_error: 1.9108
# Epoch 81/100
# 736/746 [============================>.] - ETA: 0s - loss: 2.1521 - mean_squared_error: 2.1521
# Epoch 00081: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-1-channels-trim-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 448us/sample - loss: 2.1666 - mean_squared_error: 2.1666 - val_loss: 1.9080 - val_mean_squared_error: 1.9080
# Epoch 82/100
# 704/746 [===========================>..] - ETA: 0s - loss: 2.1136 - mean_squared_error: 2.1136
# Epoch 00082: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-1-channels-trim-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 482us/sample - loss: 2.1627 - mean_squared_error: 2.1627 - val_loss: 1.9039 - val_mean_squared_error: 1.9039
# Epoch 83/100
# 704/746 [===========================>..] - ETA: 0s - loss: 2.1604 - mean_squared_error: 2.1604
# Epoch 00083: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-1-channels-trim-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 426us/sample - loss: 2.1583 - mean_squared_error: 2.1583 - val_loss: 1.8995 - val_mean_squared_error: 1.8995
# Epoch 84/100
# 704/746 [===========================>..] - ETA: 0s - loss: 2.1646 - mean_squared_error: 2.1646
# Epoch 00084: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-1-channels-trim-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 368us/sample - loss: 2.1533 - mean_squared_error: 2.1533 - val_loss: 1.8964 - val_mean_squared_error: 1.8964
# Epoch 85/100
# 640/746 [========================>.....] - ETA: 0s - loss: 2.1150 - mean_squared_error: 2.1150
# Epoch 00085: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-1-channels-trim-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 476us/sample - loss: 2.1497 - mean_squared_error: 2.1497 - val_loss: 1.8899 - val_mean_squared_error: 1.8899
# Epoch 86/100
# 704/746 [===========================>..] - ETA: 0s - loss: 2.1523 - mean_squared_error: 2.1523
# Epoch 00086: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-1-channels-trim-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 362us/sample - loss: 2.1456 - mean_squared_error: 2.1456 - val_loss: 1.8882 - val_mean_squared_error: 1.8882
# Epoch 87/100
# 736/746 [============================>.] - ETA: 0s - loss: 2.1390 - mean_squared_error: 2.1390
# Epoch 00087: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-1-channels-trim-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 403us/sample - loss: 2.1396 - mean_squared_error: 2.1396 - val_loss: 1.8837 - val_mean_squared_error: 1.8837
# Epoch 88/100
# 640/746 [========================>.....] - ETA: 0s - loss: 2.1573 - mean_squared_error: 2.1573
# Epoch 00088: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-1-channels-trim-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 492us/sample - loss: 2.1355 - mean_squared_error: 2.1355 - val_loss: 1.8835 - val_mean_squared_error: 1.8835
# Epoch 89/100
# 704/746 [===========================>..] - ETA: 0s - loss: 2.1470 - mean_squared_error: 2.1470
# Epoch 00089: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-1-channels-trim-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 369us/sample - loss: 2.1319 - mean_squared_error: 2.1319 - val_loss: 1.8758 - val_mean_squared_error: 1.8758
# Epoch 90/100
# 608/746 [=======================>......] - ETA: 0s - loss: 2.0985 - mean_squared_error: 2.0985
# Epoch 00090: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-1-channels-trim-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 421us/sample - loss: 2.1268 - mean_squared_error: 2.1268 - val_loss: 1.8712 - val_mean_squared_error: 1.8712
# Epoch 91/100
# 736/746 [============================>.] - ETA: 0s - loss: 2.1262 - mean_squared_error: 2.1262
# Epoch 00091: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-1-channels-trim-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 462us/sample - loss: 2.1223 - mean_squared_error: 2.1223 - val_loss: 1.8692 - val_mean_squared_error: 1.8692
# Epoch 92/100
# 608/746 [=======================>......] - ETA: 0s - loss: 2.1448 - mean_squared_error: 2.1448
# Epoch 00092: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-1-channels-trim-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 414us/sample - loss: 2.1188 - mean_squared_error: 2.1188 - val_loss: 1.8649 - val_mean_squared_error: 1.8649
# Epoch 93/100
# 640/746 [========================>.....] - ETA: 0s - loss: 2.1401 - mean_squared_error: 2.1401
# Epoch 00093: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-1-channels-trim-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 376us/sample - loss: 2.1139 - mean_squared_error: 2.1139 - val_loss: 1.8622 - val_mean_squared_error: 1.8622
# Epoch 94/100
# 704/746 [===========================>..] - ETA: 0s - loss: 2.1085 - mean_squared_error: 2.1085
# Epoch 00094: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-1-channels-trim-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 470us/sample - loss: 2.1103 - mean_squared_error: 2.1103 - val_loss: 1.8579 - val_mean_squared_error: 1.8579
# Epoch 95/100
# 704/746 [===========================>..] - ETA: 0s - loss: 2.0940 - mean_squared_error: 2.0940
# Epoch 00095: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-1-channels-trim-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 452us/sample - loss: 2.1053 - mean_squared_error: 2.1053 - val_loss: 1.8524 - val_mean_squared_error: 1.8524
# Epoch 96/100
# 704/746 [===========================>..] - ETA: 0s - loss: 2.1053 - mean_squared_error: 2.1053
# Epoch 00096: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-1-channels-trim-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 474us/sample - loss: 2.1015 - mean_squared_error: 2.1015 - val_loss: 1.8480 - val_mean_squared_error: 1.8480
# Epoch 97/100
# 672/746 [==========================>...] - ETA: 0s - loss: 2.0683 - mean_squared_error: 2.0683
# Epoch 00097: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-1-channels-trim-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 564us/sample - loss: 2.0972 - mean_squared_error: 2.0972 - val_loss: 1.8432 - val_mean_squared_error: 1.8432
# Epoch 98/100
# 704/746 [===========================>..] - ETA: 0s - loss: 2.1156 - mean_squared_error: 2.1156
# Epoch 00098: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-1-channels-trim-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 470us/sample - loss: 2.0942 - mean_squared_error: 2.0942 - val_loss: 1.8426 - val_mean_squared_error: 1.8426
# Epoch 99/100
# 672/746 [==========================>...] - ETA: 0s - loss: 2.0807 - mean_squared_error: 2.0807
# Epoch 00099: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-1-channels-trim-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 405us/sample - loss: 2.0898 - mean_squared_error: 2.0898 - val_loss: 1.8394 - val_mean_squared_error: 1.8394
# Epoch 100/100
# 672/746 [==========================>...] - ETA: 0s - loss: 2.1323 - mean_squared_error: 2.1323
# Epoch 00100: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-1-channels-trim-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 472us/sample - loss: 2.0848 - mean_squared_error: 2.0848 - val_loss: 1.8342 - val_mean_squared_error: 1.8342
# (83, 2, 6)
# Decoded seq from VAE: (3, 24)
# Decoded seq from lstm: (2, 24)
# Decoded seq from VAE: (3, 24)
# Decoded seq from lstm: (2, 24)
# Decoded seq from VAE: (3, 24)
# Decoded seq from lstm: (2, 24)
# Decoded seq from VAE: (3, 24)
# Decoded seq from lstm: (2, 24)
# Decoded seq from VAE: (3, 24)
# Decoded seq from lstm: (2, 24)
# Decoded seq from VAE: (3, 24)
# Decoded seq from lstm: (2, 24)
# Decoded seq from VAE: (3, 24)
# Decoded seq from lstm: (2, 24)
# Decoded seq from VAE: (3, 24)
# Decoded seq from lstm: (2, 24)
# Decoded seq from VAE: (3, 24)
# Decoded seq from lstm: (2, 24)
# Decoded seq from VAE: (3, 24)
# Decoded seq from lstm: (2, 24)

# %%
# load normalised time series
save_dir = '../datasets/' + config['data_dir'] #NAB-known-anomaly/'
dataset = config['dataset']
file_name = config['filename']
filename = '{}.npz'.format(file_name)
result = dict(np.load(save_dir+filename, allow_pickle=True))
if dataset == 'machine_temp':
    result['test'] = result['test'][0]
    result['idx_anomaly_test'] = result['idx_anomaly_test'][0]
    result['t_test'] = result['t_test'][0]

# slice into rolling windows and rolling sequences
def slice_rolling_windows_and_sequences(config, time_seq):
    n_sample = len(time_seq)
    print("The given sequence has {} samples".format(n_sample))
    n_vae_win = n_sample - config['l_win'] + 1
    if config['n_channel'] == 1:
        rolling_windows = np.zeros((n_vae_win, config['l_win']))
    else:
        rolling_windows = np.zeros((n_vae_win, config['l_win'], config['n_channel']), dtype=float)
    for i in range(n_vae_win):
        rolling_windows[i] = time_seq[i:i + config['l_win']]
        sample_m = np.mean(rolling_windows, axis=1)
        sample_std = np.std(rolling_windows, axis=1)

        n_lstm_seq = n_sample - config['l_seq']*config['l_win']+1
        if config['n_channel'] == 1:
            lstm_seq = np.zeros((n_lstm_seq, config['l_seq'], config['l_win']))
        else:
            lstm_seq = np.zeros((n_lstm_seq, config['l_seq'], config['l_win'], config['n_channel']), dtype=float)
    for i in range(n_lstm_seq):
        cur_seq = time_seq[i:i+config['l_seq']*config['l_win']]
        for j in range(config['l_seq']):
            lstm_seq[i,j] = cur_seq[config['l_win']*j:config['l_win']*(j+1)]
    
    return rolling_windows, lstm_seq, sample_m, sample_std

test_windows, test_seq, test_sample_m, test_sample_std = slice_rolling_windows_and_sequences(config, result['test'])
if config['n_channel'] == 1:
    test_windows = np.expand_dims(test_windows, -1)
    test_seq = np.expand_dims(test_seq, -1)
else:
    test_windows = test_windows
    test_seq = test_seq
print(test_windows.shape)
print(test_seq.shape)
# Out:
#   File "<ipython-input-8-706256537108>", line 29
#     else:
#        ^
# SyntaxError: invalid syntax

# %%
# Evaluate ELBO and LSTM prediction error on the validation set
# evaluate some anomaly detection metrics
def evaluate_vae_anomaly_metrics_for_a_window(test_win):
    feed_dict = {model_vae.original_signal: np.expand_dims(test_win, 0),
                 model_vae.is_code_input: False,
                 model_vae.code_input: np.zeros((1, config['code_size']))}

    # VAE reconstruction error
    recons_win_vae = np.squeeze(sess.run(model_vae.decoded, feed_dict=feed_dict))
    test_vae_recons_error = np.sum(np.square(recons_win_vae - test_win))

    # VAE latent embedding likelihood
    vae_code_mean, vae_code_std = sess.run([model_vae.code_mean, model_vae.code_std_dev], feed_dict=feed_dict)
    test_vae_kl = 0.5 * (np.sum(np.square(vae_code_mean)) + \
                            np.sum(np.square(vae_code_std)) - \
                            np.sum(np.log(np.square(vae_code_std))) - config['code_size'])

    # VAE ELBO loss
    sigma2 = 0.0005
    input_dims = model_vae.input_dims
    sigma_regularisor = input_dims/2. * np.log(sigma2) + input_dims * np.pi
    test_vae_elbo = test_vae_recons_error/sigma2 + test_vae_kl + sigma_regularisor
    return test_vae_recons_error, test_vae_kl, test_vae_elbo

def evaluate_lstm_anomaly_metric_for_a_seq(test_seq):
    feed_dict = {model_vae.original_signal: test_seq,
                 model_vae.is_code_input: False,
                 model_vae.code_input: np.zeros((1, config['code_size']))}
    vae_embedding = np.squeeze(sess.run(model_vae.code_mean, feed_dict=feed_dict))
    #print(vae_embedding.shape)
    lstm_embedding = np.squeeze(lstm_nn_model.predict(np.expand_dims(vae_embedding[:config['l_seq']-1], 0), batch_size=1))
    lstm_embedding_error = np.sum(np.square(vae_embedding[1:] - lstm_embedding))
    
    # LSTM prediction error
    feed_dict_lstm = {model_vae.original_signal: np.zeros((config['l_seq'] - 1, config['l_win'], test_seq.shape[2])),
                      model_vae.is_code_input: True,
                      model_vae.code_input: lstm_embedding}
    recons_win_lstm = np.squeeze(sess.run(model_vae.decoded, feed_dict=feed_dict_lstm))
    lstm_recons_error = np.sum(np.square(recons_win_lstm - np.squeeze(test_seq[1:])))
    return lstm_recons_error, lstm_embedding_error

n_val_vae = data.val_set_vae['data'].shape[0]
n_val_lstm = data.val_set_lstm['data'].shape[0]

val_vae_recons_error = np.zeros(n_val_vae)
val_vae_kl_error = np.zeros(n_val_vae)
val_vae_elbo_loss = np.zeros(n_val_vae)
for i in range(n_val_vae):
    val_vae_recons_error[i], val_vae_kl_error[i], val_vae_elbo_loss[i] = evaluate_vae_anomaly_metrics_for_a_window(data.val_set_vae['data'][i])

val_lstm_recons_error, val_lstm_embedding_error = np.zeros(n_val_lstm), np.zeros(n_val_lstm)
for i in range(n_val_lstm):
    val_lstm_recons_error[i], val_lstm_embedding_error[i] = evaluate_lstm_anomaly_metric_for_a_seq(data.val_set_lstm['data'][i])

# %%
from scipy.stats import norm
def plot_histogram(test_anomaly_metric, n_bins, title, mean=None, std=None, xlim=None, saveplot=False):
    test_anomaly_list = np.squeeze(np.ndarray.flatten(test_anomaly_metric))
    his = plt.hist(test_anomaly_list, bins=n_bins, density=True)
    if mean is None and std is None:
        mean = np.mean(test_anomaly_list)
        std = np.std(test_anomaly_list)
        legend_label = None
    else:
        legend_label = 1
    x_axis = np.arange(mean-5*std, mean+5*std, std/100)
    plt.plot(x_axis, norm.pdf(x_axis,mean,std))
    plt.title(title)
    plt.xlabel('anomaly score value')
    plt.ylabel('probability density')
    if xlim is not None:
        plt.xlim(0, xlim)
    else:
        plt.xlim(0, np.amax(test_anomaly_list))
    if legend_label is None:
        plt.legend(('Fitted Gaussian', 'histogram'))
    else:
        plt.legend(('normal data distribution','test data distribution (contain anomalies)'))
    if saveplot:
        savefig(config['result_dir']+'reconstruction_error_histogram.pdf')
    else:
        plt.show()
    threshold_25 = np.percentile(test_anomaly_list, 25)
    threshold_75 = np.percentile(test_anomaly_list, 75)
    threshold_1 = np.percentile(test_anomaly_list, 99)
    idx_large_error = np.squeeze(np.argwhere(test_anomaly_metric > threshold_1))
#     print(his[0][-20:])
#     print(his[1][-20:])
    print("25% percentile: {}".format(threshold_25))
    print("75% percentile: {}".format(threshold_75))
#     print("Median: {}".format(np.median(test_anomaly_list)))
#     print("Mean: {}".format(np.mean(test_anomaly_list)))
#     print("Std dev: {}".format(np.std(test_anomaly_list)))
    print("These windows scored the top 1% of anomaly metric ({}): \n{}".format(threshold_1, idx_large_error))
    return mean, std

# %%
# Histogram of VAE ELBO loss - validation set
vae_elbo_m, vae_elbo_std = plot_histogram(val_vae_elbo_loss, 100, 
                                          'VAE ELBO error distribution on the val set', 
                                          mean=None, std=None, xlim=None)

# %%
# Histogram of LSTM reconstruction error - validation set 
#  --> to decide the anomaly detection threshold
lstm_recons_m, lstm_recons_std = plot_histogram(val_lstm_recons_error, 100,  
                                              'LSTM reconstruction error distribution on the val set', 
                                              mean=None, std=None, xlim=None)

# %%
# Evaluate the anomaly metrics on the test windows and sequences
n_test_lstm = test_seq.shape[0]

test_lstm_recons_error, test_lstm_embedding_error = np.zeros(n_test_lstm), np.zeros(n_test_lstm)
for i in range(n_test_lstm):
    test_lstm_recons_error[i], test_lstm_embedding_error[i] = evaluate_lstm_anomaly_metric_for_a_seq(test_seq[i])
print("All windows' reconstruction error is computed.")
print("The total number of windows is {}".format(len(test_lstm_recons_error)))

# %%
# Histogram of LSTM reconstruction error - test set 
#  --> to detect anomaly now
_, _ = plot_histogram(test_lstm_recons_error, 100,
                      'LSTM reconstruction error distribution on the test set', 
                      mean=lstm_recons_m, std=lstm_recons_std, xlim=None, saveplot=True)

# %%
# Produce the ground truth anomaly indices 
# if result['idx_split'][0] == 0:
#     idx_anomaly_test = result['idx_anomaly_test']
# else:
#     idx_anomaly_test = result['idx_anomaly_test'][0]
idx_anomaly_test = result['idx_anomaly_test']    
anomaly_index_lstm = []
test_labels_lstm = np.zeros(n_test_lstm)
for i in range(len(idx_anomaly_test)):
    idx_start = idx_anomaly_test[i]-(config['l_win']*config['l_seq']-1)
    idx_end = idx_anomaly_test[i]+1
    if idx_start < 0:
        idx_start = 0
    if idx_end > n_test_lstm:
        idx_end = n_test_lstm
    anomaly_index_lstm.append(np.arange(idx_start,idx_end))
    test_labels_lstm[idx_start:idx_end] = 1
    
print(test_labels_lstm.shape)

# %%
def return_anomaly_idx_by_threshold(test_anomaly_metric, threshold):
    test_list = np.squeeze(np.ndarray.flatten(test_anomaly_metric))
    idx_error = np.squeeze(np.argwhere(test_anomaly_metric > threshold))
    
    if len(idx_error.shape) == 0:
        idx_error = np.expand_dims(idx_error, 0)
    
    return list(idx_error)

# %%
def augment_detected_idx(idx_detected_anomaly, anomaly_index):
    n_anomaly = len(anomaly_index)
    idx_detected_anomaly_extended = list(idx_detected_anomaly)
    for i in range(n_anomaly):
        #print(idx_detected_anomaly)
        for j in idx_detected_anomaly:
            if j in anomaly_index[i]:
                in_original_detection = set(idx_detected_anomaly_extended)
                currect_anomaly_win = set(anomaly_index[i])
                idx_detected_anomaly_extended = idx_detected_anomaly_extended + list(currect_anomaly_win - in_original_detection)
                #print(j)
                break
                
    return list(np.sort(idx_detected_anomaly_extended))

# %%
def count_TP_FP_FN(idx_detected_anomaly, anomaly_index, test_labels):
    n_TP = 0
    n_FP = 0
    n_detection = len(idx_detected_anomaly)
    for i in range(n_detection):
        if test_labels[idx_detected_anomaly[i]] == 1:
            n_TP = n_TP + 1
        else:
            n_FP = n_FP + 1
    
    idx_undetected = list(set(np.arange(len(test_labels)))- set(idx_detected_anomaly))
    n_FN = 0
    for i in idx_undetected:
        if test_labels[i] == 1:
            n_FN = n_FN + 1
    
    return n_TP, n_FP, n_FN

# %%
def compute_precision_and_recall(idx_detected_anomaly, anomaly_index, test_labels):
    # compute true positive
    n_TP, n_FP, n_FN = count_TP_FP_FN(idx_detected_anomaly, anomaly_index, test_labels)
    
    if n_TP + n_FP == 0:
        precision = 1
    else:
        precision = n_TP / (n_TP + n_FP)
    recall = n_TP / (n_TP + n_FN)
    if precision + recall == 0:
        F1 = 0
    else:
        F1 = 2* (precision * recall)/(precision + recall)
    
    return precision, recall, F1, n_TP, n_FP, n_FN

# %%
n_threshold = 200
precision = np.zeros(n_threshold)
recall = np.zeros(n_threshold)
F1 = np.zeros(n_threshold)
precision_aug = np.zeros(n_threshold)
recall_aug = np.zeros(n_threshold)
F1_aug = np.zeros(n_threshold)
i = 0
threshold_list = np.linspace(np.amin(test_lstm_recons_error), np.amax(test_lstm_recons_error), n_threshold, endpoint=True)
threshold_list = np.flip(threshold_list)
for threshold in threshold_list:
    #print(threshold_list[i])
    idx_detection_lstm = return_anomaly_idx_by_threshold(test_lstm_recons_error, threshold)
    precision[i], recall[i], F1[i], _, _, _ = compute_precision_and_recall(idx_detection_lstm, 
                                                                           anomaly_index_lstm, 
                                                                           test_labels_lstm)
    # augment the detection using the ground truth labels
    # a method to discount the factor one anomaly appears in multiple consecutive windows
    # introduced in "Unsupervised anomaly detection via variational auto-encoder for seasonal kpis in web applications"
    idx_detection_lstm_augmented = augment_detected_idx(idx_detection_lstm, anomaly_index_lstm)
    precision_aug[i], recall_aug[i], F1_aug[i], _, _, _ = compute_precision_and_recall(idx_detection_lstm_augmented, 
                                                                                       anomaly_index_lstm, 
                                                                                       test_labels_lstm)
    i = i + 1
    #print(precision, recall, F1)

# %%
print("Best F1 score is {}".format(np.amax(F1)))
idx_best_threshold = np.squeeze(np.argwhere(F1 == np.amax(F1)))
print("Best threshold is {}".format(threshold_list[idx_best_threshold]))
print("At this threshold, precision is {}, recall is {}".format(precision[idx_best_threshold], recall[idx_best_threshold]))
average_precision = np.sum(precision[1:] * (recall[1:] - recall[:-1]))
print("Average precision is {}".format(average_precision))

print("\nAugmented detection:")
print("Best F1 score is {}".format(np.amax(F1_aug)))
idx_best_threshold = np.squeeze(np.argwhere(F1_aug == np.amax(F1_aug)))
print("Best threshold is {}".format(threshold_list[idx_best_threshold]))
print("At this threshold, precision is {}, recall is {}".format(precision_aug[idx_best_threshold], 
                                                                recall_aug[idx_best_threshold]))

average_precision_aug = np.sum(precision_aug[1:] * (recall_aug[1:] - recall_aug[:-1]))
print("Average precision is {}".format(average_precision_aug))

# %%
# Now select a threshold
print(idx_best_threshold.ndim)
if idx_best_threshold.ndim > 0:
    threshold = threshold_list[idx_best_threshold[0]]
else:
    threshold = threshold_list[idx_best_threshold]

print("Threshold is {}".format(threshold))
idx_detection = return_anomaly_idx_by_threshold(test_lstm_recons_error, threshold)
idx_detection_augmented = augment_detected_idx(idx_detection, anomaly_index_lstm)
precision, recall, F1, n_TP, n_FP, n_FN = compute_precision_and_recall(idx_detection_augmented, 
                                                                       anomaly_index_lstm, 
                                                                       test_labels_lstm)
print("\nPR evaluation using augmented detection:")
print("Precision: {}".format(precision))
print("Recall: {}".format(recall))
print("F1: {}".format(F1))
print("TP: {}".format(n_TP))
print("FP: {}".format(n_FP))
print("FN: {}".format(n_FN))

# %%
def slice_detected_indices_into_seq(idx_detection, interval):
    detected_seq = []
    i = 0
    while i < len(idx_detection):
        if i == 0:
            cur_seq = [idx_detection[i]]
            i = i + 1
        else:
            if idx_detection[i] - idx_detection[i-1] > interval:
                detected_seq.append(cur_seq)
                cur_seq = [idx_detection[i]]
            else:
                cur_seq.append(idx_detection[i])
                if i == len(idx_detection) - 1:
                    detected_seq.append(cur_seq)
            i = i + 1
    
    print("Detected {} sequences".format(len(detected_seq)))
    return detected_seq

# %%
def plot_detected_anomalies(idx_detection, interval, dataset, result, detection_method, augmented_flag=1, y_scale=5, y_lim=None):
    detected_seq = slice_detected_indices_into_seq(idx_detection, interval=interval)
    t_test = result['t_test']
    test = result['test']
    idx_anomaly_test = result['idx_anomaly_test']
        
    # plot detected sequences
    fig, axs = plt.subplots(1, 1, figsize=(18, 5), edgecolor='k')
    fig.subplots_adjust(hspace=.4, wspace=.4)
    axs.plot(t_test, test)
    for j in range(len(idx_anomaly_test)):
        if j == 0:
            axs.plot(idx_anomaly_test[j] * np.ones(20), np.linspace(-y_scale, y_scale, 20), 'r--', label='true anomalies')
        else:
            axs.plot(idx_anomaly_test[j] * np.ones(20), np.linspace(-y_scale, y_scale, 20), 'r--')
        
    for i in range(len(detected_seq)):
        for j in detected_seq[i]:
            if j == detected_seq[0][0]:
                axs.plot((j+interval*2) * np.ones(20), np.linspace(-y_scale, -0.8*y_scale, 20), 'g-', label='detected anomalies')
            else:
                axs.plot((j+interval*2) * np.ones(20), np.linspace(-y_scale, -0.8*y_scale, 20), 'g-')
    
    for j in range(len(idx_anomaly_test)):
        axs.plot(idx_anomaly_test[j] * np.ones(20), np.linspace(-y_scale, y_scale, 20), 'r--')

    for i in range(len(detected_seq)):
        interval_x = np.asarray([detected_seq[i][0], detected_seq[i][-1]+interval*2])
        interval_y = np.asarray([y_scale,y_scale])
        if i == 0:
            axs.fill_between(interval_x, interval_y, alpha=0.2, color='y', label='detected anomaly windows')
        else:
            axs.fill_between(interval_x, interval_y, alpha=0.2, color='y')
        interval_y = np.asarray([-y_scale,-y_scale])
        axs.fill_between(interval_x, interval_y, alpha=0.2, color='y')
    axs.grid(True)
    axs.set_xlim(0, len(t_test))
    if y_lim is None:
        axs.set_ylim(-y_scale, y_scale)
    else:
        axs.set_ylim(-y_scale, y_lim)
    axs.set_xlabel("timestamp (every {})".format(result['t_unit']))
    axs.set_ylabel("normalised readings")
    #axs.set_title("{} dataset test sequence\n(normalised by train mean {:.4f} and std {:.4f})\n Detection method: {}".format(dataset, 
    #                                                                                    result['train_m'], 
    #                                                                                    result['train_std'],
    #                                                                                    detection_method))
    axs.set_title("{} dataset test sequence\n Detection method: {}".format(dataset, detection_method))
    axs.legend()
    savefig(config['result_dir']+'detected_anomalies_{}_aug_{}.pdf'.format(detection_method, augmented_flag))

# %%
plot_detected_anomalies(idx_detection_augmented, 
                        interval=config['l_win']*config['l_seq']/2, 
                        dataset=dataset, 
                        result=result, 
                        detection_method='lstm reconstruction error',
                        augmented_flag=1,
                        y_scale=5,
                        y_lim=5)
