# %%
from google.colab import drive
drive.mount('/content/drive')
global GIT_DIR
GIT_DIR='/content/drive/My\ Drive/afeka/y2/sem1/dl/code/LSTM-VAE/VAE-LSTM-for-anomaly-detection'
# %cd $GIT_DIR
# !ls

# %%
# %cd $GIT_DIR/codes/

# %%
import warnings

def fxn():
    warnings.warn("deprecated", DeprecationWarning)

with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    fxn()

# %%
# %tensorflow_version 1.x

# %%
import tensorflow as tf
import tensorflow_probability as tfp
import numpy as np
import matplotlib.pylab as plt
from matplotlib.pyplot import plot, ion, show, savefig, cla, figure
import random
import time

# %%
import os
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"   # see issue #152
os.environ["CUDA_VISIBLE_DEVICES"]="0"

import tensorflow as tf
from data_loader import DataGenerator
from models import VAEmodel, lstmKerasModel
from trainers import vaeTrainer

from utils import process_config, create_dirs, get_args

# %%
from tensorflow.python.client import device_lib

def get_available_gpus():
    local_device_protos = device_lib.list_local_devices()
    return [x.name for x in local_device_protos if x.device_type == 'GPU']

print(get_available_gpus())
# Out:
# []

# %%
# load VAE model
config = process_config('NAB_config.json')
# create the experiments dirs
create_dirs([config['result_dir'], config['checkpoint_dir']])
# create tensorflow session
sess = tf.Session(config=tf.ConfigProto(log_device_placement=True))
# create your data generator
data = DataGenerator(config)
# create a CNN model
model_vae = VAEmodel(config)
# create a CNN model
trainer_vae = vaeTrainer(sess, model_vae, data, config)
model_vae.load(sess)

# here you train your model
if config['TRAIN_VAE']:
    if config['num_epochs_vae'] > 0:
        trainer_vae.train()
# Out:
# ained for 0.303225306669871 min; Remaining 7.2774073600769045 min.
# Saving model...
# Model saved.
# 2/49, test loss: -elbo: 910.4019, recons_loss_weighted: 1715.5039, recons_loss_ls: 34.3101, KL_loss: 12.3776, sigma_regularisor: -110.5241, code_std_dev: [0.9970415  0.651455   0.13694009 0.9195118  0.30422544 0.7589939 ]
# Loss on training and val sets:
# train: 825.8121, val: 684.5162
# Current sigma2: 0.0100000
# Already trained for 0.4639032999674479 min; Remaining 7.267818366156685 min.
# Saving model...
# Model saved.
# 3/49, test loss: -elbo: 840.0579, recons_loss_weighted: 1571.0452, recons_loss_ls: 31.4209, KL_loss: 14.2630, sigma_regularisor: -110.5241, code_std_dev: [1.0931314  0.30005196 0.2237144  0.84881157 0.16489603 0.61538434]
# Loss on training and val sets:
# train: 719.5162, val: 570.5380
# Current sigma2: 0.0100000
# Already trained for 0.6102148373921712 min; Remaining 7.017470630009969 min.
# Saving model...
# Model saved.
# 4/49, test loss: -elbo: 789.2447, recons_loss_weighted: 1468.9243, recons_loss_ls: 29.3785, KL_loss: 14.5102, sigma_regularisor: -110.5241, code_std_dev: [0.8500417  0.28678784 0.1448721  0.63607246 0.14940181 0.48204702]
# Loss on training and val sets:
# train: 673.9928, val: 740.9081
# Current sigma2: 0.0100000
# Already trained for 0.7553997198740642 min; Remaining 6.798597478866577 min.
# Saving model...
# Model saved.
# 5/49, test loss: -elbo: 739.7150, recons_loss_weighted: 1366.4994, recons_loss_ls: 27.3300, KL_loss: 16.1930, sigma_regularisor: -110.5241, code_std_dev: [0.6815059  0.25996327 0.12045167 0.621779   0.10806379 0.47666445]
# Loss on training and val sets:
# train: 649.5175, val: 591.9178
# Current sigma2: 0.0100000
# Already trained for 0.9047293225924175 min; Remaining 6.63468169901106 min.
# Saving model...
# Model saved.
# 6/49, test loss: -elbo: 682.1556, recons_loss_weighted: 1246.8965, recons_loss_ls: 24.9379, KL_loss: 18.4351, sigma_regularisor: -110.5241, code_std_dev: [0.31095955 0.2644865  0.10519668 0.59467226 0.09935108 0.49926412]
# Loss on training and val sets:
# train: 624.9391, val: 559.4722
# Current sigma2: 0.0100000
# Already trained for 1.047919217745463 min; Remaining 6.437218051864987 min.
# Saving model...
# Model saved.
# 7/49, test loss: -elbo: 646.7061, recons_loss_weighted: 1170.5834, recons_loss_ls: 23.4117, KL_loss: 21.1421, sigma_regularisor: -110.5241, code_std_dev: [0.13355753 0.23210308 0.08750113 0.4908403  0.04734049 0.5646168 ]
# Loss on training and val sets:
# train: 594.2226, val: 523.0005
# Current sigma2: 0.0100000
# Already trained for 1.1946040352185567 min; Remaining 6.271671184897423 min.
# Saving model...
# Model saved.
# 8/49, test loss: -elbo: 618.0283, recons_loss_weighted: 1115.7216, recons_loss_ls: 22.3144, KL_loss: 19.8951, sigma_regularisor: -110.5241, code_std_dev: [0.19860457 0.22288528 0.10134998 0.5005778  0.0465007  0.6293389 ]
# Loss on training and val sets:
# train: 582.3918, val: 540.0828
# Current sigma2: 0.0100000
# Already trained for 1.3344907840092977 min; Remaining 6.079346904931245 min.
# Saving model...
# Model saved.
# 9/49, test loss: -elbo: 601.8661, recons_loss_weighted: 1081.2528, recons_loss_ls: 21.6251, KL_loss: 20.9674, sigma_regularisor: -110.5241, code_std_dev: [0.13173257 0.25780886 0.11587255 0.48940805 0.08611137 0.6032483 ]
# Loss on training and val sets:
# train: 560.6346, val: 401.9376
# Current sigma2: 0.0100000
# Already trained for 1.4806410749753316 min; Remaining 5.922564299901326 min.
# Saving model...
# Model saved.
# 10/49, test loss: -elbo: 591.7628, recons_loss_weighted: 1060.4623, recons_loss_ls: 21.2092, KL_loss: 21.2593, sigma_regularisor: -110.5241, code_std_dev: [0.13438143 0.25077456 0.05675002 0.4605337  0.07963678 0.53682864]
# Loss on training and val sets:
# train: 541.3264, val: 516.0932
# Current sigma2: 0.0100000
# Already trained for 1.624567480882009 min; Remaining 5.759830159490759 min.
# Saving model...
# Model saved.
# 11/49, test loss: -elbo: 576.4010, recons_loss_weighted: 1028.5989, recons_loss_ls: 20.5720, KL_loss: 21.8292, sigma_regularisor: -110.5241, code_std_dev: [0.09071387 0.26395035 0.06077832 0.44755793 0.0634158  0.7050212 ]
# Loss on training and val sets:
# train: 520.5638, val: 567.8056
# Current sigma2: 0.0100000
# Already trained for 1.769174301624298 min; Remaining 5.602385288476944 min.
# Saving model...
# Model saved.
# 12/49, test loss: -elbo: 567.4735, recons_loss_weighted: 1011.7913, recons_loss_ls: 20.2358, KL_loss: 21.3055, sigma_regularisor: -110.5241, code_std_dev: [0.11190425 0.25518566 0.1167694  0.3770385  0.066334   0.64705104]
# Loss on training and val sets:
# train: 497.1571, val: 457.8540
# Current sigma2: 0.0100000
# Already trained for 1.916554327805837 min; Remaining 5.4548084714473815 min.
# Saving model...
# Model saved.
# 13/49, test loss: -elbo: 538.4907, recons_loss_weighted: 951.6285, recons_loss_ls: 19.0326, KL_loss: 22.4041, sigma_regularisor: -110.5241, code_std_dev: [0.12342867 0.19543394 0.09730649 0.3249591  0.07201102 0.59444094]
# Loss on training and val sets:
# train: 473.3881, val: 553.6695
# Current sigma2: 0.0100000
# Already trained for 2.057469133536021 min; Remaining 5.290634914806911 min.
# Saving model...
# Model saved.
# 14/49, test loss: -elbo: 524.7830, recons_loss_weighted: 923.6267, recons_loss_ls: 18.4725, KL_loss: 22.6973, sigma_regularisor: -110.5241, code_std_dev: [0.10410352 0.25355527 0.08636862 0.2666138  0.07962154 0.57461405]
# Loss on training and val sets:
# train: 457.9963, val: 425.4650
# Current sigma2: 0.0100000
# Already trained for 2.207439335187276 min; Remaining 5.150691782103644 min.
# Saving model...
# Model saved.
# 15/49, test loss: -elbo: 501.8969, recons_loss_weighted: 873.0201, recons_loss_ls: 17.4604, KL_loss: 25.1144, sigma_regularisor: -110.5241, code_std_dev: [0.11161668 0.20599061 0.05641533 0.26562932 0.06571054 0.41458994]
# Loss on training and val sets:
# train: 435.3411, val: 378.9149
# Current sigma2: 0.0100000
# Already trained for 2.351975707213084 min; Remaining 4.997948377827803 min.
# Saving model...
# Model saved.
# 16/49, test loss: -elbo: 485.5497, recons_loss_weighted: 838.9733, recons_loss_ls: 16.7795, KL_loss: 25.7908, sigma_regularisor: -110.5241, code_std_dev: [0.12297829 0.23936258 0.1063986  0.21292147 0.06456986 0.44798684]
# Loss on training and val sets:
# train: 409.4207, val: 439.2750
# Current sigma2: 0.0100000
# Already trained for 2.4963586727778115 min; Remaining 4.845872717745165 min.
# Saving model...
# Model saved.
# 17/49, test loss: -elbo: 464.4677, recons_loss_weighted: 794.6050, recons_loss_ls: 15.8921, KL_loss: 26.8929, sigma_regularisor: -110.5241, code_std_dev: [0.09802096 0.17812069 0.07180601 0.24729756 0.04519818 0.39275557]
# Loss on training and val sets:
# train: 392.8587, val: 358.6561
# Current sigma2: 0.0100000
# Already trained for 2.641414268811544 min; Remaining 4.6958475889983005 min.
# Saving model...
# Model saved.
# 18/49, test loss: -elbo: 451.2505, recons_loss_weighted: 766.8837, recons_loss_ls: 15.3377, KL_loss: 27.5363, sigma_regularisor: -110.5241, code_std_dev: [0.14074595 0.1552934  0.0758378  0.20674536 0.09063191 0.4655033 ]
# Loss on training and val sets:
# train: 378.0800, val: 350.8959
# Current sigma2: 0.0100000
# Already trained for 2.7909090717633567 min; Remaining 4.553588485508635 min.
# Saving model...
# Model saved.
# 19/49, test loss: -elbo: 432.0601, recons_loss_weighted: 727.8508, recons_loss_ls: 14.5570, KL_loss: 27.8623, sigma_regularisor: -110.5241, code_std_dev: [0.12411957 0.16354069 0.08978735 0.18447888 0.05274067 0.40313587]
# Loss on training and val sets:
# train: 357.5998, val: 383.0515
# Current sigma2: 0.0100000
# Already trained for 2.935751815636953 min; Remaining 4.403627723455429 min.
# Saving model...
# Model saved.
# 20/49, test loss: -elbo: 419.8604, recons_loss_weighted: 699.2479, recons_loss_ls: 13.9850, KL_loss: 29.9641, sigma_regularisor: -110.5241, code_std_dev: [0.11435718 0.15766264 0.07185423 0.12024317 0.05146306 0.36178505]
# Loss on training and val sets:
# train: 343.3670, val: 353.2605
# Current sigma2: 0.0100000
# Already trained for 3.0849440813064577 min; Remaining 4.260160874185108 min.
# Saving model...
# Model saved.
# 21/49, test loss: -elbo: 407.5113, recons_loss_weighted: 675.2180, recons_loss_ls: 13.5044, KL_loss: 29.6299, sigma_regularisor: -110.5241, code_std_dev: [0.0777477  0.1681975  0.10726129 0.20866627 0.06444423 0.25637338]
# Loss on training and val sets:
# train: 330.0735, val: 307.2002
# Current sigma2: 0.0100000
# Already trained for 3.2274163007736205 min; Remaining 4.107620746439154 min.
# Saving model...
# Model saved.
# 22/49, test loss: -elbo: 398.1757, recons_loss_weighted: 653.1768, recons_loss_ls: 13.0635, KL_loss: 31.3149, sigma_regularisor: -110.5241, code_std_dev: [0.05323296 0.18544073 0.08005727 0.19418196 0.05988491 0.3081525 ]
# Loss on training and val sets:
# train: 316.2734, val: 294.5244
# Current sigma2: 0.0100000
# Already trained for 3.3713792006174725 min; Remaining 3.957706018116163 min.
# Saving model...
# Model saved.
# 23/49, test loss: -elbo: 386.1972, recons_loss_weighted: 631.3679, recons_loss_ls: 12.6274, KL_loss: 30.2408, sigma_regularisor: -110.5241, code_std_dev: [0.11014077 0.19656602 0.11111947 0.15213424 0.11399748 0.23145205]
# Loss on training and val sets:
# train: 307.6734, val: 353.8860
# Current sigma2: 0.0100000
# Already trained for 3.5161935766537984 min; Remaining 3.809209708041615 min.
# Saving model...
# Model saved.
# 24/49, test loss: -elbo: 390.2969, recons_loss_weighted: 636.2104, recons_loss_ls: 12.7242, KL_loss: 31.9194, sigma_regularisor: -110.5241, code_std_dev: [0.09071668 0.16422571 0.0704162  0.20838296 0.07791479 0.22622815]
# Loss on training and val sets:
# train: 294.7871, val: 317.7592
# Current sigma2: 0.0100000
# Already trained for 3.6578824520111084 min; Remaining 3.6578824520111084 min.
# Saving model...
# Model saved.
# 25/49, test loss: -elbo: 365.2523, recons_loss_weighted: 587.4871, recons_loss_ls: 11.7497, KL_loss: 31.2364, sigma_regularisor: -110.5241, code_std_dev: [0.11708753 0.17145632 0.10339964 0.15568075 0.07708924 0.19182691]
# Loss on training and val sets:
# train: 287.7494, val: 321.6465
# Current sigma2: 0.0100000
# Already trained for 3.801708141962687 min; Remaining 3.5092690541194043 min.
# Saving model...
# Model saved.
# 26/49, test loss: -elbo: 356.7648, recons_loss_weighted: 568.1160, recons_loss_ls: 11.3623, KL_loss: 32.4344, sigma_regularisor: -110.5241, code_std_dev: [0.11311638 0.14728352 0.0731486  0.12199531 0.05991299 0.23793381]
# Loss on training and val sets:
# train: 276.4239, val: 281.8159
# Current sigma2: 0.0100000
# Already trained for 3.9415884693463643 min; Remaining 3.3576494368506067 min.
# Saving model...
# Model saved.
# 27/49, test loss: -elbo: 355.2604, recons_loss_weighted: 564.6977, recons_loss_ls: 11.2940, KL_loss: 32.6392, sigma_regularisor: -110.5241, code_std_dev: [0.09797546 0.13710997 0.08677965 0.10399681 0.07279859 0.17966914]
# Loss on training and val sets:
# train: 267.3219, val: 252.2633
# Current sigma2: 0.0100000
# Already trained for 4.087890148162842 min; Remaining 3.211913687842233 min.
# Saving model...
# Model saved.
# 28/49, test loss: -elbo: 345.4962, recons_loss_weighted: 545.5108, recons_loss_ls: 10.9102, KL_loss: 32.4684, sigma_regularisor: -110.5241, code_std_dev: [0.07046621 0.13603386 0.07266144 0.1210615  0.08338705 0.22140189]
# Loss on training and val sets:
# train: 259.9325, val: 250.6722
# Current sigma2: 0.0100000
# Already trained for 4.2285849491755165 min; Remaining 3.0620787562995124 min.
# Saving model...
# Model saved.
# 29/49, test loss: -elbo: 340.7188, recons_loss_weighted: 536.1888, recons_loss_ls: 10.7238, KL_loss: 32.3519, sigma_regularisor: -110.5241, code_std_dev: [0.0760841  0.13259465 0.06605642 0.16643602 0.04818467 0.24761896]
# Loss on training and val sets:
# train: 252.1843, val: 286.0303
# Current sigma2: 0.0100000
# Already trained for 4.380736605326335 min; Remaining 2.9204910702175564 min.
# Saving model...
# Model saved.
# 30/49, test loss: -elbo: 337.5399, recons_loss_weighted: 529.7391, recons_loss_ls: 10.5948, KL_loss: 32.3980, sigma_regularisor: -110.5241, code_std_dev: [0.08633514 0.16414459 0.0775017  0.13535953 0.08189999 0.23815961]
# Loss on training and val sets:
# train: 248.5789, val: 295.2549
# Current sigma2: 0.0100000
# Already trained for 4.523932945728302 min; Remaining 2.772733095768959 min.
# Saving model...
# Model saved.
# 31/49, test loss: -elbo: 323.9111, recons_loss_weighted: 502.9159, recons_loss_ls: 10.0583, KL_loss: 32.1808, sigma_regularisor: -110.5241, code_std_dev: [0.0771516  0.12241231 0.07968928 0.11988212 0.08768953 0.1932922 ]
# Loss on training and val sets:
# train: 246.7049, val: 275.5359
# Current sigma2: 0.0100000
# Already trained for 4.6740551590919495 min; Remaining 2.6291560269892216 min.
# Saving model...
# Model saved.
# 32/49, test loss: -elbo: 321.8286, recons_loss_weighted: 498.3233, recons_loss_ls: 9.9665, KL_loss: 32.3946, sigma_regularisor: -110.5241, code_std_dev: [0.08458424 0.15576367 0.07803406 0.12864044 0.08695316 0.17638421]
# Loss on training and val sets:
# train: 237.6235, val: 244.1511
# Current sigma2: 0.0100000
# Already trained for 4.820437109470367 min; Remaining 2.48325548063625 min.
# Saving model...
# Model saved.
# 33/49, test loss: -elbo: 331.3093, recons_loss_weighted: 515.9055, recons_loss_ls: 10.3181, KL_loss: 33.0842, sigma_regularisor: -110.5241, code_std_dev: [0.08384291 0.16846348 0.06538359 0.09854608 0.06006608 0.20019343]
# Loss on training and val sets:
# train: 235.5949, val: 247.2275
# Current sigma2: 0.0100000
# Already trained for 4.963351849714915 min; Remaining 2.3356949881011366 min.
# Saving model...
# Model saved.
# 34/49, test loss: -elbo: 314.9054, recons_loss_weighted: 483.6297, recons_loss_ls: 9.6726, KL_loss: 32.8182, sigma_regularisor: -110.5241, code_std_dev: [0.10520942 0.15541117 0.08132988 0.09770519 0.05837241 0.19173792]
# Loss on training and val sets:
# train: 231.6047, val: 306.8198
# Current sigma2: 0.0100000
# Already trained for 5.1123396833737695 min; Remaining 2.191002721445901 min.
# Saving model...
# Model saved.
# 35/49, test loss: -elbo: 312.5031, recons_loss_weighted: 480.7430, recons_loss_ls: 9.6149, KL_loss: 31.8593, sigma_regularisor: -110.5241, code_std_dev: [0.10565917 0.148698   0.07276346 0.114811   0.08065404 0.22730203]
# Loss on training and val sets:
# train: 227.2418, val: 249.5426
# Current sigma2: 0.0100000
# Already trained for 5.254985018571218 min; Remaining 2.043605284999918 min.
# Saving model...
# Model saved.
# 36/49, test loss: -elbo: 312.4486, recons_loss_weighted: 481.1471, recons_loss_ls: 9.6229, KL_loss: 31.6027, sigma_regularisor: -110.5241, code_std_dev: [0.08875309 0.1943234  0.08318959 0.14020453 0.0677934  0.25207862]
# Loss on training and val sets:
# train: 224.8991, val: 247.9937
# Current sigma2: 0.0100000
# Already trained for 5.402816502253215 min; Remaining 1.8982868791700482 min.
# Saving model...
# Model saved.
# 37/49, test loss: -elbo: 303.7550, recons_loss_weighted: 462.5425, recons_loss_ls: 9.2509, KL_loss: 32.2114, sigma_regularisor: -110.5241, code_std_dev: [0.06836521 0.15415312 0.08936632 0.10350294 0.06927173 0.23601252]
# Loss on training and val sets:
# train: 219.7596, val: 241.9783
# Current sigma2: 0.0100000
# Already trained for 5.544183150927226 min; Remaining 1.7507946792401763 min.
# Saving model...
# Model saved.
# 38/49, test loss: -elbo: 304.4572, recons_loss_weighted: 464.8955, recons_loss_ls: 9.2979, KL_loss: 31.7371, sigma_regularisor: -110.5241, code_std_dev: [0.09212288 0.17972825 0.07635625 0.12287323 0.07309068 0.23012885]
# Loss on training and val sets:
# train: 215.5795, val: 280.0598
# Current sigma2: 0.0100000
# Already trained for 5.690899205207825 min; Remaining 1.605125416853489 min.
# Saving model...
# Model saved.
# 39/49, test loss: -elbo: 305.8077, recons_loss_weighted: 466.0624, recons_loss_ls: 9.3212, KL_loss: 32.5041, sigma_regularisor: -110.5241, code_std_dev: [0.0979569  0.16496071 0.04620966 0.09845565 0.06394894 0.20531008]
# Loss on training and val sets:
# train: 214.8913, val: 265.1202
# Current sigma2: 0.0100000
# Already trained for 5.8362693071365355 min; Remaining 1.4590673267841339 min.
# Saving model...
# Model saved.
# 40/49, test loss: -elbo: 304.0349, recons_loss_weighted: 462.4415, recons_loss_ls: 9.2488, KL_loss: 32.5417, sigma_regularisor: -110.5241, code_std_dev: [0.06132808 0.13320789 0.0857285  0.11282485 0.05267348 0.20011696]
# Loss on training and val sets:
# train: 206.9776, val: 222.4404
# Current sigma2: 0.0100000
# Already trained for 5.9866873025894165 min; Remaining 1.3141508713001158 min.
# Saving model...
# Model saved.
# 41/49, test loss: -elbo: 295.1669, recons_loss_weighted: 446.2806, recons_loss_ls: 8.9256, KL_loss: 31.7542, sigma_regularisor: -110.5241, code_std_dev: [0.07748967 0.18178025 0.05636103 0.13101111 0.09065279 0.21537945]
# Loss on training and val sets:
# train: 207.8586, val: 239.3856
# Current sigma2: 0.0100000
# Already trained for 6.128867848714193 min; Remaining 1.1674033997550843 min.
# Saving model...
# Model saved.
# 42/49, test loss: -elbo: 297.9062, recons_loss_weighted: 450.4832, recons_loss_ls: 9.0097, KL_loss: 32.3922, sigma_regularisor: -110.5241, code_std_dev: [0.09148909 0.15951352 0.07733427 0.10094347 0.06620305 0.19065529]
# Loss on training and val sets:
# train: 206.5056, val: 263.0955
# Current sigma2: 0.0100000
# Already trained for 6.277001198132833 min; Remaining 1.0218374043472054 min.
# Saving model...
# Model saved.
# 43/49, test loss: -elbo: 292.5080, recons_loss_weighted: 440.2723, recons_loss_ls: 8.8054, KL_loss: 32.0995, sigma_regularisor: -110.5241, code_std_dev: [0.09540099 0.16224378 0.10117611 0.09190088 0.06740207 0.20227775]
# Loss on training and val sets:
# train: 203.5443, val: 256.6494
# Current sigma2: 0.0100000
# Already trained for 6.42014502286911 min; Remaining 0.8754743213003332 min.
# Saving model...
# Model saved.
# 44/49, test loss: -elbo: 294.4122, recons_loss_weighted: 441.9342, recons_loss_ls: 8.8387, KL_loss: 33.1728, sigma_regularisor: -110.5241, code_std_dev: [0.05968978 0.13215318 0.06370065 0.11615533 0.03749681 0.18882614]
# Loss on training and val sets:
# train: 203.0549, val: 265.6644
# Current sigma2: 0.0100000
# Already trained for 6.564270039399465 min; Remaining 0.7293633377110517 min.
# Saving model...
# Model saved.
# 45/49, test loss: -elbo: 289.1287, recons_loss_weighted: 433.9812, recons_loss_ls: 8.6796, KL_loss: 31.8657, sigma_regularisor: -110.5241, code_std_dev: [0.09632415 0.17164586 0.06654164 0.09864598 0.06759871 0.20439506]
# Loss on training and val sets:
# train: 197.3286, val: 246.1984
# Current sigma2: 0.0100000
# Already trained for 6.70844228665034 min; Remaining 0.5833428075348122 min.
# Saving model...
# Model saved.
# 46/49, test loss: -elbo: 292.5266, recons_loss_weighted: 439.9686, recons_loss_ls: 8.7994, KL_loss: 32.2699, sigma_regularisor: -110.5241, code_std_dev: [0.08389734 0.21426123 0.05286479 0.11597086 0.09746765 0.15455087]
# Loss on training and val sets:
# train: 194.9637, val: 265.3180
# Current sigma2: 0.0100000
# Already trained for 6.851140964031219 min; Remaining 0.43730687004454594 min.
# Saving model...
# Model saved.
# 47/49, test loss: -elbo: 285.1744, recons_loss_weighted: 424.7515, recons_loss_ls: 8.4950, KL_loss: 32.5263, sigma_regularisor: -110.5241, code_std_dev: [0.08194903 0.14639564 0.08693339 0.1062202  0.06914569 0.2137839 ]
# Loss on training and val sets:
# train: 193.5549, val: 236.5421
# Current sigma2: 0.0100000
# Already trained for 6.9994197924931845 min; Remaining 0.29164249135388265 min.
# Saving model...
# Model saved.
# 48/49, test loss: -elbo: 285.6759, recons_loss_weighted: 425.7578, recons_loss_ls: 8.5152, KL_loss: 32.5246, sigma_regularisor: -110.5241, code_std_dev: [0.06697407 0.14844474 0.07528963 0.10846043 0.06065905 0.21323374]
# Loss on training and val sets:
# train: 191.8996, val: 214.1497
# Current sigma2: 0.0100000
# Already trained for 7.143778924147288 min; Remaining 0.14579140661525078 min.
# Saving model...
# Model saved.
# 49/49, test loss: -elbo: 284.9818, recons_loss_weighted: 425.5081, recons_loss_ls: 8.5102, KL_loss: 31.9554, sigma_regularisor: -110.5241, code_std_dev: [0.07403475 0.1451804  0.0786643  0.11504477 0.0479688  0.21655636]
# Loss on training and val sets:
# train: 187.9956, val: 211.3406
# Current sigma2: 0.0100000
# Already trained for 7.289708630243937 min; Remaining 0.0 min.

# %%
# load LSTM model
lstm_model = lstmKerasModel(data)
lstm_model.produce_embeddings(config, model_vae, data, sess)
lstm_nn_model = lstm_model.create_lstm_model(config)
lstm_nn_model.summary()   # Display the model's architecture

# checkpoint path
checkpoint_path = config['checkpoint_dir_lstm'] + "cp.ckpt"
checkpoint_dir = os.path.dirname(checkpoint_path)
# Create a callback that saves the model's weights
cp_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path,
                                                 save_weights_only=True,
                                                 verbose=1)
# load weights if possible
lstm_model.load_model(lstm_nn_model, config, checkpoint_path)
# start training
if config['TRAIN_LSTM']:
    if config['num_epochs_lstm'] > 0:
        lstm_model.train(config, lstm_nn_model, cp_callback)

    # make a prediction on the test set using the trained model
    lstm_embedding = lstm_nn_model.predict(lstm_model.x_test, batch_size=config['batch_size_lstm'])
    print(lstm_embedding.shape)

    # visualise the first 10 test sequences
    for i in range(10):
        lstm_model.plot_lstm_embedding_prediction(i, config, model_vae, sess, data, lstm_embedding)
# Out:
# tch-32/PX4-QUAD-HITL-2-channels-trim-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 351us/sample - loss: 2.4090 - mean_squared_error: 2.4090 - val_loss: 2.6630 - val_mean_squared_error: 2.6630
# Epoch 56/100
# 576/746 [======================>.......] - ETA: 0s - loss: 2.4216 - mean_squared_error: 2.4216
# Epoch 00056: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-2-channels-trim-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 445us/sample - loss: 2.4015 - mean_squared_error: 2.4015 - val_loss: 2.6563 - val_mean_squared_error: 2.6563
# Epoch 57/100
# 672/746 [==========================>...] - ETA: 0s - loss: 2.3949 - mean_squared_error: 2.3949
# Epoch 00057: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-2-channels-trim-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 413us/sample - loss: 2.3938 - mean_squared_error: 2.3938 - val_loss: 2.6565 - val_mean_squared_error: 2.6565
# Epoch 58/100
# 672/746 [==========================>...] - ETA: 0s - loss: 2.4125 - mean_squared_error: 2.4125
# Epoch 00058: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-2-channels-trim-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 392us/sample - loss: 2.3863 - mean_squared_error: 2.3863 - val_loss: 2.6448 - val_mean_squared_error: 2.6448
# Epoch 59/100
# 704/746 [===========================>..] - ETA: 0s - loss: 2.3851 - mean_squared_error: 2.3851
# Epoch 00059: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-2-channels-trim-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 358us/sample - loss: 2.3806 - mean_squared_error: 2.3806 - val_loss: 2.6448 - val_mean_squared_error: 2.6448
# Epoch 60/100
# 736/746 [============================>.] - ETA: 0s - loss: 2.3683 - mean_squared_error: 2.3683
# Epoch 00060: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-2-channels-trim-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 404us/sample - loss: 2.3712 - mean_squared_error: 2.3712 - val_loss: 2.6386 - val_mean_squared_error: 2.6386
# Epoch 61/100
# 640/746 [========================>.....] - ETA: 0s - loss: 2.3666 - mean_squared_error: 2.3666
# Epoch 00061: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-2-channels-trim-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 378us/sample - loss: 2.3648 - mean_squared_error: 2.3648 - val_loss: 2.6336 - val_mean_squared_error: 2.6336
# Epoch 62/100
# 672/746 [==========================>...] - ETA: 0s - loss: 2.3175 - mean_squared_error: 2.3175
# Epoch 00062: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-2-channels-trim-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 379us/sample - loss: 2.3582 - mean_squared_error: 2.3582 - val_loss: 2.6268 - val_mean_squared_error: 2.6268
# Epoch 63/100
# 608/746 [=======================>......] - ETA: 0s - loss: 2.3647 - mean_squared_error: 2.3647
# Epoch 00063: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-2-channels-trim-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 405us/sample - loss: 2.3519 - mean_squared_error: 2.3519 - val_loss: 2.6231 - val_mean_squared_error: 2.6231
# Epoch 64/100
# 736/746 [============================>.] - ETA: 0s - loss: 2.3545 - mean_squared_error: 2.3545
# Epoch 00064: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-2-channels-trim-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 452us/sample - loss: 2.3460 - mean_squared_error: 2.3460 - val_loss: 2.6169 - val_mean_squared_error: 2.6169
# Epoch 65/100
# 736/746 [============================>.] - ETA: 0s - loss: 2.3286 - mean_squared_error: 2.3286
# Epoch 00065: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-2-channels-trim-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 439us/sample - loss: 2.3397 - mean_squared_error: 2.3397 - val_loss: 2.6112 - val_mean_squared_error: 2.6112
# Epoch 66/100
# 640/746 [========================>.....] - ETA: 0s - loss: 2.3531 - mean_squared_error: 2.3531
# Epoch 00066: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-2-channels-trim-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 390us/sample - loss: 2.3327 - mean_squared_error: 2.3327 - val_loss: 2.6045 - val_mean_squared_error: 2.6045
# Epoch 67/100
# 608/746 [=======================>......] - ETA: 0s - loss: 2.3005 - mean_squared_error: 2.3005
# Epoch 00067: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-2-channels-trim-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 392us/sample - loss: 2.3268 - mean_squared_error: 2.3268 - val_loss: 2.6038 - val_mean_squared_error: 2.6038
# Epoch 68/100
# 672/746 [==========================>...] - ETA: 0s - loss: 2.3210 - mean_squared_error: 2.3210
# Epoch 00068: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-2-channels-trim-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 382us/sample - loss: 2.3213 - mean_squared_error: 2.3213 - val_loss: 2.5967 - val_mean_squared_error: 2.5967
# Epoch 69/100
# 608/746 [=======================>......] - ETA: 0s - loss: 2.3732 - mean_squared_error: 2.3732
# Epoch 00069: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-2-channels-trim-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 406us/sample - loss: 2.3155 - mean_squared_error: 2.3155 - val_loss: 2.5950 - val_mean_squared_error: 2.5950
# Epoch 70/100
# 640/746 [========================>.....] - ETA: 0s - loss: 2.3102 - mean_squared_error: 2.3102
# Epoch 00070: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-2-channels-trim-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 388us/sample - loss: 2.3108 - mean_squared_error: 2.3108 - val_loss: 2.5869 - val_mean_squared_error: 2.5869
# Epoch 71/100
# 640/746 [========================>.....] - ETA: 0s - loss: 2.2670 - mean_squared_error: 2.2670
# Epoch 00071: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-2-channels-trim-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 391us/sample - loss: 2.3050 - mean_squared_error: 2.3050 - val_loss: 2.5840 - val_mean_squared_error: 2.5840
# Epoch 72/100
# 640/746 [========================>.....] - ETA: 0s - loss: 2.3380 - mean_squared_error: 2.3380
# Epoch 00072: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-2-channels-trim-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 382us/sample - loss: 2.3001 - mean_squared_error: 2.3001 - val_loss: 2.5814 - val_mean_squared_error: 2.5814
# Epoch 73/100
# 640/746 [========================>.....] - ETA: 0s - loss: 2.2656 - mean_squared_error: 2.2656
# Epoch 00073: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-2-channels-trim-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 386us/sample - loss: 2.2953 - mean_squared_error: 2.2953 - val_loss: 2.5751 - val_mean_squared_error: 2.5751
# Epoch 74/100
# 672/746 [==========================>...] - ETA: 0s - loss: 2.2955 - mean_squared_error: 2.2955
# Epoch 00074: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-2-channels-trim-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 392us/sample - loss: 2.2897 - mean_squared_error: 2.2897 - val_loss: 2.5682 - val_mean_squared_error: 2.5682
# Epoch 75/100
# 672/746 [==========================>...] - ETA: 0s - loss: 2.2939 - mean_squared_error: 2.2939
# Epoch 00075: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-2-channels-trim-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 393us/sample - loss: 2.2850 - mean_squared_error: 2.2850 - val_loss: 2.5635 - val_mean_squared_error: 2.5635
# Epoch 76/100
# 640/746 [========================>.....] - ETA: 0s - loss: 2.2338 - mean_squared_error: 2.2338
# Epoch 00076: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-2-channels-trim-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 401us/sample - loss: 2.2792 - mean_squared_error: 2.2792 - val_loss: 2.5552 - val_mean_squared_error: 2.5552
# Epoch 77/100
# 672/746 [==========================>...] - ETA: 0s - loss: 2.2820 - mean_squared_error: 2.2820
# Epoch 00077: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-2-channels-trim-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 402us/sample - loss: 2.2753 - mean_squared_error: 2.2753 - val_loss: 2.5514 - val_mean_squared_error: 2.5514
# Epoch 78/100
# 640/746 [========================>.....] - ETA: 0s - loss: 2.2553 - mean_squared_error: 2.2553
# Epoch 00078: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-2-channels-trim-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 475us/sample - loss: 2.2701 - mean_squared_error: 2.2701 - val_loss: 2.5497 - val_mean_squared_error: 2.5497
# Epoch 79/100
# 736/746 [============================>.] - ETA: 0s - loss: 2.2720 - mean_squared_error: 2.2720
# Epoch 00079: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-2-channels-trim-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 421us/sample - loss: 2.2664 - mean_squared_error: 2.2664 - val_loss: 2.5392 - val_mean_squared_error: 2.5392
# Epoch 80/100
# 704/746 [===========================>..] - ETA: 0s - loss: 2.2569 - mean_squared_error: 2.2569
# Epoch 00080: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-2-channels-trim-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 444us/sample - loss: 2.2632 - mean_squared_error: 2.2632 - val_loss: 2.5358 - val_mean_squared_error: 2.5358
# Epoch 81/100
# 672/746 [==========================>...] - ETA: 0s - loss: 2.2532 - mean_squared_error: 2.2532
# Epoch 00081: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-2-channels-trim-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 377us/sample - loss: 2.2572 - mean_squared_error: 2.2572 - val_loss: 2.5311 - val_mean_squared_error: 2.5311
# Epoch 82/100
# 640/746 [========================>.....] - ETA: 0s - loss: 2.3041 - mean_squared_error: 2.3041
# Epoch 00082: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-2-channels-trim-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 409us/sample - loss: 2.2523 - mean_squared_error: 2.2523 - val_loss: 2.5256 - val_mean_squared_error: 2.5256
# Epoch 83/100
# 640/746 [========================>.....] - ETA: 0s - loss: 2.2291 - mean_squared_error: 2.2291
# Epoch 00083: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-2-channels-trim-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 407us/sample - loss: 2.2487 - mean_squared_error: 2.2487 - val_loss: 2.5185 - val_mean_squared_error: 2.5185
# Epoch 84/100
# 640/746 [========================>.....] - ETA: 0s - loss: 2.2555 - mean_squared_error: 2.2555
# Epoch 00084: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-2-channels-trim-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 405us/sample - loss: 2.2445 - mean_squared_error: 2.2445 - val_loss: 2.5129 - val_mean_squared_error: 2.5129
# Epoch 85/100
# 672/746 [==========================>...] - ETA: 0s - loss: 2.2227 - mean_squared_error: 2.2227
# Epoch 00085: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-2-channels-trim-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 403us/sample - loss: 2.2395 - mean_squared_error: 2.2395 - val_loss: 2.5128 - val_mean_squared_error: 2.5128
# Epoch 86/100
# 672/746 [==========================>...] - ETA: 0s - loss: 2.2343 - mean_squared_error: 2.2343
# Epoch 00086: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-2-channels-trim-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 398us/sample - loss: 2.2354 - mean_squared_error: 2.2354 - val_loss: 2.5051 - val_mean_squared_error: 2.5051
# Epoch 87/100
# 672/746 [==========================>...] - ETA: 0s - loss: 2.1790 - mean_squared_error: 2.1790
# Epoch 00087: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-2-channels-trim-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 395us/sample - loss: 2.2318 - mean_squared_error: 2.2318 - val_loss: 2.4998 - val_mean_squared_error: 2.4998
# Epoch 88/100
# 640/746 [========================>.....] - ETA: 0s - loss: 2.1973 - mean_squared_error: 2.1973
# Epoch 00088: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-2-channels-trim-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 393us/sample - loss: 2.2269 - mean_squared_error: 2.2269 - val_loss: 2.4951 - val_mean_squared_error: 2.4951
# Epoch 89/100
# 672/746 [==========================>...] - ETA: 0s - loss: 2.2055 - mean_squared_error: 2.2055
# Epoch 00089: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-2-channels-trim-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 392us/sample - loss: 2.2232 - mean_squared_error: 2.2232 - val_loss: 2.4883 - val_mean_squared_error: 2.4883
# Epoch 90/100
# 672/746 [==========================>...] - ETA: 0s - loss: 2.2528 - mean_squared_error: 2.2528
# Epoch 00090: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-2-channels-trim-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 372us/sample - loss: 2.2192 - mean_squared_error: 2.2192 - val_loss: 2.4848 - val_mean_squared_error: 2.4848
# Epoch 91/100
# 672/746 [==========================>...] - ETA: 0s - loss: 2.2523 - mean_squared_error: 2.2523
# Epoch 00091: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-2-channels-trim-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 372us/sample - loss: 2.2151 - mean_squared_error: 2.2151 - val_loss: 2.4810 - val_mean_squared_error: 2.4810
# Epoch 92/100
# 736/746 [============================>.] - ETA: 0s - loss: 2.2021 - mean_squared_error: 2.2021
# Epoch 00092: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-2-channels-trim-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 417us/sample - loss: 2.2112 - mean_squared_error: 2.2112 - val_loss: 2.4735 - val_mean_squared_error: 2.4735
# Epoch 93/100
# 672/746 [==========================>...] - ETA: 0s - loss: 2.2124 - mean_squared_error: 2.2124
# Epoch 00093: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-2-channels-trim-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 397us/sample - loss: 2.2070 - mean_squared_error: 2.2070 - val_loss: 2.4691 - val_mean_squared_error: 2.4691
# Epoch 94/100
# 672/746 [==========================>...] - ETA: 0s - loss: 2.2350 - mean_squared_error: 2.2350
# Epoch 00094: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-2-channels-trim-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 386us/sample - loss: 2.2034 - mean_squared_error: 2.2034 - val_loss: 2.4669 - val_mean_squared_error: 2.4669
# Epoch 95/100
# 608/746 [=======================>......] - ETA: 0s - loss: 2.1517 - mean_squared_error: 2.1517
# Epoch 00095: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-2-channels-trim-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 397us/sample - loss: 2.2000 - mean_squared_error: 2.2000 - val_loss: 2.4581 - val_mean_squared_error: 2.4581
# Epoch 96/100
# 608/746 [=======================>......] - ETA: 0s - loss: 2.2001 - mean_squared_error: 2.2001
# Epoch 00096: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-2-channels-trim-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 428us/sample - loss: 2.1958 - mean_squared_error: 2.1958 - val_loss: 2.4543 - val_mean_squared_error: 2.4543
# Epoch 97/100
# 736/746 [============================>.] - ETA: 0s - loss: 2.2006 - mean_squared_error: 2.2006
# Epoch 00097: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-2-channels-trim-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 441us/sample - loss: 2.1927 - mean_squared_error: 2.1927 - val_loss: 2.4527 - val_mean_squared_error: 2.4527
# Epoch 98/100
# 704/746 [===========================>..] - ETA: 0s - loss: 2.1764 - mean_squared_error: 2.1764
# Epoch 00098: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-2-channels-trim-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 487us/sample - loss: 2.1884 - mean_squared_error: 2.1884 - val_loss: 2.4459 - val_mean_squared_error: 2.4459
# Epoch 99/100
# 640/746 [========================>.....] - ETA: 0s - loss: 2.1921 - mean_squared_error: 2.1921
# Epoch 00099: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-2-channels-trim-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 406us/sample - loss: 2.1852 - mean_squared_error: 2.1852 - val_loss: 2.4424 - val_mean_squared_error: 2.4424
# Epoch 100/100
# 672/746 [==========================>...] - ETA: 0s - loss: 2.1329 - mean_squared_error: 2.1329
# Epoch 00100: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-2-channels-trim-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 400us/sample - loss: 2.1816 - mean_squared_error: 2.1816 - val_loss: 2.4352 - val_mean_squared_error: 2.4352
# (83, 2, 6)
# Decoded seq from VAE: (3, 24, 2)
# Decoded seq from lstm: (2, 24, 2)
# Decoded seq from VAE: (3, 24, 2)
# Decoded seq from lstm: (2, 24, 2)
# Decoded seq from VAE: (3, 24, 2)
# Decoded seq from lstm: (2, 24, 2)
# Decoded seq from VAE: (3, 24, 2)
# Decoded seq from lstm: (2, 24, 2)
# Decoded seq from VAE: (3, 24, 2)
# Decoded seq from lstm: (2, 24, 2)
# Decoded seq from VAE: (3, 24, 2)
# Decoded seq from lstm: (2, 24, 2)
# Decoded seq from VAE: (3, 24, 2)
# Decoded seq from lstm: (2, 24, 2)
# Decoded seq from VAE: (3, 24, 2)
# Decoded seq from lstm: (2, 24, 2)
# Decoded seq from VAE: (3, 24, 2)
# Decoded seq from lstm: (2, 24, 2)
# Decoded seq from VAE: (3, 24, 2)
# Decoded seq from lstm: (2, 24, 2)

# %%
# load normalised time series
save_dir = '../datasets/' + config['data_dir'] #NAB-known-anomaly/'
dataset = config['dataset']
file_name = config['filename']
filename = '{}.npz'.format(file_name)
result = dict(np.load(save_dir+filename, allow_pickle=True))
if dataset == 'machine_temp':
    result['test'] = result['test'][0]
    result['idx_anomaly_test'] = result['idx_anomaly_test'][0]
    result['t_test'] = result['t_test'][0]

# slice into rolling windows and rolling sequences
def slice_rolling_windows_and_sequences(config, time_seq):
    n_sample = len(time_seq)
    print("The given sequence has {} samples".format(n_sample))
    n_vae_win = n_sample - config['l_win'] + 1
    rolling_windows = np.zeros((n_vae_win, config['l_win'], config['n_channel']), dtype=float)
    for i in range(n_vae_win):
        rolling_windows[i] = time_seq[i:i + config['l_win']]
        sample_m = np.mean(rolling_windows, axis=1)
        sample_std = np.std(rolling_windows, axis=1)

        n_lstm_seq = n_sample - config['l_seq']*config['l_win']+1
        lstm_seq = np.zeros((n_lstm_seq, config['l_seq'], config['l_win'], config['n_channel']), dtype=float)
    for i in range(n_lstm_seq):
        cur_seq = time_seq[i:i+config['l_seq']*config['l_win']]
        for j in range(config['l_seq']):
            lstm_seq[i,j] = cur_seq[config['l_win']*j:config['l_win']*(j+1)]
    
    return rolling_windows, lstm_seq, sample_m, sample_std

test_windows, test_seq, test_sample_m, test_sample_std = slice_rolling_windows_and_sequences(config, result['test'])
if config['n_channel'] == 1:
    test_windows = np.expand_dims(test_windows, -1)
    test_seq = np.expand_dims(test_seq, -1)
else:
    test_windows = test_windows
    test_seq = test_seq
print(test_windows.shape)
print(test_seq.shape)
# Out:
# The given sequence has 583 samples
# (560, 24, 2)
# (512, 3, 24, 2)

# %%
# Evaluate ELBO and LSTM prediction error on the validation set
# evaluate some anomaly detection metrics
def evaluate_vae_anomaly_metrics_for_a_window(test_win):
    feed_dict = {model_vae.original_signal: np.expand_dims(test_win, 0),
                 model_vae.is_code_input: False,
                 model_vae.code_input: np.zeros((1, config['code_size']))}

    # VAE reconstruction error
    recons_win_vae = np.squeeze(sess.run(model_vae.decoded, feed_dict=feed_dict))
    test_vae_recons_error = np.sum(np.square(recons_win_vae - test_win))

    # VAE latent embedding likelihood
    vae_code_mean, vae_code_std = sess.run([model_vae.code_mean, model_vae.code_std_dev], feed_dict=feed_dict)
    test_vae_kl = 0.5 * (np.sum(np.square(vae_code_mean)) + \
                            np.sum(np.square(vae_code_std)) - \
                            np.sum(np.log(np.square(vae_code_std))) - config['code_size'])

    # VAE ELBO loss
    sigma2 = 0.0005
    input_dims = model_vae.input_dims
    sigma_regularisor = input_dims/2. * np.log(sigma2) + input_dims * np.pi
    test_vae_elbo = test_vae_recons_error/sigma2 + test_vae_kl + sigma_regularisor
    return test_vae_recons_error, test_vae_kl, test_vae_elbo

def evaluate_lstm_anomaly_metric_for_a_seq(test_seq):
    feed_dict = {model_vae.original_signal: test_seq,
                 model_vae.is_code_input: False,
                 model_vae.code_input: np.zeros((1, config['code_size']))}
    vae_embedding = np.squeeze(sess.run(model_vae.code_mean, feed_dict=feed_dict))
    #print(vae_embedding.shape)
    lstm_embedding = np.squeeze(lstm_nn_model.predict(np.expand_dims(vae_embedding[:config['l_seq']-1], 0), batch_size=1))
    lstm_embedding_error = np.sum(np.square(vae_embedding[1:] - lstm_embedding))
    
    # LSTM prediction error
    feed_dict_lstm = {model_vae.original_signal: np.zeros((config['l_seq'] - 1, config['l_win'], test_seq.shape[2])),
                      model_vae.is_code_input: True,
                      model_vae.code_input: lstm_embedding}
    recons_win_lstm = np.squeeze(sess.run(model_vae.decoded, feed_dict=feed_dict_lstm))
    lstm_recons_error = np.sum(np.square(recons_win_lstm - np.squeeze(test_seq[1:])))
    return lstm_recons_error, lstm_embedding_error

n_val_vae = data.val_set_vae['data'].shape[0]
n_val_lstm = data.val_set_lstm['data'].shape[0]

val_vae_recons_error = np.zeros(n_val_vae)
val_vae_kl_error = np.zeros(n_val_vae)
val_vae_elbo_loss = np.zeros(n_val_vae)
for i in range(n_val_vae):
    val_vae_recons_error[i], val_vae_kl_error[i], val_vae_elbo_loss[i] = evaluate_vae_anomaly_metrics_for_a_window(data.val_set_vae['data'][i])

val_lstm_recons_error, val_lstm_embedding_error = np.zeros(n_val_lstm), np.zeros(n_val_lstm)
for i in range(n_val_lstm):
    val_lstm_recons_error[i], val_lstm_embedding_error[i] = evaluate_lstm_anomaly_metric_for_a_seq(data.val_set_lstm['data'][i])

# %%
from scipy.stats import norm
def plot_histogram(test_anomaly_metric, n_bins, title, mean=None, std=None, xlim=None, saveplot=False):
    test_anomaly_list = np.squeeze(np.ndarray.flatten(test_anomaly_metric))
    his = plt.hist(test_anomaly_list, bins=n_bins, density=True)
    if mean is None and std is None:
        mean = np.mean(test_anomaly_list)
        std = np.std(test_anomaly_list)
        legend_label = None
    else:
        legend_label = 1
    x_axis = np.arange(mean-5*std, mean+5*std, std/100)
    plt.plot(x_axis, norm.pdf(x_axis,mean,std))
    plt.title(title)
    plt.xlabel('anomaly score value')
    plt.ylabel('probability density')
    if xlim is not None:
        plt.xlim(0, xlim)
    else:
        plt.xlim(0, np.amax(test_anomaly_list))
    if legend_label is None:
        plt.legend(('Fitted Gaussian', 'histogram'))
    else:
        plt.legend(('normal data distribution','test data distribution (contain anomalies)'))
    if saveplot:
        savefig(config['result_dir']+'reconstruction_error_histogram.pdf')
    else:
        plt.show()
    threshold_25 = np.percentile(test_anomaly_list, 25)
    threshold_75 = np.percentile(test_anomaly_list, 75)
    threshold_1 = np.percentile(test_anomaly_list, 99)
    idx_large_error = np.squeeze(np.argwhere(test_anomaly_metric > threshold_1))
#     print(his[0][-20:])
#     print(his[1][-20:])
    print("25% percentile: {}".format(threshold_25))
    print("75% percentile: {}".format(threshold_75))
#     print("Median: {}".format(np.median(test_anomaly_list)))
#     print("Mean: {}".format(np.mean(test_anomaly_list)))
#     print("Std dev: {}".format(np.std(test_anomaly_list)))
    print("These windows scored the top 1% of anomaly metric ({}): \n{}".format(threshold_1, idx_large_error))
    return mean, std

# %%
# Histogram of VAE ELBO loss - validation set
vae_elbo_m, vae_elbo_std = plot_histogram(val_vae_elbo_loss, 100, 
                                          'VAE ELBO error distribution on the val set', 
                                          mean=None, std=None, xlim=None)
# Out:
# 25% percentile: 384.2395177652405
# 75% percentile: 14349.74563236431
# These windows scored the top 1% of anomaly metric (109562.74986948656):
# 55

# %%
# Histogram of LSTM reconstruction error - validation set 
#  --> to decide the anomaly detection threshold
lstm_recons_m, lstm_recons_std = plot_histogram(val_lstm_recons_error, 100,  
                                              'LSTM reconstruction error distribution on the val set', 
                                              mean=None, std=None, xlim=None)
# Out:
# 25% percentile: 9.554637329240332
# 75% percentile: 105.75674469057132
# These windows scored the top 1% of anomaly metric (177.93348253425975):
# 6

# %%
# Evaluate the anomaly metrics on the test windows and sequences
n_test_lstm = test_seq.shape[0]

test_lstm_recons_error, test_lstm_embedding_error = np.zeros(n_test_lstm), np.zeros(n_test_lstm)
for i in range(n_test_lstm):
    test_lstm_recons_error[i], test_lstm_embedding_error[i] = evaluate_lstm_anomaly_metric_for_a_seq(test_seq[i])
print("All windows' reconstruction error is computed.")
print("The total number of windows is {}".format(len(test_lstm_recons_error)))
# Out:
# All windows' reconstruction error is computed.
# The total number of windows is 512

# %%
# Histogram of LSTM reconstruction error - test set 
#  --> to detect anomaly now
_, _ = plot_histogram(test_lstm_recons_error, 100,
                      'LSTM reconstruction error distribution on the test set', 
                      mean=lstm_recons_m, std=lstm_recons_std, xlim=None, saveplot=True)
# Out:
# 25% percentile: 47.01833435544965
# 75% percentile: 149.9247178700956
# These windows scored the top 1% of anomaly metric (664.0321133588433):
# [499 500 501 502 503 511]

# %%
# Produce the ground truth anomaly indices 
# if result['idx_split'][0] == 0:
#     idx_anomaly_test = result['idx_anomaly_test']
# else:
#     idx_anomaly_test = result['idx_anomaly_test'][0]
idx_anomaly_test = result['idx_anomaly_test']    
anomaly_index_lstm = []
test_labels_lstm = np.zeros(n_test_lstm)
for i in range(len(idx_anomaly_test)):
    idx_start = idx_anomaly_test[i]-(config['l_win']*config['l_seq']-1)
    idx_end = idx_anomaly_test[i]+1
    if idx_start < 0:
        idx_start = 0
    if idx_end > n_test_lstm:
        idx_end = n_test_lstm
    anomaly_index_lstm.append(np.arange(idx_start,idx_end))
    test_labels_lstm[idx_start:idx_end] = 1
    
print(test_labels_lstm.shape)
# Out:
# (512,)

# %%
def return_anomaly_idx_by_threshold(test_anomaly_metric, threshold):
    test_list = np.squeeze(np.ndarray.flatten(test_anomaly_metric))
    idx_error = np.squeeze(np.argwhere(test_anomaly_metric > threshold))
    
    if len(idx_error.shape) == 0:
        idx_error = np.expand_dims(idx_error, 0)
    
    return list(idx_error)

# %%
def augment_detected_idx(idx_detected_anomaly, anomaly_index):
    n_anomaly = len(anomaly_index)
    idx_detected_anomaly_extended = list(idx_detected_anomaly)
    for i in range(n_anomaly):
        #print(idx_detected_anomaly)
        for j in idx_detected_anomaly:
            if j in anomaly_index[i]:
                in_original_detection = set(idx_detected_anomaly_extended)
                currect_anomaly_win = set(anomaly_index[i])
                idx_detected_anomaly_extended = idx_detected_anomaly_extended + list(currect_anomaly_win - in_original_detection)
                #print(j)
                break
                
    return list(np.sort(idx_detected_anomaly_extended))

# %%
def count_TP_FP_FN(idx_detected_anomaly, anomaly_index, test_labels):
    n_TP = 0
    n_FP = 0
    n_detection = len(idx_detected_anomaly)
    for i in range(n_detection):
        if test_labels[idx_detected_anomaly[i]] == 1:
            n_TP = n_TP + 1
        else:
            n_FP = n_FP + 1
    
    idx_undetected = list(set(np.arange(len(test_labels)))- set(idx_detected_anomaly))
    n_FN = 0
    for i in idx_undetected:
        if test_labels[i] == 1:
            n_FN = n_FN + 1
    
    return n_TP, n_FP, n_FN

# %%
def compute_precision_and_recall(idx_detected_anomaly, anomaly_index, test_labels):
    # compute true positive
    n_TP, n_FP, n_FN = count_TP_FP_FN(idx_detected_anomaly, anomaly_index, test_labels)
    
    if n_TP + n_FP == 0:
        precision = 1
    else:
        precision = n_TP / (n_TP + n_FP)
    recall = n_TP / (n_TP + n_FN)
    if precision + recall == 0:
        F1 = 0
    else:
        F1 = 2* (precision * recall)/(precision + recall)
    
    return precision, recall, F1, n_TP, n_FP, n_FN

# %%
n_threshold = 200
precision = np.zeros(n_threshold)
recall = np.zeros(n_threshold)
F1 = np.zeros(n_threshold)
precision_aug = np.zeros(n_threshold)
recall_aug = np.zeros(n_threshold)
F1_aug = np.zeros(n_threshold)
i = 0
threshold_list = np.linspace(np.amin(test_lstm_recons_error), np.amax(test_lstm_recons_error), n_threshold, endpoint=True)
threshold_list = np.flip(threshold_list)
for threshold in threshold_list:
    #print(threshold_list[i])
    idx_detection_lstm = return_anomaly_idx_by_threshold(test_lstm_recons_error, threshold)
    precision[i], recall[i], F1[i], _, _, _ = compute_precision_and_recall(idx_detection_lstm, 
                                                                           anomaly_index_lstm, 
                                                                           test_labels_lstm)
    # augment the detection using the ground truth labels
    # a method to discount the factor one anomaly appears in multiple consecutive windows
    # introduced in "Unsupervised anomaly detection via variational auto-encoder for seasonal kpis in web applications"
    idx_detection_lstm_augmented = augment_detected_idx(idx_detection_lstm, anomaly_index_lstm)
    precision_aug[i], recall_aug[i], F1_aug[i], _, _, _ = compute_precision_and_recall(idx_detection_lstm_augmented, 
                                                                                       anomaly_index_lstm, 
                                                                                       test_labels_lstm)
    i = i + 1
    #print(precision, recall, F1)

# %%
print("Best F1 score is {}".format(np.amax(F1)))
idx_best_threshold = np.squeeze(np.argwhere(F1 == np.amax(F1)))
print("Best threshold is {}".format(threshold_list[idx_best_threshold]))
print("At this threshold, precision is {}, recall is {}".format(precision[idx_best_threshold], recall[idx_best_threshold]))
average_precision = np.sum(precision[1:] * (recall[1:] - recall[:-1]))
print("Average precision is {}".format(average_precision))

print("\nAugmented detection:")
print("Best F1 score is {}".format(np.amax(F1_aug)))
idx_best_threshold = np.squeeze(np.argwhere(F1_aug == np.amax(F1_aug)))
print("Best threshold is {}".format(threshold_list[idx_best_threshold]))
print("At this threshold, precision is {}, recall is {}".format(precision_aug[idx_best_threshold], 
                                                                recall_aug[idx_best_threshold]))

average_precision_aug = np.sum(precision_aug[1:] * (recall_aug[1:] - recall_aug[:-1]))
print("Average precision is {}".format(average_precision_aug))
# Out:
# Best F1 score is 0.3066666666666667
# Best threshold is 49.96726871875593
# At this threshold, precision is 0.18253968253968253, recall is 0.9583333333333334
# Average precision is 0.16440956265934065
#
# Augmented detection:
# Best F1 score is 0.7912087912087912
# Best threshold is 200.64673440106
# At this threshold, precision is 0.6545454545454545, recall is 1.0
# Average precision is 0.6545454545454545

# %%
# Now select a threshold
print(idx_best_threshold.ndim)
if idx_best_threshold.ndim > 0:
    threshold = threshold_list[idx_best_threshold[0]]
else:
    threshold = threshold_list[idx_best_threshold]

print("Threshold is {}".format(threshold))
idx_detection = return_anomaly_idx_by_threshold(test_lstm_recons_error, threshold)
idx_detection_augmented = augment_detected_idx(idx_detection, anomaly_index_lstm)
precision, recall, F1, n_TP, n_FP, n_FN = compute_precision_and_recall(idx_detection_augmented, 
                                                                       anomaly_index_lstm, 
                                                                       test_labels_lstm)
print("\nPR evaluation using augmented detection:")
print("Precision: {}".format(precision))
print("Recall: {}".format(recall))
print("F1: {}".format(F1))
print("TP: {}".format(n_TP))
print("FP: {}".format(n_FP))
print("FN: {}".format(n_FN))
# Out:
# 0
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-21-96f346ffd559> in <module>
#       2 print(idx_best_threshold.ndim)
#       3 if isinstance(idx_best_threshold,(list,np.ndarray)):
# ----> 4     threshold = threshold_list[idx_best_threshold[0]]
#       5 else:
#       6     threshold = threshold_list[idx_best_threshold]
#
# IndexError: too many indices for array: array is 0-dimensional, but 1 were indexed

# %%
def slice_detected_indices_into_seq(idx_detection, interval):
    detected_seq = []
    i = 0
    while i < len(idx_detection):
        if i == 0:
            cur_seq = [idx_detection[i]]
            i = i + 1
        else:
            if idx_detection[i] - idx_detection[i-1] > interval:
                detected_seq.append(cur_seq)
                cur_seq = [idx_detection[i]]
            else:
                cur_seq.append(idx_detection[i])
                if i == len(idx_detection) - 1:
                    detected_seq.append(cur_seq)
            i = i + 1
    
    print("Detected {} sequences".format(len(detected_seq)))
    return detected_seq

# %%
def plot_detected_anomalies(idx_detection, interval, dataset, result, detection_method, augmented_flag=1, y_scale=5, y_lim=None):
    detected_seq = slice_detected_indices_into_seq(idx_detection, interval=interval)
    t_test = result['t_test']
    test = result['test']
    idx_anomaly_test = result['idx_anomaly_test']
        
    # plot detected sequences
    fig, axs = plt.subplots(1, 1, figsize=(18, 5), edgecolor='k')
    fig.subplots_adjust(hspace=.4, wspace=.4)
    axs.plot(t_test, test)
    for j in range(len(idx_anomaly_test)):
        if j == 0:
            axs.plot(idx_anomaly_test[j] * np.ones(20), np.linspace(-y_scale, y_scale, 20), 'r--', label='true anomalies')
        else:
            axs.plot(idx_anomaly_test[j] * np.ones(20), np.linspace(-y_scale, y_scale, 20), 'r--')
        
    for i in range(len(detected_seq)):
        for j in detected_seq[i]:
            if j == detected_seq[0][0]:
                axs.plot((j+interval*2) * np.ones(20), np.linspace(-y_scale, -0.8*y_scale, 20), 'g-', label='detected anomalies')
            else:
                axs.plot((j+interval*2) * np.ones(20), np.linspace(-y_scale, -0.8*y_scale, 20), 'g-')
    
    for j in range(len(idx_anomaly_test)):
        axs.plot(idx_anomaly_test[j] * np.ones(20), np.linspace(-y_scale, y_scale, 20), 'r--')

    for i in range(len(detected_seq)):
        interval_x = np.asarray([detected_seq[i][0], detected_seq[i][-1]+interval*2])
        interval_y = np.asarray([y_scale,y_scale])
        if i == 0:
            axs.fill_between(interval_x, interval_y, alpha=0.2, color='y', label='detected anomaly windows')
        else:
            axs.fill_between(interval_x, interval_y, alpha=0.2, color='y')
        interval_y = np.asarray([-y_scale,-y_scale])
        axs.fill_between(interval_x, interval_y, alpha=0.2, color='y')
    axs.grid(True)
    axs.set_xlim(0, len(t_test))
    if y_lim is None:
        axs.set_ylim(-y_scale, y_scale)
    else:
        axs.set_ylim(-y_scale, y_lim)
    axs.set_xlabel("timestamp (every {})".format(result['t_unit']))
    axs.set_ylabel("normalised readings")
    #axs.set_title("{} dataset test sequence\n(normalised by train mean {:.4f} and std {:.4f})\n Detection method: {}".format(dataset, 
    #                                                                                    result['train_m'], 
    #                                                                                    result['train_std'],
    #                                                                                    detection_method))
    axs.set_title("{} dataset test sequence\n Detection method: {}".format(dataset, detection_method))
    axs.legend()
    savefig(config['result_dir']+'detected_anomalies_{}_aug_{}.pdf'.format(detection_method, augmented_flag))

# %%
plot_detected_anomalies(idx_detection_augmented, 
                        interval=config['l_win']*config['l_seq']/2, 
                        dataset=dataset, 
                        result=result, 
                        detection_method='lstm reconstruction error',
                        augmented_flag=1,
                        y_scale=5,
                        y_lim=5)
