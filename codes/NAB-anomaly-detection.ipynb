# %%
from google.colab import drive
drive.mount('/content/drive')
global GIT_DIR
GIT_DIR='/content/drive/My\ Drive/afeka/y2/sem1/dl/code/LSTM-VAE/VAE-LSTM-for-anomaly-detection'
# %cd $GIT_DIR
# !ls

# %%
# %cd $GIT_DIR/codes/

# %%
import warnings

def fxn():
    warnings.warn("deprecated", DeprecationWarning)

with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    fxn()

# %%
# %tensorflow_version 1.x

# %%
import tensorflow as tf
import tensorflow_probability as tfp
import numpy as np
import matplotlib.pylab as plt
from matplotlib.pyplot import plot, ion, show, savefig, cla, figure
import random
import time

# %%
import os
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"   # see issue #152
os.environ["CUDA_VISIBLE_DEVICES"]="0"

import tensorflow as tf
from data_loader import DataGenerator
from models import VAEmodel, lstmKerasModel
from trainers import vaeTrainer

from utils import process_config, create_dirs, get_args

# %%
from tensorflow.python.client import device_lib

def get_available_gpus():
    local_device_protos = device_lib.list_local_devices()
    return [x.name for x in local_device_protos if x.device_type == 'GPU']

print(get_available_gpus())
# Out:
# []

# %%
# load VAE model
config = process_config('NAB_config.json')
# create the experiments dirs
create_dirs([config['result_dir'], config['checkpoint_dir']])
# create tensorflow session
sess = tf.Session(config=tf.ConfigProto(log_device_placement=True))
# create your data generator
data = DataGenerator(config)
# create a CNN model
model_vae = VAEmodel(config)
# create a CNN model
trainer_vae = vaeTrainer(sess, model_vae, data, config)
model_vae.load(sess)

# here you train your model
if config['TRAIN_VAE']:
    if config['num_epochs_vae'] > 0:
        trainer_vae.train()
# Out:
#  23.8272, sigma_regularisor: -331.5723, code_std_dev: [0.11399798 0.7594675  0.06232158 0.10778189 0.24964657 0.10709594]
# Loss on training and val sets:
# train: 3090.4635, val: 3718.2372
# Current sigma2: 0.0100000
# Already trained for 1.2404988765716554 min; Remaining 19.4344823996226 min.
# Saving model...
# Model saved.
# 3/49, test loss: -elbo: 2490.8254, recons_loss_weighted: 4691.5938, recons_loss_ls: 93.8319, KL_loss: 24.2114, sigma_regularisor: -331.5723, code_std_dev: [0.18979318 1.0501854  0.0700103  0.06856063 0.24439456 0.2411136 ]
# Loss on training and val sets:
# train: 2993.2264, val: 3538.6744
# Current sigma2: 0.0100000
# Already trained for 1.6533166646957398 min; Remaining 19.013141644001006 min.
# Saving model...
# Model saved.
# 4/49, test loss: -elbo: 2222.8750, recons_loss_weighted: 4130.9932, recons_loss_ls: 82.6199, KL_loss: 36.5614, sigma_regularisor: -331.5723, code_std_dev: [0.19676395 1.2485753  0.06859786 0.10762829 0.3631629  0.17481577]
# Loss on training and val sets:
# train: 2831.9798, val: 3141.0337
# Current sigma2: 0.0100000
# Already trained for 2.062940839926402 min; Remaining 18.566467559337617 min.
# Saving model...
# Model saved.
# 5/49, test loss: -elbo: 2110.7058, recons_loss_weighted: 3903.1179, recons_loss_ls: 78.0624, KL_loss: 38.3300, sigma_regularisor: -331.5723, code_std_dev: [0.08437968 0.9325493  0.02086118 0.10947999 0.26287308 0.2850435 ]
# Loss on training and val sets:
# train: 2618.2277, val: 2516.2482
# Current sigma2: 0.0100000
# Already trained for 2.4647603114446004 min; Remaining 18.074908950593734 min.
# Saving model...
# Model saved.
# 6/49, test loss: -elbo: 1955.3636, recons_loss_weighted: 3594.8896, recons_loss_ls: 71.8978, KL_loss: 37.1016, sigma_regularisor: -331.5723, code_std_dev: [0.09060899 0.62266326 0.19561103 0.12183169 0.07682629 0.17365074]
# Loss on training and val sets:
# train: 2481.7598, val: 2739.0254
# Current sigma2: 0.0100000
# Already trained for 2.8614105304082234 min; Remaining 17.5772361153648 min.
# Saving model...
# Model saved.
# 7/49, test loss: -elbo: 1925.0942, recons_loss_weighted: 3534.7979, recons_loss_ls: 70.6960, KL_loss: 36.8782, sigma_regularisor: -331.5723, code_std_dev: [0.1033291  0.3223224  0.09930653 0.13589236 0.09750526 0.1082121 ]
# Loss on training and val sets:
# train: 2340.1209, val: 2652.5210
# Current sigma2: 0.0100000
# Already trained for 3.253605631987254 min; Remaining 17.081429567933082 min.
# Saving model...
# Model saved.
# 8/49, test loss: -elbo: 1883.4640, recons_loss_weighted: 3445.2322, recons_loss_ls: 68.9046, KL_loss: 40.0309, sigma_regularisor: -331.5723, code_std_dev: [0.05155823 0.38820893 0.06982239 0.06469593 0.06408885 0.07432281]
# Loss on training and val sets:
# train: 2268.0515, val: 2336.8281
# Current sigma2: 0.0100000
# Already trained for 3.650783201058706 min; Remaining 16.631345693711882 min.
# Saving model...
# Model saved.
# 9/49, test loss: -elbo: 1834.1300, recons_loss_weighted: 3346.7881, recons_loss_ls: 66.9358, KL_loss: 39.9188, sigma_regularisor: -331.5723, code_std_dev: [0.0468607  0.3261976  0.12327134 0.06710753 0.07774605 0.07793035]
# Loss on training and val sets:
# train: 2189.5374, val: 2245.4854
# Current sigma2: 0.0100000
# Already trained for 4.05582484404246 min; Remaining 16.22329937616984 min.
# Saving model...
# Model saved.
# 10/49, test loss: -elbo: 1803.1472, recons_loss_weighted: 3284.3755, recons_loss_ls: 65.6875, KL_loss: 40.1423, sigma_regularisor: -331.5723, code_std_dev: [0.04156241 0.20740664 0.16114758 0.06319895 0.1161316  0.0620496 ]
# Loss on training and val sets:
# train: 2077.2544, val: 2396.7748
# Current sigma2: 0.0100000
# Already trained for 4.4556464672088625 min; Remaining 15.797292020104148 min.
# Saving model...
# Model saved.
# 11/49, test loss: -elbo: 1778.0730, recons_loss_weighted: 3231.9089, recons_loss_ls: 64.6382, KL_loss: 41.3015, sigma_regularisor: -331.5723, code_std_dev: [0.15312491 0.24929233 0.16850686 0.06180238 0.10792971 0.07047942]
# Loss on training and val sets:
# train: 2023.2070, val: 2415.9875
# Current sigma2: 0.0100000
# Already trained for 4.85646424293518 min; Remaining 15.378803435961405 min.
# Saving model...
# Model saved.
# 12/49, test loss: -elbo: 1757.9171, recons_loss_weighted: 3187.6531, recons_loss_ls: 63.7531, KL_loss: 43.2736, sigma_regularisor: -331.5723, code_std_dev: [0.13173102 0.1564593  0.13945907 0.06821066 0.0972849  0.0666177 ]
# Loss on training and val sets:
# train: 1977.5307, val: 2136.9438
# Current sigma2: 0.0100000
# Already trained for 5.252097618579865 min; Remaining 14.948277837496537 min.
# Saving model...
# Model saved.
# 13/49, test loss: -elbo: 1773.9929, recons_loss_weighted: 3214.6101, recons_loss_ls: 64.2922, KL_loss: 45.8708, sigma_regularisor: -331.5723, code_std_dev: [0.10861344 0.10318221 0.15451872 0.08103777 0.1613953  0.0609521 ]
# Loss on training and val sets:
# train: 1862.9103, val: 2061.1936
# Current sigma2: 0.0100000
# Already trained for 5.654003429412842 min; Remaining 14.538865961347309 min.
# Saving model...
# Model saved.
# 14/49, test loss: -elbo: 1695.5170, recons_loss_weighted: 3052.8801, recons_loss_ls: 61.0576, KL_loss: 48.2599, sigma_regularisor: -331.5723, code_std_dev: [0.07461379 0.20369455 0.18904023 0.04058607 0.07913666 0.07260685]
# Loss on training and val sets:
# train: 1824.7181, val: 2070.3521
# Current sigma2: 0.0100000
# Already trained for 6.056330259641012 min; Remaining 14.131437272495695 min.
# Saving model...
# Model saved.
# 15/49, test loss: -elbo: 1654.6842, recons_loss_weighted: 2971.9778, recons_loss_ls: 59.4396, KL_loss: 47.8783, sigma_regularisor: -331.5723, code_std_dev: [0.1271272  0.25286627 0.13100407 0.08499232 0.07620945 0.09277645]
# Loss on training and val sets:
# train: 1774.9047, val: 2088.3817
# Current sigma2: 0.0100000
# Already trained for 6.471869162718455 min; Remaining 13.752721970776717 min.
# Saving model...
# Model saved.
# 16/49, test loss: -elbo: 1607.0829, recons_loss_weighted: 2882.0813, recons_loss_ls: 57.6416, KL_loss: 45.2253, sigma_regularisor: -331.5723, code_std_dev: [0.08539384 0.17998168 0.19267963 0.07049126 0.08077856 0.08631817]
# Loss on training and val sets:
# train: 1721.7052, val: 1834.8146
# Current sigma2: 0.0100000
# Already trained for 6.8767948587735495 min; Remaining 13.34907237291336 min.
# Saving model...
# Model saved.
# 17/49, test loss: -elbo: 1593.0417, recons_loss_weighted: 2850.0032, recons_loss_ls: 57.0001, KL_loss: 47.2231, sigma_regularisor: -331.5723, code_std_dev: [0.06465054 0.17561823 0.10623794 0.07638081 0.09494101 0.09181234]
# Loss on training and val sets:
# train: 1659.2364, val: 2141.3967
# Current sigma2: 0.0100000
# Already trained for 7.284431179364522 min; Remaining 12.950099874425819 min.
# Saving model...
# Model saved.
# 18/49, test loss: -elbo: 1564.9561, recons_loss_weighted: 2797.7529, recons_loss_ls: 55.9551, KL_loss: 45.2624, sigma_regularisor: -331.5723, code_std_dev: [0.14392067 0.2695231  0.16371761 0.08831672 0.10339145 0.09658214]
# Loss on training and val sets:
# train: 1611.8789, val: 2161.7960
# Current sigma2: 0.0100000
# Already trained for 7.69504298766454 min; Remaining 12.55507013776846 min.
# Saving model...
# Model saved.
# 19/49, test loss: -elbo: 1570.2454, recons_loss_weighted: 2808.6577, recons_loss_ls: 56.1732, KL_loss: 45.0993, sigma_regularisor: -331.5723, code_std_dev: [0.09795001 0.18053687 0.13913092 0.07897669 0.1179604  0.09767742]
# Loss on training and val sets:
# train: 1584.0888, val: 2058.5061
# Current sigma2: 0.0100000
# Already trained for 8.092280677954356 min; Remaining 12.138421016931535 min.
# Saving model...
# Model saved.
# 20/49, test loss: -elbo: 1522.7113, recons_loss_weighted: 2709.7175, recons_loss_ls: 54.1944, KL_loss: 47.0356, sigma_regularisor: -331.5723, code_std_dev: [0.12854983 0.10778298 0.14988697 0.05921656 0.07091568 0.08920051]
# Loss on training and val sets:
# train: 1539.4509, val: 1947.3519
# Current sigma2: 0.0100000
# Already trained for 8.496525681018829 min; Remaining 11.733297369026001 min.
# Saving model...
# Model saved.
# 21/49, test loss: -elbo: 1516.8691, recons_loss_weighted: 2704.7815, recons_loss_ls: 54.0956, KL_loss: 43.6613, sigma_regularisor: -331.5723, code_std_dev: [0.12394103 0.16687869 0.16768219 0.08020416 0.08910283 0.10570177]
# Loss on training and val sets:
# train: 1514.7122, val: 1987.3857
# Current sigma2: 0.0100000
# Already trained for 8.914029026031494 min; Remaining 11.34512785131281 min.
# Saving model...
# Model saved.
# 22/49, test loss: -elbo: 1498.8330, recons_loss_weighted: 2666.6411, recons_loss_ls: 53.3328, KL_loss: 44.6953, sigma_regularisor: -331.5723, code_std_dev: [0.08494957 0.17662    0.10324468 0.08231676 0.11786819 0.12845391]
# Loss on training and val sets:
# train: 1492.9895, val: 1864.1995
# Current sigma2: 0.0100000
# Already trained for 9.335126574834188 min; Remaining 10.958626848718394 min.
# Saving model...
# Model saved.
# 23/49, test loss: -elbo: 1483.0247, recons_loss_weighted: 2636.0566, recons_loss_ls: 52.7211, KL_loss: 44.1792, sigma_regularisor: -331.5723, code_std_dev: [0.08771542 0.17464158 0.09649394 0.05239474 0.09809654 0.11726998]
# Loss on training and val sets:
# train: 1473.9532, val: 1745.5305
# Current sigma2: 0.0100000
# Already trained for 9.74918251434962 min; Remaining 10.561614390545422 min.
# Saving model...
# Model saved.
# 24/49, test loss: -elbo: 1471.8091, recons_loss_weighted: 2613.9221, recons_loss_ls: 52.2784, KL_loss: 44.0311, sigma_regularisor: -331.5723, code_std_dev: [0.14983821 0.17724065 0.14416403 0.06085024 0.10348877 0.1252526 ]
# Loss on training and val sets:
# train: 1446.1136, val: 1724.5734
# Current sigma2: 0.0100000
# Already trained for 10.161731012662251 min; Remaining 10.161731012662251 min.
# Saving model...
# Model saved.
# 25/49, test loss: -elbo: 1464.1853, recons_loss_weighted: 2599.2117, recons_loss_ls: 51.9842, KL_loss: 43.7624, sigma_regularisor: -331.5723, code_std_dev: [0.08411542 0.18617186 0.09859268 0.04939859 0.09796822 0.1184132 ]
# Loss on training and val sets:
# train: 1430.6022, val: 1571.0942
# Current sigma2: 0.0100000
# Already trained for 10.579092872142791 min; Remaining 9.765316497362578 min.
# Saving model...
# Model saved.
# 26/49, test loss: -elbo: 1444.1415, recons_loss_weighted: 2560.7161, recons_loss_ls: 51.2143, KL_loss: 42.9664, sigma_regularisor: -331.5723, code_std_dev: [0.10338304 0.15003726 0.1413298  0.0746612  0.11769887 0.10826955]
# Loss on training and val sets:
# train: 1397.5306, val: 1588.3599
# Current sigma2: 0.0100000
# Already trained for 10.978371079762777 min; Remaining 9.351945734612737 min.
# Saving model...
# Model saved.
# 27/49, test loss: -elbo: 1432.3423, recons_loss_weighted: 2537.6062, recons_loss_ls: 50.7521, KL_loss: 42.7222, sigma_regularisor: -331.5723, code_std_dev: [0.07308016 0.17976041 0.166463   0.07615749 0.115577   0.09423778]
# Loss on training and val sets:
# train: 1371.2513, val: 1790.1710
# Current sigma2: 0.0100000
# Already trained for 11.384458001454671 min; Remaining 8.94493128685724 min.
# Saving model...
# Model saved.
# 28/49, test loss: -elbo: 1416.7347, recons_loss_weighted: 2503.9248, recons_loss_ls: 50.0785, KL_loss: 43.9552, sigma_regularisor: -331.5723, code_std_dev: [0.04808033 0.18472627 0.08530316 0.04615372 0.09122304 0.07363951]
# Loss on training and val sets:
# train: 1378.1850, val: 1799.8260
# Current sigma2: 0.0100000
# Already trained for 11.800542239348093 min; Remaining 8.54522024228655 min.
# Saving model...
# Model saved.
# 29/49, test loss: -elbo: 1422.4545, recons_loss_weighted: 2516.6228, recons_loss_ls: 50.3325, KL_loss: 43.3260, sigma_regularisor: -331.5723, code_std_dev: [0.05602188 0.12945865 0.12097871 0.05731292 0.11364625 0.09063043]
# Loss on training and val sets:
# train: 1357.2536, val: 1744.1138
# Current sigma2: 0.0100000
# Already trained for 12.223804001013438 min; Remaining 8.14920266734229 min.
# Saving model...
# Model saved.
# 30/49, test loss: -elbo: 1418.9408, recons_loss_weighted: 2508.1899, recons_loss_ls: 50.1638, KL_loss: 44.0287, sigma_regularisor: -331.5723, code_std_dev: [0.06797945 0.16846947 0.12956508 0.06341447 0.07429678 0.06730703]
# Loss on training and val sets:
# train: 1342.0701, val: 1652.7235
# Current sigma2: 0.0100000
# Already trained for 12.636149088541666 min; Remaining 7.744736538138441 min.
# Saving model...
# Model saved.
# 31/49, test loss: -elbo: 1421.1079, recons_loss_weighted: 2514.7742, recons_loss_ls: 50.2955, KL_loss: 42.9039, sigma_regularisor: -331.5723, code_std_dev: [0.100743   0.11439309 0.1011261  0.05020482 0.12388485 0.08375505]
# Loss on training and val sets:
# train: 1331.7504, val: 1720.9574
# Current sigma2: 0.0100000
# Already trained for 13.038171883424123 min; Remaining 7.33397168442607 min.
# Saving model...
# Model saved.
# 32/49, test loss: -elbo: 1411.7401, recons_loss_weighted: 2495.1426, recons_loss_ls: 49.9029, KL_loss: 43.3516, sigma_regularisor: -331.5723, code_std_dev: [0.0716427  0.19883797 0.10273746 0.05508777 0.13230227 0.08423858]
# Loss on training and val sets:
# train: 1309.2519, val: 1643.3838
# Current sigma2: 0.0100000
# Already trained for 13.458449121316274 min; Remaining 6.933140456435656 min.
# Saving model...
# Model saved.
# 33/49, test loss: -elbo: 1414.9476, recons_loss_weighted: 2501.4050, recons_loss_ls: 50.0281, KL_loss: 43.4281, sigma_regularisor: -331.5723, code_std_dev: [0.06941663 0.16529675 0.11740737 0.05203128 0.09568051 0.06778069]
# Loss on training and val sets:
# train: 1307.8866, val: 1755.6993
# Current sigma2: 0.0100000
# Already trained for 13.88092507123947 min; Remaining 6.532200033524457 min.
# Saving model...
# Model saved.
# 34/49, test loss: -elbo: 1398.5283, recons_loss_weighted: 2469.1489, recons_loss_ls: 49.3830, KL_loss: 43.1368, sigma_regularisor: -331.5723, code_std_dev: [0.097491   0.14989139 0.12082805 0.05439324 0.11344565 0.11232011]
# Loss on training and val sets:
# train: 1295.5984, val: 1420.0718
# Current sigma2: 0.0100000
# Already trained for 14.30923860470454 min; Remaining 6.132530830587659 min.
# Saving model...
# Model saved.
# 35/49, test loss: -elbo: 1386.7800, recons_loss_weighted: 2447.5676, recons_loss_ls: 48.9514, KL_loss: 42.1793, sigma_regularisor: -331.5723, code_std_dev: [0.10500194 0.15573968 0.11463863 0.08293115 0.1173598  0.10561448]
# Loss on training and val sets:
# train: 1274.9886, val: 1533.0408
# Current sigma2: 0.0100000
# Already trained for 14.722993644078572 min; Remaining 5.725608639363889 min.
# Saving model...
# Model saved.
# 36/49, test loss: -elbo: 1384.4537, recons_loss_weighted: 2440.9453, recons_loss_ls: 48.8189, KL_loss: 43.1639, sigma_regularisor: -331.5723, code_std_dev: [0.12242595 0.17964584 0.135569   0.06873785 0.09653587 0.12197829]
# Loss on training and val sets:
# train: 1280.3887, val: 1775.9650
# Current sigma2: 0.0100000
# Already trained for 15.14313980738322 min; Remaining 5.320562635026536 min.
# Saving model...
# Model saved.
# 37/49, test loss: -elbo: 1382.9333, recons_loss_weighted: 2439.7178, recons_loss_ls: 48.7944, KL_loss: 42.2574, sigma_regularisor: -331.5723, code_std_dev: [0.08873864 0.193336   0.09161142 0.06157304 0.0873836  0.12643372]
# Loss on training and val sets:
# train: 1265.7539, val: 1586.0419
# Current sigma2: 0.0100000
# Already trained for 15.56401710510254 min; Remaining 4.914952770032381 min.
# Saving model...
# Model saved.
# 38/49, test loss: -elbo: 1361.6976, recons_loss_weighted: 2396.0918, recons_loss_ls: 47.9218, KL_loss: 42.8346, sigma_regularisor: -331.5723, code_std_dev: [0.10752507 0.17192285 0.09931002 0.05638222 0.09167366 0.09147324]
# Loss on training and val sets:
# train: 1247.1673, val: 1633.3054
# Current sigma2: 0.0100000
# Already trained for 15.987800029913585 min; Remaining 4.509379495616653 min.
# Saving model...
# Model saved.
# 39/49, test loss: -elbo: 1367.5093, recons_loss_weighted: 2406.6018, recons_loss_ls: 48.1320, KL_loss: 43.3914, sigma_regularisor: -331.5723, code_std_dev: [0.06089715 0.17521216 0.09233017 0.06558333 0.12083992 0.090023  ]
# Loss on training and val sets:
# train: 1234.9705, val: 1497.2859
# Current sigma2: 0.0100000
# Already trained for 16.397066525618236 min; Remaining 4.099266631404559 min.
# Saving model...
# Model saved.
# 40/49, test loss: -elbo: 1361.9113, recons_loss_weighted: 2396.5916, recons_loss_ls: 47.9318, KL_loss: 42.7985, sigma_regularisor: -331.5723, code_std_dev: [0.10491535 0.15789606 0.09370449 0.05823627 0.09958949 0.08678103]
# Loss on training and val sets:
# train: 1230.2592, val: 1512.3202
# Current sigma2: 0.0100000
# Already trained for 16.814070276419322 min; Remaining 3.6908934753115585 min.
# Saving model...
# Model saved.
# 41/49, test loss: -elbo: 1361.6982, recons_loss_weighted: 2395.3723, recons_loss_ls: 47.9074, KL_loss: 43.1951, sigma_regularisor: -331.5723, code_std_dev: [0.07022103 0.15258867 0.12449426 0.06280658 0.09385169 0.06902111]
# Loss on training and val sets:
# train: 1205.8594, val: 1486.7768
# Current sigma2: 0.0100000
# Already trained for 17.229406889279684 min; Remaining 3.2817917884342256 min.
# Saving model...
# Model saved.
# 42/49, test loss: -elbo: 1362.9899, recons_loss_weighted: 2399.5925, recons_loss_ls: 47.9919, KL_loss: 42.3766, sigma_regularisor: -331.5723, code_std_dev: [0.08426793 0.17880304 0.09130125 0.05896236 0.11329081 0.10405549]
# Loss on training and val sets:
# train: 1203.4660, val: 1590.2197
# Current sigma2: 0.0100000
# Already trained for 17.634785517056784 min; Remaining 2.8707790376604065 min.
# Saving model...
# Model saved.
# 43/49, test loss: -elbo: 1363.7593, recons_loss_weighted: 2398.6089, recons_loss_ls: 47.9722, KL_loss: 43.6377, sigma_regularisor: -331.5723, code_std_dev: [0.1065053  0.09274834 0.11816966 0.06941167 0.09234441 0.08410136]
# Loss on training and val sets:
# train: 1191.5006, val: 1575.2776
# Current sigma2: 0.0100000
# Already trained for 18.037927321592967 min; Remaining 2.4597173620354047 min.
# Saving model...
# Model saved.
# 44/49, test loss: -elbo: 1350.3121, recons_loss_weighted: 2375.9893, recons_loss_ls: 47.5198, KL_loss: 41.5004, sigma_regularisor: -331.5723, code_std_dev: [0.10181643 0.12844922 0.13449892 0.07221662 0.12560947 0.10002246]
# Loss on training and val sets:
# train: 1193.7638, val: 1430.4659
# Current sigma2: 0.0100000
# Already trained for 18.44746098915736 min; Remaining 2.049717887684151 min.
# Saving model...
# Model saved.
# 45/49, test loss: -elbo: 1349.3062, recons_loss_weighted: 2371.2488, recons_loss_ls: 47.4250, KL_loss: 42.8648, sigma_regularisor: -331.5723, code_std_dev: [0.05068197 0.13823035 0.08641313 0.04743408 0.10493765 0.07368391]
# Loss on training and val sets:
# train: 1185.8502, val: 1529.8781
# Current sigma2: 0.0100000
# Already trained for 18.850624374548595 min; Remaining 1.639184728221617 min.
# Saving model...
# Model saved.
# 46/49, test loss: -elbo: 1341.6141, recons_loss_weighted: 2356.3440, recons_loss_ls: 47.1269, KL_loss: 42.6252, sigma_regularisor: -331.5723, code_std_dev: [0.06045131 0.19480403 0.10780787 0.06209172 0.0859432  0.08834554]
# Loss on training and val sets:
# train: 1176.6313, val: 1601.8337
# Current sigma2: 0.0100000
# Already trained for 19.26135956843694 min; Remaining 1.2294484830917194 min.
# Saving model...
# Model saved.
# 47/49, test loss: -elbo: 1343.0448, recons_loss_weighted: 2359.7476, recons_loss_ls: 47.1950, KL_loss: 42.3539, sigma_regularisor: -331.5723, code_std_dev: [0.06597381 0.17327921 0.12144162 0.06694487 0.1026844  0.0837681 ]
# Loss on training and val sets:
# train: 1170.2306, val: 1370.1669
# Current sigma2: 0.0100000
# Already trained for 19.668532903989156 min; Remaining 0.8195222043328816 min.
# Saving model...
# Model saved.
# 48/49, test loss: -elbo: 1352.4766, recons_loss_weighted: 2379.0361, recons_loss_ls: 47.5807, KL_loss: 42.1413, sigma_regularisor: -331.5723, code_std_dev: [0.06940793 0.15071736 0.10665562 0.07165625 0.12081544 0.10927317]
# Loss on training and val sets:
# train: 1155.1264, val: 1539.4700
# Current sigma2: 0.0100000
# Already trained for 20.07508402268092 min; Remaining 0.40969559229961056 min.
# Saving model...
# Model saved.
# 49/49, test loss: -elbo: 1327.3899, recons_loss_weighted: 2328.9360, recons_loss_ls: 46.5787, KL_loss: 42.1047, sigma_regularisor: -331.5723, code_std_dev: [0.0959625  0.12498482 0.13318059 0.0748052  0.13062088 0.09134483]
# Loss on training and val sets:
# train: 1156.6672, val: 1384.2853
# Current sigma2: 0.0100000
# Already trained for 20.503691959381104 min; Remaining 0.0 min.

# %%
# load LSTM model
lstm_model = lstmKerasModel(data)
lstm_model.produce_embeddings(config, model_vae, data, sess)
lstm_nn_model = lstm_model.create_lstm_model(config)
lstm_nn_model.summary()   # Display the model's architecture

# checkpoint path
checkpoint_path = config['checkpoint_dir_lstm'] + "cp.ckpt"
checkpoint_dir = os.path.dirname(checkpoint_path)
# Create a callback that saves the model's weights
cp_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path,
                                                 save_weights_only=True,
                                                 verbose=1)
# load weights if possible
lstm_model.load_model(lstm_nn_model, config, checkpoint_path)
# start training
if config['TRAIN_LSTM']:
    if config['num_epochs_lstm'] > 0:
        lstm_model.train(config, lstm_nn_model, cp_callback)

    # make a prediction on the test set using the trained model
    lstm_embedding = lstm_nn_model.predict(lstm_model.x_test, batch_size=config['batch_size_lstm'])
    print(lstm_embedding.shape)

    # visualise the first 10 test sequences
    for i in range(10):
        lstm_model.plot_lstm_embedding_prediction(i, config, model_vae, sess, data, lstm_embedding)
# Out:
# tch-32/PX4-QUAD-HITL-6-channels-trim-24-6-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 681/681 [==============================] - 0s 530us/sample - loss: 6.6448 - mean_squared_error: 6.6448 - val_loss: 6.3849 - val_mean_squared_error: 6.3849
# Epoch 56/100
# 672/681 [============================>.] - ETA: 0s - loss: 6.5879 - mean_squared_error: 6.5879
# Epoch 00056: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-6-channels-trim-24-6-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 681/681 [==============================] - 0s 558us/sample - loss: 6.5975 - mean_squared_error: 6.5975 - val_loss: 6.3366 - val_mean_squared_error: 6.3366
# Epoch 57/100
# 672/681 [============================>.] - ETA: 0s - loss: 6.5444 - mean_squared_error: 6.5444
# Epoch 00057: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-6-channels-trim-24-6-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 681/681 [==============================] - 0s 597us/sample - loss: 6.5455 - mean_squared_error: 6.5455 - val_loss: 6.2933 - val_mean_squared_error: 6.2933
# Epoch 58/100
# 608/681 [=========================>....] - ETA: 0s - loss: 6.4788 - mean_squared_error: 6.4788
# Epoch 00058: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-6-channels-trim-24-6-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 681/681 [==============================] - 0s 598us/sample - loss: 6.5002 - mean_squared_error: 6.5002 - val_loss: 6.2365 - val_mean_squared_error: 6.2365
# Epoch 59/100
# 608/681 [=========================>....] - ETA: 0s - loss: 6.3886 - mean_squared_error: 6.3886
# Epoch 00059: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-6-channels-trim-24-6-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 681/681 [==============================] - 0s 678us/sample - loss: 6.4523 - mean_squared_error: 6.4523 - val_loss: 6.2089 - val_mean_squared_error: 6.2089
# Epoch 60/100
# 608/681 [=========================>....] - ETA: 0s - loss: 6.3523 - mean_squared_error: 6.3523
# Epoch 00060: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-6-channels-trim-24-6-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 681/681 [==============================] - 0s 619us/sample - loss: 6.4082 - mean_squared_error: 6.4082 - val_loss: 6.1651 - val_mean_squared_error: 6.1651
# Epoch 61/100
# 608/681 [=========================>....] - ETA: 0s - loss: 6.3846 - mean_squared_error: 6.3846
# Epoch 00061: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-6-channels-trim-24-6-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 681/681 [==============================] - 0s 598us/sample - loss: 6.3658 - mean_squared_error: 6.3658 - val_loss: 6.1337 - val_mean_squared_error: 6.1337
# Epoch 62/100
# 608/681 [=========================>....] - ETA: 0s - loss: 6.2876 - mean_squared_error: 6.2876
# Epoch 00062: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-6-channels-trim-24-6-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 681/681 [==============================] - 0s 638us/sample - loss: 6.3252 - mean_squared_error: 6.3252 - val_loss: 6.0970 - val_mean_squared_error: 6.0970
# Epoch 63/100
# 608/681 [=========================>....] - ETA: 0s - loss: 6.3110 - mean_squared_error: 6.3110
# Epoch 00063: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-6-channels-trim-24-6-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 681/681 [==============================] - 0s 569us/sample - loss: 6.2854 - mean_squared_error: 6.2854 - val_loss: 6.0664 - val_mean_squared_error: 6.0665
# Epoch 64/100
# 672/681 [============================>.] - ETA: 0s - loss: 6.2493 - mean_squared_error: 6.2493
# Epoch 00064: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-6-channels-trim-24-6-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 681/681 [==============================] - 0s 598us/sample - loss: 6.2444 - mean_squared_error: 6.2444 - val_loss: 6.0265 - val_mean_squared_error: 6.0265
# Epoch 65/100
# 576/681 [========================>.....] - ETA: 0s - loss: 6.2038 - mean_squared_error: 6.2038
# Epoch 00065: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-6-channels-trim-24-6-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 681/681 [==============================] - 0s 540us/sample - loss: 6.2085 - mean_squared_error: 6.2085 - val_loss: 5.9870 - val_mean_squared_error: 5.9870
# Epoch 66/100
# 672/681 [============================>.] - ETA: 0s - loss: 6.1684 - mean_squared_error: 6.1684
# Epoch 00066: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-6-channels-trim-24-6-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 681/681 [==============================] - 0s 589us/sample - loss: 6.1713 - mean_squared_error: 6.1713 - val_loss: 5.9705 - val_mean_squared_error: 5.9705
# Epoch 67/100
# 608/681 [=========================>....] - ETA: 0s - loss: 6.1022 - mean_squared_error: 6.1022
# Epoch 00067: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-6-channels-trim-24-6-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 681/681 [==============================] - 0s 653us/sample - loss: 6.1319 - mean_squared_error: 6.1319 - val_loss: 5.9166 - val_mean_squared_error: 5.9166
# Epoch 68/100
# 640/681 [===========================>..] - ETA: 0s - loss: 6.1135 - mean_squared_error: 6.1135
# Epoch 00068: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-6-channels-trim-24-6-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 681/681 [==============================] - 0s 625us/sample - loss: 6.0915 - mean_squared_error: 6.0915 - val_loss: 5.8933 - val_mean_squared_error: 5.8933
# Epoch 69/100
# 576/681 [========================>.....] - ETA: 0s - loss: 6.0366 - mean_squared_error: 6.0366
# Epoch 00069: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-6-channels-trim-24-6-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 681/681 [==============================] - 0s 587us/sample - loss: 6.0565 - mean_squared_error: 6.0565 - val_loss: 5.8694 - val_mean_squared_error: 5.8694
# Epoch 70/100
# 672/681 [============================>.] - ETA: 0s - loss: 6.0139 - mean_squared_error: 6.0139
# Epoch 00070: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-6-channels-trim-24-6-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 681/681 [==============================] - 0s 590us/sample - loss: 6.0211 - mean_squared_error: 6.0211 - val_loss: 5.8336 - val_mean_squared_error: 5.8336
# Epoch 71/100
# 672/681 [============================>.] - ETA: 0s - loss: 5.9783 - mean_squared_error: 5.9783
# Epoch 00071: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-6-channels-trim-24-6-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 681/681 [==============================] - 0s 632us/sample - loss: 5.9855 - mean_squared_error: 5.9855 - val_loss: 5.8199 - val_mean_squared_error: 5.8199
# Epoch 72/100
# 608/681 [=========================>....] - ETA: 0s - loss: 5.9115 - mean_squared_error: 5.9115
# Epoch 00072: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-6-channels-trim-24-6-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 681/681 [==============================] - 0s 640us/sample - loss: 5.9523 - mean_squared_error: 5.9523 - val_loss: 5.7825 - val_mean_squared_error: 5.7825
# Epoch 73/100
# 672/681 [============================>.] - ETA: 0s - loss: 5.9263 - mean_squared_error: 5.9263
# Epoch 00073: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-6-channels-trim-24-6-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 681/681 [==============================] - 0s 593us/sample - loss: 5.9169 - mean_squared_error: 5.9169 - val_loss: 5.7512 - val_mean_squared_error: 5.7512
# Epoch 74/100
# 640/681 [===========================>..] - ETA: 0s - loss: 5.8577 - mean_squared_error: 5.8577
# Epoch 00074: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-6-channels-trim-24-6-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 681/681 [==============================] - 0s 591us/sample - loss: 5.8855 - mean_squared_error: 5.8855 - val_loss: 5.7292 - val_mean_squared_error: 5.7292
# Epoch 75/100
# 640/681 [===========================>..] - ETA: 0s - loss: 5.8822 - mean_squared_error: 5.8822
# Epoch 00075: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-6-channels-trim-24-6-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 681/681 [==============================] - 0s 628us/sample - loss: 5.8545 - mean_squared_error: 5.8545 - val_loss: 5.6986 - val_mean_squared_error: 5.6986
# Epoch 76/100
# 608/681 [=========================>....] - ETA: 0s - loss: 5.7881 - mean_squared_error: 5.7881
# Epoch 00076: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-6-channels-trim-24-6-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 681/681 [==============================] - 0s 633us/sample - loss: 5.8207 - mean_squared_error: 5.8207 - val_loss: 5.6773 - val_mean_squared_error: 5.6773
# Epoch 77/100
# 672/681 [============================>.] - ETA: 0s - loss: 5.7952 - mean_squared_error: 5.7952
# Epoch 00077: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-6-channels-trim-24-6-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 681/681 [==============================] - 0s 598us/sample - loss: 5.7911 - mean_squared_error: 5.7911 - val_loss: 5.6498 - val_mean_squared_error: 5.6498
# Epoch 78/100
# 672/681 [============================>.] - ETA: 0s - loss: 5.7651 - mean_squared_error: 5.7651
# Epoch 00078: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-6-channels-trim-24-6-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 681/681 [==============================] - 0s 691us/sample - loss: 5.7616 - mean_squared_error: 5.7616 - val_loss: 5.6328 - val_mean_squared_error: 5.6328
# Epoch 79/100
# 608/681 [=========================>....] - ETA: 0s - loss: 5.6948 - mean_squared_error: 5.6948
# Epoch 00079: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-6-channels-trim-24-6-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 681/681 [==============================] - 0s 550us/sample - loss: 5.7278 - mean_squared_error: 5.7278 - val_loss: 5.6012 - val_mean_squared_error: 5.6012
# Epoch 80/100
# 608/681 [=========================>....] - ETA: 0s - loss: 5.6459 - mean_squared_error: 5.6459
# Epoch 00080: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-6-channels-trim-24-6-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 681/681 [==============================] - 0s 646us/sample - loss: 5.6945 - mean_squared_error: 5.6945 - val_loss: 5.5790 - val_mean_squared_error: 5.5790
# Epoch 81/100
# 608/681 [=========================>....] - ETA: 0s - loss: 5.6937 - mean_squared_error: 5.6937
# Epoch 00081: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-6-channels-trim-24-6-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 681/681 [==============================] - 0s 639us/sample - loss: 5.6659 - mean_squared_error: 5.6659 - val_loss: 5.5576 - val_mean_squared_error: 5.5576
# Epoch 82/100
# 672/681 [============================>.] - ETA: 0s - loss: 5.6397 - mean_squared_error: 5.6397
# Epoch 00082: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-6-channels-trim-24-6-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 681/681 [==============================] - 0s 678us/sample - loss: 5.6351 - mean_squared_error: 5.6351 - val_loss: 5.5336 - val_mean_squared_error: 5.5336
# Epoch 83/100
# 608/681 [=========================>....] - ETA: 0s - loss: 5.6307 - mean_squared_error: 5.6307
# Epoch 00083: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-6-channels-trim-24-6-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 681/681 [==============================] - 0s 581us/sample - loss: 5.6018 - mean_squared_error: 5.6018 - val_loss: 5.5137 - val_mean_squared_error: 5.5137
# Epoch 84/100
# 608/681 [=========================>....] - ETA: 0s - loss: 5.6041 - mean_squared_error: 5.6041
# Epoch 00084: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-6-channels-trim-24-6-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 681/681 [==============================] - 0s 557us/sample - loss: 5.5753 - mean_squared_error: 5.5753 - val_loss: 5.4945 - val_mean_squared_error: 5.4945
# Epoch 85/100
# 640/681 [===========================>..] - ETA: 0s - loss: 5.5412 - mean_squared_error: 5.5412
# Epoch 00085: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-6-channels-trim-24-6-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 681/681 [==============================] - 0s 616us/sample - loss: 5.5432 - mean_squared_error: 5.5432 - val_loss: 5.4652 - val_mean_squared_error: 5.4652
# Epoch 86/100
# 576/681 [========================>.....] - ETA: 0s - loss: 5.5296 - mean_squared_error: 5.5296
# Epoch 00086: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-6-channels-trim-24-6-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 681/681 [==============================] - 0s 567us/sample - loss: 5.5134 - mean_squared_error: 5.5134 - val_loss: 5.4441 - val_mean_squared_error: 5.4441
# Epoch 87/100
# 640/681 [===========================>..] - ETA: 0s - loss: 5.4849 - mean_squared_error: 5.4849
# Epoch 00087: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-6-channels-trim-24-6-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 681/681 [==============================] - 0s 587us/sample - loss: 5.4856 - mean_squared_error: 5.4856 - val_loss: 5.4250 - val_mean_squared_error: 5.4250
# Epoch 88/100
# 640/681 [===========================>..] - ETA: 0s - loss: 5.4255 - mean_squared_error: 5.4255
# Epoch 00088: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-6-channels-trim-24-6-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 681/681 [==============================] - 0s 598us/sample - loss: 5.4581 - mean_squared_error: 5.4581 - val_loss: 5.4001 - val_mean_squared_error: 5.4001
# Epoch 89/100
# 672/681 [============================>.] - ETA: 0s - loss: 5.4327 - mean_squared_error: 5.4327
# Epoch 00089: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-6-channels-trim-24-6-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 681/681 [==============================] - 0s 641us/sample - loss: 5.4350 - mean_squared_error: 5.4350 - val_loss: 5.3824 - val_mean_squared_error: 5.3824
# Epoch 90/100
# 608/681 [=========================>....] - ETA: 0s - loss: 5.3866 - mean_squared_error: 5.3866
# Epoch 00090: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-6-channels-trim-24-6-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 681/681 [==============================] - 0s 535us/sample - loss: 5.4119 - mean_squared_error: 5.4119 - val_loss: 5.3631 - val_mean_squared_error: 5.3631
# Epoch 91/100
# 608/681 [=========================>....] - ETA: 0s - loss: 5.4019 - mean_squared_error: 5.4019
# Epoch 00091: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-6-channels-trim-24-6-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 681/681 [==============================] - 0s 612us/sample - loss: 5.3796 - mean_squared_error: 5.3796 - val_loss: 5.3331 - val_mean_squared_error: 5.3331
# Epoch 92/100
# 608/681 [=========================>....] - ETA: 0s - loss: 5.3150 - mean_squared_error: 5.3150
# Epoch 00092: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-6-channels-trim-24-6-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 681/681 [==============================] - 0s 604us/sample - loss: 5.3513 - mean_squared_error: 5.3513 - val_loss: 5.3163 - val_mean_squared_error: 5.3163
# Epoch 93/100
# 608/681 [=========================>....] - ETA: 0s - loss: 5.2839 - mean_squared_error: 5.2839
# Epoch 00093: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-6-channels-trim-24-6-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 681/681 [==============================] - 0s 593us/sample - loss: 5.3239 - mean_squared_error: 5.3239 - val_loss: 5.2968 - val_mean_squared_error: 5.2968
# Epoch 94/100
# 672/681 [============================>.] - ETA: 0s - loss: 5.2986 - mean_squared_error: 5.2986
# Epoch 00094: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-6-channels-trim-24-6-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 681/681 [==============================] - 0s 583us/sample - loss: 5.2982 - mean_squared_error: 5.2982 - val_loss: 5.2708 - val_mean_squared_error: 5.2708
# Epoch 95/100
# 608/681 [=========================>....] - ETA: 0s - loss: 5.2076 - mean_squared_error: 5.2076
# Epoch 00095: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-6-channels-trim-24-6-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 681/681 [==============================] - 0s 561us/sample - loss: 5.2770 - mean_squared_error: 5.2770 - val_loss: 5.2379 - val_mean_squared_error: 5.2379
# Epoch 96/100
# 672/681 [============================>.] - ETA: 0s - loss: 5.2551 - mean_squared_error: 5.2551
# Epoch 00096: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-6-channels-trim-24-6-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 681/681 [==============================] - 0s 611us/sample - loss: 5.2490 - mean_squared_error: 5.2490 - val_loss: 5.2229 - val_mean_squared_error: 5.2229
# Epoch 97/100
# 608/681 [=========================>....] - ETA: 0s - loss: 5.2101 - mean_squared_error: 5.2101
# Epoch 00097: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-6-channels-trim-24-6-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 681/681 [==============================] - 0s 639us/sample - loss: 5.2250 - mean_squared_error: 5.2250 - val_loss: 5.2102 - val_mean_squared_error: 5.2102
# Epoch 98/100
# 672/681 [============================>.] - ETA: 0s - loss: 5.1976 - mean_squared_error: 5.1976
# Epoch 00098: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-6-channels-trim-24-6-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 681/681 [==============================] - 0s 624us/sample - loss: 5.2014 - mean_squared_error: 5.2014 - val_loss: 5.1909 - val_mean_squared_error: 5.1909
# Epoch 99/100
# 672/681 [============================>.] - ETA: 0s - loss: 5.1837 - mean_squared_error: 5.1837
# Epoch 00099: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-6-channels-trim-24-6-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 681/681 [==============================] - 0s 611us/sample - loss: 5.1766 - mean_squared_error: 5.1766 - val_loss: 5.1752 - val_mean_squared_error: 5.1752
# Epoch 100/100
# 640/681 [===========================>..] - ETA: 0s - loss: 5.1686 - mean_squared_error: 5.1686
# Epoch 00100: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-6-channels-trim-24-6-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 681/681 [==============================] - 0s 620us/sample - loss: 5.1566 - mean_squared_error: 5.1566 - val_loss: 5.1454 - val_mean_squared_error: 5.1454
# (76, 5, 6)
# Decoded seq from VAE: (6, 24, 6)
# Decoded seq from lstm: (5, 24, 6)
# Decoded seq from VAE: (6, 24, 6)
# Decoded seq from lstm: (5, 24, 6)
# Decoded seq from VAE: (6, 24, 6)
# Decoded seq from lstm: (5, 24, 6)
# Decoded seq from VAE: (6, 24, 6)
# Decoded seq from lstm: (5, 24, 6)
# Decoded seq from VAE: (6, 24, 6)
# Decoded seq from lstm: (5, 24, 6)
# Decoded seq from VAE: (6, 24, 6)
# Decoded seq from lstm: (5, 24, 6)
# Decoded seq from VAE: (6, 24, 6)
# Decoded seq from lstm: (5, 24, 6)
# Decoded seq from VAE: (6, 24, 6)
# Decoded seq from lstm: (5, 24, 6)
# Decoded seq from VAE: (6, 24, 6)
# Decoded seq from lstm: (5, 24, 6)
# Decoded seq from VAE: (6, 24, 6)
# Decoded seq from lstm: (5, 24, 6)

# %%
# load normalised time series
save_dir = '../datasets/' + config['data_dir'] #NAB-known-anomaly/'
dataset = config['dataset']
file_name = config['filename']
filename = '{}.npz'.format(file_name)
result = dict(np.load(save_dir+filename, allow_pickle=True))
if dataset == 'machine_temp':
    result['test'] = result['test'][0]
    result['idx_anomaly_test'] = result['idx_anomaly_test'][0]
    result['t_test'] = result['t_test'][0]

# slice into rolling windows and rolling sequences
def slice_rolling_windows_and_sequences(config, time_seq):
    n_sample = len(time_seq)
    print("The given sequence has {} samples".format(n_sample))
    n_vae_win = n_sample - config['l_win'] + 1
    rolling_windows = np.zeros((n_vae_win, config['l_win'], config['n_channel']), dtype=float)
    for i in range(n_vae_win):
        rolling_windows[i] = time_seq[i:i + config['l_win']]
        sample_m = np.mean(rolling_windows, axis=1)
        sample_std = np.std(rolling_windows, axis=1)

        n_lstm_seq = n_sample - config['l_seq']*config['l_win']+1
        lstm_seq = np.zeros((n_lstm_seq, config['l_seq'], config['l_win'], config['n_channel']), dtype=float)
    for i in range(n_lstm_seq):
        cur_seq = time_seq[i:i+config['l_seq']*config['l_win']]
        for j in range(config['l_seq']):
            lstm_seq[i,j] = cur_seq[config['l_win']*j:config['l_win']*(j+1)]
    
    return rolling_windows, lstm_seq, sample_m, sample_std

test_windows, test_seq, test_sample_m, test_sample_std = slice_rolling_windows_and_sequences(config, result['test'])
if config['n_channel'] == 1:
    test_windows = np.expand_dims(test_windows, -1)
    test_seq = np.expand_dims(test_seq, -1)
else:
    test_windows = test_windows
    test_seq = test_seq
print(test_windows.shape)
print(test_seq.shape)
# Out:
# The given sequence has 583 samples
# (560, 24, 6)
# (440, 6, 24, 6)

# %%
# Evaluate ELBO and LSTM prediction error on the validation set
# evaluate some anomaly detection metrics
def evaluate_vae_anomaly_metrics_for_a_window(test_win):
    feed_dict = {model_vae.original_signal: np.expand_dims(test_win, 0),
                 model_vae.is_code_input: False,
                 model_vae.code_input: np.zeros((1, config['code_size']))}

    # VAE reconstruction error
    recons_win_vae = np.squeeze(sess.run(model_vae.decoded, feed_dict=feed_dict))
    test_vae_recons_error = np.sum(np.square(recons_win_vae - test_win))

    # VAE latent embedding likelihood
    vae_code_mean, vae_code_std = sess.run([model_vae.code_mean, model_vae.code_std_dev], feed_dict=feed_dict)
    test_vae_kl = 0.5 * (np.sum(np.square(vae_code_mean)) + \
                            np.sum(np.square(vae_code_std)) - \
                            np.sum(np.log(np.square(vae_code_std))) - config['code_size'])

    # VAE ELBO loss
    sigma2 = 0.0005
    input_dims = model_vae.input_dims
    sigma_regularisor = input_dims/2. * np.log(sigma2) + input_dims * np.pi
    test_vae_elbo = test_vae_recons_error/sigma2 + test_vae_kl + sigma_regularisor
    return test_vae_recons_error, test_vae_kl, test_vae_elbo

def evaluate_lstm_anomaly_metric_for_a_seq(test_seq):
    feed_dict = {model_vae.original_signal: test_seq,
                 model_vae.is_code_input: False,
                 model_vae.code_input: np.zeros((1, config['code_size']))}
    vae_embedding = np.squeeze(sess.run(model_vae.code_mean, feed_dict=feed_dict))
    #print(vae_embedding.shape)
    lstm_embedding = np.squeeze(lstm_nn_model.predict(np.expand_dims(vae_embedding[:config['l_seq']-1], 0), batch_size=1))
    lstm_embedding_error = np.sum(np.square(vae_embedding[1:] - lstm_embedding))
    
    # LSTM prediction error
    feed_dict_lstm = {model_vae.original_signal: np.zeros((config['l_seq'] - 1, config['l_win'], test_seq.shape[2])),
                      model_vae.is_code_input: True,
                      model_vae.code_input: lstm_embedding}
    recons_win_lstm = np.squeeze(sess.run(model_vae.decoded, feed_dict=feed_dict_lstm))
    lstm_recons_error = np.sum(np.square(recons_win_lstm - np.squeeze(test_seq[1:])))
    return lstm_recons_error, lstm_embedding_error

n_val_vae = data.val_set_vae['data'].shape[0]
n_val_lstm = data.val_set_lstm['data'].shape[0]

val_vae_recons_error = np.zeros(n_val_vae)
val_vae_kl_error = np.zeros(n_val_vae)
val_vae_elbo_loss = np.zeros(n_val_vae)
for i in range(n_val_vae):
    val_vae_recons_error[i], val_vae_kl_error[i], val_vae_elbo_loss[i] = evaluate_vae_anomaly_metrics_for_a_window(data.val_set_vae['data'][i])

val_lstm_recons_error, val_lstm_embedding_error = np.zeros(n_val_lstm), np.zeros(n_val_lstm)
for i in range(n_val_lstm):
    val_lstm_recons_error[i], val_lstm_embedding_error[i] = evaluate_lstm_anomaly_metric_for_a_seq(data.val_set_lstm['data'][i])

# %%
from scipy.stats import norm
def plot_histogram(test_anomaly_metric, n_bins, title, mean=None, std=None, xlim=None, saveplot=False):
    test_anomaly_list = np.squeeze(np.ndarray.flatten(test_anomaly_metric))
    his = plt.hist(test_anomaly_list, bins=n_bins, density=True)
    if mean is None and std is None:
        mean = np.mean(test_anomaly_list)
        std = np.std(test_anomaly_list)
        legend_label = None
    else:
        legend_label = 1
    x_axis = np.arange(mean-5*std, mean+5*std, std/100)
    plt.plot(x_axis, norm.pdf(x_axis,mean,std))
    plt.title(title)
    plt.xlabel('anomaly score value')
    plt.ylabel('probability density')
    if xlim is not None:
        plt.xlim(0, xlim)
    else:
        plt.xlim(0, np.amax(test_anomaly_list))
    if legend_label is None:
        plt.legend(('Fitted Gaussian', 'histogram'))
    else:
        plt.legend(('normal data distribution','test data distribution (contain anomalies)'))
    if saveplot:
        savefig(config['result_dir']+'reconstruction_error_histogram.pdf')
    else:
        plt.show()
    threshold_25 = np.percentile(test_anomaly_list, 25)
    threshold_75 = np.percentile(test_anomaly_list, 75)
    threshold_1 = np.percentile(test_anomaly_list, 99)
    idx_large_error = np.squeeze(np.argwhere(test_anomaly_metric > threshold_1))
#     print(his[0][-20:])
#     print(his[1][-20:])
    print("25% percentile: {}".format(threshold_25))
    print("75% percentile: {}".format(threshold_75))
#     print("Median: {}".format(np.median(test_anomaly_list)))
#     print("Mean: {}".format(np.mean(test_anomaly_list)))
#     print("Std dev: {}".format(np.std(test_anomaly_list)))
    print("These windows scored the top 1% of anomaly metric ({}): \n{}".format(threshold_1, idx_large_error))
    return mean, std

# %%
# Histogram of VAE ELBO loss - validation set
vae_elbo_m, vae_elbo_std = plot_histogram(val_vae_elbo_loss, 100, 
                                          'VAE ELBO error distribution on the val set', 
                                          mean=None, std=None, xlim=None)
# Out:
# 25% percentile: 9444.169061773582
# 75% percentile: 211067.4473668849
# These windows scored the top 1% of anomaly metric (384535.48911340575):
# 86

# %%
# Histogram of LSTM reconstruction error - validation set 
#  --> to decide the anomaly detection threshold
lstm_recons_m, lstm_recons_std = plot_histogram(val_lstm_recons_error, 100,  
                                              'LSTM reconstruction error distribution on the val set', 
                                              mean=None, std=None, xlim=None)
# Out:
# 25% percentile: 423.2076869969254
# 75% percentile: 553.2034632559324
# These windows scored the top 1% of anomaly metric (805.3222143878982):
# 65

# %%
# Evaluate the anomaly metrics on the test windows and sequences
n_test_lstm = test_seq.shape[0]

test_lstm_recons_error, test_lstm_embedding_error = np.zeros(n_test_lstm), np.zeros(n_test_lstm)
for i in range(n_test_lstm):
    test_lstm_recons_error[i], test_lstm_embedding_error[i] = evaluate_lstm_anomaly_metric_for_a_seq(test_seq[i])
print("All windows' reconstruction error is computed.")
print("The total number of windows is {}".format(len(test_lstm_recons_error)))
# Out:
# All windows' reconstruction error is computed.
# The total number of windows is 440

# %%
# Histogram of LSTM reconstruction error - test set 
#  --> to detect anomaly now
_, _ = plot_histogram(test_lstm_recons_error, 100,
                      'LSTM reconstruction error distribution on the test set', 
                      mean=lstm_recons_m, std=lstm_recons_std, xlim=None, saveplot=True)
# Out:
# 25% percentile: 763.4091488261656
# 75% percentile: 1068.4040402335056
# These windows scored the top 1% of anomaly metric (1512.0613932758072):
# [430 436 437 438 439]

# %%
# Produce the ground truth anomaly indices 
# if result['idx_split'][0] == 0:
#     idx_anomaly_test = result['idx_anomaly_test']
# else:
#     idx_anomaly_test = result['idx_anomaly_test'][0]
idx_anomaly_test = result['idx_anomaly_test']    
anomaly_index_lstm = []
test_labels_lstm = np.zeros(n_test_lstm)
for i in range(len(idx_anomaly_test)):
    idx_start = idx_anomaly_test[i]-(config['l_win']*config['l_seq']-1)
    idx_end = idx_anomaly_test[i]+1
    if idx_start < 0:
        idx_start = 0
    if idx_end > n_test_lstm:
        idx_end = n_test_lstm
    anomaly_index_lstm.append(np.arange(idx_start,idx_end))
    test_labels_lstm[idx_start:idx_end] = 1
    
print(test_labels_lstm.shape)
# Out:
# (440,)

# %%
def return_anomaly_idx_by_threshold(test_anomaly_metric, threshold):
    test_list = np.squeeze(np.ndarray.flatten(test_anomaly_metric))
    idx_error = np.squeeze(np.argwhere(test_anomaly_metric > threshold))
    
    if len(idx_error.shape) == 0:
        idx_error = np.expand_dims(idx_error, 0)
    
    return list(idx_error)

# %%
def augment_detected_idx(idx_detected_anomaly, anomaly_index):
    n_anomaly = len(anomaly_index)
    idx_detected_anomaly_extended = list(idx_detected_anomaly)
    for i in range(n_anomaly):
        #print(idx_detected_anomaly)
        for j in idx_detected_anomaly:
            if j in anomaly_index[i]:
                in_original_detection = set(idx_detected_anomaly_extended)
                currect_anomaly_win = set(anomaly_index[i])
                idx_detected_anomaly_extended = idx_detected_anomaly_extended + list(currect_anomaly_win - in_original_detection)
                #print(j)
                break
                
    return list(np.sort(idx_detected_anomaly_extended))

# %%
def count_TP_FP_FN(idx_detected_anomaly, anomaly_index, test_labels):
    n_TP = 0
    n_FP = 0
    n_detection = len(idx_detected_anomaly)
    for i in range(n_detection):
        if test_labels[idx_detected_anomaly[i]] == 1:
            n_TP = n_TP + 1
        else:
            n_FP = n_FP + 1
    
    idx_undetected = list(set(np.arange(len(test_labels)))- set(idx_detected_anomaly))
    n_FN = 0
    for i in idx_undetected:
        if test_labels[i] == 1:
            n_FN = n_FN + 1
    
    return n_TP, n_FP, n_FN

# %%
def compute_precision_and_recall(idx_detected_anomaly, anomaly_index, test_labels):
    # compute true positive
    n_TP, n_FP, n_FN = count_TP_FP_FN(idx_detected_anomaly, anomaly_index, test_labels)
    
    if n_TP + n_FP == 0:
        precision = 1
    else:
        precision = n_TP / (n_TP + n_FP)
    recall = n_TP / (n_TP + n_FN)
    if precision + recall == 0:
        F1 = 0
    else:
        F1 = 2* (precision * recall)/(precision + recall)
    
    return precision, recall, F1, n_TP, n_FP, n_FN

# %%
n_threshold = 200
precision = np.zeros(n_threshold)
recall = np.zeros(n_threshold)
F1 = np.zeros(n_threshold)
precision_aug = np.zeros(n_threshold)
recall_aug = np.zeros(n_threshold)
F1_aug = np.zeros(n_threshold)
i = 0
threshold_list = np.linspace(np.amin(test_lstm_recons_error), np.amax(test_lstm_recons_error), n_threshold, endpoint=True)
threshold_list = np.flip(threshold_list)
for threshold in threshold_list:
    #print(threshold_list[i])
    idx_detection_lstm = return_anomaly_idx_by_threshold(test_lstm_recons_error, threshold)
    precision[i], recall[i], F1[i], _, _, _ = compute_precision_and_recall(idx_detection_lstm, 
                                                                           anomaly_index_lstm, 
                                                                           test_labels_lstm)
    # augment the detection using the ground truth labels
    # a method to discount the factor one anomaly appears in multiple consecutive windows
    # introduced in "Unsupervised anomaly detection via variational auto-encoder for seasonal kpis in web applications"
    idx_detection_lstm_augmented = augment_detected_idx(idx_detection_lstm, anomaly_index_lstm)
    precision_aug[i], recall_aug[i], F1_aug[i], _, _, _ = compute_precision_and_recall(idx_detection_lstm_augmented, 
                                                                                       anomaly_index_lstm, 
                                                                                       test_labels_lstm)
    i = i + 1
    #print(precision, recall, F1)

# %%
print("Best F1 score is {}".format(np.amax(F1)))
idx_best_threshold = np.squeeze(np.argwhere(F1 == np.amax(F1)))
print("Best threshold is {}".format(threshold_list[idx_best_threshold]))
print("At this threshold, precision is {}, recall is {}".format(precision[idx_best_threshold], recall[idx_best_threshold]))
average_precision = np.sum(precision[1:] * (recall[1:] - recall[:-1]))
print("Average precision is {}".format(average_precision))

print("\nAugmented detection:")
print("Best F1 score is {}".format(np.amax(F1_aug)))
idx_best_threshold = np.squeeze(np.argwhere(F1_aug == np.amax(F1_aug)))
print("Best threshold is {}".format(threshold_list[idx_best_threshold]))
print("At this threshold, precision is {}, recall is {}".format(precision_aug[idx_best_threshold], 
                                                                recall_aug[idx_best_threshold]))

average_precision_aug = np.sum(precision_aug[1:] * (recall_aug[1:] - recall_aug[:-1]))
print("Average precision is {}".format(average_precision_aug))
# Out:
# Best F1 score is 0.6181818181818182
# Best threshold is 896.7574377060428
# At this threshold, precision is 0.49377593360995853, recall is 0.8263888888888888
# Average precision is 0.49285900004531696
#
# Augmented detection:
# Best F1 score is 0.9504950495049505
# Best threshold is [1438.22109472 1432.58084829]
# At this threshold, precision is [0.90566038 0.90566038], recall is [1. 1.]
# Average precision is 0.9056603773584906

# %%
# Now select a threshold
print(idx_best_threshold.shape)
if isinstance(idx_best_threshold,(list,np.ndarray)):
    threshold = threshold_list[idx_best_threshold[0]]
else:
    threshold = threshold_list[idx_best_threshold]

print("Threshold is {}".format(threshold))
idx_detection = return_anomaly_idx_by_threshold(test_lstm_recons_error, threshold)
idx_detection_augmented = augment_detected_idx(idx_detection, anomaly_index_lstm)
precision, recall, F1, n_TP, n_FP, n_FN = compute_precision_and_recall(idx_detection_augmented, 
                                                                       anomaly_index_lstm, 
                                                                       test_labels_lstm)
print("\nPR evaluation using augmented detection:")
print("Precision: {}".format(precision))
print("Recall: {}".format(recall))
print("F1: {}".format(F1))
print("TP: {}".format(n_TP))
print("FP: {}".format(n_FP))
print("FN: {}".format(n_FN))
# Out:
# (2,)
# Threshold is 1438.2210947182289
#
# PR evaluation using augmented detection:
# Precision: 0.9056603773584906
# Recall: 1.0
# F1: 0.9504950495049505
# TP: 144
# FP: 15
# FN: 0

# %%
def slice_detected_indices_into_seq(idx_detection, interval):
    detected_seq = []
    i = 0
    while i < len(idx_detection):
        if i == 0:
            cur_seq = [idx_detection[i]]
            i = i + 1
        else:
            if idx_detection[i] - idx_detection[i-1] > interval:
                detected_seq.append(cur_seq)
                cur_seq = [idx_detection[i]]
            else:
                cur_seq.append(idx_detection[i])
                if i == len(idx_detection) - 1:
                    detected_seq.append(cur_seq)
            i = i + 1
    
    print("Detected {} sequences".format(len(detected_seq)))
    return detected_seq

# %%
def plot_detected_anomalies(idx_detection, interval, dataset, result, detection_method, augmented_flag=1, y_scale=5, y_lim=None):
    detected_seq = slice_detected_indices_into_seq(idx_detection, interval=interval)
    t_test = result['t_test']
    test = result['test']
    idx_anomaly_test = result['idx_anomaly_test']
        
    # plot detected sequences
    fig, axs = plt.subplots(1, 1, figsize=(18, 5), edgecolor='k')
    fig.subplots_adjust(hspace=.4, wspace=.4)
    axs.plot(t_test, test)
    for j in range(len(idx_anomaly_test)):
        if j == 0:
            axs.plot(idx_anomaly_test[j] * np.ones(20), np.linspace(-y_scale, y_scale, 20), 'r--', label='true anomalies')
        else:
            axs.plot(idx_anomaly_test[j] * np.ones(20), np.linspace(-y_scale, y_scale, 20), 'r--')
        
    for i in range(len(detected_seq)):
        for j in detected_seq[i]:
            if j == detected_seq[0][0]:
                axs.plot((j+interval*2) * np.ones(20), np.linspace(-y_scale, -0.8*y_scale, 20), 'g-', label='detected anomalies')
            else:
                axs.plot((j+interval*2) * np.ones(20), np.linspace(-y_scale, -0.8*y_scale, 20), 'g-')
    
    for j in range(len(idx_anomaly_test)):
        axs.plot(idx_anomaly_test[j] * np.ones(20), np.linspace(-y_scale, y_scale, 20), 'r--')

    for i in range(len(detected_seq)):
        interval_x = np.asarray([detected_seq[i][0], detected_seq[i][-1]+interval*2])
        interval_y = np.asarray([y_scale,y_scale])
        if i == 0:
            axs.fill_between(interval_x, interval_y, alpha=0.2, color='y', label='detected anomaly windows')
        else:
            axs.fill_between(interval_x, interval_y, alpha=0.2, color='y')
        interval_y = np.asarray([-y_scale,-y_scale])
        axs.fill_between(interval_x, interval_y, alpha=0.2, color='y')
    axs.grid(True)
    axs.set_xlim(0, len(t_test))
    if y_lim is None:
        axs.set_ylim(-y_scale, y_scale)
    else:
        axs.set_ylim(-y_scale, y_lim)
    axs.set_xlabel("timestamp (every {})".format(result['t_unit']))
    axs.set_ylabel("normalised readings")
    #axs.set_title("{} dataset test sequence\n(normalised by train mean {:.4f} and std {:.4f})\n Detection method: {}".format(dataset, 
    #                                                                                    result['train_m'], 
    #                                                                                    result['train_std'],
    #                                                                                    detection_method))
    axs.set_title("{} dataset test sequence\n Detection method: {}".format(dataset, detection_method))
    axs.legend()
    savefig(config['result_dir']+'detected_anomalies_{}_aug_{}.pdf'.format(detection_method, augmented_flag))

# %%
plot_detected_anomalies(idx_detection_augmented, 
                        interval=config['l_win']*config['l_seq']/2, 
                        dataset=dataset, 
                        result=result, 
                        detection_method='lstm reconstruction error',
                        augmented_flag=1,
                        y_scale=5,
                        y_lim=5)
# Out:
# Detected 2 sequences
