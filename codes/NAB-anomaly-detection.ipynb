# %%
from google.colab import drive
drive.mount('/content/drive')
global GIT_DIR
GIT_DIR='/content/drive/My\ Drive/afeka/y2/sem1/dl/code/LSTM-VAE/VAE-LSTM-for-anomaly-detection'
# %cd $GIT_DIR
# !ls

# %%
# %cd $GIT_DIR/codes/

# %%
import warnings

def fxn():
    warnings.warn("deprecated", DeprecationWarning)

with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    fxn()

# %%
# %tensorflow_version 1.x

# %%
import tensorflow as tf
import tensorflow_probability as tfp
import numpy as np
import matplotlib.pylab as plt
from matplotlib.pyplot import plot, ion, show, savefig, cla, figure
import random
import time

# %%
import os
os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"   # see issue #152
os.environ["CUDA_VISIBLE_DEVICES"] = "0"
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'

import tensorflow as tf
from data_loader import DataGenerator
from models import VAEmodel, lstmKerasModel
from trainers import vaeTrainer

from utils import process_config, create_dirs, get_args

# %%
from tensorflow.python.client import device_lib

def get_available_gpus():
    local_device_protos = device_lib.list_local_devices()
    return [x.name for x in local_device_protos if x.device_type == 'GPU']

print(get_available_gpus())
# Out:
# []

# %%
# load VAE model
config = process_config('PX4_config.json')
# create the experiments dirs
create_dirs([config['result_dir'], config['checkpoint_dir']])
# create tensorflow session
sess = tf.Session(config=tf.ConfigProto(log_device_placement=True))
# create your data generator
data = DataGenerator(config)
# create a CNN model
model_vae = VAEmodel(config)
# create a CNN model
trainer_vae = vaeTrainer(sess, model_vae, data, config)
model_vae.load(sess)

# here you train your model
if config['TRAIN_VAE']:
    if config['num_epochs_vae'] > 0:
        trainer_vae.train()
# Out:
# 4804078 min; Remaining 5.282470035552978 min.
# Saving model...
# Model saved.
# 2/49, test loss: -elbo: 711.0840, recons_loss_weighted: 1291.7902, recons_loss_ls: 25.8358, KL_loss: 24.9166, sigma_regularisor: -110.5241, code_std_dev: [0.12382898 0.33412287 0.09926424 0.14709347 0.09846091 0.16927536]
# Loss on training and val sets:
# train: 843.8851, val: 894.0607
# Current sigma2: 0.0100000
# Already trained for 0.3242705543835958 min; Remaining 5.0802386853430015 min.
# Saving model...
# Model saved.
# 3/49, test loss: -elbo: 652.9233, recons_loss_weighted: 1173.3531, recons_loss_ls: 23.4671, KL_loss: 25.9744, sigma_regularisor: -110.5241, code_std_dev: [0.09167019 0.31803945 0.10360054 0.121798   0.13850956 0.10045431]
# Loss on training and val sets:
# train: 753.7967, val: 762.1618
# Current sigma2: 0.0100000
# Already trained for 0.43125783602396645 min; Remaining 4.9594651142756145 min.
# Saving model...
# Model saved.
# 4/49, test loss: -elbo: 575.3801, recons_loss_weighted: 1014.3157, recons_loss_ls: 20.2863, KL_loss: 27.9499, sigma_regularisor: -110.5241, code_std_dev: [0.13751435 0.11073792 0.06882038 0.09658774 0.11288512 0.05153687]
# Loss on training and val sets:
# train: 660.3715, val: 632.1645
# Current sigma2: 0.0100000
# Already trained for 0.5429900964101155 min; Remaining 4.88691086769104 min.
# Saving model...
# Model saved.
# 5/49, test loss: -elbo: 557.1889, recons_loss_weighted: 977.8915, recons_loss_ls: 19.5578, KL_loss: 27.9708, sigma_regularisor: -110.5241, code_std_dev: [0.08868147 0.15257035 0.04158054 0.10394488 0.06717346 0.09839617]
# Loss on training and val sets:
# train: 584.5062, val: 593.1982
# Current sigma2: 0.0100000
# Already trained for 0.6504940112431844 min; Remaining 4.770289415783352 min.
# Saving model...
# Model saved.
# 6/49, test loss: -elbo: 504.4864, recons_loss_weighted: 868.7183, recons_loss_ls: 17.3744, KL_loss: 29.8548, sigma_regularisor: -110.5241, code_std_dev: [0.11859379 0.06845623 0.04499204 0.15675032 0.03649259 0.05134463]
# Loss on training and val sets:
# train: 536.9145, val: 544.3496
# Current sigma2: 0.0100000
# Already trained for 0.7607455770174663 min; Remaining 4.673151401678721 min.
# Saving model...
# Model saved.
# 7/49, test loss: -elbo: 489.4757, recons_loss_weighted: 835.8499, recons_loss_ls: 16.7170, KL_loss: 31.2784, sigma_regularisor: -110.5241, code_std_dev: [0.05719813 0.0631199  0.03958439 0.13442323 0.04374231 0.03343992]
# Loss on training and val sets:
# train: 506.4536, val: 504.0689
# Current sigma2: 0.0100000
# Already trained for 0.8681493719418844 min; Remaining 4.557784202694893 min.
# Saving model...
# Model saved.
# 8/49, test loss: -elbo: 475.2187, recons_loss_weighted: 806.8959, recons_loss_ls: 16.1379, KL_loss: 31.4984, sigma_regularisor: -110.5241, code_std_dev: [0.08369394 0.06562518 0.05140097 0.09488995 0.04071506 0.07129364]
# Loss on training and val sets:
# train: 476.8614, val: 497.8265
# Current sigma2: 0.0100000
# Already trained for 0.9751394987106323 min; Remaining 4.442302160792881 min.
# Saving model...
# Model saved.
# 9/49, test loss: -elbo: 467.1431, recons_loss_weighted: 789.0724, recons_loss_ls: 15.7814, KL_loss: 32.3345, sigma_regularisor: -110.5241, code_std_dev: [0.09291486 0.10715123 0.03670156 0.12221216 0.10347363 0.08332652]
# Loss on training and val sets:
# train: 450.9225, val: 502.4942
# Current sigma2: 0.0100000
# Already trained for 1.0820472200711568 min; Remaining 4.328188880284627 min.
# Saving model...
# Model saved.
# 10/49, test loss: -elbo: 441.1193, recons_loss_weighted: 734.7396, recons_loss_ls: 14.6948, KL_loss: 33.4771, sigma_regularisor: -110.5241, code_std_dev: [0.096368   0.06056305 0.06035942 0.0817091  0.0424529  0.04168182]
# Loss on training and val sets:
# train: 426.2466, val: 478.1525
# Current sigma2: 0.0100000
# Already trained for 1.1865460316340128 min; Remaining 4.206845021247863 min.
# Saving model...
# Model saved.
# 11/49, test loss: -elbo: 428.7498, recons_loss_weighted: 709.2325, recons_loss_ls: 14.1847, KL_loss: 33.8611, sigma_regularisor: -110.5241, code_std_dev: [0.0590874  0.08064618 0.03802474 0.09118126 0.04787463 0.07374275]
# Loss on training and val sets:
# train: 406.4774, val: 477.3200
# Current sigma2: 0.0100000
# Already trained for 1.2931868433952332 min; Remaining 4.095091670751572 min.
# Saving model...
# Model saved.
# 12/49, test loss: -elbo: 423.0204, recons_loss_weighted: 694.5291, recons_loss_ls: 13.8906, KL_loss: 35.4835, sigma_regularisor: -110.5241, code_std_dev: [0.05254648 0.08298474 0.056524   0.05282563 0.03617513 0.0704672 ]
# Loss on training and val sets:
# train: 389.4437, val: 417.8247
# Current sigma2: 0.0100000
# Already trained for 1.4014922936757406 min; Remaining 3.9888626820001845 min.
# Saving model...
# Model saved.
# 13/49, test loss: -elbo: 401.0428, recons_loss_weighted: 650.9786, recons_loss_ls: 13.0196, KL_loss: 35.2811, sigma_regularisor: -110.5241, code_std_dev: [0.04293392 0.07135968 0.04099882 0.1407344  0.03599252 0.03695852]
# Loss on training and val sets:
# train: 366.5807, val: 442.3960
# Current sigma2: 0.0100000
# Already trained for 1.513144814968109 min; Remaining 3.8909438099179945 min.
# Saving model...
# Model saved.
# 14/49, test loss: -elbo: 395.7991, recons_loss_weighted: 640.4499, recons_loss_ls: 12.8090, KL_loss: 35.3018, sigma_regularisor: -110.5241, code_std_dev: [0.05540058 0.09062569 0.07322473 0.11533439 0.0383494  0.04996937]
# Loss on training and val sets:
# train: 353.6957, val: 388.8917
# Current sigma2: 0.0100000
# Already trained for 1.6179203708966574 min; Remaining 3.7751475320922006 min.
# Saving model...
# Model saved.
# 15/49, test loss: -elbo: 394.8330, recons_loss_weighted: 639.3007, recons_loss_ls: 12.7860, KL_loss: 34.9103, sigma_regularisor: -110.5241, code_std_dev: [0.05832216 0.07700428 0.06634279 0.0944033  0.06672763 0.07036516]
# Loss on training and val sets:
# train: 338.7350, val: 370.8838
# Current sigma2: 0.0100000
# Already trained for 1.725127681096395 min; Remaining 3.665896322329839 min.
# Saving model...
# Model saved.
# 16/49, test loss: -elbo: 389.6901, recons_loss_weighted: 630.3360, recons_loss_ls: 12.6067, KL_loss: 34.2497, sigma_regularisor: -110.5241, code_std_dev: [0.05109954 0.07684363 0.05317989 0.11882418 0.0390645  0.0842758 ]
# Loss on training and val sets:
# train: 328.5109, val: 396.2040
# Current sigma2: 0.0100000
# Already trained for 1.8271754105885825 min; Remaining 3.546869914671954 min.
# Saving model...
# Model saved.
# 17/49, test loss: -elbo: 366.6784, recons_loss_weighted: 584.7920, recons_loss_ls: 11.6958, KL_loss: 34.0101, sigma_regularisor: -110.5241, code_std_dev: [0.05462839 0.07119656 0.03801977 0.10484333 0.05740602 0.05390478]
# Loss on training and val sets:
# train: 317.7025, val: 383.1387
# Current sigma2: 0.0100000
# Already trained for 1.9311538894971212 min; Remaining 3.433162470217104 min.
# Saving model...
# Model saved.
# 18/49, test loss: -elbo: 362.6734, recons_loss_weighted: 576.9731, recons_loss_ls: 11.5395, KL_loss: 33.9145, sigma_regularisor: -110.5241, code_std_dev: [0.04022643 0.06621891 0.04448481 0.11439122 0.05913399 0.06134909]
# Loss on training and val sets:
# train: 310.6877, val: 358.3163
# Current sigma2: 0.0100000
# Already trained for 2.0344757239023843 min; Remaining 3.3194077600512584 min.
# Saving model...
# Model saved.
# 19/49, test loss: -elbo: 364.0386, recons_loss_weighted: 580.3383, recons_loss_ls: 11.6068, KL_loss: 33.5971, sigma_regularisor: -110.5241, code_std_dev: [0.04544592 0.07651409 0.03360061 0.10527728 0.04326305 0.06037427]
# Loss on training and val sets:
# train: 302.6652, val: 325.9331
# Current sigma2: 0.0100000
# Already trained for 2.137555952866872 min; Remaining 3.206333929300308 min.
# Saving model...
# Model saved.
# 20/49, test loss: -elbo: 364.0275, recons_loss_weighted: 580.6689, recons_loss_ls: 11.6134, KL_loss: 33.4206, sigma_regularisor: -110.5241, code_std_dev: [0.03952662 0.0710664  0.06915545 0.07330935 0.05960505 0.06777067]
# Loss on training and val sets:
# train: 293.8888, val: 344.7835
# Current sigma2: 0.0100000
# Already trained for 2.246238652865092 min; Remaining 3.101948615861317 min.
# Saving model...
# Model saved.
# 21/49, test loss: -elbo: 357.8337, recons_loss_weighted: 567.8346, recons_loss_ls: 11.3567, KL_loss: 33.6441, sigma_regularisor: -110.5241, code_std_dev: [0.05548617 0.06656358 0.03276605 0.08537009 0.03251705 0.0489615 ]
# Loss on training and val sets:
# train: 289.5415, val: 368.4504
# Current sigma2: 0.0100000
# Already trained for 2.3629441618919373 min; Remaining 3.0073834787715565 min.
# Saving model...
# Model saved.
# 22/49, test loss: -elbo: 355.8397, recons_loss_weighted: 564.0773, recons_loss_ls: 11.2815, KL_loss: 33.5286, sigma_regularisor: -110.5241, code_std_dev: [0.05806411 0.0756016  0.046147   0.084806   0.05313971 0.04831764]
# Loss on training and val sets:
# train: 282.5034, val: 339.1646
# Current sigma2: 0.0100000
# Already trained for 2.4825549920399985 min; Remaining 2.914303686307824 min.
# Saving model...
# Model saved.
# 23/49, test loss: -elbo: 355.3599, recons_loss_weighted: 564.4088, recons_loss_ls: 11.2882, KL_loss: 32.8831, sigma_regularisor: -110.5241, code_std_dev: [0.04931181 0.0674855  0.03011631 0.1332645  0.03688794 0.04640398]
# Loss on training and val sets:
# train: 276.1938, val: 345.0197
# Current sigma2: 0.0100000
# Already trained for 2.6010852297147116 min; Remaining 2.817842332190937 min.
# Saving model...
# Model saved.
# 24/49, test loss: -elbo: 338.7961, recons_loss_weighted: 531.7901, recons_loss_ls: 10.6358, KL_loss: 32.6287, sigma_regularisor: -110.5241, code_std_dev: [0.03550835 0.06521463 0.03261428 0.11743613 0.03690901 0.05564067]
# Loss on training and val sets:
# train: 271.9724, val: 328.4002
# Current sigma2: 0.0100000
# Already trained for 2.7167786995569867 min; Remaining 2.7167786995569867 min.
# Saving model...
# Model saved.
# 25/49, test loss: -elbo: 354.0266, recons_loss_weighted: 563.5474, recons_loss_ls: 11.2709, KL_loss: 31.9805, sigma_regularisor: -110.5241, code_std_dev: [0.05153836 0.09582897 0.03446728 0.15349793 0.05359027 0.03607459]
# Loss on training and val sets:
# train: 268.7024, val: 330.1820
# Current sigma2: 0.0100000
# Already trained for 2.8345973014831545 min; Remaining 2.6165513552152198 min.
# Saving model...
# Model saved.
# 26/49, test loss: -elbo: 340.0842, recons_loss_weighted: 535.9708, recons_loss_ls: 10.7194, KL_loss: 31.8265, sigma_regularisor: -110.5241, code_std_dev: [0.04189517 0.065083   0.02928745 0.13405448 0.07870538 0.07200947]
# Loss on training and val sets:
# train: 262.7205, val: 343.2995
# Current sigma2: 0.0100000
# Already trained for 2.953802307446798 min; Remaining 2.5162019656028276 min.
# Saving model...
# Model saved.
# 27/49, test loss: -elbo: 349.1346, recons_loss_weighted: 552.5170, recons_loss_ls: 11.0503, KL_loss: 32.6037, sigma_regularisor: -110.5241, code_std_dev: [0.03457476 0.07215746 0.03314355 0.1010401  0.06635995 0.0431084 ]
# Loss on training and val sets:
# train: 256.5621, val: 318.0039
# Current sigma2: 0.0100000
# Already trained for 3.062837489446004 min; Remaining 2.406515170279003 min.
# Saving model...
# Model saved.
# 28/49, test loss: -elbo: 332.7042, recons_loss_weighted: 519.5984, recons_loss_ls: 10.3920, KL_loss: 32.6326, sigma_regularisor: -110.5241, code_std_dev: [0.03381558 0.05873732 0.04123529 0.0728436  0.03576683 0.05151021]
# Loss on training and val sets:
# train: 254.8534, val: 315.3238
# Current sigma2: 0.0100000
# Already trained for 3.164843014876048 min; Remaining 2.2917828728412757 min.
# Saving model...
# Model saved.
# 29/49, test loss: -elbo: 345.6792, recons_loss_weighted: 546.5241, recons_loss_ls: 10.9305, KL_loss: 32.1448, sigma_regularisor: -110.5241, code_std_dev: [0.05060712 0.07119931 0.04041392 0.09356606 0.03826592 0.04317825]
# Loss on training and val sets:
# train: 250.0721, val: 308.9889
# Current sigma2: 0.0100000
# Already trained for 3.2707995971043906 min; Remaining 2.1805330647362604 min.
# Saving model...
# Model saved.
# 30/49, test loss: -elbo: 337.3629, recons_loss_weighted: 531.1157, recons_loss_ls: 10.6223, KL_loss: 31.5327, sigma_regularisor: -110.5241, code_std_dev: [0.06014672 0.06896306 0.03147496 0.11904091 0.06484741 0.05485383]
# Loss on training and val sets:
# train: 244.5742, val: 339.4306
# Current sigma2: 0.0100000
# Already trained for 3.37722909450531 min; Remaining 2.0699146063097063 min.
# Saving model...
# Model saved.
# 31/49, test loss: -elbo: 338.9003, recons_loss_weighted: 533.8429, recons_loss_ls: 10.6769, KL_loss: 31.7065, sigma_regularisor: -110.5241, code_std_dev: [0.04077506 0.06044031 0.03440097 0.11485388 0.05932998 0.04569442]
# Loss on training and val sets:
# train: 241.8974, val: 319.3730
# Current sigma2: 0.0100000
# Already trained for 3.4877002676328024 min; Remaining 1.9618314005434514 min.
# Saving model...
# Model saved.
# 32/49, test loss: -elbo: 340.8723, recons_loss_weighted: 538.2570, recons_loss_ls: 10.7651, KL_loss: 31.4714, sigma_regularisor: -110.5241, code_std_dev: [0.05641539 0.07249753 0.04182379 0.09553985 0.05913374 0.06036404]
# Loss on training and val sets:
# train: 238.2229, val: 316.2758
# Current sigma2: 0.0100000
# Already trained for 3.5989932378133136 min; Remaining 1.854026819479586 min.
# Saving model...
# Model saved.
# 33/49, test loss: -elbo: 332.0353, recons_loss_weighted: 520.0497, recons_loss_ls: 10.4010, KL_loss: 31.7381, sigma_regularisor: -110.5241, code_std_dev: [0.03753712 0.06333215 0.04945502 0.10888253 0.04955224 0.05342449]
# Loss on training and val sets:
# train: 235.7007, val: 316.3021
# Current sigma2: 0.0100000
# Already trained for 3.7098889191945394 min; Remaining 1.7458300796209596 min.
# Saving model...
# Model saved.
# 34/49, test loss: -elbo: 335.7599, recons_loss_weighted: 528.2333, recons_loss_ls: 10.5647, KL_loss: 31.3709, sigma_regularisor: -110.5241, code_std_dev: [0.03535552 0.06900257 0.03743827 0.12170406 0.04888963 0.05446334]
# Loss on training and val sets:
# train: 233.1576, val: 308.4369
# Current sigma2: 0.0100000
# Already trained for 3.8241203308105467 min; Remaining 1.63890871320452 min.
# Saving model...
# Model saved.
# 35/49, test loss: -elbo: 342.7790, recons_loss_weighted: 542.8333, recons_loss_ls: 10.8567, KL_loss: 31.0900, sigma_regularisor: -110.5241, code_std_dev: [0.05723093 0.07585944 0.03075357 0.128425   0.06137548 0.03991792]
# Loss on training and val sets:
# train: 228.8608, val: 310.3447
# Current sigma2: 0.0100000
# Already trained for 3.936513392130534 min; Remaining 1.5308663191618743 min.
# Saving model...
# Model saved.
# 36/49, test loss: -elbo: 340.5054, recons_loss_weighted: 538.0158, recons_loss_ls: 10.7603, KL_loss: 31.2251, sigma_regularisor: -110.5241, code_std_dev: [0.05338727 0.07932603 0.03472377 0.12150088 0.07026213 0.05121447]
# Loss on training and val sets:
# train: 223.6241, val: 300.8629
# Current sigma2: 0.0100000
# Already trained for 4.038180259863536 min; Remaining 1.4188200913034046 min.
# Saving model...
# Model saved.
# 37/49, test loss: -elbo: 337.5947, recons_loss_weighted: 532.4918, recons_loss_ls: 10.6498, KL_loss: 31.0764, sigma_regularisor: -110.5241, code_std_dev: [0.0502988  0.0772183  0.03074136 0.10676817 0.05072922 0.06224462]
# Loss on training and val sets:
# train: 224.2759, val: 318.7029
# Current sigma2: 0.0100000
# Already trained for 4.137028551101684 min; Remaining 1.306430068768953 min.
# Saving model...
# Model saved.
# 38/49, test loss: -elbo: 338.4216, recons_loss_weighted: 533.6395, recons_loss_ls: 10.6728, KL_loss: 31.3295, sigma_regularisor: -110.5241, code_std_dev: [0.04156899 0.08495455 0.02666144 0.13506372 0.04317416 0.03392678]
# Loss on training and val sets:
# train: 219.5405, val: 308.9191
# Current sigma2: 0.0100000
# Already trained for 4.242810563246409 min; Remaining 1.1966901588643717 min.
# Saving model...
# Model saved.
# 39/49, test loss: -elbo: 331.9220, recons_loss_weighted: 519.8134, recons_loss_ls: 10.3963, KL_loss: 31.7429, sigma_regularisor: -110.5241, code_std_dev: [0.02588946 0.07264721 0.03077123 0.08204409 0.04910636 0.0513343 ]
# Loss on training and val sets:
# train: 217.5277, val: 315.4063
# Current sigma2: 0.0100000
# Already trained for 4.346961963176727 min; Remaining 1.0867404907941818 min.
# Saving model...
# Model saved.
# 40/49, test loss: -elbo: 324.5851, recons_loss_weighted: 504.4610, recons_loss_ls: 10.0892, KL_loss: 32.0822, sigma_regularisor: -110.5241, code_std_dev: [0.03105274 0.0546009  0.03275461 0.08234406 0.02972272 0.03312133]
# Loss on training and val sets:
# train: 215.2614, val: 277.2542
# Current sigma2: 0.0100000
# Already trained for 4.457528193791707 min; Remaining 0.9784817986372041 min.
# Saving model...
# Model saved.
# 41/49, test loss: -elbo: 325.6333, recons_loss_weighted: 507.8530, recons_loss_ls: 10.1571, KL_loss: 31.4344, sigma_regularisor: -110.5241, code_std_dev: [0.04621768 0.06326345 0.03364087 0.07891078 0.04065827 0.05105849]
# Loss on training and val sets:
# train: 211.1495, val: 293.4718
# Current sigma2: 0.0100000
# Already trained for 4.563865172863006 min; Remaining 0.8693076519739059 min.
# Saving model...
# Model saved.
# 42/49, test loss: -elbo: 337.8055, recons_loss_weighted: 532.6920, recons_loss_ls: 10.6538, KL_loss: 31.1871, sigma_regularisor: -110.5241, code_std_dev: [0.05190304 0.06667947 0.0367897  0.0873747  0.04217799 0.0498909 ]
# Loss on training and val sets:
# train: 209.8916, val: 288.9960
# Current sigma2: 0.0100000
# Already trained for 4.670042320092519 min; Remaining 0.7602394474569217 min.
# Saving model...
# Model saved.
# 43/49, test loss: -elbo: 336.7255, recons_loss_weighted: 531.7610, recons_loss_ls: 10.6352, KL_loss: 30.5726, sigma_regularisor: -110.5241, code_std_dev: [0.05638443 0.08216915 0.04081871 0.1280539  0.07188332 0.07644961]
# Loss on training and val sets:
# train: 207.0546, val: 307.7120
# Current sigma2: 0.0100000
# Already trained for 4.772632277011871 min; Remaining 0.6508134923198006 min.
# Saving model...
# Model saved.
# 44/49, test loss: -elbo: 334.6383, recons_loss_weighted: 527.1785, recons_loss_ls: 10.5436, KL_loss: 30.7767, sigma_regularisor: -110.5241, code_std_dev: [0.03507235 0.08161443 0.04354992 0.13031772 0.04491518 0.05076027]
# Loss on training and val sets:
# train: 205.4429, val: 287.7480
# Current sigma2: 0.0100000
# Already trained for 4.87929352124532 min; Remaining 0.5421437245828133 min.
# Saving model...
# Model saved.
# 45/49, test loss: -elbo: 329.3473, recons_loss_weighted: 515.5029, recons_loss_ls: 10.3101, KL_loss: 31.3235, sigma_regularisor: -110.5241, code_std_dev: [0.03282437 0.06040234 0.03324768 0.10846887 0.05039171 0.05339816]
# Loss on training and val sets:
# train: 205.0299, val: 298.9941
# Current sigma2: 0.0100000
# Already trained for 4.982776232560476 min; Remaining 0.4332848897878675 min.
# Saving model...
# Model saved.
# 46/49, test loss: -elbo: 319.8439, recons_loss_weighted: 498.0920, recons_loss_ls: 9.9618, KL_loss: 30.5255, sigma_regularisor: -110.5241, code_std_dev: [0.04797833 0.08926461 0.0272934  0.1281933  0.05636955 0.06248665]
# Loss on training and val sets:
# train: 200.9281, val: 282.3215
# Current sigma2: 0.0100000
# Already trained for 5.086841702461243 min; Remaining 0.32469202356135596 min.
# Saving model...
# Model saved.
# 47/49, test loss: -elbo: 326.6591, recons_loss_weighted: 510.6767, recons_loss_ls: 10.2135, KL_loss: 31.0484, sigma_regularisor: -110.5241, code_std_dev: [0.0417086  0.06955341 0.03145133 0.08437267 0.04691305 0.05066396]
# Loss on training and val sets:
# train: 198.8640, val: 287.8086
# Current sigma2: 0.0100000
# Already trained for 5.194581425189972 min; Remaining 0.21644089271624883 min.
# Saving model...
# Model saved.
# 48/49, test loss: -elbo: 328.7461, recons_loss_weighted: 515.2296, recons_loss_ls: 10.3046, KL_loss: 30.8590, sigma_regularisor: -110.5241, code_std_dev: [0.03563941 0.07777019 0.03548235 0.11106156 0.0377711  0.05232186]
# Loss on training and val sets:
# train: 197.1170, val: 301.1995
# Current sigma2: 0.0100000
# Already trained for 5.295218773682913 min; Remaining 0.10806568925883495 min.
# Saving model...
# Model saved.
# 49/49, test loss: -elbo: 331.0866, recons_loss_weighted: 518.7809, recons_loss_ls: 10.3756, KL_loss: 31.4238, sigma_regularisor: -110.5241, code_std_dev: [0.03960021 0.06628417 0.03138528 0.09140497 0.03505672 0.04361748]
# Loss on training and val sets:
# train: 194.5392, val: 297.8903
# Current sigma2: 0.0100000
# Already trained for 5.4011670311292015 min; Remaining 0.0 min.

# %%
# load LSTM model
lstm_model = lstmKerasModel(data)
lstm_model.produce_embeddings(config, model_vae, data, sess)
lstm_nn_model = lstm_model.create_lstm_model(config)
lstm_nn_model.summary()   # Display the model's architecture

# checkpoint path
checkpoint_path = config['checkpoint_dir_lstm'] + "cp.ckpt"
checkpoint_dir = os.path.dirname(checkpoint_path)
# Create a callback that saves the model's weights
cp_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path,
                                                 save_weights_only=True,
                                                 verbose=1)
# load weights if possible
lstm_model.load_model(lstm_nn_model, config, checkpoint_path)
# start training
if config['TRAIN_LSTM']:
    if config['num_epochs_lstm'] > 0:
        lstm_model.train(config, lstm_nn_model, cp_callback)

    # make a prediction on the test set using the trained model
    lstm_embedding = lstm_nn_model.predict(lstm_model.x_test, batch_size=config['batch_size_lstm'])
    print(lstm_embedding.shape)

    # visualise the first 10 test sequences
    for i in range(10):
        lstm_model.plot_lstm_embedding_prediction(i, config, model_vae, sess, data, lstm_embedding)
# Out:
# g model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-1-channels-comb-48-6-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 866/866 [==============================] - 0s 508us/sample - loss: 2.2923 - mean_squared_error: 2.2923 - val_loss: 2.4376 - val_mean_squared_error: 2.4376
# Epoch 56/100
# 864/866 [============================>.] - ETA: 0s - loss: 2.2714 - mean_squared_error: 2.2714
# Epoch 00056: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-1-channels-comb-48-6-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 866/866 [==============================] - 0s 506us/sample - loss: 2.2744 - mean_squared_error: 2.2744 - val_loss: 2.4238 - val_mean_squared_error: 2.4238
# Epoch 57/100
# 800/866 [==========================>...] - ETA: 0s - loss: 2.2713 - mean_squared_error: 2.2713
# Epoch 00057: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-1-channels-comb-48-6-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 866/866 [==============================] - 0s 542us/sample - loss: 2.2612 - mean_squared_error: 2.2612 - val_loss: 2.4142 - val_mean_squared_error: 2.4142
# Epoch 58/100
# 800/866 [==========================>...] - ETA: 0s - loss: 2.2429 - mean_squared_error: 2.2429
# Epoch 00058: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-1-channels-comb-48-6-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 866/866 [==============================] - 1s 600us/sample - loss: 2.2412 - mean_squared_error: 2.2412 - val_loss: 2.3844 - val_mean_squared_error: 2.3844
# Epoch 59/100
# 736/866 [========================>.....] - ETA: 0s - loss: 2.2167 - mean_squared_error: 2.2167
# Epoch 00059: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-1-channels-comb-48-6-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 866/866 [==============================] - 0s 523us/sample - loss: 2.2214 - mean_squared_error: 2.2214 - val_loss: 2.3730 - val_mean_squared_error: 2.3730
# Epoch 60/100
# 768/866 [=========================>....] - ETA: 0s - loss: 2.2094 - mean_squared_error: 2.2094
# Epoch 00060: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-1-channels-comb-48-6-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 866/866 [==============================] - 1s 586us/sample - loss: 2.2040 - mean_squared_error: 2.2040 - val_loss: 2.3617 - val_mean_squared_error: 2.3617
# Epoch 61/100
# 832/866 [===========================>..] - ETA: 0s - loss: 2.1886 - mean_squared_error: 2.1886
# Epoch 00061: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-1-channels-comb-48-6-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 866/866 [==============================] - 0s 518us/sample - loss: 2.1889 - mean_squared_error: 2.1889 - val_loss: 2.3432 - val_mean_squared_error: 2.3432
# Epoch 62/100
# 800/866 [==========================>...] - ETA: 0s - loss: 2.1780 - mean_squared_error: 2.1780
# Epoch 00062: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-1-channels-comb-48-6-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 866/866 [==============================] - 0s 561us/sample - loss: 2.1737 - mean_squared_error: 2.1737 - val_loss: 2.3336 - val_mean_squared_error: 2.3336
# Epoch 63/100
# 768/866 [=========================>....] - ETA: 0s - loss: 2.1671 - mean_squared_error: 2.1671
# Epoch 00063: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-1-channels-comb-48-6-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 866/866 [==============================] - 0s 481us/sample - loss: 2.1593 - mean_squared_error: 2.1593 - val_loss: 2.3177 - val_mean_squared_error: 2.3177
# Epoch 64/100
# 768/866 [=========================>....] - ETA: 0s - loss: 2.1393 - mean_squared_error: 2.1393
# Epoch 00064: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-1-channels-comb-48-6-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 866/866 [==============================] - 0s 465us/sample - loss: 2.1438 - mean_squared_error: 2.1438 - val_loss: 2.3058 - val_mean_squared_error: 2.3058
# Epoch 65/100
# 864/866 [============================>.] - ETA: 0s - loss: 2.1293 - mean_squared_error: 2.1293
# Epoch 00065: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-1-channels-comb-48-6-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 866/866 [==============================] - 1s 584us/sample - loss: 2.1285 - mean_squared_error: 2.1285 - val_loss: 2.2949 - val_mean_squared_error: 2.2949
# Epoch 66/100
# 800/866 [==========================>...] - ETA: 0s - loss: 2.1144 - mean_squared_error: 2.1144
# Epoch 00066: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-1-channels-comb-48-6-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 866/866 [==============================] - 0s 536us/sample - loss: 2.1155 - mean_squared_error: 2.1155 - val_loss: 2.2814 - val_mean_squared_error: 2.2814
# Epoch 67/100
# 768/866 [=========================>....] - ETA: 0s - loss: 2.0987 - mean_squared_error: 2.0987
# Epoch 00067: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-1-channels-comb-48-6-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 866/866 [==============================] - 0s 501us/sample - loss: 2.1023 - mean_squared_error: 2.1023 - val_loss: 2.2678 - val_mean_squared_error: 2.2678
# Epoch 68/100
# 800/866 [==========================>...] - ETA: 0s - loss: 2.0804 - mean_squared_error: 2.0804
# Epoch 00068: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-1-channels-comb-48-6-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 866/866 [==============================] - 0s 512us/sample - loss: 2.0874 - mean_squared_error: 2.0874 - val_loss: 2.2603 - val_mean_squared_error: 2.2603
# Epoch 69/100
# 864/866 [============================>.] - ETA: 0s - loss: 2.0744 - mean_squared_error: 2.0744
# Epoch 00069: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-1-channels-comb-48-6-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 866/866 [==============================] - 0s 530us/sample - loss: 2.0762 - mean_squared_error: 2.0762 - val_loss: 2.2461 - val_mean_squared_error: 2.2461
# Epoch 70/100
# 800/866 [==========================>...] - ETA: 0s - loss: 2.0548 - mean_squared_error: 2.0548
# Epoch 00070: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-1-channels-comb-48-6-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 866/866 [==============================] - 0s 483us/sample - loss: 2.0625 - mean_squared_error: 2.0625 - val_loss: 2.2369 - val_mean_squared_error: 2.2369
# Epoch 71/100
# 800/866 [==========================>...] - ETA: 0s - loss: 2.0582 - mean_squared_error: 2.0582
# Epoch 00071: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-1-channels-comb-48-6-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 866/866 [==============================] - 0s 545us/sample - loss: 2.0501 - mean_squared_error: 2.0501 - val_loss: 2.2241 - val_mean_squared_error: 2.2241
# Epoch 72/100
# 800/866 [==========================>...] - ETA: 0s - loss: 2.0375 - mean_squared_error: 2.0375
# Epoch 00072: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-1-channels-comb-48-6-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 866/866 [==============================] - 0s 537us/sample - loss: 2.0381 - mean_squared_error: 2.0381 - val_loss: 2.2184 - val_mean_squared_error: 2.2184
# Epoch 73/100
# 832/866 [===========================>..] - ETA: 0s - loss: 2.0221 - mean_squared_error: 2.0221
# Epoch 00073: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-1-channels-comb-48-6-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 866/866 [==============================] - 0s 487us/sample - loss: 2.0269 - mean_squared_error: 2.0269 - val_loss: 2.2078 - val_mean_squared_error: 2.2078
# Epoch 74/100
# 800/866 [==========================>...] - ETA: 0s - loss: 2.0205 - mean_squared_error: 2.0205
# Epoch 00074: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-1-channels-comb-48-6-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 866/866 [==============================] - 0s 494us/sample - loss: 2.0138 - mean_squared_error: 2.0138 - val_loss: 2.1951 - val_mean_squared_error: 2.1951
# Epoch 75/100
# 864/866 [============================>.] - ETA: 0s - loss: 2.0033 - mean_squared_error: 2.0033
# Epoch 00075: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-1-channels-comb-48-6-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 866/866 [==============================] - 0s 518us/sample - loss: 2.0032 - mean_squared_error: 2.0032 - val_loss: 2.1849 - val_mean_squared_error: 2.1849
# Epoch 76/100
# 768/866 [=========================>....] - ETA: 0s - loss: 2.0003 - mean_squared_error: 2.0003
# Epoch 00076: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-1-channels-comb-48-6-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 866/866 [==============================] - 0s 527us/sample - loss: 1.9905 - mean_squared_error: 1.9905 - val_loss: 2.1814 - val_mean_squared_error: 2.1814
# Epoch 77/100
# 800/866 [==========================>...] - ETA: 0s - loss: 1.9707 - mean_squared_error: 1.9707
# Epoch 00077: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-1-channels-comb-48-6-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 866/866 [==============================] - 0s 553us/sample - loss: 1.9791 - mean_squared_error: 1.9791 - val_loss: 2.1685 - val_mean_squared_error: 2.1685
# Epoch 78/100
# 768/866 [=========================>....] - ETA: 0s - loss: 1.9720 - mean_squared_error: 1.9720
# Epoch 00078: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-1-channels-comb-48-6-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 866/866 [==============================] - 0s 492us/sample - loss: 1.9695 - mean_squared_error: 1.9695 - val_loss: 2.1556 - val_mean_squared_error: 2.1556
# Epoch 79/100
# 864/866 [============================>.] - ETA: 0s - loss: 1.9601 - mean_squared_error: 1.9601
# Epoch 00079: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-1-channels-comb-48-6-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 866/866 [==============================] - 0s 526us/sample - loss: 1.9591 - mean_squared_error: 1.9591 - val_loss: 2.1425 - val_mean_squared_error: 2.1425
# Epoch 80/100
# 864/866 [============================>.] - ETA: 0s - loss: 1.9465 - mean_squared_error: 1.9465
# Epoch 00080: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-1-channels-comb-48-6-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 866/866 [==============================] - 1s 641us/sample - loss: 1.9473 - mean_squared_error: 1.9473 - val_loss: 2.1448 - val_mean_squared_error: 2.1448
# Epoch 81/100
# 832/866 [===========================>..] - ETA: 0s - loss: 1.9364 - mean_squared_error: 1.9364
# Epoch 00081: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-1-channels-comb-48-6-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 866/866 [==============================] - 1s 597us/sample - loss: 1.9363 - mean_squared_error: 1.9363 - val_loss: 2.1283 - val_mean_squared_error: 2.1283
# Epoch 82/100
# 736/866 [========================>.....] - ETA: 0s - loss: 1.9179 - mean_squared_error: 1.9179
# Epoch 00082: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-1-channels-comb-48-6-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 866/866 [==============================] - 0s 554us/sample - loss: 1.9252 - mean_squared_error: 1.9252 - val_loss: 2.1276 - val_mean_squared_error: 2.1276
# Epoch 83/100
# 864/866 [============================>.] - ETA: 0s - loss: 1.9151 - mean_squared_error: 1.9151
# Epoch 00083: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-1-channels-comb-48-6-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 866/866 [==============================] - 0s 519us/sample - loss: 1.9144 - mean_squared_error: 1.9144 - val_loss: 2.1197 - val_mean_squared_error: 2.1197
# Epoch 84/100
# 864/866 [============================>.] - ETA: 0s - loss: 1.9035 - mean_squared_error: 1.9035
# Epoch 00084: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-1-channels-comb-48-6-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 866/866 [==============================] - 0s 508us/sample - loss: 1.9037 - mean_squared_error: 1.9037 - val_loss: 2.1066 - val_mean_squared_error: 2.1066
# Epoch 85/100
# 736/866 [========================>.....] - ETA: 0s - loss: 1.9136 - mean_squared_error: 1.9136
# Epoch 00085: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-1-channels-comb-48-6-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 866/866 [==============================] - 0s 516us/sample - loss: 1.8962 - mean_squared_error: 1.8962 - val_loss: 2.1035 - val_mean_squared_error: 2.1035
# Epoch 86/100
# 832/866 [===========================>..] - ETA: 0s - loss: 1.8802 - mean_squared_error: 1.8802
# Epoch 00086: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-1-channels-comb-48-6-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 866/866 [==============================] - 0s 547us/sample - loss: 1.8840 - mean_squared_error: 1.8840 - val_loss: 2.0950 - val_mean_squared_error: 2.0950
# Epoch 87/100
# 864/866 [============================>.] - ETA: 0s - loss: 1.8724 - mean_squared_error: 1.8724
# Epoch 00087: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-1-channels-comb-48-6-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 866/866 [==============================] - 0s 540us/sample - loss: 1.8728 - mean_squared_error: 1.8728 - val_loss: 2.0860 - val_mean_squared_error: 2.0860
# Epoch 88/100
# 832/866 [===========================>..] - ETA: 0s - loss: 1.8605 - mean_squared_error: 1.8605
# Epoch 00088: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-1-channels-comb-48-6-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 866/866 [==============================] - 0s 520us/sample - loss: 1.8646 - mean_squared_error: 1.8646 - val_loss: 2.0806 - val_mean_squared_error: 2.0806
# Epoch 89/100
# 864/866 [============================>.] - ETA: 0s - loss: 1.8573 - mean_squared_error: 1.8573
# Epoch 00089: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-1-channels-comb-48-6-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 866/866 [==============================] - 0s 539us/sample - loss: 1.8572 - mean_squared_error: 1.8572 - val_loss: 2.0816 - val_mean_squared_error: 2.0816
# Epoch 90/100
# 768/866 [=========================>....] - ETA: 0s - loss: 1.8467 - mean_squared_error: 1.8467
# Epoch 00090: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-1-channels-comb-48-6-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 866/866 [==============================] - 0s 571us/sample - loss: 1.8472 - mean_squared_error: 1.8472 - val_loss: 2.0648 - val_mean_squared_error: 2.0648
# Epoch 91/100
# 768/866 [=========================>....] - ETA: 0s - loss: 1.8384 - mean_squared_error: 1.8384
# Epoch 00091: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-1-channels-comb-48-6-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 866/866 [==============================] - 0s 467us/sample - loss: 1.8363 - mean_squared_error: 1.8363 - val_loss: 2.0509 - val_mean_squared_error: 2.0509
# Epoch 92/100
# 864/866 [============================>.] - ETA: 0s - loss: 1.8255 - mean_squared_error: 1.8255
# Epoch 00092: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-1-channels-comb-48-6-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 866/866 [==============================] - 1s 664us/sample - loss: 1.8257 - mean_squared_error: 1.8257 - val_loss: 2.0512 - val_mean_squared_error: 2.0512
# Epoch 93/100
# 800/866 [==========================>...] - ETA: 0s - loss: 1.8177 - mean_squared_error: 1.8177
# Epoch 00093: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-1-channels-comb-48-6-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 866/866 [==============================] - 0s 559us/sample - loss: 1.8169 - mean_squared_error: 1.8169 - val_loss: 2.0422 - val_mean_squared_error: 2.0422
# Epoch 94/100
# 768/866 [=========================>....] - ETA: 0s - loss: 1.8229 - mean_squared_error: 1.8229
# Epoch 00094: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-1-channels-comb-48-6-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 866/866 [==============================] - 0s 516us/sample - loss: 1.8072 - mean_squared_error: 1.8072 - val_loss: 2.0343 - val_mean_squared_error: 2.0343
# Epoch 95/100
# 832/866 [===========================>..] - ETA: 0s - loss: 1.8038 - mean_squared_error: 1.8038
# Epoch 00095: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-1-channels-comb-48-6-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 866/866 [==============================] - 0s 542us/sample - loss: 1.7985 - mean_squared_error: 1.7985 - val_loss: 2.0322 - val_mean_squared_error: 2.0322
# Epoch 96/100
# 800/866 [==========================>...] - ETA: 0s - loss: 1.7852 - mean_squared_error: 1.7852
# Epoch 00096: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-1-channels-comb-48-6-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 866/866 [==============================] - 0s 514us/sample - loss: 1.7898 - mean_squared_error: 1.7898 - val_loss: 2.0201 - val_mean_squared_error: 2.0201
# Epoch 97/100
# 800/866 [==========================>...] - ETA: 0s - loss: 1.7776 - mean_squared_error: 1.7776
# Epoch 00097: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-1-channels-comb-48-6-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 866/866 [==============================] - 0s 503us/sample - loss: 1.7800 - mean_squared_error: 1.7800 - val_loss: 2.0144 - val_mean_squared_error: 2.0144
# Epoch 98/100
# 864/866 [============================>.] - ETA: 0s - loss: 1.7715 - mean_squared_error: 1.7715
# Epoch 00098: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-1-channels-comb-48-6-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 866/866 [==============================] - 1s 650us/sample - loss: 1.7718 - mean_squared_error: 1.7718 - val_loss: 2.0088 - val_mean_squared_error: 2.0088
# Epoch 99/100
# 832/866 [===========================>..] - ETA: 0s - loss: 1.7694 - mean_squared_error: 1.7694
# Epoch 00099: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-1-channels-comb-48-6-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 866/866 [==============================] - 0s 567us/sample - loss: 1.7639 - mean_squared_error: 1.7639 - val_loss: 2.0032 - val_mean_squared_error: 2.0032
# Epoch 100/100
# 800/866 [==========================>...] - ETA: 0s - loss: 1.7612 - mean_squared_error: 1.7612
# Epoch 00100: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-1-channels-comb-48-6-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 866/866 [==============================] - 1s 610us/sample - loss: 1.7553 - mean_squared_error: 1.7553 - val_loss: 2.0028 - val_mean_squared_error: 2.0028
# (97, 5, 6)
# Decoded seq from VAE: (6, 48)
# Decoded seq from lstm: (5, 48)
# Decoded seq from VAE: (6, 48)
# Decoded seq from lstm: (5, 48)
# Decoded seq from VAE: (6, 48)
# Decoded seq from lstm: (5, 48)
# Decoded seq from VAE: (6, 48)
# Decoded seq from lstm: (5, 48)
# Decoded seq from VAE: (6, 48)
# Decoded seq from lstm: (5, 48)
# Decoded seq from VAE: (6, 48)
# Decoded seq from lstm: (5, 48)
# Decoded seq from VAE: (6, 48)
# Decoded seq from lstm: (5, 48)
# Decoded seq from VAE: (6, 48)
# Decoded seq from lstm: (5, 48)
# Decoded seq from VAE: (6, 48)
# Decoded seq from lstm: (5, 48)
# Decoded seq from VAE: (6, 48)
# Decoded seq from lstm: (5, 48)

# %%
# load normalised time series
save_dir = '../datasets/' + config['data_dir'] #NAB-known-anomaly/'
dataset = config['dataset']
file_name = config['filename']
filename = '{}.npz'.format(file_name)
result = dict(np.load(save_dir+filename, allow_pickle=True))
if dataset == 'machine_temp':
    result['test'] = result['test'][0]
    result['idx_anomaly_test'] = result['idx_anomaly_test'][0]
    result['t_test'] = result['t_test'][0]

# slice into rolling windows and rolling sequences
def slice_rolling_windows_and_sequences(config, time_seq):
    n_sample = len(time_seq)
    print("The given sequence has {} samples".format(n_sample))
    n_vae_win = n_sample - config['l_win'] + 1
    if config['n_channel'] == 1:
        rolling_windows = np.zeros((n_vae_win, config['l_win']))
    else:
        rolling_windows = np.zeros((n_vae_win, config['l_win'], config['n_channel']), dtype=float)
    for i in range(n_vae_win):
        if config['n_channel'] == 1:
            rolling_windows[i] = time_seq[i:i + config['l_win']].ravel()
        else:
            rolling_windows[i] = time_seq[i:i + config['l_win']]
        sample_m = np.mean(rolling_windows, axis=1)
        sample_std = np.std(rolling_windows, axis=1)

        n_lstm_seq = n_sample - config['l_seq']*config['l_win']+1
        if config['n_channel'] == 1:
            lstm_seq = np.zeros((n_lstm_seq, config['l_seq'], config['l_win']))
        else:
            lstm_seq = np.zeros((n_lstm_seq, config['l_seq'], config['l_win'], config['n_channel']), dtype=float)
    for i in range(n_lstm_seq):
        cur_seq = time_seq[i:i+config['l_seq']*config['l_win']]
        for j in range(config['l_seq']):
            if config['n_channel'] == 1:
                lstm_seq[i,j] = cur_seq[config['l_win']*j:config['l_win']*(j+1)].ravel()
            else:
                lstm_seq[i,j] = cur_seq[config['l_win']*j:config['l_win']*(j+1)]
    
    return rolling_windows, lstm_seq, sample_m, sample_std

test_windows, test_seq, test_sample_m, test_sample_std = slice_rolling_windows_and_sequences(config, result['test'])
if config['n_channel'] == 1:
    test_windows = np.expand_dims(test_windows, -1)
    test_seq = np.expand_dims(test_seq, -1)
else:
    test_windows = test_windows
    test_seq = test_seq
print(test_windows.shape)
print(test_seq.shape)
# Out:
# The given sequence has 1320 samples
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-f477bf8b5b3a> in <module>
#      39     return rolling_windows, lstm_seq, sample_m, sample_std
#      40
# ---> 41 test_windows, test_seq, test_sample_m, test_sample_std = slice_rolling_windows_and_sequences(config, result['test'])
#      42 if config['n_channel'] == 1:
#      43     test_windows = np.expand_dims(test_windows, -1)
#
# <ipython-input-7-f477bf8b5b3a> in slice_rolling_windows_and_sequences(config, time_seq)
#      35         cur_seq = time_seq[i:i+config['l_seq']*config['l_win']]
#      36         for j in range(config['l_seq']):
# ---> 37             lstm_seq[i,j] = cur_seq[config['l_win']*j:config['l_win']*(j+1)]
#      38
#      39     return rolling_windows, lstm_seq, sample_m, sample_std
#
# ValueError: could not broadcast input array from shape (48,1) into shape (48)

# %%
# Evaluate ELBO and LSTM prediction error on the validation set
# evaluate some anomaly detection metrics
def evaluate_vae_anomaly_metrics_for_a_window(test_win):
    feed_dict = {model_vae.original_signal: np.expand_dims(test_win, 0),
                 model_vae.is_code_input: False,
                 model_vae.code_input: np.zeros((1, config['code_size']))}

    # VAE reconstruction error
    recons_win_vae = np.squeeze(sess.run(model_vae.decoded, feed_dict=feed_dict))
    test_vae_recons_error = np.sum(np.square(recons_win_vae - test_win))

    # VAE latent embedding likelihood
    vae_code_mean, vae_code_std = sess.run([model_vae.code_mean, model_vae.code_std_dev], feed_dict=feed_dict)
    test_vae_kl = 0.5 * (np.sum(np.square(vae_code_mean)) + \
                            np.sum(np.square(vae_code_std)) - \
                            np.sum(np.log(np.square(vae_code_std))) - config['code_size'])

    # VAE ELBO loss
    sigma2 = 0.0005
    input_dims = model_vae.input_dims
    sigma_regularisor = input_dims/2. * np.log(sigma2) + input_dims * np.pi
    test_vae_elbo = test_vae_recons_error/sigma2 + test_vae_kl + sigma_regularisor
    return test_vae_recons_error, test_vae_kl, test_vae_elbo

def evaluate_lstm_anomaly_metric_for_a_seq(test_seq):
    feed_dict = {model_vae.original_signal: test_seq,
                 model_vae.is_code_input: False,
                 model_vae.code_input: np.zeros((1, config['code_size']))}
    vae_embedding = np.squeeze(sess.run(model_vae.code_mean, feed_dict=feed_dict))
    #print(vae_embedding.shape)
    lstm_embedding = np.squeeze(lstm_nn_model.predict(np.expand_dims(vae_embedding[:config['l_seq']-1], 0), batch_size=1))
    lstm_embedding_error = np.sum(np.square(vae_embedding[1:] - lstm_embedding))
    
    # LSTM prediction error
    feed_dict_lstm = {model_vae.original_signal: np.zeros((config['l_seq'] - 1, config['l_win'], test_seq.shape[2])),
                      model_vae.is_code_input: True,
                      model_vae.code_input: lstm_embedding}
    recons_win_lstm = np.squeeze(sess.run(model_vae.decoded, feed_dict=feed_dict_lstm))
    lstm_recons_error = np.sum(np.square(recons_win_lstm - np.squeeze(test_seq[1:])))
    return lstm_recons_error, lstm_embedding_error

n_val_vae = data.val_set_vae['data'].shape[0]
n_val_lstm = data.val_set_lstm['data'].shape[0]

val_vae_recons_error = np.zeros(n_val_vae)
val_vae_kl_error = np.zeros(n_val_vae)
val_vae_elbo_loss = np.zeros(n_val_vae)
for i in range(n_val_vae):
    val_vae_recons_error[i], val_vae_kl_error[i], val_vae_elbo_loss[i] = evaluate_vae_anomaly_metrics_for_a_window(data.val_set_vae['data'][i])

val_lstm_recons_error, val_lstm_embedding_error = np.zeros(n_val_lstm), np.zeros(n_val_lstm)
for i in range(n_val_lstm):
    val_lstm_recons_error[i], val_lstm_embedding_error[i] = evaluate_lstm_anomaly_metric_for_a_seq(data.val_set_lstm['data'][i])

# %%
from scipy.stats import norm
def plot_histogram(test_anomaly_metric, n_bins, title, mean=None, std=None, xlim=None, saveplot=False):
    test_anomaly_list = np.squeeze(np.ndarray.flatten(test_anomaly_metric))
    his = plt.hist(test_anomaly_list, bins=n_bins, density=True)
    if mean is None and std is None:
        mean = np.mean(test_anomaly_list)
        std = np.std(test_anomaly_list)
        legend_label = None
    else:
        legend_label = 1
    x_axis = np.arange(mean-5*std, mean+5*std, std/100)
    plt.plot(x_axis, norm.pdf(x_axis,mean,std))
    plt.title(title)
    plt.xlabel('anomaly score value')
    plt.ylabel('probability density')
    if xlim is not None:
        plt.xlim(0, xlim)
    else:
        plt.xlim(0, np.amax(test_anomaly_list))
    if legend_label is None:
        plt.legend(('Fitted Gaussian', 'histogram'))
    else:
        plt.legend(('normal data distribution','test data distribution (contain anomalies)'))
    if saveplot:
        savefig(config['result_dir']+'reconstruction_error_histogram.pdf')
    else:
        plt.show()
    threshold_25 = np.percentile(test_anomaly_list, 25)
    threshold_75 = np.percentile(test_anomaly_list, 75)
    threshold_1 = np.percentile(test_anomaly_list, 99)
    idx_large_error = np.squeeze(np.argwhere(test_anomaly_metric > threshold_1))
#     print(his[0][-20:])
#     print(his[1][-20:])
    print("25% percentile: {}".format(threshold_25))
    print("75% percentile: {}".format(threshold_75))
#     print("Median: {}".format(np.median(test_anomaly_list)))
#     print("Mean: {}".format(np.mean(test_anomaly_list)))
#     print("Std dev: {}".format(np.std(test_anomaly_list)))
    print("These windows scored the top 1% of anomaly metric ({}): \n{}".format(threshold_1, idx_large_error))
    return mean, std

# %%
# Histogram of VAE ELBO loss - validation set
vae_elbo_m, vae_elbo_std = plot_histogram(val_vae_elbo_loss, 100, 
                                          'VAE ELBO error distribution on the val set', 
                                          mean=None, std=None, xlim=None)

# %%
# Histogram of LSTM reconstruction error - validation set 
#  --> to decide the anomaly detection threshold
lstm_recons_m, lstm_recons_std = plot_histogram(val_lstm_recons_error, 100,  
                                              'LSTM reconstruction error distribution on the val set', 
                                              mean=None, std=None, xlim=None)

# %%
# Evaluate the anomaly metrics on the test windows and sequences
n_test_lstm = test_seq.shape[0]

test_lstm_recons_error, test_lstm_embedding_error = np.zeros(n_test_lstm), np.zeros(n_test_lstm)
for i in range(n_test_lstm):
    test_lstm_recons_error[i], test_lstm_embedding_error[i] = evaluate_lstm_anomaly_metric_for_a_seq(test_seq[i])
print("All windows' reconstruction error is computed.")
print("The total number of windows is {}".format(len(test_lstm_recons_error)))

# %%
# Histogram of LSTM reconstruction error - test set 
#  --> to detect anomaly now
_, _ = plot_histogram(test_lstm_recons_error, 100,
                      'LSTM reconstruction error distribution on the test set', 
                      mean=lstm_recons_m, std=lstm_recons_std, xlim=None, saveplot=True)

# %%
# Produce the ground truth anomaly indices 
# if result['idx_split'][0] == 0:
#     idx_anomaly_test = result['idx_anomaly_test']
# else:
#     idx_anomaly_test = result['idx_anomaly_test'][0]
idx_anomaly_test = result['idx_anomaly_test']    
anomaly_index_lstm = []
test_labels_lstm = np.zeros(n_test_lstm)
for i in range(len(idx_anomaly_test)):
    idx_start = idx_anomaly_test[i]-(config['l_win']*config['l_seq']-1)
    idx_end = idx_anomaly_test[i]+1
    if idx_start < 0:
        idx_start = 0
    if idx_end > n_test_lstm:
        idx_end = n_test_lstm
    anomaly_index_lstm.append(np.arange(idx_start,idx_end))
    test_labels_lstm[idx_start:idx_end] = 1
    
print(test_labels_lstm.shape)

# %%
def return_anomaly_idx_by_threshold(test_anomaly_metric, threshold):
    test_list = np.squeeze(np.ndarray.flatten(test_anomaly_metric))
    idx_error = np.squeeze(np.argwhere(test_anomaly_metric > threshold))
    
    if len(idx_error.shape) == 0:
        idx_error = np.expand_dims(idx_error, 0)
    
    return list(idx_error)

# %%
def augment_detected_idx(idx_detected_anomaly, anomaly_index):
    n_anomaly = len(anomaly_index)
    idx_detected_anomaly_extended = list(idx_detected_anomaly)
    lag = 0
    for i in range(n_anomaly):
        #print(idx_detected_anomaly)
        for j in idx_detected_anomaly:
            if j in anomaly_index[i]:
                in_original_detection = set(idx_detected_anomaly_extended)
                currect_anomaly_win = set(anomaly_index[i])
                idx_detected_anomaly_extended = idx_detected_anomaly_extended + list(currect_anomaly_win - in_original_detection)
                lag = j - anomaly_index[i][0]
                #print(j)
                break
                
    return list(np.sort(idx_detected_anomaly_extended)), lag

# %%
def count_TP_FP_FN(idx_detected_anomaly, anomaly_index, test_labels):
    n_TP = 0
    n_FP = 0
    n_detection = len(idx_detected_anomaly)
    for i in range(n_detection):
        if test_labels[idx_detected_anomaly[i]] == 1:
            n_TP = n_TP + 1
        else:
            n_FP = n_FP + 1
    
    idx_undetected = list(set(np.arange(len(test_labels)))- set(idx_detected_anomaly))
    n_FN = 0
    for i in idx_undetected:
        if test_labels[i] == 1:
            n_FN = n_FN + 1
    
    return n_TP, n_FP, n_FN

# %%
def compute_precision_and_recall(idx_detected_anomaly, anomaly_index, test_labels):
    # compute true positive
    n_TP, n_FP, n_FN = count_TP_FP_FN(idx_detected_anomaly, anomaly_index, test_labels)
    
    if n_TP + n_FP == 0:
        precision = 1
    else:
        precision = n_TP / (n_TP + n_FP)
    recall = n_TP / (n_TP + n_FN)
    if precision + recall == 0:
        F1 = 0
    else:
        F1 = 2* (precision * recall)/(precision + recall)
    
    return precision, recall, F1, n_TP, n_FP, n_FN

# %%
n_threshold = 200
precision = np.zeros(n_threshold)
recall = np.zeros(n_threshold)
F1 = np.zeros(n_threshold)
precision_aug = np.zeros(n_threshold)
recall_aug = np.zeros(n_threshold)
F1_aug = np.zeros(n_threshold)
i = 0
threshold_list = np.linspace(np.amin(test_lstm_recons_error), np.amax(test_lstm_recons_error), n_threshold, endpoint=True)
threshold_list = np.flip(threshold_list)
for threshold in threshold_list:
    #print(threshold_list[i])
    idx_detection_lstm = return_anomaly_idx_by_threshold(test_lstm_recons_error, threshold)
    precision[i], recall[i], F1[i], _, _, _ = compute_precision_and_recall(idx_detection_lstm, 
                                                                           anomaly_index_lstm, 
                                                                           test_labels_lstm)
    # augment the detection using the ground truth labels
    # a method to discount the factor one anomaly appears in multiple consecutive windows
    # introduced in "Unsupervised anomaly detection via variational auto-encoder for seasonal kpis in web applications"
    idx_detection_lstm_augmented, lag = augment_detected_idx(idx_detection_lstm, anomaly_index_lstm)
    precision_aug[i], recall_aug[i], F1_aug[i], _, _, _ = compute_precision_and_recall(idx_detection_lstm_augmented, 
                                                                                       anomaly_index_lstm, 
                                                                                       test_labels_lstm)
    i = i + 1
    #print(precision, recall, F1)

# %%
print("Best F1 score is {}".format(np.amax(F1)))
idx_best_threshold = np.squeeze(np.argwhere(F1 == np.amax(F1)))
print("Best threshold is {}".format(threshold_list[idx_best_threshold]))
print("At this threshold, precision is {}, recall is {}".format(precision[idx_best_threshold], recall[idx_best_threshold]))
average_precision = np.sum(precision[1:] * (recall[1:] - recall[:-1]))
print("Average precision is {}".format(average_precision))

print("\nAugmented detection:")
print("Best F1 score is {}".format(np.amax(F1_aug)))
idx_best_threshold = np.squeeze(np.argwhere(F1_aug == np.amax(F1_aug)))
print("Best threshold is {}".format(threshold_list[idx_best_threshold]))
print("At this threshold, precision is {}, recall is {}".format(precision_aug[idx_best_threshold], 
                                                                recall_aug[idx_best_threshold]))

average_precision_aug = np.sum(precision_aug[1:] * (recall_aug[1:] - recall_aug[:-1]))
print("Average precision is {}".format(average_precision_aug))

# %%
# Now select a threshold
print(idx_best_threshold.ndim)
if idx_best_threshold.ndim > 0:
    threshold = threshold_list[idx_best_threshold[0]]
else:
    threshold = threshold_list[idx_best_threshold]

#threshold = 1400
print("Threshold is {}".format(threshold))
idx_detection = return_anomaly_idx_by_threshold(test_lstm_recons_error, threshold)
print(idx_detection)
print(anomaly_index_lstm)
idx_detection_augmented, lag = augment_detected_idx(idx_detection, anomaly_index_lstm)
print(idx_detection_augmented)

precision, recall, F1, n_TP, n_FP, n_FN = compute_precision_and_recall(idx_detection_augmented, 
                                                                       anomaly_index_lstm, 
                                                                       test_labels_lstm)
print("\nPR evaluation using augmented detection:")
print("Avg Lag is {}".format(lag))
print("Precision: {}".format(precision))
print("Recall: {}".format(recall))
print("F1: {}".format(F1))
print("TP: {}".format(n_TP))
print("FP: {}".format(n_FP))
print("FN: {}".format(n_FN))

# %%
def slice_detected_indices_into_seq(idx_detection, interval):
    detected_seq = []
    i = 0
    while i < len(idx_detection):
        if i == 0:
            cur_seq = [idx_detection[i]]
            i = i + 1
        else:
            if idx_detection[i] - idx_detection[i-1] > interval:
                detected_seq.append(cur_seq)
                cur_seq = [idx_detection[i]]
            else:
                cur_seq.append(idx_detection[i])
                if i == len(idx_detection) - 1:
                    detected_seq.append(cur_seq)
            i = i + 1
    
    print("Detected {} sequences".format(len(detected_seq)))
    return detected_seq

# %%
def plot_detected_anomalies(idx_detection, interval, dataset, result, detection_method, augmented_flag=1, y_scale=5, y_lim=None):
    detected_seq = slice_detected_indices_into_seq(idx_detection, interval=interval)
    t_test = result['t_test']
    test = result['test']
    idx_anomaly_test = result['idx_anomaly_test']
        
    # plot detected sequences
    fig, axs = plt.subplots(2, 1, figsize=(18, 6), edgecolor='k')
    fig.subplots_adjust(hspace=.4, wspace=.4)
    axs[0].plot(t_test, test)

    error = np.zeros(t_test.shape)
    #error[0:len(test_lstm_recons_error)] = test_lstm_recons_error
    error[-len(test_lstm_recons_error):] = test_lstm_recons_error
    axs[1].plot(t_test, error)
    axs[1].plot(t_test, threshold * np.ones(t_test.shape), 'r--')
    print(t_test.shape)
    print(test_lstm_recons_error.shape)
    print(idx_detection)
    for j in range(len(idx_anomaly_test)):
        if j == 0:
            axs[0].plot(idx_anomaly_test[j] * np.ones(20), np.linspace(-y_scale, y_scale, 20), 'r--', label='true anomalies')
        else:
            axs[0].plot(idx_anomaly_test[j] * np.ones(20), np.linspace(-y_scale, y_scale, 20), 'r--')
        
    for i in range(len(detected_seq)):
        for j in detected_seq[i]:
            if j == detected_seq[0][0]:
                axs[0].plot((j+interval*2) * np.ones(20), np.linspace(-y_scale, -0.8*y_scale, 20), 'g-', label='detected anomalies')
            else:
                axs[0].plot((j+interval*2) * np.ones(20), np.linspace(-y_scale, -0.8*y_scale, 20), 'g-')
    
    for j in range(len(idx_anomaly_test)):
        axs[0].plot(idx_anomaly_test[j] * np.ones(20), np.linspace(-y_scale, y_scale, 20), 'r--')

    for i in range(len(detected_seq)):
        interval_x = np.asarray([detected_seq[i][0], detected_seq[i][-1]+interval*2])
        interval_y = np.asarray([y_scale,y_scale])
        if i == 0:
            axs[0].fill_between(interval_x, interval_y, alpha=0.2, color='y', label='detected anomaly windows')
        else:
            axs[0].fill_between(interval_x, interval_y, alpha=0.2, color='y')
        interval_y = np.asarray([-y_scale,-y_scale])
        axs[0].fill_between(interval_x, interval_y, alpha=0.2, color='y')
    axs[0].grid(True)
    axs[0].set_xlim(0, len(t_test))
    axs[1].set_xlim(0, len(t_test))
    if y_lim is None:
        axs[0].set_ylim(-y_scale, y_scale)
    else:
        axs[0].set_ylim(-y_scale, y_lim)
    axs[0].set_xlabel("timestamp (every {})".format(result['t_unit']))
    axs[0].set_ylabel("normalised readings")
    #axs.set_title("{} dataset test sequence\n(normalised by train mean {:.4f} and std {:.4f})\n Detection method: {}".format(dataset, 
    #                                                                                    result['train_m'], 
    #                                                                                    result['train_std'],
    #                                                                                    detection_method))
    axs[0].set_title("{} dataset test sequence\n Detection method: {}".format(dataset, detection_method))
    axs[0].legend()
    savefig(config['result_dir']+'detected_anomalies_{}_aug_{}.pdf'.format(detection_method, augmented_flag))

# %%
plot_detected_anomalies(idx_detection_augmented, 
                        interval=config['l_win']*config['l_seq']/2, 
                        dataset=dataset, 
                        result=result, 
                        detection_method='lstm reconstruction error',
                        augmented_flag=1,
                        y_scale=5,
                        y_lim=5)
