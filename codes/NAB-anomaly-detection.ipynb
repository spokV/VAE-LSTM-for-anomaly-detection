# %%
from google.colab import drive
drive.mount('/content/drive')
global GIT_DIR
GIT_DIR='/content/drive/My\ Drive/afeka/y2/sem1/dl/code/LSTM-VAE/VAE-LSTM-for-anomaly-detection'
# %cd $GIT_DIR
# !ls
# Out:
# Mounted at /content/drive
# /content/drive/My Drive/afeka/y2/sem1/dl/code/LSTM-VAE/VAE-LSTM-for-anomaly-detection
# ANOMALY-DETECTION-FOR-TIME-SERIES-USING-VAE-LSTM-HYBRID-MODEL.pdf
# codes
# datasets
# experiments
# figures
# README.md
# requirements.txt

# %%
# %cd $GIT_DIR/codes/
# Out:
# /content/drive/My Drive/afeka/y2/sem1/dl/code/LSTM-VAE/VAE-LSTM-for-anomaly-detection/codes

# %%
import warnings

def fxn():
    warnings.warn("deprecated", DeprecationWarning)

with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    fxn()

# %%
# %tensorflow_version 1.x
# Out:
# TensorFlow 1.x selected.

# %%
import tensorflow as tf
import tensorflow_probability as tfp
import numpy as np
import matplotlib.pylab as plt
from matplotlib.pyplot import plot, ion, show, savefig, cla, figure
import random
import time

# %%
import os
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"   # see issue #152
os.environ["CUDA_VISIBLE_DEVICES"]="0"

import tensorflow as tf
from data_loader import DataGenerator
from models import VAEmodel, lstmKerasModel
from trainers import vaeTrainer

from utils import process_config, create_dirs, get_args

# %%
from tensorflow.python.client import device_lib

def get_available_gpus():
    local_device_protos = device_lib.list_local_devices()
    return [x.name for x in local_device_protos if x.device_type == 'GPU']

print(get_available_gpus())
# Out:
# ['/device:GPU:0']

# %%
# load VAE model
config = process_config('NAB_config.json')
# create the experiments dirs
create_dirs([config['result_dir'], config['checkpoint_dir']])
# create tensorflow session
sess = tf.Session(config=tf.ConfigProto(log_device_placement=True))
# create your data generator
data = DataGenerator(config)
# create a CNN model
model_vae = VAEmodel(config)
# create a CNN model
trainer_vae = vaeTrainer(sess, model_vae, data, config)
model_vae.load(sess)

# here you train your model
if config['TRAIN_VAE']:
    if config['num_epochs_vae'] > 0:
        trainer_vae.train()
# Out:
# Device mapping:
# /job:localhost/replica:0/task:0/device:XLA_CPU:0 -> device: XLA_CPU device
# /job:localhost/replica:0/task:0/device:XLA_GPU:0 -> device: XLA_GPU device
# /job:localhost/replica:0/task:0/device:GPU:0 -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
#
# training:  [[-1.33635601  3.82605577]
#  [-1.33635601  3.82605577]
#  [ 0.01864954  4.17533683]
#  ...
#  [ 0.10606925 -0.37928818]
#  [ 0.0623594  -0.39325943]
#  [ 0.14977911 -0.39325943]]
# training:  (877, 24, 2)
# WARNING:tensorflow:From /content/drive/My Drive/afeka/y2/sem1/dl/code/LSTM-VAE/VAE-LSTM-for-anomaly-detection/codes/base.py:62: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# WARNING:tensorflow:From /content/drive/My Drive/afeka/y2/sem1/dl/code/LSTM-VAE/VAE-LSTM-for-anomaly-detection/codes/base.py:64: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# WARNING:tensorflow:From /content/drive/My Drive/afeka/y2/sem1/dl/code/LSTM-VAE/VAE-LSTM-for-anomaly-detection/codes/models.py:25: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/data/util/random_seed.py:58: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /content/drive/My Drive/afeka/y2/sem1/dl/code/LSTM-VAE/VAE-LSTM-for-anomaly-detection/codes/models.py:31: DatasetV1.make_initializable_iterator (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `for ... in dataset:` to iterate over a dataset. If using `tf.estimator`, return the `Dataset` object directly from your input function. As a last resort, you can use `tf.compat.v1.data.make_initializable_iterator(dataset)`.
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From /content/drive/My Drive/afeka/y2/sem1/dl/code/LSTM-VAE/VAE-LSTM-for-anomaly-detection/codes/models.py:48: conv2d (from tensorflow.python.layers.convolutional) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.keras.layers.Conv2D` instead.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/layers/convolutional.py:424: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# conv_1: Tensor("encoder/conv2d/LeakyRelu:0", shape=(?, 16, 2, 32), dtype=float32)
# conv_2: Tensor("encoder/conv2d_1/LeakyRelu:0", shape=(?, 8, 2, 64), dtype=float32)
# conv_3: Tensor("encoder/conv2d_2/LeakyRelu:0", shape=(?, 4, 2, 128), dtype=float32)
# conv_4: Tensor("encoder/conv2d_3/LeakyRelu:0", shape=(?, 1, 1, 512), dtype=float32)
# WARNING:tensorflow:From /content/drive/My Drive/afeka/y2/sem1/dl/code/LSTM-VAE/VAE-LSTM-for-anomaly-detection/codes/models.py:141: flatten (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.flatten instead.
# WARNING:tensorflow:From /content/drive/My Drive/afeka/y2/sem1/dl/code/LSTM-VAE/VAE-LSTM-for-anomaly-detection/codes/models.py:145: dense (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.Dense instead.
# finish encoder:
# Tensor("encoder/MultivariateNormalDiag/sample/affine_linear_operator/forward/add:0", shape=(?, 6), dtype=float32)
#
#
# decoded_2 is: Tensor("decoder/Reshape_1:0", shape=(?, 4, 1, 128), dtype=float32)
# decoded_3 is: Tensor("decoder/Reshape_2:0", shape=(?, 8, 1, 64), dtype=float32)
# decoded_4 is: Tensor("decoder/Reshape_3:0", shape=(?, 16, 1, 32), dtype=float32)
# decoded_5 is: Tensor("decoder/Reshape_4:0", shape=(?, 32, 1, 16), dtype=float32)
# decoded_6 is: Tensor("decoder/conv2d_4/BiasAdd:0", shape=(?, 24, 1, 2), dtype=float32)
# finish decoder:
# Tensor("decoder/Reshape_5:0", shape=(?, 24, 2), dtype=float32)
#
#
# sigma2:
# Tensor("sigma2_dataset/Square:0", shape=(), dtype=float32)
#
# WARNING:tensorflow:From /content/drive/My Drive/afeka/y2/sem1/dl/code/LSTM-VAE/VAE-LSTM-for-anomaly-detection/codes/base.py:73: The name tf.log is deprecated. Please use tf.math.log instead.
#
# WARNING:tensorflow:From /content/drive/My Drive/afeka/y2/sem1/dl/code/LSTM-VAE/VAE-LSTM-for-anomaly-detection/codes/base.py:97: The name tf.get_collection is deprecated. Please use tf.compat.v1.get_collection instead.
#
# WARNING:tensorflow:From /content/drive/My Drive/afeka/y2/sem1/dl/code/LSTM-VAE/VAE-LSTM-for-anomaly-detection/codes/base.py:97: The name tf.GraphKeys is deprecated. Please use tf.compat.v1.GraphKeys instead.
#
# WARNING:tensorflow:From /content/drive/My Drive/afeka/y2/sem1/dl/code/LSTM-VAE/VAE-LSTM-for-anomaly-detection/codes/utils.py:86: The name tf.trainable_variables is deprecated. Please use tf.compat.v1.trainable_variables instead.
#
# The total number of trainable parameters in the encoder model is: 599268
# The total number of trainable parameters in the decoder model is: 331266
# The total number of trainable parameters in the sigma2_dataset model is: 0
# Total number of trainable parameters in the VAE network is: 930534
# WARNING:tensorflow:From /content/drive/My Drive/afeka/y2/sem1/dl/code/LSTM-VAE/VAE-LSTM-for-anomaly-detection/codes/base.py:110: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
#
# gvs for dataset: [(<tf.Tensor 'gradients/encoder/conv2d/Conv2D_grad/tuple/control_dependency_1:0' shape=(3, 2, 1, 32) dtype=float32>, <tf.Variable 'encoder/conv2d/kernel:0' shape=(3, 2, 1, 32) dtype=float32_ref>), (<tf.Tensor 'gradients/encoder/conv2d/BiasAdd_grad/tuple/control_dependency_1:0' shape=(32,) dtype=float32>, <tf.Variable 'encoder/conv2d/bias:0' shape=(32,) dtype=float32_ref>), (<tf.Tensor 'gradients/encoder/conv2d_1/Conv2D_grad/tuple/control_dependency_1:0' shape=(3, 2, 32, 64) dtype=float32>, <tf.Variable 'encoder/conv2d_1/kernel:0' shape=(3, 2, 32, 64) dtype=float32_ref>), (<tf.Tensor 'gradients/encoder/conv2d_1/BiasAdd_grad/tuple/control_dependency_1:0' shape=(64,) dtype=float32>, <tf.Variable 'encoder/conv2d_1/bias:0' shape=(64,) dtype=float32_ref>), (<tf.Tensor 'gradients/encoder/conv2d_2/Conv2D_grad/tuple/control_dependency_1:0' shape=(3, 2, 64, 128) dtype=float32>, <tf.Variable 'encoder/conv2d_2/kernel:0' shape=(3, 2, 64, 128) dtype=float32_ref>), (<tf.Tensor 'gradients/encoder/conv2d_2/BiasAdd_grad/tuple/control_dependency_1:0' shape=(128,) dtype=float32>, <tf.Variable 'encoder/conv2d_2/bias:0' shape=(128,) dtype=float32_ref>), (<tf.Tensor 'gradients/encoder/conv2d_3/Conv2D_grad/tuple/control_dependency_1:0' shape=(4, 2, 128, 512) dtype=float32>, <tf.Variable 'encoder/conv2d_3/kernel:0' shape=(4, 2, 128, 512) dtype=float32_ref>), (<tf.Tensor 'gradients/encoder/conv2d_3/BiasAdd_grad/tuple/control_dependency_1:0' shape=(512,) dtype=float32>, <tf.Variable 'encoder/conv2d_3/bias:0' shape=(512,) dtype=float32_ref>), (<tf.Tensor 'gradients/encoder/dense/MatMul_grad/tuple/control_dependency_1:0' shape=(512, 24) dtype=float32>, <tf.Variable 'encoder/dense/kernel:0' shape=(512, 24) dtype=float32_ref>), (<tf.Tensor 'gradients/encoder/dense/BiasAdd_grad/tuple/control_dependency_1:0' shape=(24,) dtype=float32>, <tf.Variable 'encoder/dense/bias:0' shape=(24,) dtype=float32_ref>), (<tf.Tensor 'gradients/encoder/code_mean/MatMul_grad/tuple/control_dependency_1:0' shape=(24, 6) dtype=float32>, <tf.Variable 'encoder/code_mean/kernel:0' shape=(24, 6) dtype=float32_ref>), (<tf.Tensor 'gradients/encoder/code_mean/BiasAdd_grad/tuple/control_dependency_1:0' shape=(6,) dtype=float32>, <tf.Variable 'encoder/code_mean/bias:0' shape=(6,) dtype=float32_ref>), (<tf.Tensor 'gradients/encoder/code_std_dev/MatMul_grad/tuple/control_dependency_1:0' shape=(24, 6) dtype=float32>, <tf.Variable 'encoder/code_std_dev/kernel:0' shape=(24, 6) dtype=float32_ref>), (<tf.Tensor 'gradients/encoder/code_std_dev/BiasAdd_grad/tuple/control_dependency_1:0' shape=(6,) dtype=float32>, <tf.Variable 'encoder/code_std_dev/bias:0' shape=(6,) dtype=float32_ref>), (<tf.Tensor 'gradients/decoder/dense/MatMul_grad/tuple/control_dependency_1:0' shape=(6, 512) dtype=float32>, <tf.Variable 'decoder/dense/kernel:0' shape=(6, 512) dtype=float32_ref>), (<tf.Tensor 'gradients/decoder/dense/BiasAdd_grad/tuple/control_dependency_1:0' shape=(512,) dtype=float32>, <tf.Variable 'decoder/dense/bias:0' shape=(512,) dtype=float32_ref>), (<tf.Tensor 'gradients/decoder/conv2d/Conv2D_grad/tuple/control_dependency_1:0' shape=(1, 1, 512, 512) dtype=float32>, <tf.Variable 'decoder/conv2d/kernel:0' shape=(1, 1, 512, 512) dtype=float32_ref>), (<tf.Tensor 'gradients/decoder/conv2d/BiasAdd_grad/tuple/control_dependency_1:0' shape=(512,) dtype=float32>, <tf.Variable 'decoder/conv2d/bias:0' shape=(512,) dtype=float32_ref>), (<tf.Tensor 'gradients/decoder/conv2d_1/Conv2D_grad/tuple/control_dependency_1:0' shape=(3, 1, 128, 128) dtype=float32>, <tf.Variable 'decoder/conv2d_1/kernel:0' shape=(3, 1, 128, 128) dtype=float32_ref>), (<tf.Tensor 'gradients/decoder/conv2d_1/BiasAdd_grad/tuple/control_dependency_1:0' shape=(128,) dtype=float32>, <tf.Variable 'decoder/conv2d_1/bias:0' shape=(128,) dtype=float32_ref>), (<tf.Tensor 'gradients/decoder/conv2d_2/Conv2D_grad/tuple/control_dependency_1:0' shape=(3, 1, 64, 64) dtype=float32>, <tf.Variable 'decoder/conv2d_2/kernel:0' shape=(3, 1, 64, 64) dty ...
# Reach the definition of loss for VAE
# WARNING:tensorflow:From /content/drive/My Drive/afeka/y2/sem1/dl/code/LSTM-VAE/VAE-LSTM-for-anomaly-detection/codes/base.py:126: The name tf.train.Saver is deprecated. Please use tf.compat.v1.train.Saver instead.
#
# WARNING:tensorflow:From /content/drive/My Drive/afeka/y2/sem1/dl/code/LSTM-VAE/VAE-LSTM-for-anomaly-detection/codes/base.py:135: The name tf.global_variables_initializer is deprecated. Please use tf.compat.v1.global_variables_initializer instead.
#
# WARNING:tensorflow:From /content/drive/My Drive/afeka/y2/sem1/dl/code/LSTM-VAE/VAE-LSTM-for-anomaly-detection/codes/base.py:136: The name tf.local_variables_initializer is deprecated. Please use tf.compat.v1.local_variables_initializer instead.
#
# checkpoint_dir at loading: ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-2-channels-trim-24-3-6-fixedSigma-0.1/checkpoint/
# Loading model checkpoint ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-2-channels-trim-24-3-6-fixedSigma-0.1/checkpoint/-720 ...
#
# INFO:tensorflow:Restoring parameters from ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-2-channels-trim-24-3-6-fixedSigma-0.1/checkpoint/-720
# Model loaded.
# Saving model...
# Model saved.
# 0/29, test loss: -elbo: 130.0595, recons_loss_weighted: 136.8478, recons_loss_ls: 2.7370, KL_loss: 21.3633, sigma_regularisor: -110.5241, code_std_dev: [0.24701153 0.17737958 0.19651638 0.01       0.31876773 0.01      ]
# Loss on training and val sets:
# train: 162.0660, val: 135.2477
# Current sigma2: 0.0100000
# Already trained for 0.264964226881663 min; Remaining 7.683962579568227 min.
# Saving model...
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/training/saver.py:963: remove_checkpoint (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to delete files with this prefix.
# Model saved.
# 1/29, test loss: -elbo: 122.3369, recons_loss_weighted: 121.4896, recons_loss_ls: 2.4298, KL_loss: 21.3197, sigma_regularisor: -110.5241, code_std_dev: [0.22612327 0.17938948 0.13611281 0.01       0.27837586 0.01      ]
# Loss on training and val sets:
# train: 149.7046, val: 127.6927
# Current sigma2: 0.0100000
# Already trained for 0.3938167969385783 min; Remaining 5.513435157140096 min.
# Saving model...
# Model saved.
# 2/29, test loss: -elbo: 133.3097, recons_loss_weighted: 142.2012, recons_loss_ls: 2.8440, KL_loss: 21.9368, sigma_regularisor: -110.5241, code_std_dev: [0.2296921  0.14292464 0.14863724 0.01       0.29599983 0.01      ]
# Loss on training and val sets:
# train: 143.9256, val: 121.0463
# Current sigma2: 0.0100000
# Already trained for 0.5202843149503072 min; Remaining 4.682558834552765 min.
# Saving model...
# Model saved.
# 3/29, test loss: -elbo: 130.3341, recons_loss_weighted: 137.8286, recons_loss_ls: 2.7566, KL_loss: 21.1474, sigma_regularisor: -110.5241, code_std_dev: [0.22104308 0.19857074 0.12373266 0.01       0.31141844 0.01046857]
# Loss on training and val sets:
# train: 145.3434, val: 127.8780
# Current sigma2: 0.0100000
# Already trained for 0.646568751335144 min; Remaining 4.202696883678437 min.
# Saving model...
# Model saved.
# 4/29, test loss: -elbo: 130.4045, recons_loss_weighted: 137.3987, recons_loss_ls: 2.7480, KL_loss: 21.4328, sigma_regularisor: -110.5241, code_std_dev: [0.23345405 0.22477214 0.10945975 0.01       0.32517144 0.01      ]
# Loss on training and val sets:
# train: 143.4939, val: 128.0162
# Current sigma2: 0.0100000
# Already trained for 0.7727348248163859 min; Remaining 3.86367412408193 min.
# Saving model...
# Model saved.
# 5/29, test loss: -elbo: 137.1899, recons_loss_weighted: 150.7545, recons_loss_ls: 3.0151, KL_loss: 21.5403, sigma_regularisor: -110.5241, code_std_dev: [0.18902923 0.19507459 0.08206663 0.01       0.25230986 0.01      ]
# Loss on training and val sets:
# train: 139.0277, val: 131.1568
# Current sigma2: 0.0100000
# Already trained for 0.898387090365092 min; Remaining 3.593548361460368 min.
# Saving model...
# Model saved.
# 6/29, test loss: -elbo: 134.9917, recons_loss_weighted: 145.0549, recons_loss_ls: 2.9011, KL_loss: 22.1919, sigma_regularisor: -110.5241, code_std_dev: [0.20074049 0.18879114 0.06644246 0.01       0.3096105  0.01183258]
# Loss on training and val sets:
# train: 136.5129, val: 126.9181
# Current sigma2: 0.0100000
# Already trained for 1.0272131085395813 min; Remaining 3.3751287852014813 min.
# Saving model...
# Model saved.
# 7/29, test loss: -elbo: 133.1615, recons_loss_weighted: 142.5661, recons_loss_ls: 2.8513, KL_loss: 21.6060, sigma_regularisor: -110.5241, code_std_dev: [0.209666   0.18621841 0.10562632 0.01       0.2773829  0.01127276]
# Loss on training and val sets:
# train: 137.8707, val: 146.1352
# Current sigma2: 0.0100000
# Already trained for 1.1552926301956177 min; Remaining 3.1770547330379486 min.
# Saving model...
# Model saved.
# 8/29, test loss: -elbo: 127.1501, recons_loss_weighted: 131.7984, recons_loss_ls: 2.6360, KL_loss: 20.9786, sigma_regularisor: -110.5241, code_std_dev: [0.24341762 0.23242475 0.131016   0.01       0.27872163 0.01      ]
# Loss on training and val sets:
# train: 133.1163, val: 125.6159
# Current sigma2: 0.0100000
# Already trained for 1.286834450562795 min; Remaining 3.0026137179798553 min.
# Saving model...
# Model saved.
# 9/29, test loss: -elbo: 136.1569, recons_loss_weighted: 149.1934, recons_loss_ls: 2.9839, KL_loss: 21.2879, sigma_regularisor: -110.5241, code_std_dev: [0.21429563 0.17782712 0.11394844 0.01       0.26797915 0.01      ]
# Loss on training and val sets:
# train: 133.7355, val: 129.6691
# Current sigma2: 0.0100000
# Already trained for 1.4170764366785684 min; Remaining 2.834152873357137 min.
# Saving model...
# Model saved.
# 10/29, test loss: -elbo: 136.5169, recons_loss_weighted: 149.8589, recons_loss_ls: 2.9972, KL_loss: 21.3151, sigma_regularisor: -110.5241, code_std_dev: [0.19662797 0.17421155 0.10977569 0.01       0.2747946  0.01045431]
# Loss on training and val sets:
# train: 129.5259, val: 141.8718
# Current sigma2: 0.0100000
# Already trained for 1.5454394539197287 min; Remaining 2.6693954204068038 min.
# Saving model...
# Model saved.
# 11/29, test loss: -elbo: 130.0784, recons_loss_weighted: 137.4032, recons_loss_ls: 2.7481, KL_loss: 21.1045, sigma_regularisor: -110.5241, code_std_dev: [0.25477427 0.1793989  0.12234718 0.01       0.28596422 0.0100424 ]
# Loss on training and val sets:
# train: 130.9236, val: 147.3878
# Current sigma2: 0.0100000
# Already trained for 1.6769083658854167 min; Remaining 2.515362548828125 min.
# Saving model...
# Model saved.
# 12/29, test loss: -elbo: 129.4840, recons_loss_weighted: 135.3565, recons_loss_ls: 2.7071, KL_loss: 21.5334, sigma_regularisor: -110.5241, code_std_dev: [0.17010862 0.2309002  0.11826556 0.01       0.26965833 0.01      ]
# Loss on training and val sets:
# train: 128.1813, val: 125.5176
# Current sigma2: 0.0100000
# Already trained for 1.8045245329538981 min; Remaining 2.359762850785867 min.
# Saving model...
# Model saved.
# 13/29, test loss: -elbo: 129.9070, recons_loss_weighted: 136.6284, recons_loss_ls: 2.7326, KL_loss: 21.3205, sigma_regularisor: -110.5241, code_std_dev: [0.2679597  0.1938285  0.11210866 0.01       0.29020214 0.01      ]
# Loss on training and val sets:
# train: 126.2149, val: 131.5999
# Current sigma2: 0.0100000
# Already trained for 1.9364057143529256 min; Remaining 2.213035102117629 min.
# Saving model...
# Model saved.
# 14/29, test loss: -elbo: 137.0116, recons_loss_weighted: 150.6509, recons_loss_ls: 3.0130, KL_loss: 21.4137, sigma_regularisor: -110.5241, code_std_dev: [0.21167937 0.19502397 0.10920678 0.01       0.27380466 0.010247  ]
# Loss on training and val sets:
# train: 126.1130, val: 144.4283
# Current sigma2: 0.0100000
# Already trained for 2.0661291758219402 min; Remaining 2.0661291758219402 min.
# Saving model...
# Model saved.
# 15/29, test loss: -elbo: 135.7421, recons_loss_weighted: 148.1638, recons_loss_ls: 2.9633, KL_loss: 21.3878, sigma_regularisor: -110.5241, code_std_dev: [0.22476566 0.1972125  0.11711409 0.01       0.2917445  0.01      ]
# Loss on training and val sets:
# train: 122.7737, val: 123.2821
# Current sigma2: 0.0100000
# Already trained for 2.1991544445355733 min; Remaining 1.9242601389686267 min.
# Saving model...
# Model saved.
# 16/29, test loss: -elbo: 129.3198, recons_loss_weighted: 134.9542, recons_loss_ls: 2.6991, KL_loss: 21.5703, sigma_regularisor: -110.5241, code_std_dev: [0.26148033 0.2309707  0.06008691 0.01       0.256977   0.01      ]
# Loss on training and val sets:
# train: 124.0799, val: 147.4270
# Current sigma2: 0.0100000
# Already trained for 2.328883719444275 min; Remaining 1.7809110795750338 min.
# Saving model...
# Model saved.
# 17/29, test loss: -elbo: 129.5661, recons_loss_weighted: 134.9443, recons_loss_ls: 2.6989, KL_loss: 21.8216, sigma_regularisor: -110.5241, code_std_dev: [0.20441636 0.17487516 0.08545985 0.01       0.27210903 0.01051523]
# Loss on training and val sets:
# train: 122.1101, val: 128.7176
# Current sigma2: 0.0100000
# Already trained for 2.4589823047320047 min; Remaining 1.639321536488003 min.
# Saving model...
# Model saved.
# 18/29, test loss: -elbo: 133.9398, recons_loss_weighted: 143.9084, recons_loss_ls: 2.8782, KL_loss: 21.7133, sigma_regularisor: -110.5241, code_std_dev: [0.15419175 0.20347379 0.11979986 0.01       0.25903586 0.01071812]
# Loss on training and val sets:
# train: 121.5148, val: 143.4600
# Current sigma2: 0.0100000
# Already trained for 2.5859180609385173 min; Remaining 1.4971104563328257 min.
# Saving model...
# Model saved.
# 19/29, test loss: -elbo: 128.8587, recons_loss_weighted: 134.4005, recons_loss_ls: 2.6880, KL_loss: 21.3861, sigma_regularisor: -110.5241, code_std_dev: [0.23619059 0.17252088 0.10973906 0.01       0.28939557 0.01128381]
# Loss on training and val sets:
# train: 119.5508, val: 138.8920
# Current sigma2: 0.0100000
# Already trained for 2.714975821971893 min; Remaining 1.3574879109859466 min.
# Saving model...
# Model saved.
# 20/29, test loss: -elbo: 134.9772, recons_loss_weighted: 147.1830, recons_loss_ls: 2.9437, KL_loss: 21.1133, sigma_regularisor: -110.5241, code_std_dev: [0.18915659 0.19312674 0.11477658 0.01       0.27423567 0.01069222]
# Loss on training and val sets:
# train: 118.0003, val: 146.7714
# Current sigma2: 0.0100000
# Already trained for 2.8458561261494952 min; Remaining 1.219652625492641 min.
# Saving model...
# Model saved.
# 21/29, test loss: -elbo: 132.5327, recons_loss_weighted: 141.5380, recons_loss_ls: 2.8308, KL_loss: 21.4913, sigma_regularisor: -110.5241, code_std_dev: [0.2218513  0.19733708 0.12539001 0.01       0.2843445  0.01064744]
# Loss on training and val sets:
# train: 119.1625, val: 143.0983
# Current sigma2: 0.0100000
# Already trained for 2.9724217454592385 min; Remaining 1.0808806347124504 min.
# Saving model...
# Model saved.
# 22/29, test loss: -elbo: 131.3361, recons_loss_weighted: 139.8909, recons_loss_ls: 2.7978, KL_loss: 21.1183, sigma_regularisor: -110.5241, code_std_dev: [0.24460156 0.19513859 0.12208703 0.01       0.26110783 0.01207945]
# Loss on training and val sets:
# train: 115.5002, val: 135.9963
# Current sigma2: 0.0100000
# Already trained for 3.101215100288391 min; Remaining 0.9438480740008148 min.
# Saving model...
# Model saved.
# 23/29, test loss: -elbo: 134.6833, recons_loss_weighted: 146.2486, recons_loss_ls: 2.9250, KL_loss: 21.2867, sigma_regularisor: -110.5241, code_std_dev: [0.20527959 0.21585573 0.09735871 0.01       0.30043513 0.01259285]
# Loss on training and val sets:
# train: 115.2187, val: 133.1717
# Current sigma2: 0.0100000
# Already trained for 3.2313106497128805 min; Remaining 0.8078276624282201 min.
# Saving model...
# Model saved.
# 24/29, test loss: -elbo: 129.8127, recons_loss_weighted: 136.5444, recons_loss_ls: 2.7309, KL_loss: 21.2681, sigma_regularisor: -110.5241, code_std_dev: [0.20007329 0.1925406  0.12265955 0.01       0.2773346  0.01025113]
# Loss on training and val sets:
# train: 114.5924, val: 113.7711
# Current sigma2: 0.0100000
# Already trained for 3.362144140402476 min; Remaining 0.6724288280804951 min.
# Saving model...
# Model saved.
# 25/29, test loss: -elbo: 132.4020, recons_loss_weighted: 141.1875, recons_loss_ls: 2.8238, KL_loss: 21.5359, sigma_regularisor: -110.5241, code_std_dev: [0.24511346 0.1892667  0.08826382 0.01       0.28382757 0.01179192]
# Loss on training and val sets:
# train: 113.9740, val: 149.6289
# Current sigma2: 0.0100000
# Already trained for 3.489934245745341 min; Remaining 0.5369129608838986 min.
# Saving model...
# Model saved.
# 26/29, test loss: -elbo: 129.2283, recons_loss_weighted: 135.3358, recons_loss_ls: 2.7067, KL_loss: 21.2881, sigma_regularisor: -110.5241, code_std_dev: [0.25665054 0.17414707 0.11597271 0.01       0.2900229  0.01224501]
# Loss on training and val sets:
# train: 113.0284, val: 107.1173
# Current sigma2: 0.0100000
# Already trained for 3.618025076389313 min; Remaining 0.40200278626547914 min.
# Saving model...
# Model saved.
# 27/29, test loss: -elbo: 131.3830, recons_loss_weighted: 140.1093, recons_loss_ls: 2.8022, KL_loss: 21.0560, sigma_regularisor: -110.5241, code_std_dev: [0.2118386  0.21742028 0.11641433 0.01       0.2932906  0.01129791]
# Loss on training and val sets:
# train: 111.1122, val: 121.1383
# Current sigma2: 0.0100000
# Already trained for 3.7476000150044757 min; Remaining 0.26768571535746255 min.
# Saving model...
# Model saved.
# 28/29, test loss: -elbo: 129.7421, recons_loss_weighted: 136.2402, recons_loss_ls: 2.7248, KL_loss: 21.3497, sigma_regularisor: -110.5241, code_std_dev: [0.21729659 0.20575264 0.10222739 0.01       0.27001953 0.01140155]
# Loss on training and val sets:
# train: 110.3420, val: 132.2688
# Current sigma2: 0.0100000
# Already trained for 3.877023681004842 min; Remaining 0.13369047175878765 min.
# Saving model...
# Model saved.
# 29/29, test loss: -elbo: 135.5074, recons_loss_weighted: 147.7365, recons_loss_ls: 2.9547, KL_loss: 21.3668, sigma_regularisor: -110.5241, code_std_dev: [0.221859   0.18763427 0.11968789 0.01       0.2649314  0.01169139]
# Loss on training and val sets:
# train: 110.9274, val: 143.4389
# Current sigma2: 0.0100000
# Already trained for 4.001945269107819 min; Remaining 0.0 min.

# %%
# load LSTM model
lstm_model = lstmKerasModel(data)
lstm_model.produce_embeddings(config, model_vae, data, sess)
lstm_nn_model = lstm_model.create_lstm_model(config)
lstm_nn_model.summary()   # Display the model's architecture

# checkpoint path
checkpoint_path = config['checkpoint_dir_lstm'] + "cp.ckpt"
checkpoint_dir = os.path.dirname(checkpoint_path)
# Create a callback that saves the model's weights
cp_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path,
                                                 save_weights_only=True,
                                                 verbose=1)
# load weights if possible
lstm_model.load_model(lstm_nn_model, config, checkpoint_path)
# start training
if config['TRAIN_LSTM']:
    if config['num_epochs_lstm'] > 0:
        lstm_model.train(config, lstm_nn_model, cp_callback)

    # make a prediction on the test set using the trained model
    lstm_embedding = lstm_nn_model.predict(lstm_model.x_test, batch_size=config['batch_size_lstm'])
    print(lstm_embedding.shape)

    # visualise the first 10 test sequences
    for i in range(10):
        lstm_model.plot_lstm_embedding_prediction(i, config, model_vae, sess, data, lstm_embedding)
# Out:
# Finish processing the embeddings of the entire dataset.
# The first a few embeddings are
# [[-2.0817728   3.20358777 -2.06718302  2.26100707 -2.29244113 -0.5332917 ]
#  [-0.04018767 -0.27067465  0.53095973  0.21444364  0.2532872   1.04626215]
#  [ 2.24574423 -1.78022766 -0.17401944 -1.04077399 -0.34228832  1.37978351]]
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 2, 6)]            0
# _________________________________________________________________
# lstm (LSTM)                  (None, 2, 64)             18176
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 2, 64)             33024
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 2, 6)              1704
# =================================================================
# Total params: 52,904
# Trainable params: 52,904
# Non-trainable params: 0
# _________________________________________________________________
# ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-2-channels-trim-24-3-6-fixedSigma-0.1/checkpoint/lstm/checkpoint
# LSTM model loaded.
# Train on 746 samples, validate on 83 samples
# Epoch 1/100
# 640/746 [========================>.....] - ETA: 0s - loss: 1.1423 - mean_squared_error: 1.1423
# Epoch 00001: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-2-channels-trim-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 2s 2ms/sample - loss: 1.1568 - mean_squared_error: 1.1568 - val_loss: 1.4780 - val_mean_squared_error: 1.4780
# Epoch 2/100
# 672/746 [==========================>...] - ETA: 0s - loss: 1.1696 - mean_squared_error: 1.1696
# Epoch 00002: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-2-channels-trim-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 466us/sample - loss: 1.1400 - mean_squared_error: 1.1400 - val_loss: 1.4722 - val_mean_squared_error: 1.4722
# Epoch 3/100
# 672/746 [==========================>...] - ETA: 0s - loss: 1.1188 - mean_squared_error: 1.1188
# Epoch 00003: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-2-channels-trim-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 629us/sample - loss: 1.1343 - mean_squared_error: 1.1343 - val_loss: 1.4723 - val_mean_squared_error: 1.4723
# Epoch 4/100
# 672/746 [==========================>...] - ETA: 0s - loss: 1.1393 - mean_squared_error: 1.1393
# Epoch 00004: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-2-channels-trim-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 469us/sample - loss: 1.1312 - mean_squared_error: 1.1312 - val_loss: 1.4744 - val_mean_squared_error: 1.4744
# Epoch 5/100
# 672/746 [==========================>...] - ETA: 0s - loss: 1.1625 - mean_squared_error: 1.1625
# Epoch 00005: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-2-channels-trim-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 636us/sample - loss: 1.1284 - mean_squared_error: 1.1284 - val_loss: 1.4723 - val_mean_squared_error: 1.4723
# Epoch 6/100
# 608/746 [=======================>......] - ETA: 0s - loss: 1.1230 - mean_squared_error: 1.1230
# Epoch 00006: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-2-channels-trim-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 471us/sample - loss: 1.1266 - mean_squared_error: 1.1266 - val_loss: 1.4735 - val_mean_squared_error: 1.4735
# Epoch 7/100
# 640/746 [========================>.....] - ETA: 0s - loss: 1.0927 - mean_squared_error: 1.0927
# Epoch 00007: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-2-channels-trim-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 659us/sample - loss: 1.1242 - mean_squared_error: 1.1242 - val_loss: 1.4720 - val_mean_squared_error: 1.4720
# Epoch 8/100
# 672/746 [==========================>...] - ETA: 0s - loss: 1.1157 - mean_squared_error: 1.1157
# Epoch 00008: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-2-channels-trim-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 621us/sample - loss: 1.1221 - mean_squared_error: 1.1221 - val_loss: 1.4733 - val_mean_squared_error: 1.4733
# Epoch 9/100
# 672/746 [==========================>...] - ETA: 0s - loss: 1.1319 - mean_squared_error: 1.1319
# Epoch 00009: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-2-channels-trim-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 483us/sample - loss: 1.1201 - mean_squared_error: 1.1201 - val_loss: 1.4710 - val_mean_squared_error: 1.4710
# Epoch 10/100
# 672/746 [==========================>...] - ETA: 0s - loss: 1.1225 - mean_squared_error: 1.1225
# Epoch 00010: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-2-channels-trim-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 628us/sample - loss: 1.1191 - mean_squared_error: 1.1191 - val_loss: 1.4721 - val_mean_squared_error: 1.4721
# Epoch 11/100
# 672/746 [==========================>...] - ETA: 0s - loss: 1.1319 - mean_squared_error: 1.1319
# Epoch 00011: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-2-channels-trim-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 470us/sample - loss: 1.1166 - mean_squared_error: 1.1166 - val_loss: 1.4709 - val_mean_squared_error: 1.4709
# Epoch 12/100
# 608/746 [=======================>......] - ETA: 0s - loss: 1.0880 - mean_squared_error: 1.0880
# Epoch 00012: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-2-channels-trim-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 1s 677us/sample - loss: 1.1154 - mean_squared_error: 1.1154 - val_loss: 1.4724 - val_mean_squared_error: 1.4724
# Epoch 13/100
# 672/746 [==========================>...] - ETA: 0s - loss: 1.0951 - mean_squared_error: 1.0951
# Epoch 00013: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-2-channels-trim-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 476us/sample - loss: 1.1132 - mean_squared_error: 1.1132 - val_loss: 1.4713 - val_mean_squared_error: 1.4713
# Epoch 14/100
# 672/746 [==========================>...] - ETA: 0s - loss: 1.1042 - mean_squared_error: 1.1042
# Epoch 00014: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-2-channels-trim-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 669us/sample - loss: 1.1109 - mean_squared_error: 1.1109 - val_loss: 1.4700 - val_mean_squared_error: 1.4700
# Epoch 15/100
# 640/746 [========================>.....] - ETA: 0s - loss: 1.1331 - mean_squared_error: 1.1331
# Epoch 00015: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-2-channels-trim-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 483us/sample - loss: 1.1097 - mean_squared_error: 1.1097 - val_loss: 1.4696 - val_mean_squared_error: 1.4696
# Epoch 16/100
# 672/746 [==========================>...] - ETA: 0s - loss: 1.0881 - mean_squared_error: 1.0881
# Epoch 00016: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-2-channels-trim-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 1s 670us/sample - loss: 1.1088 - mean_squared_error: 1.1088 - val_loss: 1.4712 - val_mean_squared_error: 1.4712
# Epoch 17/100
# 672/746 [==========================>...] - ETA: 0s - loss: 1.0671 - mean_squared_error: 1.0671
# Epoch 00017: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-2-channels-trim-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 472us/sample - loss: 1.1064 - mean_squared_error: 1.1064 - val_loss: 1.4682 - val_mean_squared_error: 1.4682
# Epoch 18/100
# 640/746 [========================>.....] - ETA: 0s - loss: 1.1118 - mean_squared_error: 1.1118
# Epoch 00018: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-2-channels-trim-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 535us/sample - loss: 1.1058 - mean_squared_error: 1.1058 - val_loss: 1.4707 - val_mean_squared_error: 1.4707
# Epoch 19/100
# 640/746 [========================>.....] - ETA: 0s - loss: 1.0792 - mean_squared_error: 1.0792
# Epoch 00019: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-2-channels-trim-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 486us/sample - loss: 1.1044 - mean_squared_error: 1.1044 - val_loss: 1.4687 - val_mean_squared_error: 1.4687
# Epoch 20/100
# 640/746 [========================>.....] - ETA: 0s - loss: 1.1033 - mean_squared_error: 1.1033
# Epoch 00020: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-2-channels-trim-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 669us/sample - loss: 1.1017 - mean_squared_error: 1.1017 - val_loss: 1.4682 - val_mean_squared_error: 1.4682
# Epoch 21/100
# 608/746 [=======================>......] - ETA: 0s - loss: 1.0844 - mean_squared_error: 1.0844
# Epoch 00021: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-2-channels-trim-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 655us/sample - loss: 1.1003 - mean_squared_error: 1.1003 - val_loss: 1.4671 - val_mean_squared_error: 1.4671
# Epoch 22/100
# 672/746 [==========================>...] - ETA: 0s - loss: 1.0841 - mean_squared_error: 1.0841
# Epoch 00022: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-2-channels-trim-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 496us/sample - loss: 1.0995 - mean_squared_error: 1.0995 - val_loss: 1.4676 - val_mean_squared_error: 1.4676
# Epoch 23/100
# 672/746 [==========================>...] - ETA: 0s - loss: 1.1178 - mean_squared_error: 1.1178
# Epoch 00023: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-2-channels-trim-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 649us/sample - loss: 1.0973 - mean_squared_error: 1.0973 - val_loss: 1.4636 - val_mean_squared_error: 1.4636
# Epoch 24/100
# 640/746 [========================>.....] - ETA: 0s - loss: 1.0490 - mean_squared_error: 1.0490
# Epoch 00024: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-2-channels-trim-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 495us/sample - loss: 1.0965 - mean_squared_error: 1.0965 - val_loss: 1.4634 - val_mean_squared_error: 1.4634
# Epoch 25/100
# 608/746 [=======================>......] - ETA: 0s - loss: 1.0934 - mean_squared_error: 1.0934
# Epoch 00025: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-2-channels-trim-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 1s 683us/sample - loss: 1.0945 - mean_squared_error: 1.0945 - val_loss: 1.4632 - val_mean_squared_error: 1.4632
# Epoch 26/100
# 640/746 [========================>.....] - ETA: 0s - loss: 1.0820 - mean_squared_error: 1.0820
# Epoch 00026: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-2-channels-trim-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 500us/sample - loss: 1.0932 - mean_squared_error: 1.0932 - val_loss: 1.4635 - val_mean_squared_error: 1.4635
# Epoch 27/100
# 736/746 [============================>.] - ETA: 0s - loss: 1.0978 - mean_squared_error: 1.0978
# Epoch 00027: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-2-channels-trim-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 1s 694us/sample - loss: 1.0918 - mean_squared_error: 1.0918 - val_loss: 1.4629 - val_mean_squared_error: 1.4629
# Epoch 28/100
# 704/746 [===========================>..] - ETA: 0s - loss: 1.0688 - mean_squared_error: 1.0688
# Epoch 00028: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-2-channels-trim-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 518us/sample - loss: 1.0909 - mean_squared_error: 1.0909 - val_loss: 1.4601 - val_mean_squared_error: 1.4601
# Epoch 29/100
# 736/746 [============================>.] - ETA: 0s - loss: 1.0939 - mean_squared_error: 1.0939
# Epoch 00029: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-2-channels-trim-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 1s 753us/sample - loss: 1.0889 - mean_squared_error: 1.0889 - val_loss: 1.4611 - val_mean_squared_error: 1.4611
# Epoch 30/100
# 608/746 [=======================>......] - ETA: 0s - loss: 1.0647 - mean_squared_error: 1.0647
# Epoch 00030: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-2-channels-trim-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 1s 714us/sample - loss: 1.0877 - mean_squared_error: 1.0877 - val_loss: 1.4607 - val_mean_squared_error: 1.4607
# Epoch 31/100
# 640/746 [========================>.....] - ETA: 0s - loss: 1.0834 - mean_squared_error: 1.0834
# Epoch 00031: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-2-channels-trim-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 480us/sample - loss: 1.0861 - mean_squared_error: 1.0861 - val_loss: 1.4580 - val_mean_squared_error: 1.4580
# Epoch 32/100
# 608/746 [=======================>......] - ETA: 0s - loss: 1.1113 - mean_squared_error: 1.1113
# Epoch 00032: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-2-channels-trim-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 1s 689us/sample - loss: 1.0843 - mean_squared_error: 1.0843 - val_loss: 1.4584 - val_mean_squared_error: 1.4584
# Epoch 33/100
# 608/746 [=======================>......] - ETA: 0s - loss: 1.1219 - mean_squared_error: 1.1219
# Epoch 00033: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-2-channels-trim-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 509us/sample - loss: 1.0827 - mean_squared_error: 1.0827 - val_loss: 1.4562 - val_mean_squared_error: 1.4562
# Epoch 34/100
# 704/746 [===========================>..] - ETA: 0s - loss: 1.0816 - mean_squared_error: 1.0816
# Epoch 00034: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-2-channels-trim-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 1s 734us/sample - loss: 1.0823 - mean_squared_error: 1.0823 - val_loss: 1.4568 - val_mean_squared_error: 1.4568
# Epoch 35/100
# 672/746 [==========================>...] - ETA: 0s - loss: 1.1170 - mean_squared_error: 1.1170
# Epoch 00035: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-2-channels-trim-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 1s 697us/sample - loss: 1.0812 - mean_squared_error: 1.0812 - val_loss: 1.4560 - val_mean_squared_error: 1.4560
# Epoch 36/100
# 640/746 [========================>.....] - ETA: 0s - loss: 1.0559 - mean_squared_error: 1.0559
# Epoch 00036: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-2-channels-trim-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 518us/sample - loss: 1.0788 - mean_squared_error: 1.0788 - val_loss: 1.4554 - val_mean_squared_error: 1.4554
# Epoch 37/100
# 672/746 [==========================>...] - ETA: 0s - loss: 1.0694 - mean_squared_error: 1.0694
# Epoch 00037: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-2-channels-trim-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 656us/sample - loss: 1.0777 - mean_squared_error: 1.0777 - val_loss: 1.4571 - val_mean_squared_error: 1.4571
# Epoch 38/100
# 736/746 [============================>.] - ETA: 0s - loss: 1.0711 - mean_squared_error: 1.0711
# Epoch 00038: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-2-channels-trim-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 534us/sample - loss: 1.0761 - mean_squared_error: 1.0761 - val_loss: 1.4558 - val_mean_squared_error: 1.4558
# Epoch 39/100
# 672/746 [==========================>...] - ETA: 0s - loss: 1.0684 - mean_squared_error: 1.0684
# Epoch 00039: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-2-channels-trim-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 1s 705us/sample - loss: 1.0749 - mean_squared_error: 1.0749 - val_loss: 1.4543 - val_mean_squared_error: 1.4543
# Epoch 40/100
# 608/746 [=======================>......] - ETA: 0s - loss: 1.0768 - mean_squared_error: 1.0768
# Epoch 00040: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-2-channels-trim-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 1s 706us/sample - loss: 1.0742 - mean_squared_error: 1.0742 - val_loss: 1.4543 - val_mean_squared_error: 1.4543
# Epoch 41/100
# 640/746 [========================>.....] - ETA: 0s - loss: 1.0612 - mean_squared_error: 1.0612
# Epoch 00041: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-2-channels-trim-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 479us/sample - loss: 1.0722 - mean_squared_error: 1.0722 - val_loss: 1.4547 - val_mean_squared_error: 1.4547
# Epoch 42/100
# 608/746 [=======================>......] - ETA: 0s - loss: 1.0413 - mean_squared_error: 1.0413
# Epoch 00042: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-2-channels-trim-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 1s 701us/sample - loss: 1.0709 - mean_squared_error: 1.0709 - val_loss: 1.4529 - val_mean_squared_error: 1.4529
# Epoch 43/100
# 704/746 [===========================>..] - ETA: 0s - loss: 1.0672 - mean_squared_error: 1.0672
# Epoch 00043: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-2-channels-trim-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 538us/sample - loss: 1.0696 - mean_squared_error: 1.0696 - val_loss: 1.4539 - val_mean_squared_error: 1.4539
# Epoch 44/100
# 672/746 [==========================>...] - ETA: 0s - loss: 1.0413 - mean_squared_error: 1.0413
# Epoch 00044: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-2-channels-trim-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 670us/sample - loss: 1.0682 - mean_squared_error: 1.0682 - val_loss: 1.4509 - val_mean_squared_error: 1.4509
# Epoch 45/100
# 640/746 [========================>.....] - ETA: 0s - loss: 1.0544 - mean_squared_error: 1.0544
# Epoch 00045: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-2-channels-trim-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 1s 698us/sample - loss: 1.0665 - mean_squared_error: 1.0665 - val_loss: 1.4526 - val_mean_squared_error: 1.4526
# Epoch 46/100
# 640/746 [========================>.....] - ETA: 0s - loss: 1.0787 - mean_squared_error: 1.0787
# Epoch 00046: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-2-channels-trim-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 513us/sample - loss: 1.0674 - mean_squared_error: 1.0674 - val_loss: 1.4502 - val_mean_squared_error: 1.4502
# Epoch 47/100
# 672/746 [==========================>...] - ETA: 0s - loss: 1.0662 - mean_squared_error: 1.0662
# Epoch 00047: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-2-channels-trim-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 1s 709us/sample - loss: 1.0653 - mean_squared_error: 1.0653 - val_loss: 1.4495 - val_mean_squared_error: 1.4495
# Epoch 48/100
# 736/746 [============================>.] - ETA: 0s - loss: 1.0657 - mean_squared_error: 1.0657
# Epoch 00048: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-2-channels-trim-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 1s 679us/sample - loss: 1.0631 - mean_squared_error: 1.0631 - val_loss: 1.4496 - val_mean_squared_error: 1.4496
# Epoch 49/100
# 672/746 [==========================>...] - ETA: 0s - loss: 1.0759 - mean_squared_error: 1.0759
# Epoch 00049: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-2-channels-trim-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 490us/sample - loss: 1.0622 - mean_squared_error: 1.0622 - val_loss: 1.4497 - val_mean_squared_error: 1.4497
# Epoch 50/100
# 704/746 [===========================>..] - ETA: 0s - loss: 1.0703 - mean_squared_error: 1.0703
# Epoch 00050: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-2-channels-trim-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 1s 712us/sample - loss: 1.0612 - mean_squared_error: 1.0612 - val_loss: 1.4468 - val_mean_squared_error: 1.4468
# Epoch 51/100
# 704/746 [===========================>..] - ETA: 0s - loss: 1.0601 - mean_squared_error: 1.0601
# Epoch 00051: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-2-channels-trim-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 530us/sample - loss: 1.0590 - mean_squared_error: 1.0590 - val_loss: 1.4475 - val_mean_squared_error: 1.4475
# Epoch 52/100
# 736/746 [============================>.] - ETA: 0s - loss: 1.0590 - mean_squared_error: 1.0590
# Epoch 00052: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-2-channels-trim-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 1s 712us/sample - loss: 1.0580 - mean_squared_error: 1.0580 - val_loss: 1.4472 - val_mean_squared_error: 1.4472
# Epoch 53/100
# 608/746 [=======================>......] - ETA: 0s - loss: 1.0441 - mean_squared_error: 1.0441
# Epoch 00053: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-2-channels-trim-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 1s 695us/sample - loss: 1.0580 - mean_squared_error: 1.0580 - val_loss: 1.4468 - val_mean_squared_error: 1.4468
# Epoch 54/100
# 608/746 [=======================>......] - ETA: 0s - loss: 1.0462 - mean_squared_error: 1.0462
# Epoch 00054: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-2-channels-trim-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 493us/sample - loss: 1.0566 - mean_squared_error: 1.0566 - val_loss: 1.4468 - val_mean_squared_error: 1.4468
# Epoch 55/100
# 736/746 [============================>.] - ETA: 0s - loss: 1.0639 - mean_squared_error: 1.0639
# Epoch 00055: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-2-channels-trim-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 1s 744us/sample - loss: 1.0550 - mean_squared_error: 1.0550 - val_loss: 1.4458 - val_mean_squared_error: 1.4458
# Epoch 56/100
# 704/746 [===========================>..] - ETA: 0s - loss: 1.0541 - mean_squared_error: 1.0541
# Epoch 00056: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-2-channels-trim-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 538us/sample - loss: 1.0535 - mean_squared_error: 1.0535 - val_loss: 1.4430 - val_mean_squared_error: 1.4430
# Epoch 57/100
# 736/746 [============================>.] - ETA: 0s - loss: 1.0593 - mean_squared_error: 1.0593
# Epoch 00057: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-2-channels-trim-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 1s 718us/sample - loss: 1.0521 - mean_squared_error: 1.0521 - val_loss: 1.4444 - val_mean_squared_error: 1.4444
# Epoch 58/100
# 640/746 [========================>.....] - ETA: 0s - loss: 1.0514 - mean_squared_error: 1.0514
# Epoch 00058: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-2-channels-trim-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 1s 704us/sample - loss: 1.0508 - mean_squared_error: 1.0508 - val_loss: 1.4450 - val_mean_squared_error: 1.4450
# Epoch 59/100
# 608/746 [=======================>......] - ETA: 0s - loss: 1.0785 - mean_squared_error: 1.0785
# Epoch 00059: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-2-channels-trim-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 515us/sample - loss: 1.0496 - mean_squared_error: 1.0496 - val_loss: 1.4442 - val_mean_squared_error: 1.4442
# Epoch 60/100
# 736/746 [============================>.] - ETA: 0s - loss: 1.0483 - mean_squared_error: 1.0483
# Epoch 00060: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-2-channels-trim-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 1s 708us/sample - loss: 1.0485 - mean_squared_error: 1.0485 - val_loss: 1.4403 - val_mean_squared_error: 1.4403
# Epoch 61/100
# 736/746 [============================>.] - ETA: 0s - loss: 1.0433 - mean_squared_error: 1.0433
# Epoch 00061: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-2-channels-trim-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 642us/sample - loss: 1.0473 - mean_squared_error: 1.0473 - val_loss: 1.4402 - val_mean_squared_error: 1.4402
# Epoch 62/100
# 640/746 [========================>.....] - ETA: 0s - loss: 1.0463 - mean_squared_error: 1.0463
# Epoch 00062: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-2-channels-trim-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 508us/sample - loss: 1.0456 - mean_squared_error: 1.0456 - val_loss: 1.4401 - val_mean_squared_error: 1.4401
# Epoch 63/100
# 736/746 [============================>.] - ETA: 0s - loss: 1.0508 - mean_squared_error: 1.0508
# Epoch 00063: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-2-channels-trim-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 1s 749us/sample - loss: 1.0453 - mean_squared_error: 1.0453 - val_loss: 1.4394 - val_mean_squared_error: 1.4394
# Epoch 64/100
# 672/746 [==========================>...] - ETA: 0s - loss: 1.0611 - mean_squared_error: 1.0611
# Epoch 00064: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-2-channels-trim-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 557us/sample - loss: 1.0444 - mean_squared_error: 1.0444 - val_loss: 1.4394 - val_mean_squared_error: 1.4394
# Epoch 65/100
# 704/746 [===========================>..] - ETA: 0s - loss: 1.0526 - mean_squared_error: 1.0526
# Epoch 00065: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-2-channels-trim-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 1s 728us/sample - loss: 1.0428 - mean_squared_error: 1.0428 - val_loss: 1.4387 - val_mean_squared_error: 1.4387
# Epoch 66/100
# 672/746 [==========================>...] - ETA: 0s - loss: 1.0426 - mean_squared_error: 1.0426
# Epoch 00066: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-2-channels-trim-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 1s 723us/sample - loss: 1.0414 - mean_squared_error: 1.0414 - val_loss: 1.4354 - val_mean_squared_error: 1.4354
# Epoch 67/100
# 672/746 [==========================>...] - ETA: 0s - loss: 1.0203 - mean_squared_error: 1.0203
# Epoch 00067: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-2-channels-trim-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 559us/sample - loss: 1.0405 - mean_squared_error: 1.0405 - val_loss: 1.4358 - val_mean_squared_error: 1.4358
# Epoch 68/100
# 704/746 [===========================>..] - ETA: 0s - loss: 1.0380 - mean_squared_error: 1.0380
# Epoch 00068: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-2-channels-trim-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 1s 749us/sample - loss: 1.0393 - mean_squared_error: 1.0393 - val_loss: 1.4348 - val_mean_squared_error: 1.4348
# Epoch 69/100
# 704/746 [===========================>..] - ETA: 0s - loss: 1.0244 - mean_squared_error: 1.0244
# Epoch 00069: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-2-channels-trim-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 660us/sample - loss: 1.0382 - mean_squared_error: 1.0382 - val_loss: 1.4352 - val_mean_squared_error: 1.4352
# Epoch 70/100
# 608/746 [=======================>......] - ETA: 0s - loss: 1.0893 - mean_squared_error: 1.0893
# Epoch 00070: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-2-channels-trim-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 547us/sample - loss: 1.0373 - mean_squared_error: 1.0373 - val_loss: 1.4340 - val_mean_squared_error: 1.4340
# Epoch 71/100
# 608/746 [=======================>......] - ETA: 0s - loss: 1.0431 - mean_squared_error: 1.0431
# Epoch 00071: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-2-channels-trim-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 1s 706us/sample - loss: 1.0361 - mean_squared_error: 1.0361 - val_loss: 1.4327 - val_mean_squared_error: 1.4327
# Epoch 72/100
# 736/746 [============================>.] - ETA: 0s - loss: 1.0348 - mean_squared_error: 1.0348
# Epoch 00072: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-2-channels-trim-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 572us/sample - loss: 1.0347 - mean_squared_error: 1.0347 - val_loss: 1.4344 - val_mean_squared_error: 1.4344
# Epoch 73/100
# 736/746 [============================>.] - ETA: 0s - loss: 1.0355 - mean_squared_error: 1.0355
# Epoch 00073: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-2-channels-trim-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 1s 754us/sample - loss: 1.0343 - mean_squared_error: 1.0343 - val_loss: 1.4306 - val_mean_squared_error: 1.4306
# Epoch 74/100
# 736/746 [============================>.] - ETA: 0s - loss: 1.0336 - mean_squared_error: 1.0336
# Epoch 00074: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-2-channels-trim-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 1s 720us/sample - loss: 1.0326 - mean_squared_error: 1.0326 - val_loss: 1.4304 - val_mean_squared_error: 1.4304
# Epoch 75/100
# 736/746 [============================>.] - ETA: 0s - loss: 1.0396 - mean_squared_error: 1.0396
# Epoch 00075: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-2-channels-trim-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 560us/sample - loss: 1.0319 - mean_squared_error: 1.0319 - val_loss: 1.4294 - val_mean_squared_error: 1.4294
# Epoch 76/100
# 608/746 [=======================>......] - ETA: 0s - loss: 1.0124 - mean_squared_error: 1.0124
# Epoch 00076: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-2-channels-trim-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 1s 754us/sample - loss: 1.0308 - mean_squared_error: 1.0308 - val_loss: 1.4314 - val_mean_squared_error: 1.4314
# Epoch 77/100
# 736/746 [============================>.] - ETA: 0s - loss: 1.0371 - mean_squared_error: 1.0371
# Epoch 00077: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-2-channels-trim-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 1s 720us/sample - loss: 1.0301 - mean_squared_error: 1.0301 - val_loss: 1.4302 - val_mean_squared_error: 1.4302
# Epoch 78/100
# 736/746 [============================>.] - ETA: 0s - loss: 1.0217 - mean_squared_error: 1.0217
# Epoch 00078: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-2-channels-trim-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 540us/sample - loss: 1.0284 - mean_squared_error: 1.0284 - val_loss: 1.4313 - val_mean_squared_error: 1.4313
# Epoch 79/100
# 736/746 [============================>.] - ETA: 0s - loss: 1.0252 - mean_squared_error: 1.0252
# Epoch 00079: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-2-channels-trim-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 1s 734us/sample - loss: 1.0272 - mean_squared_error: 1.0272 - val_loss: 1.4297 - val_mean_squared_error: 1.4297
# Epoch 80/100
# 736/746 [============================>.] - ETA: 0s - loss: 1.0238 - mean_squared_error: 1.0238
# Epoch 00080: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-2-channels-trim-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 574us/sample - loss: 1.0260 - mean_squared_error: 1.0260 - val_loss: 1.4278 - val_mean_squared_error: 1.4278
# Epoch 81/100
# 608/746 [=======================>......] - ETA: 0s - loss: 0.9890 - mean_squared_error: 0.9890
# Epoch 00081: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-2-channels-trim-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 1s 737us/sample - loss: 1.0251 - mean_squared_error: 1.0251 - val_loss: 1.4271 - val_mean_squared_error: 1.4271
# Epoch 82/100
# 640/746 [========================>.....] - ETA: 0s - loss: 1.0595 - mean_squared_error: 1.0595
# Epoch 00082: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-2-channels-trim-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 1s 696us/sample - loss: 1.0240 - mean_squared_error: 1.0240 - val_loss: 1.4271 - val_mean_squared_error: 1.4271
# Epoch 83/100
# 704/746 [===========================>..] - ETA: 0s - loss: 1.0262 - mean_squared_error: 1.0262
# Epoch 00083: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-2-channels-trim-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 562us/sample - loss: 1.0233 - mean_squared_error: 1.0233 - val_loss: 1.4262 - val_mean_squared_error: 1.4262
# Epoch 84/100
# 736/746 [============================>.] - ETA: 0s - loss: 1.0192 - mean_squared_error: 1.0192
# Epoch 00084: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-2-channels-trim-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 1s 813us/sample - loss: 1.0216 - mean_squared_error: 1.0216 - val_loss: 1.4250 - val_mean_squared_error: 1.4250
# Epoch 85/100
# 704/746 [===========================>..] - ETA: 0s - loss: 1.0294 - mean_squared_error: 1.0294
# Epoch 00085: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-2-channels-trim-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 1s 723us/sample - loss: 1.0204 - mean_squared_error: 1.0204 - val_loss: 1.4249 - val_mean_squared_error: 1.4249
# Epoch 86/100
# 704/746 [===========================>..] - ETA: 0s - loss: 1.0093 - mean_squared_error: 1.0093
# Epoch 00086: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-2-channels-trim-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 550us/sample - loss: 1.0194 - mean_squared_error: 1.0194 - val_loss: 1.4226 - val_mean_squared_error: 1.4226
# Epoch 87/100
# 672/746 [==========================>...] - ETA: 0s - loss: 1.0205 - mean_squared_error: 1.0205
# Epoch 00087: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-2-channels-trim-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 1s 764us/sample - loss: 1.0202 - mean_squared_error: 1.0202 - val_loss: 1.4238 - val_mean_squared_error: 1.4238
# Epoch 88/100
# 608/746 [=======================>......] - ETA: 0s - loss: 0.9990 - mean_squared_error: 0.9990
# Epoch 00088: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-2-channels-trim-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 519us/sample - loss: 1.0182 - mean_squared_error: 1.0182 - val_loss: 1.4217 - val_mean_squared_error: 1.4217
# Epoch 89/100
# 608/746 [=======================>......] - ETA: 0s - loss: 0.9909 - mean_squared_error: 0.9909
# Epoch 00089: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-2-channels-trim-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 1s 722us/sample - loss: 1.0159 - mean_squared_error: 1.0159 - val_loss: 1.4206 - val_mean_squared_error: 1.4206
# Epoch 90/100
# 736/746 [============================>.] - ETA: 0s - loss: 1.0208 - mean_squared_error: 1.0208
# Epoch 00090: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-2-channels-trim-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 1s 738us/sample - loss: 1.0152 - mean_squared_error: 1.0152 - val_loss: 1.4215 - val_mean_squared_error: 1.4215
# Epoch 91/100
# 704/746 [===========================>..] - ETA: 0s - loss: 1.0187 - mean_squared_error: 1.0187
# Epoch 00091: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-2-channels-trim-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 548us/sample - loss: 1.0138 - mean_squared_error: 1.0138 - val_loss: 1.4194 - val_mean_squared_error: 1.4194
# Epoch 92/100
# 608/746 [=======================>......] - ETA: 0s - loss: 1.0387 - mean_squared_error: 1.0387
# Epoch 00092: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-2-channels-trim-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 1s 750us/sample - loss: 1.0138 - mean_squared_error: 1.0138 - val_loss: 1.4202 - val_mean_squared_error: 1.4202
# Epoch 93/100
# 704/746 [===========================>..] - ETA: 0s - loss: 1.0105 - mean_squared_error: 1.0105
# Epoch 00093: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-2-channels-trim-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 1s 726us/sample - loss: 1.0122 - mean_squared_error: 1.0122 - val_loss: 1.4194 - val_mean_squared_error: 1.4194
# Epoch 94/100
# 704/746 [===========================>..] - ETA: 0s - loss: 0.9988 - mean_squared_error: 0.9988
# Epoch 00094: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-2-channels-trim-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 528us/sample - loss: 1.0120 - mean_squared_error: 1.0120 - val_loss: 1.4156 - val_mean_squared_error: 1.4156
# Epoch 95/100
# 704/746 [===========================>..] - ETA: 0s - loss: 1.0178 - mean_squared_error: 1.0178
# Epoch 00095: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-2-channels-trim-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 1s 757us/sample - loss: 1.0106 - mean_squared_error: 1.0106 - val_loss: 1.4185 - val_mean_squared_error: 1.4185
# Epoch 96/100
# 640/746 [========================>.....] - ETA: 0s - loss: 1.0037 - mean_squared_error: 1.0037
# Epoch 00096: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-2-channels-trim-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 1s 722us/sample - loss: 1.0094 - mean_squared_error: 1.0094 - val_loss: 1.4142 - val_mean_squared_error: 1.4142
# Epoch 97/100
# 736/746 [============================>.] - ETA: 0s - loss: 1.0056 - mean_squared_error: 1.0056
# Epoch 00097: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-2-channels-trim-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 551us/sample - loss: 1.0073 - mean_squared_error: 1.0073 - val_loss: 1.4158 - val_mean_squared_error: 1.4158
# Epoch 98/100
# 736/746 [============================>.] - ETA: 0s - loss: 1.0036 - mean_squared_error: 1.0036
# Epoch 00098: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-2-channels-trim-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 1s 696us/sample - loss: 1.0069 - mean_squared_error: 1.0069 - val_loss: 1.4131 - val_mean_squared_error: 1.4131
# Epoch 99/100
# 704/746 [===========================>..] - ETA: 0s - loss: 1.0114 - mean_squared_error: 1.0114
# Epoch 00099: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-2-channels-trim-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 1s 704us/sample - loss: 1.0062 - mean_squared_error: 1.0062 - val_loss: 1.4184 - val_mean_squared_error: 1.4184
# Epoch 100/100
# 672/746 [==========================>...] - ETA: 0s - loss: 1.0242 - mean_squared_error: 1.0242
# Epoch 00100: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-2-channels-trim-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 606us/sample - loss: 1.0045 - mean_squared_error: 1.0045 - val_loss: 1.4132 - val_mean_squared_error: 1.4132
# (83, 2, 6)
# Decoded seq from VAE: (3, 24, 2)
# Decoded seq from lstm: (2, 24, 2)
# Decoded seq from VAE: (3, 24, 2)
# Decoded seq from lstm: (2, 24, 2)
# Decoded seq from VAE: (3, 24, 2)
# Decoded seq from lstm: (2, 24, 2)
# Decoded seq from VAE: (3, 24, 2)
# Decoded seq from lstm: (2, 24, 2)
# Decoded seq from VAE: (3, 24, 2)
# Decoded seq from lstm: (2, 24, 2)
# Decoded seq from VAE: (3, 24, 2)
# Decoded seq from lstm: (2, 24, 2)
# Decoded seq from VAE: (3, 24, 2)
# Decoded seq from lstm: (2, 24, 2)
# Decoded seq from VAE: (3, 24, 2)
# Decoded seq from lstm: (2, 24, 2)
# Decoded seq from VAE: (3, 24, 2)
# Decoded seq from lstm: (2, 24, 2)
# Decoded seq from VAE: (3, 24, 2)
# Decoded seq from lstm: (2, 24, 2)

# %%
# load normalised time series
save_dir = '../datasets/' + config['data_dir'] #NAB-known-anomaly/'
dataset = config['dataset']
file_name = config['filename']
filename = '{}.npz'.format(file_name)
result = dict(np.load(save_dir+filename, allow_pickle=True))
if dataset == 'machine_temp':
    result['test'] = result['test'][0]
    result['idx_anomaly_test'] = result['idx_anomaly_test'][0]
    result['t_test'] = result['t_test'][0]

# slice into rolling windows and rolling sequences
def slice_rolling_windows_and_sequences(config, time_seq):
    n_sample = len(time_seq)
    print("The given sequence has {} samples".format(n_sample))
    n_vae_win = n_sample - config['l_win'] + 1
    rolling_windows = np.zeros((n_vae_win, config['l_win'], config['n_channel']), dtype=float)
    for i in range(n_vae_win):
        rolling_windows[i] = time_seq[i:i + config['l_win']]
        sample_m = np.mean(rolling_windows, axis=1)
        sample_std = np.std(rolling_windows, axis=1)

        n_lstm_seq = n_sample - config['l_seq']*config['l_win']+1
        lstm_seq = np.zeros((n_lstm_seq, config['l_seq'], config['l_win'], config['n_channel']), dtype=float)
    for i in range(n_lstm_seq):
        cur_seq = time_seq[i:i+config['l_seq']*config['l_win']]
        for j in range(config['l_seq']):
            lstm_seq[i,j] = cur_seq[config['l_win']*j:config['l_win']*(j+1)]
    
    return rolling_windows, lstm_seq, sample_m, sample_std

test_windows, test_seq, test_sample_m, test_sample_std = slice_rolling_windows_and_sequences(config, result['test'])
if config['n_channel'] == 1:
    test_windows = np.expand_dims(test_windows, -1)
    test_seq = np.expand_dims(test_seq, -1)
else:
    test_windows = test_windows
    test_seq = test_seq
print(test_windows.shape)
print(test_seq.shape)
# Out:
# The given sequence has 583 samples
# (560, 24, 2)
# (512, 3, 24, 2)

# %%
# Evaluate ELBO and LSTM prediction error on the validation set
# evaluate some anomaly detection metrics
def evaluate_vae_anomaly_metrics_for_a_window(test_win):
    feed_dict = {model_vae.original_signal: np.expand_dims(test_win, 0),
                 model_vae.is_code_input: False,
                 model_vae.code_input: np.zeros((1, config['code_size']))}

    # VAE reconstruction error
    recons_win_vae = np.squeeze(sess.run(model_vae.decoded, feed_dict=feed_dict))
    test_vae_recons_error = np.sum(np.square(recons_win_vae - test_win))

    # VAE latent embedding likelihood
    vae_code_mean, vae_code_std = sess.run([model_vae.code_mean, model_vae.code_std_dev], feed_dict=feed_dict)
    test_vae_kl = 0.5 * (np.sum(np.square(vae_code_mean)) + \
                            np.sum(np.square(vae_code_std)) - \
                            np.sum(np.log(np.square(vae_code_std))) - config['code_size'])

    # VAE ELBO loss
    sigma2 = 0.0005
    input_dims = model_vae.input_dims
    sigma_regularisor = input_dims/2. * np.log(sigma2) + input_dims * np.pi
    test_vae_elbo = test_vae_recons_error/sigma2 + test_vae_kl + sigma_regularisor
    return test_vae_recons_error, test_vae_kl, test_vae_elbo

def evaluate_lstm_anomaly_metric_for_a_seq(test_seq):
    feed_dict = {model_vae.original_signal: test_seq,
                 model_vae.is_code_input: False,
                 model_vae.code_input: np.zeros((1, config['code_size']))}
    vae_embedding = np.squeeze(sess.run(model_vae.code_mean, feed_dict=feed_dict))
    #print(vae_embedding.shape)
    lstm_embedding = np.squeeze(lstm_nn_model.predict(np.expand_dims(vae_embedding[:config['l_seq']-1], 0), batch_size=1))
    lstm_embedding_error = np.sum(np.square(vae_embedding[1:] - lstm_embedding))
    
    # LSTM prediction error
    feed_dict_lstm = {model_vae.original_signal: np.zeros((config['l_seq'] - 1, config['l_win'], test_seq.shape[2])),
                      model_vae.is_code_input: True,
                      model_vae.code_input: lstm_embedding}
    recons_win_lstm = np.squeeze(sess.run(model_vae.decoded, feed_dict=feed_dict_lstm))
    lstm_recons_error = np.sum(np.square(recons_win_lstm - np.squeeze(test_seq[1:])))
    return lstm_recons_error, lstm_embedding_error

n_val_vae = data.val_set_vae['data'].shape[0]
n_val_lstm = data.val_set_lstm['data'].shape[0]

val_vae_recons_error = np.zeros(n_val_vae)
val_vae_kl_error = np.zeros(n_val_vae)
val_vae_elbo_loss = np.zeros(n_val_vae)
for i in range(n_val_vae):
    val_vae_recons_error[i], val_vae_kl_error[i], val_vae_elbo_loss[i] = evaluate_vae_anomaly_metrics_for_a_window(data.val_set_vae['data'][i])

val_lstm_recons_error, val_lstm_embedding_error = np.zeros(n_val_lstm), np.zeros(n_val_lstm)
for i in range(n_val_lstm):
    val_lstm_recons_error[i], val_lstm_embedding_error[i] = evaluate_lstm_anomaly_metric_for_a_seq(data.val_set_lstm['data'][i])

# %%
from scipy.stats import norm
def plot_histogram(test_anomaly_metric, n_bins, title, mean=None, std=None, xlim=None, saveplot=False):
    test_anomaly_list = np.squeeze(np.ndarray.flatten(test_anomaly_metric))
    his = plt.hist(test_anomaly_list, bins=n_bins, density=True)
    if mean is None and std is None:
        mean = np.mean(test_anomaly_list)
        std = np.std(test_anomaly_list)
        legend_label = None
    else:
        legend_label = 1
    x_axis = np.arange(mean-5*std, mean+5*std, std/100)
    plt.plot(x_axis, norm.pdf(x_axis,mean,std))
    plt.title(title)
    plt.xlabel('anomaly score value')
    plt.ylabel('probability density')
    if xlim is not None:
        plt.xlim(0, xlim)
    else:
        plt.xlim(0, np.amax(test_anomaly_list))
    if legend_label is None:
        plt.legend(('Fitted Gaussian', 'histogram'))
    else:
        plt.legend(('normal data distribution','test data distribution (contain anomalies)'))
    if saveplot:
        savefig(config['result_dir']+'reconstruction_error_histogram.pdf')
    else:
        plt.show()
    threshold_25 = np.percentile(test_anomaly_list, 25)
    threshold_75 = np.percentile(test_anomaly_list, 75)
    threshold_1 = np.percentile(test_anomaly_list, 99)
    idx_large_error = np.squeeze(np.argwhere(test_anomaly_metric > threshold_1))
#     print(his[0][-20:])
#     print(his[1][-20:])
    print("25% percentile: {}".format(threshold_25))
    print("75% percentile: {}".format(threshold_75))
#     print("Median: {}".format(np.median(test_anomaly_list)))
#     print("Mean: {}".format(np.mean(test_anomaly_list)))
#     print("Std dev: {}".format(np.std(test_anomaly_list)))
    print("These windows scored the top 1% of anomaly metric ({}): \n{}".format(threshold_1, idx_large_error))
    return mean, std

# %%
# Histogram of VAE ELBO loss - validation set
vae_elbo_m, vae_elbo_std = plot_histogram(val_vae_elbo_loss, 100, 
                                          'VAE ELBO error distribution on the val set', 
                                          mean=None, std=None, xlim=None)
# Out:
# 25% percentile: 318.35115757453536
# 75% percentile: 5547.982964209068
# These windows scored the top 1% of anomaly metric (47581.7375172492):
# 0

# %%
# Histogram of LSTM reconstruction error - validation set 
#  --> to decide the anomaly detection threshold
lstm_recons_m, lstm_recons_std = plot_histogram(val_lstm_recons_error, 100,  
                                              'LSTM reconstruction error distribution on the val set', 
                                              mean=None, std=None, xlim=None)
# Out:
# 25% percentile: 8.980135228595614
# 75% percentile: 94.02750957477741
# These windows scored the top 1% of anomaly metric (201.4676622643704):
# 11

# %%
# Evaluate the anomaly metrics on the test windows and sequences
n_test_lstm = test_seq.shape[0]

test_lstm_recons_error, test_lstm_embedding_error = np.zeros(n_test_lstm), np.zeros(n_test_lstm)
for i in range(n_test_lstm):
    test_lstm_recons_error[i], test_lstm_embedding_error[i] = evaluate_lstm_anomaly_metric_for_a_seq(test_seq[i])
print("All windows' reconstruction error is computed.")
print("The total number of windows is {}".format(len(test_lstm_recons_error)))
# Out:
# All windows' reconstruction error is computed.
# The total number of windows is 512

# %%
# Histogram of LSTM reconstruction error - test set 
#  --> to detect anomaly now
_, _ = plot_histogram(test_lstm_recons_error, 100,
                      'LSTM reconstruction error distribution on the test set', 
                      mean=lstm_recons_m, std=lstm_recons_std, xlim=None, saveplot=True)
# Out:
# 25% percentile: 46.19848571896375
# 75% percentile: 145.30237533488966
# These windows scored the top 1% of anomaly metric (581.3250998932597):
# [503 504 508 509 510 511]

# %%
# Produce the ground truth anomaly indices 
# if result['idx_split'][0] == 0:
#     idx_anomaly_test = result['idx_anomaly_test']
# else:
#     idx_anomaly_test = result['idx_anomaly_test'][0]
idx_anomaly_test = result['idx_anomaly_test']    
anomaly_index_lstm = []
test_labels_lstm = np.zeros(n_test_lstm)
for i in range(len(idx_anomaly_test)):
    idx_start = idx_anomaly_test[i]-(config['l_win']*config['l_seq']-1)
    idx_end = idx_anomaly_test[i]+1
    if idx_start < 0:
        idx_start = 0
    if idx_end > n_test_lstm:
        idx_end = n_test_lstm
    anomaly_index_lstm.append(np.arange(idx_start,idx_end))
    test_labels_lstm[idx_start:idx_end] = 1
    
print(test_labels_lstm.shape)
# Out:
# (512,)

# %%
def return_anomaly_idx_by_threshold(test_anomaly_metric, threshold):
    test_list = np.squeeze(np.ndarray.flatten(test_anomaly_metric))
    idx_error = np.squeeze(np.argwhere(test_anomaly_metric > threshold))
    
    if len(idx_error.shape) == 0:
        idx_error = np.expand_dims(idx_error, 0)
    
    return list(idx_error)

# %%
def augment_detected_idx(idx_detected_anomaly, anomaly_index):
    n_anomaly = len(anomaly_index)
    idx_detected_anomaly_extended = list(idx_detected_anomaly)
    for i in range(n_anomaly):
        #print(idx_detected_anomaly)
        for j in idx_detected_anomaly:
            if j in anomaly_index[i]:
                in_original_detection = set(idx_detected_anomaly_extended)
                currect_anomaly_win = set(anomaly_index[i])
                idx_detected_anomaly_extended = idx_detected_anomaly_extended + list(currect_anomaly_win - in_original_detection)
                #print(j)
                break
                
    return list(np.sort(idx_detected_anomaly_extended))

# %%
def count_TP_FP_FN(idx_detected_anomaly, anomaly_index, test_labels):
    n_TP = 0
    n_FP = 0
    n_detection = len(idx_detected_anomaly)
    for i in range(n_detection):
        if test_labels[idx_detected_anomaly[i]] == 1:
            n_TP = n_TP + 1
        else:
            n_FP = n_FP + 1
    
    idx_undetected = list(set(np.arange(len(test_labels)))- set(idx_detected_anomaly))
    n_FN = 0
    for i in idx_undetected:
        if test_labels[i] == 1:
            n_FN = n_FN + 1
    
    return n_TP, n_FP, n_FN

# %%
def compute_precision_and_recall(idx_detected_anomaly, anomaly_index, test_labels):
    # compute true positive
    n_TP, n_FP, n_FN = count_TP_FP_FN(idx_detected_anomaly, anomaly_index, test_labels)
    
    if n_TP + n_FP == 0:
        precision = 1
    else:
        precision = n_TP / (n_TP + n_FP)
    recall = n_TP / (n_TP + n_FN)
    if precision + recall == 0:
        F1 = 0
    else:
        F1 = 2* (precision * recall)/(precision + recall)
    
    return precision, recall, F1, n_TP, n_FP, n_FN

# %%
n_threshold = 200
precision = np.zeros(n_threshold)
recall = np.zeros(n_threshold)
F1 = np.zeros(n_threshold)
precision_aug = np.zeros(n_threshold)
recall_aug = np.zeros(n_threshold)
F1_aug = np.zeros(n_threshold)
i = 0
threshold_list = np.linspace(np.amin(test_lstm_recons_error), np.amax(test_lstm_recons_error), n_threshold, endpoint=True)
threshold_list = np.flip(threshold_list)
for threshold in threshold_list:
    #print(threshold_list[i])
    idx_detection_lstm = return_anomaly_idx_by_threshold(test_lstm_recons_error, threshold)
    precision[i], recall[i], F1[i], _, _, _ = compute_precision_and_recall(idx_detection_lstm, 
                                                                           anomaly_index_lstm, 
                                                                           test_labels_lstm)
    # augment the detection using the ground truth labels
    # a method to discount the factor one anomaly appears in multiple consecutive windows
    # introduced in "Unsupervised anomaly detection via variational auto-encoder for seasonal kpis in web applications"
    idx_detection_lstm_augmented = augment_detected_idx(idx_detection_lstm, anomaly_index_lstm)
    precision_aug[i], recall_aug[i], F1_aug[i], _, _, _ = compute_precision_and_recall(idx_detection_lstm_augmented, 
                                                                                       anomaly_index_lstm, 
                                                                                       test_labels_lstm)
    i = i + 1
    #print(precision, recall, F1)

# %%
print("Best F1 score is {}".format(np.amax(F1)))
idx_best_threshold = np.squeeze(np.argwhere(F1 == np.amax(F1)))
print("Best threshold is {}".format(threshold_list[idx_best_threshold]))
print("At this threshold, precision is {}, recall is {}".format(precision[idx_best_threshold], recall[idx_best_threshold]))
average_precision = np.sum(precision[1:] * (recall[1:] - recall[:-1]))
print("Average precision is {}".format(average_precision))

print("\nAugmented detection:")
print("Best F1 score is {}".format(np.amax(F1_aug)))
idx_best_threshold = np.squeeze(np.argwhere(F1_aug == np.amax(F1_aug)))
print("Best threshold is {}".format(threshold_list[idx_best_threshold]))
print("At this threshold, precision is {}, recall is {}".format(precision_aug[idx_best_threshold], 
                                                                recall_aug[idx_best_threshold]))

average_precision_aug = np.sum(precision_aug[1:] * (recall_aug[1:] - recall_aug[:-1]))
print("Average precision is {}".format(average_precision_aug))
# Out:
# Best F1 score is 0.30634573304157553
# Best threshold is 45.35151212029505
# At this threshold, precision is 0.18181818181818182, recall is 0.9722222222222222
# Average precision is 0.17439571120809477
#
# Augmented detection:
# Best F1 score is 0.8622754491017963
# Best threshold is 292.41894488148586
# At this threshold, precision is 0.7578947368421053, recall is 1.0
# Average precision is 0.7578947368421053

# %%
# Now select a threshold
threshold = 292

print("Threshold is {}".format(threshold))
idx_detection = return_anomaly_idx_by_threshold(test_lstm_recons_error, threshold)
idx_detection_augmented = augment_detected_idx(idx_detection, anomaly_index_lstm)
precision, recall, F1, n_TP, n_FP, n_FN = compute_precision_and_recall(idx_detection_augmented, 
                                                                       anomaly_index_lstm, 
                                                                       test_labels_lstm)
print("\nPR evaluation using augmented detection:")
print("Precision: {}".format(precision))
print("Recall: {}".format(recall))
print("F1: {}".format(F1))
print("TP: {}".format(n_TP))
print("FP: {}".format(n_FP))
print("FN: {}".format(n_FN))
# Out:
# Threshold is 292
#
# PR evaluation using augmented detection:
# Precision: 0.7578947368421053
# Recall: 1.0
# F1: 0.8622754491017963
# TP: 72
# FP: 23
# FN: 0

# %%
def slice_detected_indices_into_seq(idx_detection, interval):
    detected_seq = []
    i = 0
    while i < len(idx_detection):
        if i == 0:
            cur_seq = [idx_detection[i]]
            i = i + 1
        else:
            if idx_detection[i] - idx_detection[i-1] > interval:
                detected_seq.append(cur_seq)
                cur_seq = [idx_detection[i]]
            else:
                cur_seq.append(idx_detection[i])
                if i == len(idx_detection) - 1:
                    detected_seq.append(cur_seq)
            i = i + 1
    
    print("Detected {} sequences".format(len(detected_seq)))
    return detected_seq

# %%
def plot_detected_anomalies(idx_detection, interval, dataset, result, detection_method, augmented_flag=1, y_scale=5, y_lim=None):
    detected_seq = slice_detected_indices_into_seq(idx_detection, interval=interval)
    t_test = result['t_test']
    test = result['test']
    idx_anomaly_test = result['idx_anomaly_test']
        
    # plot detected sequences
    fig, axs = plt.subplots(1, 1, figsize=(18, 5), edgecolor='k')
    fig.subplots_adjust(hspace=.4, wspace=.4)
    axs.plot(t_test, test)
    for j in range(len(idx_anomaly_test)):
        if j == 0:
            axs.plot(idx_anomaly_test[j] * np.ones(20), np.linspace(-y_scale, y_scale, 20), 'r--', label='true anomalies')
        else:
            axs.plot(idx_anomaly_test[j] * np.ones(20), np.linspace(-y_scale, y_scale, 20), 'r--')
        
    for i in range(len(detected_seq)):
        for j in detected_seq[i]:
            if j == detected_seq[0][0]:
                axs.plot((j+interval*2) * np.ones(20), np.linspace(-y_scale, -0.8*y_scale, 20), 'g-', label='detected anomalies')
            else:
                axs.plot((j+interval*2) * np.ones(20), np.linspace(-y_scale, -0.8*y_scale, 20), 'g-')
    
    for j in range(len(idx_anomaly_test)):
        axs.plot(idx_anomaly_test[j] * np.ones(20), np.linspace(-y_scale, y_scale, 20), 'r--')

    for i in range(len(detected_seq)):
        interval_x = np.asarray([detected_seq[i][0], detected_seq[i][-1]+interval*2])
        interval_y = np.asarray([y_scale,y_scale])
        if i == 0:
            axs.fill_between(interval_x, interval_y, alpha=0.2, color='y', label='detected anomaly windows')
        else:
            axs.fill_between(interval_x, interval_y, alpha=0.2, color='y')
        interval_y = np.asarray([-y_scale,-y_scale])
        axs.fill_between(interval_x, interval_y, alpha=0.2, color='y')
    axs.grid(True)
    axs.set_xlim(0, len(t_test))
    if y_lim is None:
        axs.set_ylim(-y_scale, y_scale)
    else:
        axs.set_ylim(-y_scale, y_lim)
    axs.set_xlabel("timestamp (every {})".format(result['t_unit']))
    axs.set_ylabel("normalised readings")
    #axs.set_title("{} dataset test sequence\n(normalised by train mean {:.4f} and std {:.4f})\n Detection method: {}".format(dataset, 
    #                                                                                    result['train_m'], 
    #                                                                                    result['train_std'],
    #                                                                                    detection_method))
    axs.set_title("{} dataset test sequence\n Detection method: {}".format(dataset, detection_method))
    axs.legend()
    savefig(config['result_dir']+'detected_anomalies_{}_aug_{}.pdf'.format(detection_method, augmented_flag))

# %%
plot_detected_anomalies(idx_detection_augmented, 
                        interval=config['l_win']*config['l_seq']/2, 
                        dataset=dataset, 
                        result=result, 
                        detection_method='lstm reconstruction error',
                        augmented_flag=1,
                        y_scale=5,
                        y_lim=5)
# Out:
# Detected 2 sequences
