# %%
from google.colab import drive
drive.mount('/content/drive')
global GIT_DIR
GIT_DIR='/content/drive/My\ Drive/afeka/y2/sem1/dl/code/LSTM-VAE/VAE-LSTM-for-anomaly-detection'
# %cd $GIT_DIR
# !ls

# %%
# %cd $GIT_DIR/codes/

# %%
import warnings

def fxn():
    warnings.warn("deprecated", DeprecationWarning)

with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    fxn()

# %%
# %tensorflow_version 1.x
# Out:
# UsageError: Line magic function `%tensorflow_version` not found.

# %%
import tensorflow as tf
import tensorflow_probability as tfp
import numpy as np
import matplotlib.pylab as plt
from matplotlib.pyplot import plot, ion, show, savefig, cla, figure
import random
import time

# %%
import os
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"   # see issue #152
os.environ["CUDA_VISIBLE_DEVICES"]="0"

import tensorflow as tf
from data_loader import DataGenerator
from models import VAEmodel, lstmKerasModel
from trainers import vaeTrainer

from utils import process_config, create_dirs, get_args

# %%
from tensorflow.python.client import device_lib

def get_available_gpus():
    local_device_protos = device_lib.list_local_devices()
    return [x.name for x in local_device_protos if x.device_type == 'GPU']

print(get_available_gpus())
# Out:
# []

# %%
# load VAE model
config = process_config('NAB_config.json')
# create the experiments dirs
create_dirs([config['result_dir'], config['checkpoint_dir']])
# create tensorflow session
sess = tf.Session(config=tf.ConfigProto(log_device_placement=True))
# create your data generator
data = DataGenerator(config)
# create a CNN model
model_vae = VAEmodel(config)
# create a CNN model
trainer_vae = vaeTrainer(sess, model_vae, data, config)
model_vae.load(sess)

# here you train your model
if config['TRAIN_VAE']:
    if config['num_epochs_vae'] > 0:
        trainer_vae.train()
# Out:
# l: 224.0810
# Current sigma2: 0.0100000
# Already trained for 0.3198169509569804 min; Remaining 7.675606822967529 min.
# Saving model...
# Model saved.
# 2/49, test loss: -elbo: 230.6889, recons_loss_weighted: 324.3602, recons_loss_ls: 6.4872, KL_loss: 28.2364, sigma_regularisor: -110.5241, code_std_dev: [0.24388379 0.2023857  0.12285083 0.17067745 0.094347   0.11274276]
# Loss on training and val sets:
# train: 195.3880, val: 247.0448
# Current sigma2: 0.0100000
# Already trained for 0.46683966318766273 min; Remaining 7.31382138994005 min.
# Saving model...
# Model saved.
# 3/49, test loss: -elbo: 226.2729, recons_loss_weighted: 315.4109, recons_loss_ls: 6.3082, KL_loss: 28.2951, sigma_regularisor: -110.5241, code_std_dev: [0.24390584 0.16182274 0.08149932 0.18076256 0.03817909 0.06445022]
# Loss on training and val sets:
# train: 191.8166, val: 254.6653
# Current sigma2: 0.0100000
# Already trained for 0.6140342235565186 min; Remaining 7.061393570899964 min.
# Saving model...
# Model saved.
# 4/49, test loss: -elbo: 228.5396, recons_loss_weighted: 320.7672, recons_loss_ls: 6.4153, KL_loss: 27.8837, sigma_regularisor: -110.5241, code_std_dev: [0.25739282 0.15982462 0.07441033 0.15276623 0.06239044 0.07207606]
# Loss on training and val sets:
# train: 190.5464, val: 207.9256
# Current sigma2: 0.0100000
# Already trained for 0.7530123392740885 min; Remaining 6.777111053466797 min.
# Saving model...
# Model saved.
# 5/49, test loss: -elbo: 228.8474, recons_loss_weighted: 319.0439, recons_loss_ls: 6.3809, KL_loss: 29.0531, sigma_regularisor: -110.5241, code_std_dev: [0.23573563 0.1942673  0.06740643 0.1865884  0.02482421 0.06793109]
# Loss on training and val sets:
# train: 183.1393, val: 218.2653
# Current sigma2: 0.0100000
# Already trained for 0.8996084690093994 min; Remaining 6.597128772735596 min.
# Saving model...
# Model saved.
# 6/49, test loss: -elbo: 221.0046, recons_loss_weighted: 305.0812, recons_loss_ls: 6.1016, KL_loss: 28.1916, sigma_regularisor: -110.5241, code_std_dev: [0.30035067 0.20343931 0.07401711 0.19478741 0.03368551 0.09337388]
# Loss on training and val sets:
# train: 179.7438, val: 208.7893
# Current sigma2: 0.0100000
# Already trained for 1.0411634167035422 min; Remaining 6.3957181311789 min.
# Saving model...
# Model saved.
# 7/49, test loss: -elbo: 230.5953, recons_loss_weighted: 324.6024, recons_loss_ls: 6.4920, KL_loss: 28.0217, sigma_regularisor: -110.5241, code_std_dev: [0.26873413 0.27590814 0.04760814 0.20010965 0.01998398 0.09803013]
# Loss on training and val sets:
# train: 178.2516, val: 204.6200
# Current sigma2: 0.0100000
# Already trained for 1.1849998911221822 min; Remaining 6.221249428391457 min.
# Saving model...
# Model saved.
# 8/49, test loss: -elbo: 233.0029, recons_loss_weighted: 331.2538, recons_loss_ls: 6.6251, KL_loss: 27.1036, sigma_regularisor: -110.5241, code_std_dev: [0.23485598 0.18370737 0.13127875 0.21099426 0.09624408 0.06972717]
# Loss on training and val sets:
# train: 172.3909, val: 227.0395
# Current sigma2: 0.0100000
# Already trained for 1.324357839425405 min; Remaining 6.033185712937955 min.
# Saving model...
# Model saved.
# 9/49, test loss: -elbo: 226.1895, recons_loss_weighted: 316.7560, recons_loss_ls: 6.3351, KL_loss: 27.5391, sigma_regularisor: -110.5241, code_std_dev: [0.23741199 0.17269312 0.08041614 0.14907794 0.05097001 0.0812764 ]
# Loss on training and val sets:
# train: 172.5708, val: 221.5630
# Current sigma2: 0.0100000
# Already trained for 1.469501225153605 min; Remaining 5.87800490061442 min.
# Saving model...
# Model saved.
# 10/49, test loss: -elbo: 226.0112, recons_loss_weighted: 316.6585, recons_loss_ls: 6.3332, KL_loss: 27.4096, sigma_regularisor: -110.5241, code_std_dev: [0.21142371 0.18126583 0.10849323 0.18519904 0.04064506 0.08048958]
# Loss on training and val sets:
# train: 169.6896, val: 244.0540
# Current sigma2: 0.0100000
# Already trained for 1.6098082860310872 min; Remaining 5.70750210501931 min.
# Saving model...
# Model saved.
# 11/49, test loss: -elbo: 224.6611, recons_loss_weighted: 313.8752, recons_loss_ls: 6.2775, KL_loss: 27.4511, sigma_regularisor: -110.5241, code_std_dev: [0.2656128  0.20826943 0.102421   0.1571304  0.05516445 0.09409034]
# Loss on training and val sets:
# train: 170.6873, val: 221.3247
# Current sigma2: 0.0100000
# Already trained for 1.7522148450215658 min; Remaining 5.548680342568291 min.
# Saving model...
# Model saved.
# 12/49, test loss: -elbo: 225.2873, recons_loss_weighted: 317.0266, recons_loss_ls: 6.3405, KL_loss: 26.5017, sigma_regularisor: -110.5241, code_std_dev: [0.2461522  0.1939835  0.09164712 0.16947782 0.03943132 0.10309373]
# Loss on training and val sets:
# train: 164.6287, val: 208.7811
# Current sigma2: 0.0100000
# Already trained for 1.8913233637809754 min; Remaining 5.3829972661458525 min.
# Saving model...
# Model saved.
# 13/49, test loss: -elbo: 229.9890, recons_loss_weighted: 323.6749, recons_loss_ls: 6.4735, KL_loss: 27.8792, sigma_regularisor: -110.5241, code_std_dev: [0.2440116  0.16454436 0.08107133 0.16411537 0.05209968 0.05950386]
# Loss on training and val sets:
# train: 160.4915, val: 219.2465
# Current sigma2: 0.0100000
# Already trained for 2.031389260292053 min; Remaining 5.223572383608138 min.
# Saving model...
# Model saved.
# 14/49, test loss: -elbo: 224.3065, recons_loss_weighted: 312.6327, recons_loss_ls: 6.2527, KL_loss: 27.7178, sigma_regularisor: -110.5241, code_std_dev: [0.2251616  0.18150605 0.0880713  0.17459616 0.02445347 0.0777175 ]
# Loss on training and val sets:
# train: 161.7148, val: 240.4943
# Current sigma2: 0.0100000
# Already trained for 2.1753988742828367 min; Remaining 5.075930706659952 min.
# Saving model...
# Model saved.
# 15/49, test loss: -elbo: 224.9902, recons_loss_weighted: 315.5849, recons_loss_ls: 6.3117, KL_loss: 26.9254, sigma_regularisor: -110.5241, code_std_dev: [0.2526466  0.23110427 0.10246458 0.17673357 0.05746161 0.0877316 ]
# Loss on training and val sets:
# train: 157.5992, val: 235.2288
# Current sigma2: 0.0100000
# Already trained for 2.3191378553708395 min; Remaining 4.928167942663034 min.
# Saving model...
# Model saved.
# 16/49, test loss: -elbo: 226.8207, recons_loss_weighted: 317.3759, recons_loss_ls: 6.3475, KL_loss: 27.8604, sigma_regularisor: -110.5241, code_std_dev: [0.22718318 0.19631195 0.07489575 0.17986335 0.02649366 0.09177086]
# Loss on training and val sets:
# train: 154.8336, val: 225.1206
# Current sigma2: 0.0100000
# Already trained for 2.4656280597050984 min; Remaining 4.786219174721662 min.
# Saving model...
# Model saved.
# 17/49, test loss: -elbo: 220.1019, recons_loss_weighted: 305.0145, recons_loss_ls: 6.1003, KL_loss: 27.3223, sigma_regularisor: -110.5241, code_std_dev: [0.22084379 0.17840545 0.09310102 0.16525447 0.05246948 0.08376011]
# Loss on training and val sets:
# train: 155.0488, val: 189.7645
# Current sigma2: 0.0100000
# Already trained for 2.6046367088953652 min; Remaining 4.630465260258427 min.
# Saving model...
# Model saved.
# 18/49, test loss: -elbo: 225.5676, recons_loss_weighted: 316.2253, recons_loss_ls: 6.3245, KL_loss: 27.1825, sigma_regularisor: -110.5241, code_std_dev: [0.2313399  0.19321138 0.09410742 0.16982432 0.04549305 0.08131757]
# Loss on training and val sets:
# train: 150.2129, val: 210.8154
# Current sigma2: 0.0100000
# Already trained for 2.749405121803284 min; Remaining 4.485871514521147 min.
# Saving model...
# Model saved.
# 19/49, test loss: -elbo: 215.8371, recons_loss_weighted: 295.6814, recons_loss_ls: 5.9136, KL_loss: 27.7240, sigma_regularisor: -110.5241, code_std_dev: [0.24991433 0.19233099 0.08503564 0.18076195 0.03139278 0.06976525]
# Loss on training and val sets:
# train: 148.4896, val: 212.4733
# Current sigma2: 0.0100000
# Already trained for 2.892828178405762 min; Remaining 4.339242267608642 min.
# Saving model...
# Model saved.
# 20/49, test loss: -elbo: 230.2591, recons_loss_weighted: 325.4223, recons_loss_ls: 6.5084, KL_loss: 27.2756, sigma_regularisor: -110.5241, code_std_dev: [0.24308106 0.20329593 0.08441474 0.20485571 0.05562329 0.08286267]
# Loss on training and val sets:
# train: 148.1184, val: 224.7371
# Current sigma2: 0.0100000
# Already trained for 3.035567041238149 min; Remaining 4.191973533138396 min.
# Saving model...
# Model saved.
# 21/49, test loss: -elbo: 213.6666, recons_loss_weighted: 292.1083, recons_loss_ls: 5.8422, KL_loss: 27.3401, sigma_regularisor: -110.5241, code_std_dev: [0.2706436  0.22072172 0.06230542 0.16650695 0.03668079 0.09848952]
# Loss on training and val sets:
# train: 145.8517, val: 232.9367
# Current sigma2: 0.0100000
# Already trained for 3.178701420625051 min; Remaining 4.045619989886428 min.
# Saving model...
# Model saved.
# 22/49, test loss: -elbo: 218.1812, recons_loss_weighted: 301.5266, recons_loss_ls: 6.0305, KL_loss: 27.1456, sigma_regularisor: -110.5241, code_std_dev: [0.2325564  0.182152   0.11019845 0.1706137  0.04862075 0.09121608]
# Loss on training and val sets:
# train: 140.3272, val: 228.5365
# Current sigma2: 0.0100000
# Already trained for 3.3239864508310952 min; Remaining 3.902071050975634 min.
# Saving model...
# Model saved.
# 23/49, test loss: -elbo: 222.4186, recons_loss_weighted: 311.3692, recons_loss_ls: 6.2274, KL_loss: 26.4616, sigma_regularisor: -110.5241, code_std_dev: [0.2590567  0.21504068 0.11238404 0.18442    0.07837458 0.08467571]
# Loss on training and val sets:
# train: 141.8345, val: 212.6870
# Current sigma2: 0.0100000
# Already trained for 3.4634095867474874 min; Remaining 3.7520270523097783 min.
# Saving model...
# Model saved.
# 24/49, test loss: -elbo: 229.2839, recons_loss_weighted: 323.9734, recons_loss_ls: 6.4795, KL_loss: 27.0248, sigma_regularisor: -110.5241, code_std_dev: [0.24880044 0.20182905 0.08544239 0.18688412 0.05079814 0.08672576]
# Loss on training and val sets:
# train: 140.3886, val: 206.5387
# Current sigma2: 0.0100000
# Already trained for 3.6032323598861695 min; Remaining 3.6032323598861695 min.
# Saving model...
# Model saved.
# 25/49, test loss: -elbo: 221.6104, recons_loss_weighted: 308.3986, recons_loss_ls: 6.1680, KL_loss: 27.1387, sigma_regularisor: -110.5241, code_std_dev: [0.22553566 0.22314303 0.11003283 0.19917212 0.03215743 0.08145906]
# Loss on training and val sets:
# train: 141.2705, val: 216.4872
# Current sigma2: 0.0100000
# Already trained for 3.748165500164032 min; Remaining 3.4598450770744913 min.
# Saving model...
# Model saved.
# 26/49, test loss: -elbo: 214.5148, recons_loss_weighted: 295.3774, recons_loss_ls: 5.9075, KL_loss: 26.5538, sigma_regularisor: -110.5241, code_std_dev: [0.20898096 0.19480307 0.0928961  0.20247397 0.05247396 0.07858332]
# Loss on training and val sets:
# train: 136.9346, val: 184.3819
# Current sigma2: 0.0100000
# Already trained for 3.889082109928131 min; Remaining 3.3129217973461853 min.
# Saving model...
# Model saved.
# 27/49, test loss: -elbo: 221.5471, recons_loss_weighted: 307.2695, recons_loss_ls: 6.1454, KL_loss: 27.6400, sigma_regularisor: -110.5241, code_std_dev: [0.22964877 0.19004864 0.08210436 0.20801264 0.03606166 0.05449862]
# Loss on training and val sets:
# train: 135.0716, val: 233.0972
# Current sigma2: 0.0100000
# Already trained for 4.033255926767985 min; Remaining 3.168986799603417 min.
# Saving model...
# Model saved.
# 28/49, test loss: -elbo: 220.3009, recons_loss_weighted: 307.6824, recons_loss_ls: 6.1536, KL_loss: 26.1873, sigma_regularisor: -110.5241, code_std_dev: [0.24238275 0.24105412 0.09442972 0.18078892 0.05086188 0.09747835]
# Loss on training and val sets:
# train: 133.5111, val: 237.0152
# Current sigma2: 0.0100000
# Already trained for 4.171929589907328 min; Remaining 3.0210524616570305 min.
# Saving model...
# Model saved.
# 29/49, test loss: -elbo: 222.9804, recons_loss_weighted: 311.8183, recons_loss_ls: 6.2364, KL_loss: 26.7990, sigma_regularisor: -110.5241, code_std_dev: [0.24813917 0.23431575 0.08793917 0.20198427 0.03982996 0.09865683]
# Loss on training and val sets:
# train: 132.6746, val: 232.9617
# Current sigma2: 0.0100000
# Already trained for 4.3156694332758585 min; Remaining 2.877112955517239 min.
# Saving model...
# Model saved.
# 30/49, test loss: -elbo: 216.5190, recons_loss_weighted: 299.3245, recons_loss_ls: 5.9865, KL_loss: 26.5844, sigma_regularisor: -110.5241, code_std_dev: [0.20538719 0.20061646 0.08594738 0.18554896 0.04213035 0.0940219 ]
# Loss on training and val sets:
# train: 132.2860, val: 230.6105
# Current sigma2: 0.0100000
# Already trained for 4.457008822758993 min; Remaining 2.731715084916802 min.
# Saving model...
# Model saved.
# 31/49, test loss: -elbo: 221.3726, recons_loss_weighted: 310.0511, recons_loss_ls: 6.2010, KL_loss: 26.0746, sigma_regularisor: -110.5241, code_std_dev: [0.22816874 0.22729899 0.10490102 0.20009197 0.04534988 0.08821037]
# Loss on training and val sets:
# train: 131.7494, val: 205.1860
# Current sigma2: 0.0100000
# Already trained for 4.607807226975759 min; Remaining 2.5918915651738645 min.
# Saving model...
# Model saved.
# 32/49, test loss: -elbo: 216.9238, recons_loss_weighted: 300.8101, recons_loss_ls: 6.0162, KL_loss: 26.2464, sigma_regularisor: -110.5241, code_std_dev: [0.23067029 0.1916541  0.11145717 0.19253998 0.06009618 0.07484928]
# Loss on training and val sets:
# train: 129.6673, val: 222.9640
# Current sigma2: 0.0100000
# Already trained for 4.746114559968313 min; Remaining 2.4449681066503426 min.
# Saving model...
# Model saved.
# 33/49, test loss: -elbo: 220.8741, recons_loss_weighted: 308.7459, recons_loss_ls: 6.1749, KL_loss: 26.2288, sigma_regularisor: -110.5241, code_std_dev: [0.25189772 0.21761751 0.10122899 0.19311869 0.04336461 0.06269512]
# Loss on training and val sets:
# train: 127.0298, val: 213.8887
# Current sigma2: 0.0100000
# Already trained for 4.894649696350098 min; Remaining 2.303364562988281 min.
# Saving model...
# Model saved.
# 34/49, test loss: -elbo: 208.8453, recons_loss_weighted: 283.9792, recons_loss_ls: 5.6796, KL_loss: 26.5833, sigma_regularisor: -110.5241, code_std_dev: [0.24330822 0.20658188 0.07694127 0.18087232 0.03827121 0.07124142]
# Loss on training and val sets:
# train: 126.5957, val: 160.3604
# Current sigma2: 0.0100000
# Already trained for 5.042147870858511 min; Remaining 2.1609205160822187 min.
# Saving model...
# Model saved.
# 35/49, test loss: -elbo: 219.0172, recons_loss_weighted: 304.1114, recons_loss_ls: 6.0822, KL_loss: 26.6892, sigma_regularisor: -110.5241, code_std_dev: [0.22059323 0.19163212 0.09714956 0.18511291 0.030835   0.07322216]
# Loss on training and val sets:
# train: 124.9257, val: 179.7749
# Current sigma2: 0.0100000
# Already trained for 5.186624228954315 min; Remaining 2.0170205334822335 min.
# Saving model...
# Model saved.
# 36/49, test loss: -elbo: 222.3618, recons_loss_weighted: 311.7133, recons_loss_ls: 6.2343, KL_loss: 26.2328, sigma_regularisor: -110.5241, code_std_dev: [0.20993176 0.16879855 0.09734994 0.15862106 0.05009451 0.0739001 ]
# Loss on training and val sets:
# train: 123.8480, val: 225.8435
# Current sigma2: 0.0100000
# Already trained for 5.3339292168617245 min; Remaining 1.874083238356822 min.
# Saving model...
# Model saved.
# 37/49, test loss: -elbo: 214.8074, recons_loss_weighted: 297.0399, recons_loss_ls: 5.9408, KL_loss: 26.0151, sigma_regularisor: -110.5241, code_std_dev: [0.24261528 0.18455507 0.11351777 0.18696746 0.0531158  0.07457761]
# Loss on training and val sets:
# train: 123.7254, val: 214.3253
# Current sigma2: 0.0100000
# Already trained for 5.477718953291575 min; Remaining 1.7298059852499712 min.
# Saving model...
# Model saved.
# 38/49, test loss: -elbo: 220.0798, recons_loss_weighted: 308.0028, recons_loss_ls: 6.1601, KL_loss: 25.8061, sigma_regularisor: -110.5241, code_std_dev: [0.2458117  0.20648624 0.10361937 0.18770482 0.06515861 0.06781752]
# Loss on training and val sets:
# train: 122.3374, val: 234.9595
# Current sigma2: 0.0100000
# Already trained for 5.625356523195903 min; Remaining 1.586639019362947 min.
# Saving model...
# Model saved.
# 39/49, test loss: -elbo: 211.3069, recons_loss_weighted: 289.9324, recons_loss_ls: 5.7986, KL_loss: 26.0683, sigma_regularisor: -110.5241, code_std_dev: [0.22928286 0.1925854  0.11899286 0.18568021 0.0389775  0.08243687]
# Loss on training and val sets:
# train: 120.6219, val: 187.3844
# Current sigma2: 0.0100000
# Already trained for 5.766786909103393 min; Remaining 1.4416967272758483 min.
# Saving model...
# Model saved.
# 40/49, test loss: -elbo: 217.7065, recons_loss_weighted: 302.8039, recons_loss_ls: 6.0561, KL_loss: 26.0321, sigma_regularisor: -110.5241, code_std_dev: [0.23794128 0.21768901 0.09219905 0.1828852  0.046039   0.07033243]
# Loss on training and val sets:
# train: 119.7898, val: 170.1902
# Current sigma2: 0.0100000
# Already trained for 5.911121805508931 min; Remaining 1.297563323160497 min.
# Saving model...
# Model saved.
# 41/49, test loss: -elbo: 208.2620, recons_loss_weighted: 283.5152, recons_loss_ls: 5.6703, KL_loss: 26.2320, sigma_regularisor: -110.5241, code_std_dev: [0.23047331 0.19382513 0.09104374 0.17029989 0.0354006  0.08487364]
# Loss on training and val sets:
# train: 121.1049, val: 187.0712
# Current sigma2: 0.0100000
# Already trained for 6.053636991977692 min; Remaining 1.1530737127576556 min.
# Saving model...
# Model saved.
# 42/49, test loss: -elbo: 217.4384, recons_loss_weighted: 302.2498, recons_loss_ls: 6.0450, KL_loss: 26.0411, sigma_regularisor: -110.5241, code_std_dev: [0.23428199 0.20744827 0.09661844 0.19257908 0.03729445 0.07037508]
# Loss on training and val sets:
# train: 117.9449, val: 230.5710
# Current sigma2: 0.0100000
# Already trained for 6.19750953912735 min; Remaining 1.0088969017184057 min.
# Saving model...
# Model saved.
# 43/49, test loss: -elbo: 218.8759, recons_loss_weighted: 305.2675, recons_loss_ls: 6.1054, KL_loss: 25.9697, sigma_regularisor: -110.5241, code_std_dev: [0.21019985 0.18634008 0.09337168 0.18182026 0.05330815 0.06405724]
# Loss on training and val sets:
# train: 117.8130, val: 204.2594
# Current sigma2: 0.0100000
# Already trained for 6.338295618693034 min; Remaining 0.8643130389126864 min.
# Saving model...
# Model saved.
# 44/49, test loss: -elbo: 210.7785, recons_loss_weighted: 289.4614, recons_loss_ls: 5.7892, KL_loss: 25.7754, sigma_regularisor: -110.5241, code_std_dev: [0.22919309 0.21330048 0.10316189 0.18534403 0.0535166  0.07270434]
# Loss on training and val sets:
# train: 115.3803, val: 220.7589
# Current sigma2: 0.0100000
# Already trained for 6.480031923453013 min; Remaining 0.7200035470503348 min.
# Saving model...
# Model saved.
# 45/49, test loss: -elbo: 212.5085, recons_loss_weighted: 291.9843, recons_loss_ls: 5.8397, KL_loss: 26.2440, sigma_regularisor: -110.5241, code_std_dev: [0.22223094 0.19996245 0.08793931 0.18632644 0.03990766 0.06800061]
# Loss on training and val sets:
# train: 115.0023, val: 238.8052
# Current sigma2: 0.0100000
# Already trained for 6.624877262115478 min; Remaining 0.5760762836622155 min.
# Saving model...
# Model saved.
# 46/49, test loss: -elbo: 211.5043, recons_loss_weighted: 290.8037, recons_loss_ls: 5.8161, KL_loss: 25.8301, sigma_regularisor: -110.5241, code_std_dev: [0.23611486 0.20085461 0.09349829 0.18467855 0.04848806 0.07798947]
# Loss on training and val sets:
# train: 115.7373, val: 197.2353
# Current sigma2: 0.0100000
# Already trained for 6.766435794035593 min; Remaining 0.43190015706610174 min.
# Saving model...
# Model saved.
# 47/49, test loss: -elbo: 218.0635, recons_loss_weighted: 301.8427, recons_loss_ls: 6.0369, KL_loss: 26.8698, sigma_regularisor: -110.5241, code_std_dev: [0.2202572  0.18872732 0.08900479 0.19179972 0.03079742 0.04634714]
# Loss on training and val sets:
# train: 114.9770, val: 207.2244
# Current sigma2: 0.0100000
# Already trained for 6.909718036651611 min; Remaining 0.28790491819381714 min.
# Saving model...
# Model saved.
# 48/49, test loss: -elbo: 212.8457, recons_loss_weighted: 291.4850, recons_loss_ls: 5.8297, KL_loss: 26.8308, sigma_regularisor: -110.5241, code_std_dev: [0.22644335 0.19742703 0.09817044 0.19650702 0.03981025 0.05892463]
# Loss on training and val sets:
# train: 113.8994, val: 215.0311
# Current sigma2: 0.0100000
# Already trained for 7.057053470611573 min; Remaining 0.14402149940023617 min.
# Saving model...
# Model saved.
# 49/49, test loss: -elbo: 219.7911, recons_loss_weighted: 306.9181, recons_loss_ls: 6.1384, KL_loss: 26.0597, sigma_regularisor: -110.5241, code_std_dev: [0.22197165 0.2238263  0.08601175 0.20577458 0.03207918 0.10126903]
# Loss on training and val sets:
# train: 112.3950, val: 182.7748
# Current sigma2: 0.0100000
# Already trained for 7.20001159509023 min; Remaining 0.0 min.

# %%
# load LSTM model
lstm_model = lstmKerasModel(data)
lstm_model.produce_embeddings(config, model_vae, data, sess)
lstm_nn_model = lstm_model.create_lstm_model(config)
lstm_nn_model.summary()   # Display the model's architecture

# checkpoint path
checkpoint_path = config['checkpoint_dir_lstm'] + "cp.ckpt"
checkpoint_dir = os.path.dirname(checkpoint_path)
# Create a callback that saves the model's weights
cp_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path,
                                                 save_weights_only=True,
                                                 verbose=1)
# load weights if possible
lstm_model.load_model(lstm_nn_model, config, checkpoint_path)
# start training
if config['TRAIN_LSTM']:
    if config['num_epochs_lstm'] > 0:
        lstm_model.train(config, lstm_nn_model, cp_callback)

    # make a prediction on the test set using the trained model
    lstm_embedding = lstm_nn_model.predict(lstm_model.x_test, batch_size=config['batch_size_lstm'])
    print(lstm_embedding.shape)

    # visualise the first 10 test sequences
    for i in range(10):
        lstm_model.plot_lstm_embedding_prediction(i, config, model_vae, sess, data, lstm_embedding)
# Out:
# tch-32/PX4-QUAD-HITL-2-channels-trim-24-6-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 681/681 [==============================] - 0s 517us/sample - loss: 1.3966 - mean_squared_error: 1.3966 - val_loss: 1.5473 - val_mean_squared_error: 1.5473
# Epoch 56/100
# 608/681 [=========================>....] - ETA: 0s - loss: 1.3927 - mean_squared_error: 1.3927
# Epoch 00056: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-2-channels-trim-24-6-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 681/681 [==============================] - 0s 666us/sample - loss: 1.3933 - mean_squared_error: 1.3933 - val_loss: 1.5442 - val_mean_squared_error: 1.5442
# Epoch 57/100
# 672/681 [============================>.] - ETA: 0s - loss: 1.3873 - mean_squared_error: 1.3873
# Epoch 00057: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-2-channels-trim-24-6-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 681/681 [==============================] - 0s 605us/sample - loss: 1.3907 - mean_squared_error: 1.3907 - val_loss: 1.5447 - val_mean_squared_error: 1.5447
# Epoch 58/100
# 672/681 [============================>.] - ETA: 0s - loss: 1.3932 - mean_squared_error: 1.3932
# Epoch 00058: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-2-channels-trim-24-6-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 681/681 [==============================] - 0s 568us/sample - loss: 1.3876 - mean_squared_error: 1.3876 - val_loss: 1.5397 - val_mean_squared_error: 1.5397
# Epoch 59/100
# 672/681 [============================>.] - ETA: 0s - loss: 1.3915 - mean_squared_error: 1.3915
# Epoch 00059: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-2-channels-trim-24-6-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 681/681 [==============================] - 0s 568us/sample - loss: 1.3859 - mean_squared_error: 1.3859 - val_loss: 1.5434 - val_mean_squared_error: 1.5434
# Epoch 60/100
# 608/681 [=========================>....] - ETA: 0s - loss: 1.3825 - mean_squared_error: 1.3825
# Epoch 00060: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-2-channels-trim-24-6-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 681/681 [==============================] - 0s 627us/sample - loss: 1.3827 - mean_squared_error: 1.3827 - val_loss: 1.5376 - val_mean_squared_error: 1.5376
# Epoch 61/100
# 576/681 [========================>.....] - ETA: 0s - loss: 1.3947 - mean_squared_error: 1.3947
# Epoch 00061: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-2-channels-trim-24-6-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 681/681 [==============================] - 0s 568us/sample - loss: 1.3812 - mean_squared_error: 1.3812 - val_loss: 1.5363 - val_mean_squared_error: 1.5363
# Epoch 62/100
# 672/681 [============================>.] - ETA: 0s - loss: 1.3750 - mean_squared_error: 1.3750
# Epoch 00062: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-2-channels-trim-24-6-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 681/681 [==============================] - 0s 570us/sample - loss: 1.3771 - mean_squared_error: 1.3771 - val_loss: 1.5311 - val_mean_squared_error: 1.5311
# Epoch 63/100
# 672/681 [============================>.] - ETA: 0s - loss: 1.3714 - mean_squared_error: 1.3714
# Epoch 00063: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-2-channels-trim-24-6-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 681/681 [==============================] - 0s 585us/sample - loss: 1.3746 - mean_squared_error: 1.3746 - val_loss: 1.5321 - val_mean_squared_error: 1.5321
# Epoch 64/100
# 672/681 [============================>.] - ETA: 0s - loss: 1.3668 - mean_squared_error: 1.3668
# Epoch 00064: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-2-channels-trim-24-6-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 681/681 [==============================] - 0s 657us/sample - loss: 1.3717 - mean_squared_error: 1.3717 - val_loss: 1.5290 - val_mean_squared_error: 1.5290
# Epoch 65/100
# 608/681 [=========================>....] - ETA: 0s - loss: 1.3732 - mean_squared_error: 1.3732
# Epoch 00065: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-2-channels-trim-24-6-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 681/681 [==============================] - 0s 627us/sample - loss: 1.3688 - mean_squared_error: 1.3688 - val_loss: 1.5293 - val_mean_squared_error: 1.5293
# Epoch 66/100
# 640/681 [===========================>..] - ETA: 0s - loss: 1.3623 - mean_squared_error: 1.3623
# Epoch 00066: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-2-channels-trim-24-6-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 681/681 [==============================] - 0s 625us/sample - loss: 1.3665 - mean_squared_error: 1.3665 - val_loss: 1.5263 - val_mean_squared_error: 1.5263
# Epoch 67/100
# 640/681 [===========================>..] - ETA: 0s - loss: 1.3611 - mean_squared_error: 1.3611
# Epoch 00067: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-2-channels-trim-24-6-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 681/681 [==============================] - 0s 581us/sample - loss: 1.3649 - mean_squared_error: 1.3649 - val_loss: 1.5257 - val_mean_squared_error: 1.5257
# Epoch 68/100
# 640/681 [===========================>..] - ETA: 0s - loss: 1.3481 - mean_squared_error: 1.3481
# Epoch 00068: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-2-channels-trim-24-6-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 681/681 [==============================] - 0s 596us/sample - loss: 1.3617 - mean_squared_error: 1.3617 - val_loss: 1.5215 - val_mean_squared_error: 1.5215
# Epoch 69/100
# 576/681 [========================>.....] - ETA: 0s - loss: 1.3593 - mean_squared_error: 1.3593
# Epoch 00069: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-2-channels-trim-24-6-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 681/681 [==============================] - 0s 555us/sample - loss: 1.3604 - mean_squared_error: 1.3604 - val_loss: 1.5224 - val_mean_squared_error: 1.5224
# Epoch 70/100
# 640/681 [===========================>..] - ETA: 0s - loss: 1.3603 - mean_squared_error: 1.3603
# Epoch 00070: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-2-channels-trim-24-6-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 681/681 [==============================] - 0s 626us/sample - loss: 1.3567 - mean_squared_error: 1.3567 - val_loss: 1.5205 - val_mean_squared_error: 1.5205
# Epoch 71/100
# 608/681 [=========================>....] - ETA: 0s - loss: 1.3554 - mean_squared_error: 1.3554
# Epoch 00071: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-2-channels-trim-24-6-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 681/681 [==============================] - 0s 572us/sample - loss: 1.3551 - mean_squared_error: 1.3551 - val_loss: 1.5202 - val_mean_squared_error: 1.5202
# Epoch 72/100
# 672/681 [============================>.] - ETA: 0s - loss: 1.3522 - mean_squared_error: 1.3522
# Epoch 00072: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-2-channels-trim-24-6-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 681/681 [==============================] - 0s 596us/sample - loss: 1.3525 - mean_squared_error: 1.3525 - val_loss: 1.5208 - val_mean_squared_error: 1.5208
# Epoch 73/100
# 672/681 [============================>.] - ETA: 0s - loss: 1.3498 - mean_squared_error: 1.3498
# Epoch 00073: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-2-channels-trim-24-6-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 681/681 [==============================] - 0s 588us/sample - loss: 1.3505 - mean_squared_error: 1.3505 - val_loss: 1.5138 - val_mean_squared_error: 1.5138
# Epoch 74/100
# 672/681 [============================>.] - ETA: 0s - loss: 1.3506 - mean_squared_error: 1.3506
# Epoch 00074: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-2-channels-trim-24-6-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 681/681 [==============================] - 0s 576us/sample - loss: 1.3472 - mean_squared_error: 1.3472 - val_loss: 1.5149 - val_mean_squared_error: 1.5149
# Epoch 75/100
# 672/681 [============================>.] - ETA: 0s - loss: 1.3448 - mean_squared_error: 1.3448
# Epoch 00075: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-2-channels-trim-24-6-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 681/681 [==============================] - 0s 589us/sample - loss: 1.3450 - mean_squared_error: 1.3450 - val_loss: 1.5197 - val_mean_squared_error: 1.5197
# Epoch 76/100
# 672/681 [============================>.] - ETA: 0s - loss: 1.3445 - mean_squared_error: 1.3445
# Epoch 00076: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-2-channels-trim-24-6-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 681/681 [==============================] - 0s 620us/sample - loss: 1.3438 - mean_squared_error: 1.3438 - val_loss: 1.5120 - val_mean_squared_error: 1.5120
# Epoch 77/100
# 672/681 [============================>.] - ETA: 0s - loss: 1.3415 - mean_squared_error: 1.3415
# Epoch 00077: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-2-channels-trim-24-6-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 681/681 [==============================] - 0s 593us/sample - loss: 1.3405 - mean_squared_error: 1.3405 - val_loss: 1.5131 - val_mean_squared_error: 1.5131
# Epoch 78/100
# 608/681 [=========================>....] - ETA: 0s - loss: 1.3371 - mean_squared_error: 1.3371
# Epoch 00078: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-2-channels-trim-24-6-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 681/681 [==============================] - 0s 543us/sample - loss: 1.3382 - mean_squared_error: 1.3382 - val_loss: 1.5080 - val_mean_squared_error: 1.5080
# Epoch 79/100
# 640/681 [===========================>..] - ETA: 0s - loss: 1.3285 - mean_squared_error: 1.3285
# Epoch 00079: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-2-channels-trim-24-6-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 681/681 [==============================] - 0s 646us/sample - loss: 1.3366 - mean_squared_error: 1.3366 - val_loss: 1.5118 - val_mean_squared_error: 1.5118
# Epoch 80/100
# 608/681 [=========================>....] - ETA: 0s - loss: 1.3262 - mean_squared_error: 1.3262
# Epoch 00080: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-2-channels-trim-24-6-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 681/681 [==============================] - 0s 598us/sample - loss: 1.3330 - mean_squared_error: 1.3330 - val_loss: 1.5002 - val_mean_squared_error: 1.5002
# Epoch 81/100
# 672/681 [============================>.] - ETA: 0s - loss: 1.3363 - mean_squared_error: 1.3363
# Epoch 00081: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-2-channels-trim-24-6-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 681/681 [==============================] - 0s 654us/sample - loss: 1.3317 - mean_squared_error: 1.3317 - val_loss: 1.5058 - val_mean_squared_error: 1.5058
# Epoch 82/100
# 608/681 [=========================>....] - ETA: 0s - loss: 1.3226 - mean_squared_error: 1.3226
# Epoch 00082: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-2-channels-trim-24-6-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 681/681 [==============================] - 0s 513us/sample - loss: 1.3296 - mean_squared_error: 1.3296 - val_loss: 1.5012 - val_mean_squared_error: 1.5012
# Epoch 83/100
# 640/681 [===========================>..] - ETA: 0s - loss: 1.3216 - mean_squared_error: 1.3216
# Epoch 00083: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-2-channels-trim-24-6-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 681/681 [==============================] - 0s 542us/sample - loss: 1.3262 - mean_squared_error: 1.3262 - val_loss: 1.5003 - val_mean_squared_error: 1.5003
# Epoch 84/100
# 608/681 [=========================>....] - ETA: 0s - loss: 1.3187 - mean_squared_error: 1.3187
# Epoch 00084: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-2-channels-trim-24-6-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 681/681 [==============================] - 0s 540us/sample - loss: 1.3251 - mean_squared_error: 1.3251 - val_loss: 1.5009 - val_mean_squared_error: 1.5009
# Epoch 85/100
# 608/681 [=========================>....] - ETA: 0s - loss: 1.3293 - mean_squared_error: 1.3293
# Epoch 00085: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-2-channels-trim-24-6-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 681/681 [==============================] - 0s 571us/sample - loss: 1.3230 - mean_squared_error: 1.3230 - val_loss: 1.4982 - val_mean_squared_error: 1.4982
# Epoch 86/100
# 576/681 [========================>.....] - ETA: 0s - loss: 1.2946 - mean_squared_error: 1.2946
# Epoch 00086: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-2-channels-trim-24-6-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 681/681 [==============================] - 0s 651us/sample - loss: 1.3203 - mean_squared_error: 1.3203 - val_loss: 1.4993 - val_mean_squared_error: 1.4993
# Epoch 87/100
# 672/681 [============================>.] - ETA: 0s - loss: 1.3203 - mean_squared_error: 1.3203
# Epoch 00087: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-2-channels-trim-24-6-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 681/681 [==============================] - 0s 593us/sample - loss: 1.3184 - mean_squared_error: 1.3184 - val_loss: 1.4945 - val_mean_squared_error: 1.4945
# Epoch 88/100
# 608/681 [=========================>....] - ETA: 0s - loss: 1.3288 - mean_squared_error: 1.3288
# Epoch 00088: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-2-channels-trim-24-6-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 681/681 [==============================] - 0s 558us/sample - loss: 1.3169 - mean_squared_error: 1.3169 - val_loss: 1.4889 - val_mean_squared_error: 1.4889
# Epoch 89/100
# 608/681 [=========================>....] - ETA: 0s - loss: 1.3267 - mean_squared_error: 1.3267
# Epoch 00089: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-2-channels-trim-24-6-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 681/681 [==============================] - 0s 570us/sample - loss: 1.3138 - mean_squared_error: 1.3138 - val_loss: 1.4911 - val_mean_squared_error: 1.4911
# Epoch 90/100
# 608/681 [=========================>....] - ETA: 0s - loss: 1.3088 - mean_squared_error: 1.3088
# Epoch 00090: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-2-channels-trim-24-6-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 681/681 [==============================] - 0s 557us/sample - loss: 1.3117 - mean_squared_error: 1.3117 - val_loss: 1.4900 - val_mean_squared_error: 1.4900
# Epoch 91/100
# 640/681 [===========================>..] - ETA: 0s - loss: 1.3070 - mean_squared_error: 1.3070
# Epoch 00091: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-2-channels-trim-24-6-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 681/681 [==============================] - 0s 541us/sample - loss: 1.3107 - mean_squared_error: 1.3107 - val_loss: 1.4920 - val_mean_squared_error: 1.4920
# Epoch 92/100
# 640/681 [===========================>..] - ETA: 0s - loss: 1.3086 - mean_squared_error: 1.3086
# Epoch 00092: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-2-channels-trim-24-6-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 681/681 [==============================] - 0s 599us/sample - loss: 1.3069 - mean_squared_error: 1.3069 - val_loss: 1.4873 - val_mean_squared_error: 1.4873
# Epoch 93/100
# 640/681 [===========================>..] - ETA: 0s - loss: 1.2948 - mean_squared_error: 1.2948
# Epoch 00093: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-2-channels-trim-24-6-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 681/681 [==============================] - 0s 510us/sample - loss: 1.3072 - mean_squared_error: 1.3072 - val_loss: 1.4860 - val_mean_squared_error: 1.4860
# Epoch 94/100
# 640/681 [===========================>..] - ETA: 0s - loss: 1.2979 - mean_squared_error: 1.2979
# Epoch 00094: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-2-channels-trim-24-6-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 681/681 [==============================] - 0s 588us/sample - loss: 1.3042 - mean_squared_error: 1.3042 - val_loss: 1.4841 - val_mean_squared_error: 1.4841
# Epoch 95/100
# 672/681 [============================>.] - ETA: 0s - loss: 1.2968 - mean_squared_error: 1.2968
# Epoch 00095: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-2-channels-trim-24-6-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 681/681 [==============================] - 0s 579us/sample - loss: 1.3013 - mean_squared_error: 1.3013 - val_loss: 1.4888 - val_mean_squared_error: 1.4888
# Epoch 96/100
# 576/681 [========================>.....] - ETA: 0s - loss: 1.3083 - mean_squared_error: 1.3083
# Epoch 00096: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-2-channels-trim-24-6-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 681/681 [==============================] - 0s 542us/sample - loss: 1.2992 - mean_squared_error: 1.2992 - val_loss: 1.4821 - val_mean_squared_error: 1.4821
# Epoch 97/100
# 576/681 [========================>.....] - ETA: 0s - loss: 1.2928 - mean_squared_error: 1.2928
# Epoch 00097: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-2-channels-trim-24-6-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 681/681 [==============================] - 0s 594us/sample - loss: 1.2959 - mean_squared_error: 1.2959 - val_loss: 1.4752 - val_mean_squared_error: 1.4752
# Epoch 98/100
# 640/681 [===========================>..] - ETA: 0s - loss: 1.2899 - mean_squared_error: 1.2899
# Epoch 00098: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-2-channels-trim-24-6-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 681/681 [==============================] - 0s 566us/sample - loss: 1.2933 - mean_squared_error: 1.2933 - val_loss: 1.4768 - val_mean_squared_error: 1.4768
# Epoch 99/100
# 576/681 [========================>.....] - ETA: 0s - loss: 1.2968 - mean_squared_error: 1.2968
# Epoch 00099: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-2-channels-trim-24-6-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 681/681 [==============================] - 0s 544us/sample - loss: 1.2910 - mean_squared_error: 1.2910 - val_loss: 1.4734 - val_mean_squared_error: 1.4734
# Epoch 100/100
# 576/681 [========================>.....] - ETA: 0s - loss: 1.2898 - mean_squared_error: 1.2898
# Epoch 00100: saving model to ../experiments/local-results/PX4/PX4-QUAD-HITL/batch-32/PX4-QUAD-HITL-2-channels-trim-24-6-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 681/681 [==============================] - 0s 547us/sample - loss: 1.2876 - mean_squared_error: 1.2876 - val_loss: 1.4726 - val_mean_squared_error: 1.4726
# (76, 5, 6)
# Decoded seq from VAE: (6, 24, 2)
# Decoded seq from lstm: (5, 24, 2)
# Decoded seq from VAE: (6, 24, 2)
# Decoded seq from lstm: (5, 24, 2)
# Decoded seq from VAE: (6, 24, 2)
# Decoded seq from lstm: (5, 24, 2)
# Decoded seq from VAE: (6, 24, 2)
# Decoded seq from lstm: (5, 24, 2)
# Decoded seq from VAE: (6, 24, 2)
# Decoded seq from lstm: (5, 24, 2)
# Decoded seq from VAE: (6, 24, 2)
# Decoded seq from lstm: (5, 24, 2)
# Decoded seq from VAE: (6, 24, 2)
# Decoded seq from lstm: (5, 24, 2)
# Decoded seq from VAE: (6, 24, 2)
# Decoded seq from lstm: (5, 24, 2)
# Decoded seq from VAE: (6, 24, 2)
# Decoded seq from lstm: (5, 24, 2)
# Decoded seq from VAE: (6, 24, 2)
# Decoded seq from lstm: (5, 24, 2)

# %%
# load normalised time series
save_dir = '../datasets/' + config['data_dir'] #NAB-known-anomaly/'
dataset = config['dataset']
file_name = config['filename']
filename = '{}.npz'.format(file_name)
result = dict(np.load(save_dir+filename, allow_pickle=True))
if dataset == 'machine_temp':
    result['test'] = result['test'][0]
    result['idx_anomaly_test'] = result['idx_anomaly_test'][0]
    result['t_test'] = result['t_test'][0]

# slice into rolling windows and rolling sequences
def slice_rolling_windows_and_sequences(config, time_seq):
    n_sample = len(time_seq)
    print("The given sequence has {} samples".format(n_sample))
    n_vae_win = n_sample - config['l_win'] + 1
    rolling_windows = np.zeros((n_vae_win, config['l_win'], config['n_channel']), dtype=float)
    for i in range(n_vae_win):
        rolling_windows[i] = time_seq[i:i + config['l_win']]
        sample_m = np.mean(rolling_windows, axis=1)
        sample_std = np.std(rolling_windows, axis=1)

        n_lstm_seq = n_sample - config['l_seq']*config['l_win']+1
        lstm_seq = np.zeros((n_lstm_seq, config['l_seq'], config['l_win'], config['n_channel']), dtype=float)
    for i in range(n_lstm_seq):
        cur_seq = time_seq[i:i+config['l_seq']*config['l_win']]
        for j in range(config['l_seq']):
            lstm_seq[i,j] = cur_seq[config['l_win']*j:config['l_win']*(j+1)]
    
    return rolling_windows, lstm_seq, sample_m, sample_std

test_windows, test_seq, test_sample_m, test_sample_std = slice_rolling_windows_and_sequences(config, result['test'])
if config['n_channel'] == 1:
    test_windows = np.expand_dims(test_windows, -1)
    test_seq = np.expand_dims(test_seq, -1)
else:
    test_windows = test_windows
    test_seq = test_seq
print(test_windows.shape)
print(test_seq.shape)
# Out:
# The given sequence has 583 samples
# (560, 24, 2)
# (440, 6, 24, 2)

# %%
# Evaluate ELBO and LSTM prediction error on the validation set
# evaluate some anomaly detection metrics
def evaluate_vae_anomaly_metrics_for_a_window(test_win):
    feed_dict = {model_vae.original_signal: np.expand_dims(test_win, 0),
                 model_vae.is_code_input: False,
                 model_vae.code_input: np.zeros((1, config['code_size']))}

    # VAE reconstruction error
    recons_win_vae = np.squeeze(sess.run(model_vae.decoded, feed_dict=feed_dict))
    test_vae_recons_error = np.sum(np.square(recons_win_vae - test_win))

    # VAE latent embedding likelihood
    vae_code_mean, vae_code_std = sess.run([model_vae.code_mean, model_vae.code_std_dev], feed_dict=feed_dict)
    test_vae_kl = 0.5 * (np.sum(np.square(vae_code_mean)) + \
                            np.sum(np.square(vae_code_std)) - \
                            np.sum(np.log(np.square(vae_code_std))) - config['code_size'])

    # VAE ELBO loss
    sigma2 = 0.0005
    input_dims = model_vae.input_dims
    sigma_regularisor = input_dims/2. * np.log(sigma2) + input_dims * np.pi
    test_vae_elbo = test_vae_recons_error/sigma2 + test_vae_kl + sigma_regularisor
    return test_vae_recons_error, test_vae_kl, test_vae_elbo

def evaluate_lstm_anomaly_metric_for_a_seq(test_seq):
    feed_dict = {model_vae.original_signal: test_seq,
                 model_vae.is_code_input: False,
                 model_vae.code_input: np.zeros((1, config['code_size']))}
    vae_embedding = np.squeeze(sess.run(model_vae.code_mean, feed_dict=feed_dict))
    #print(vae_embedding.shape)
    lstm_embedding = np.squeeze(lstm_nn_model.predict(np.expand_dims(vae_embedding[:config['l_seq']-1], 0), batch_size=1))
    lstm_embedding_error = np.sum(np.square(vae_embedding[1:] - lstm_embedding))
    
    # LSTM prediction error
    feed_dict_lstm = {model_vae.original_signal: np.zeros((config['l_seq'] - 1, config['l_win'], test_seq.shape[2])),
                      model_vae.is_code_input: True,
                      model_vae.code_input: lstm_embedding}
    recons_win_lstm = np.squeeze(sess.run(model_vae.decoded, feed_dict=feed_dict_lstm))
    lstm_recons_error = np.sum(np.square(recons_win_lstm - np.squeeze(test_seq[1:])))
    return lstm_recons_error, lstm_embedding_error

n_val_vae = data.val_set_vae['data'].shape[0]
n_val_lstm = data.val_set_lstm['data'].shape[0]

val_vae_recons_error = np.zeros(n_val_vae)
val_vae_kl_error = np.zeros(n_val_vae)
val_vae_elbo_loss = np.zeros(n_val_vae)
for i in range(n_val_vae):
    val_vae_recons_error[i], val_vae_kl_error[i], val_vae_elbo_loss[i] = evaluate_vae_anomaly_metrics_for_a_window(data.val_set_vae['data'][i])

val_lstm_recons_error, val_lstm_embedding_error = np.zeros(n_val_lstm), np.zeros(n_val_lstm)
for i in range(n_val_lstm):
    val_lstm_recons_error[i], val_lstm_embedding_error[i] = evaluate_lstm_anomaly_metric_for_a_seq(data.val_set_lstm['data'][i])

# %%
from scipy.stats import norm
def plot_histogram(test_anomaly_metric, n_bins, title, mean=None, std=None, xlim=None, saveplot=False):
    test_anomaly_list = np.squeeze(np.ndarray.flatten(test_anomaly_metric))
    his = plt.hist(test_anomaly_list, bins=n_bins, density=True)
    if mean is None and std is None:
        mean = np.mean(test_anomaly_list)
        std = np.std(test_anomaly_list)
        legend_label = None
    else:
        legend_label = 1
    x_axis = np.arange(mean-5*std, mean+5*std, std/100)
    plt.plot(x_axis, norm.pdf(x_axis,mean,std))
    plt.title(title)
    plt.xlabel('anomaly score value')
    plt.ylabel('probability density')
    if xlim is not None:
        plt.xlim(0, xlim)
    else:
        plt.xlim(0, np.amax(test_anomaly_list))
    if legend_label is None:
        plt.legend(('Fitted Gaussian', 'histogram'))
    else:
        plt.legend(('normal data distribution','test data distribution (contain anomalies)'))
    if saveplot:
        savefig(config['result_dir']+'reconstruction_error_histogram.pdf')
    else:
        plt.show()
    threshold_25 = np.percentile(test_anomaly_list, 25)
    threshold_75 = np.percentile(test_anomaly_list, 75)
    threshold_1 = np.percentile(test_anomaly_list, 99)
    idx_large_error = np.squeeze(np.argwhere(test_anomaly_metric > threshold_1))
#     print(his[0][-20:])
#     print(his[1][-20:])
    print("25% percentile: {}".format(threshold_25))
    print("75% percentile: {}".format(threshold_75))
#     print("Median: {}".format(np.median(test_anomaly_list)))
#     print("Mean: {}".format(np.mean(test_anomaly_list)))
#     print("Std dev: {}".format(np.std(test_anomaly_list)))
    print("These windows scored the top 1% of anomaly metric ({}): \n{}".format(threshold_1, idx_large_error))
    return mean, std

# %%
# Histogram of VAE ELBO loss - validation set
vae_elbo_m, vae_elbo_std = plot_histogram(val_vae_elbo_loss, 100, 
                                          'VAE ELBO error distribution on the val set', 
                                          mean=None, std=None, xlim=None)
# Out:
# 25% percentile: 396.8392889264693
# 75% percentile: 11737.561725970794
# These windows scored the top 1% of anomaly metric (88120.62267072915):
# 32

# %%
# Histogram of LSTM reconstruction error - validation set 
#  --> to decide the anomaly detection threshold
lstm_recons_m, lstm_recons_std = plot_histogram(val_lstm_recons_error, 100,  
                                              'LSTM reconstruction error distribution on the val set', 
                                              mean=None, std=None, xlim=None)
# Out:
# 25% percentile: 86.82106992985604
# 75% percentile: 152.9570198969159
# These windows scored the top 1% of anomaly metric (215.65448050936516):
# 12

# %%
# Evaluate the anomaly metrics on the test windows and sequences
n_test_lstm = test_seq.shape[0]

test_lstm_recons_error, test_lstm_embedding_error = np.zeros(n_test_lstm), np.zeros(n_test_lstm)
for i in range(n_test_lstm):
    test_lstm_recons_error[i], test_lstm_embedding_error[i] = evaluate_lstm_anomaly_metric_for_a_seq(test_seq[i])
print("All windows' reconstruction error is computed.")
print("The total number of windows is {}".format(len(test_lstm_recons_error)))
# Out:
# All windows' reconstruction error is computed.
# The total number of windows is 440

# %%
# Histogram of LSTM reconstruction error - test set 
#  --> to detect anomaly now
_, _ = plot_histogram(test_lstm_recons_error, 100,
                      'LSTM reconstruction error distribution on the test set', 
                      mean=lstm_recons_m, std=lstm_recons_std, xlim=None, saveplot=True)
# Out:
# 25% percentile: 180.8116104866982
# 75% percentile: 319.12823532293737
# These windows scored the top 1% of anomaly metric (782.8696681528176):
# [431 436 437 438 439]

# %%
# Produce the ground truth anomaly indices 
# if result['idx_split'][0] == 0:
#     idx_anomaly_test = result['idx_anomaly_test']
# else:
#     idx_anomaly_test = result['idx_anomaly_test'][0]
idx_anomaly_test = result['idx_anomaly_test']    
anomaly_index_lstm = []
test_labels_lstm = np.zeros(n_test_lstm)
for i in range(len(idx_anomaly_test)):
    idx_start = idx_anomaly_test[i]-(config['l_win']*config['l_seq']-1)
    idx_end = idx_anomaly_test[i]+1
    if idx_start < 0:
        idx_start = 0
    if idx_end > n_test_lstm:
        idx_end = n_test_lstm
    anomaly_index_lstm.append(np.arange(idx_start,idx_end))
    test_labels_lstm[idx_start:idx_end] = 1
    
print(test_labels_lstm.shape)
# Out:
# (440,)

# %%
def return_anomaly_idx_by_threshold(test_anomaly_metric, threshold):
    test_list = np.squeeze(np.ndarray.flatten(test_anomaly_metric))
    idx_error = np.squeeze(np.argwhere(test_anomaly_metric > threshold))
    
    if len(idx_error.shape) == 0:
        idx_error = np.expand_dims(idx_error, 0)
    
    return list(idx_error)

# %%
def augment_detected_idx(idx_detected_anomaly, anomaly_index):
    n_anomaly = len(anomaly_index)
    idx_detected_anomaly_extended = list(idx_detected_anomaly)
    for i in range(n_anomaly):
        #print(idx_detected_anomaly)
        for j in idx_detected_anomaly:
            if j in anomaly_index[i]:
                in_original_detection = set(idx_detected_anomaly_extended)
                currect_anomaly_win = set(anomaly_index[i])
                idx_detected_anomaly_extended = idx_detected_anomaly_extended + list(currect_anomaly_win - in_original_detection)
                #print(j)
                break
                
    return list(np.sort(idx_detected_anomaly_extended))

# %%
def count_TP_FP_FN(idx_detected_anomaly, anomaly_index, test_labels):
    n_TP = 0
    n_FP = 0
    n_detection = len(idx_detected_anomaly)
    for i in range(n_detection):
        if test_labels[idx_detected_anomaly[i]] == 1:
            n_TP = n_TP + 1
        else:
            n_FP = n_FP + 1
    
    idx_undetected = list(set(np.arange(len(test_labels)))- set(idx_detected_anomaly))
    n_FN = 0
    for i in idx_undetected:
        if test_labels[i] == 1:
            n_FN = n_FN + 1
    
    return n_TP, n_FP, n_FN

# %%
def compute_precision_and_recall(idx_detected_anomaly, anomaly_index, test_labels):
    # compute true positive
    n_TP, n_FP, n_FN = count_TP_FP_FN(idx_detected_anomaly, anomaly_index, test_labels)
    
    if n_TP + n_FP == 0:
        precision = 1
    else:
        precision = n_TP / (n_TP + n_FP)
    recall = n_TP / (n_TP + n_FN)
    if precision + recall == 0:
        F1 = 0
    else:
        F1 = 2* (precision * recall)/(precision + recall)
    
    return precision, recall, F1, n_TP, n_FP, n_FN

# %%
n_threshold = 200
precision = np.zeros(n_threshold)
recall = np.zeros(n_threshold)
F1 = np.zeros(n_threshold)
precision_aug = np.zeros(n_threshold)
recall_aug = np.zeros(n_threshold)
F1_aug = np.zeros(n_threshold)
i = 0
threshold_list = np.linspace(np.amin(test_lstm_recons_error), np.amax(test_lstm_recons_error), n_threshold, endpoint=True)
threshold_list = np.flip(threshold_list)
for threshold in threshold_list:
    #print(threshold_list[i])
    idx_detection_lstm = return_anomaly_idx_by_threshold(test_lstm_recons_error, threshold)
    precision[i], recall[i], F1[i], _, _, _ = compute_precision_and_recall(idx_detection_lstm, 
                                                                           anomaly_index_lstm, 
                                                                           test_labels_lstm)
    # augment the detection using the ground truth labels
    # a method to discount the factor one anomaly appears in multiple consecutive windows
    # introduced in "Unsupervised anomaly detection via variational auto-encoder for seasonal kpis in web applications"
    idx_detection_lstm_augmented = augment_detected_idx(idx_detection_lstm, anomaly_index_lstm)
    precision_aug[i], recall_aug[i], F1_aug[i], _, _, _ = compute_precision_and_recall(idx_detection_lstm_augmented, 
                                                                                       anomaly_index_lstm, 
                                                                                       test_labels_lstm)
    i = i + 1
    #print(precision, recall, F1)

# %%
print("Best F1 score is {}".format(np.amax(F1)))
idx_best_threshold = np.squeeze(np.argwhere(F1 == np.amax(F1)))
print("Best threshold is {}".format(threshold_list[idx_best_threshold]))
print("At this threshold, precision is {}, recall is {}".format(precision[idx_best_threshold], recall[idx_best_threshold]))
average_precision = np.sum(precision[1:] * (recall[1:] - recall[:-1]))
print("Average precision is {}".format(average_precision))

print("\nAugmented detection:")
print("Best F1 score is {}".format(np.amax(F1_aug)))
idx_best_threshold = np.squeeze(np.argwhere(F1_aug == np.amax(F1_aug)))
print("Best threshold is {}".format(threshold_list[idx_best_threshold]))
print("At this threshold, precision is {}, recall is {}".format(precision_aug[idx_best_threshold], 
                                                                recall_aug[idx_best_threshold]))

average_precision_aug = np.sum(precision_aug[1:] * (recall_aug[1:] - recall_aug[:-1]))
print("Average precision is {}".format(average_precision_aug))
# Out:
# Best F1 score is 0.6013363028953229
# Best threshold is 196.7489695917277
# At this threshold, precision is 0.4426229508196721, recall is 0.9375
# Average precision is 0.41270109095791113
#
# Augmented detection:
# Best F1 score is 0.972972972972973
# Best threshold is 764.2826246484315
# At this threshold, precision is 0.9473684210526315, recall is 1.0
# Average precision is 0.9473684210526315

# %%
# Now select a threshold
print(idx_best_threshold.shape)
if isinstance(idx_best_threshold,(list,np.ndarray)):
    threshold = threshold_list[idx_best_threshold]
else:
    threshold = threshold_list[idx_best_threshold[0]]

print("Threshold is {}".format(threshold))
idx_detection = return_anomaly_idx_by_threshold(test_lstm_recons_error, threshold)
idx_detection_augmented = augment_detected_idx(idx_detection, anomaly_index_lstm)
precision, recall, F1, n_TP, n_FP, n_FN = compute_precision_and_recall(idx_detection_augmented, 
                                                                       anomaly_index_lstm, 
                                                                       test_labels_lstm)
print("\nPR evaluation using augmented detection:")
print("Precision: {}".format(precision))
print("Recall: {}".format(recall))
print("F1: {}".format(F1))
print("TP: {}".format(n_TP))
print("FP: {}".format(n_FP))
print("FN: {}".format(n_FN))
# Out:
# ()
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-4878b1151efa> in <module>
#       1 # Now select a threshold
#       2 print(idx_best_threshold.shape)
# ----> 3 if isinstance(idx_best_threshold,(list,pd.core.series.Series,np.ndarray)):
#       4     threshold = threshold_list[idx_best_threshold]
#       5 else:
#
# NameError: name 'pd' is not defined

# %%
def slice_detected_indices_into_seq(idx_detection, interval):
    detected_seq = []
    i = 0
    while i < len(idx_detection):
        if i == 0:
            cur_seq = [idx_detection[i]]
            i = i + 1
        else:
            if idx_detection[i] - idx_detection[i-1] > interval:
                detected_seq.append(cur_seq)
                cur_seq = [idx_detection[i]]
            else:
                cur_seq.append(idx_detection[i])
                if i == len(idx_detection) - 1:
                    detected_seq.append(cur_seq)
            i = i + 1
    
    print("Detected {} sequences".format(len(detected_seq)))
    return detected_seq

# %%
def plot_detected_anomalies(idx_detection, interval, dataset, result, detection_method, augmented_flag=1, y_scale=5, y_lim=None):
    detected_seq = slice_detected_indices_into_seq(idx_detection, interval=interval)
    t_test = result['t_test']
    test = result['test']
    idx_anomaly_test = result['idx_anomaly_test']
        
    # plot detected sequences
    fig, axs = plt.subplots(1, 1, figsize=(18, 5), edgecolor='k')
    fig.subplots_adjust(hspace=.4, wspace=.4)
    axs.plot(t_test, test)
    for j in range(len(idx_anomaly_test)):
        if j == 0:
            axs.plot(idx_anomaly_test[j] * np.ones(20), np.linspace(-y_scale, y_scale, 20), 'r--', label='true anomalies')
        else:
            axs.plot(idx_anomaly_test[j] * np.ones(20), np.linspace(-y_scale, y_scale, 20), 'r--')
        
    for i in range(len(detected_seq)):
        for j in detected_seq[i]:
            if j == detected_seq[0][0]:
                axs.plot((j+interval*2) * np.ones(20), np.linspace(-y_scale, -0.8*y_scale, 20), 'g-', label='detected anomalies')
            else:
                axs.plot((j+interval*2) * np.ones(20), np.linspace(-y_scale, -0.8*y_scale, 20), 'g-')
    
    for j in range(len(idx_anomaly_test)):
        axs.plot(idx_anomaly_test[j] * np.ones(20), np.linspace(-y_scale, y_scale, 20), 'r--')

    for i in range(len(detected_seq)):
        interval_x = np.asarray([detected_seq[i][0], detected_seq[i][-1]+interval*2])
        interval_y = np.asarray([y_scale,y_scale])
        if i == 0:
            axs.fill_between(interval_x, interval_y, alpha=0.2, color='y', label='detected anomaly windows')
        else:
            axs.fill_between(interval_x, interval_y, alpha=0.2, color='y')
        interval_y = np.asarray([-y_scale,-y_scale])
        axs.fill_between(interval_x, interval_y, alpha=0.2, color='y')
    axs.grid(True)
    axs.set_xlim(0, len(t_test))
    if y_lim is None:
        axs.set_ylim(-y_scale, y_scale)
    else:
        axs.set_ylim(-y_scale, y_lim)
    axs.set_xlabel("timestamp (every {})".format(result['t_unit']))
    axs.set_ylabel("normalised readings")
    #axs.set_title("{} dataset test sequence\n(normalised by train mean {:.4f} and std {:.4f})\n Detection method: {}".format(dataset, 
    #                                                                                    result['train_m'], 
    #                                                                                    result['train_std'],
    #                                                                                    detection_method))
    axs.set_title("{} dataset test sequence\n Detection method: {}".format(dataset, detection_method))
    axs.legend()
    savefig(config['result_dir']+'detected_anomalies_{}_aug_{}.pdf'.format(detection_method, augmented_flag))

# %%
plot_detected_anomalies(idx_detection_augmented, 
                        interval=config['l_win']*config['l_seq']/2, 
                        dataset=dataset, 
                        result=result, 
                        detection_method='lstm reconstruction error',
                        augmented_flag=1,
                        y_scale=5,
                        y_lim=5)
