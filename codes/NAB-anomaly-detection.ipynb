# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/MyDrive/Afeka/dnn/code/VAE-LSTM-for-anomaly-detection
# !ls
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/.shortcut-targets-by-id/1gx_Lt95fU2vcZftIeJuwhQvCftollooI/VAE-LSTM-for-anomaly-detection
# ANOMALY-DETECTION-FOR-TIME-SERIES-USING-VAE-LSTM-HYBRID-MODEL.pdf
# codes
# datasets
# experiments
# figures
# README.md
# requirements.txt

# %%
# %cd /content/drive/MyDrive/Afeka/dnn/code/VAE-LSTM-for-anomaly-detection/codes/
# Out:
# /content/drive/.shortcut-targets-by-id/1gx_Lt95fU2vcZftIeJuwhQvCftollooI/VAE-LSTM-for-anomaly-detection/codes

# %%
import warnings

def fxn():
    warnings.warn("deprecated", DeprecationWarning)

with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    fxn()

# %%
# %tensorflow_version 1.x
import tensorflow as tf
import tensorflow_probability as tfp
import numpy as np
import matplotlib.pylab as plt
from matplotlib.pyplot import plot, ion, show, savefig, cla, figure
import random
import time

# %%
import os
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"   # see issue #152
os.environ["CUDA_VISIBLE_DEVICES"]="0"

import tensorflow as tf
from data_loader import DataGenerator
from models import VAEmodel, lstmKerasModel
from trainers import vaeTrainer

from utils import process_config, create_dirs, get_args

# %%
from tensorflow.python.client import device_lib

def get_available_gpus():
    local_device_protos = device_lib.list_local_devices()
    return [x.name for x in local_device_protos if x.device_type == 'GPU']

print(get_available_gpus())
# Out:
# ['/device:GPU:0']

# %%
# load VAE model
config = process_config('NAB_config.json')
# create the experiments dirs
create_dirs([config['result_dir'], config['checkpoint_dir']])
# create tensorflow session
sess = tf.Session(config=tf.ConfigProto(log_device_placement=True))
# create your data generator
data = DataGenerator(config)
# create a CNN model
model_vae = VAEmodel(config)
# create a CNN model
trainer_vae = vaeTrainer(sess, model_vae, data, config)
model_vae.load(sess)

# here you train your model
if config['TRAIN_VAE']:
    if config['num_epochs_vae'] > 0:
        trainer_vae.train()
# Out:
# Device mapping:
# /job:localhost/replica:0/task:0/device:XLA_CPU:0 -> device: XLA_CPU device
# /job:localhost/replica:0/task:0/device:XLA_GPU:0 -> device: XLA_GPU device
# /job:localhost/replica:0/task:0/device:GPU:0 -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
#
# WARNING:tensorflow:From /content/drive/My Drive/afeka/y2/sem1/dl/code/LSTM-VAE/VAE-LSTM-for-anomaly-detection/codes/base.py:62: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# WARNING:tensorflow:From /content/drive/My Drive/afeka/y2/sem1/dl/code/LSTM-VAE/VAE-LSTM-for-anomaly-detection/codes/base.py:64: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# WARNING:tensorflow:From /content/drive/My Drive/afeka/y2/sem1/dl/code/LSTM-VAE/VAE-LSTM-for-anomaly-detection/codes/models.py:25: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/data/util/random_seed.py:58: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /content/drive/My Drive/afeka/y2/sem1/dl/code/LSTM-VAE/VAE-LSTM-for-anomaly-detection/codes/models.py:31: DatasetV1.make_initializable_iterator (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `for ... in dataset:` to iterate over a dataset. If using `tf.estimator`, return the `Dataset` object directly from your input function. As a last resort, you can use `tf.compat.v1.data.make_initializable_iterator(dataset)`.
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From /content/drive/My Drive/afeka/y2/sem1/dl/code/LSTM-VAE/VAE-LSTM-for-anomaly-detection/codes/models.py:48: conv2d (from tensorflow.python.layers.convolutional) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.keras.layers.Conv2D` instead.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/layers/convolutional.py:424: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# conv_1: Tensor("encoder/conv2d/LeakyRelu:0", shape=(?, 16, 1, 32), dtype=float32)
# conv_2: Tensor("encoder/conv2d_1/LeakyRelu:0", shape=(?, 8, 1, 64), dtype=float32)
# conv_3: Tensor("encoder/conv2d_2/LeakyRelu:0", shape=(?, 4, 1, 128), dtype=float32)
# conv_4: Tensor("encoder/conv2d_3/LeakyRelu:0", shape=(?, 1, 1, 512), dtype=float32)
# WARNING:tensorflow:From /content/drive/My Drive/afeka/y2/sem1/dl/code/LSTM-VAE/VAE-LSTM-for-anomaly-detection/codes/models.py:141: flatten (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.flatten instead.
# WARNING:tensorflow:From /content/drive/My Drive/afeka/y2/sem1/dl/code/LSTM-VAE/VAE-LSTM-for-anomaly-detection/codes/models.py:145: dense (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.Dense instead.
# finish encoder:
# Tensor("encoder/MultivariateNormalDiag/sample/affine_linear_operator/forward/add:0", shape=(?, 6), dtype=float32)
#
#
# decoded_2 is: Tensor("decoder/Reshape_1:0", shape=(?, 4, 1, 128), dtype=float32)
# decoded_3 is: Tensor("decoder/Reshape_2:0", shape=(?, 8, 1, 64), dtype=float32)
# decoded_4 is: Tensor("decoder/Reshape_3:0", shape=(?, 16, 1, 32), dtype=float32)
# decoded_5 is: Tensor("decoder/Reshape_4:0", shape=(?, 32, 1, 16), dtype=float32)
# decoded_6 is: Tensor("decoder/conv2d_4/BiasAdd:0", shape=(?, 24, 1, 1), dtype=float32)
# finish decoder:
# Tensor("decoder/Reshape_5:0", shape=(?, 24, 1), dtype=float32)
#
#
# sigma2:
# Tensor("sigma2_dataset/Square:0", shape=(), dtype=float32)
#
# WARNING:tensorflow:From /content/drive/My Drive/afeka/y2/sem1/dl/code/LSTM-VAE/VAE-LSTM-for-anomaly-detection/codes/base.py:73: The name tf.log is deprecated. Please use tf.math.log instead.
#
# WARNING:tensorflow:From /content/drive/My Drive/afeka/y2/sem1/dl/code/LSTM-VAE/VAE-LSTM-for-anomaly-detection/codes/base.py:97: The name tf.get_collection is deprecated. Please use tf.compat.v1.get_collection instead.
#
# WARNING:tensorflow:From /content/drive/My Drive/afeka/y2/sem1/dl/code/LSTM-VAE/VAE-LSTM-for-anomaly-detection/codes/base.py:97: The name tf.GraphKeys is deprecated. Please use tf.compat.v1.GraphKeys instead.
#
# WARNING:tensorflow:From /content/drive/My Drive/afeka/y2/sem1/dl/code/LSTM-VAE/VAE-LSTM-for-anomaly-detection/codes/utils.py:82: The name tf.trainable_variables is deprecated. Please use tf.compat.v1.trainable_variables instead.
#
# The total number of trainable parameters in the encoder model is: 306308
# The total number of trainable parameters in the decoder model is: 331121
# The total number of trainable parameters in the sigma2_dataset model is: 0
# Total number of trainable parameters in the VAE network is: 637429
# WARNING:tensorflow:From /content/drive/My Drive/afeka/y2/sem1/dl/code/LSTM-VAE/VAE-LSTM-for-anomaly-detection/codes/base.py:110: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
#
# gvs for dataset: [(<tf.Tensor 'gradients/encoder/conv2d/Conv2D_grad/tuple/control_dependency_1:0' shape=(3, 1, 1, 32) dtype=float32>, <tf.Variable 'encoder/conv2d/kernel:0' shape=(3, 1, 1, 32) dtype=float32_ref>), (<tf.Tensor 'gradients/encoder/conv2d/BiasAdd_grad/tuple/control_dependency_1:0' shape=(32,) dtype=float32>, <tf.Variable 'encoder/conv2d/bias:0' shape=(32,) dtype=float32_ref>), (<tf.Tensor 'gradients/encoder/conv2d_1/Conv2D_grad/tuple/control_dependency_1:0' shape=(3, 1, 32, 64) dtype=float32>, <tf.Variable 'encoder/conv2d_1/kernel:0' shape=(3, 1, 32, 64) dtype=float32_ref>), (<tf.Tensor 'gradients/encoder/conv2d_1/BiasAdd_grad/tuple/control_dependency_1:0' shape=(64,) dtype=float32>, <tf.Variable 'encoder/conv2d_1/bias:0' shape=(64,) dtype=float32_ref>), (<tf.Tensor 'gradients/encoder/conv2d_2/Conv2D_grad/tuple/control_dependency_1:0' shape=(3, 1, 64, 128) dtype=float32>, <tf.Variable 'encoder/conv2d_2/kernel:0' shape=(3, 1, 64, 128) dtype=float32_ref>), (<tf.Tensor 'gradients/encoder/conv2d_2/BiasAdd_grad/tuple/control_dependency_1:0' shape=(128,) dtype=float32>, <tf.Variable 'encoder/conv2d_2/bias:0' shape=(128,) dtype=float32_ref>), (<tf.Tensor 'gradients/encoder/conv2d_3/Conv2D_grad/tuple/control_dependency_1:0' shape=(4, 1, 128, 512) dtype=float32>, <tf.Variable 'encoder/conv2d_3/kernel:0' shape=(4, 1, 128, 512) dtype=float32_ref>), (<tf.Tensor 'gradients/encoder/conv2d_3/BiasAdd_grad/tuple/control_dependency_1:0' shape=(512,) dtype=float32>, <tf.Variable 'encoder/conv2d_3/bias:0' shape=(512,) dtype=float32_ref>), (<tf.Tensor 'gradients/encoder/dense/MatMul_grad/tuple/control_dependency_1:0' shape=(512, 24) dtype=float32>, <tf.Variable 'encoder/dense/kernel:0' shape=(512, 24) dtype=float32_ref>), (<tf.Tensor 'gradients/encoder/dense/BiasAdd_grad/tuple/control_dependency_1:0' shape=(24,) dtype=float32>, <tf.Variable 'encoder/dense/bias:0' shape=(24,) dtype=float32_ref>), (<tf.Tensor 'gradients/encoder/code_mean/MatMul_grad/tuple/control_dependency_1:0' shape=(24, 6) dtype=float32>, <tf.Variable 'encoder/code_mean/kernel:0' shape=(24, 6) dtype=float32_ref>), (<tf.Tensor 'gradients/encoder/code_mean/BiasAdd_grad/tuple/control_dependency_1:0' shape=(6,) dtype=float32>, <tf.Variable 'encoder/code_mean/bias:0' shape=(6,) dtype=float32_ref>), (<tf.Tensor 'gradients/encoder/code_std_dev/MatMul_grad/tuple/control_dependency_1:0' shape=(24, 6) dtype=float32>, <tf.Variable 'encoder/code_std_dev/kernel:0' shape=(24, 6) dtype=float32_ref>), (<tf.Tensor 'gradients/encoder/code_std_dev/BiasAdd_grad/tuple/control_dependency_1:0' shape=(6,) dtype=float32>, <tf.Variable 'encoder/code_std_dev/bias:0' shape=(6,) dtype=float32_ref>), (<tf.Tensor 'gradients/decoder/dense/MatMul_grad/tuple/control_dependency_1:0' shape=(6, 512) dtype=float32>, <tf.Variable 'decoder/dense/kernel:0' shape=(6, 512) dtype=float32_ref>), (<tf.Tensor 'gradients/decoder/dense/BiasAdd_grad/tuple/control_dependency_1:0' shape=(512,) dtype=float32>, <tf.Variable 'decoder/dense/bias:0' shape=(512,) dtype=float32_ref>), (<tf.Tensor 'gradients/decoder/conv2d/Conv2D_grad/tuple/control_dependency_1:0' shape=(1, 1, 512, 512) dtype=float32>, <tf.Variable 'decoder/conv2d/kernel:0' shape=(1, 1, 512, 512) dtype=float32_ref>), (<tf.Tensor 'gradients/decoder/conv2d/BiasAdd_grad/tuple/control_dependency_1:0' shape=(512,) dtype=float32>, <tf.Variable 'decoder/conv2d/bias:0' shape=(512,) dtype=float32_ref>), (<tf.Tensor 'gradients/decoder/conv2d_1/Conv2D_grad/tuple/control_dependency_1:0' shape=(3, 1, 128, 128) dtype=float32>, <tf.Variable 'decoder/conv2d_1/kernel:0' shape=(3, 1, 128, 128) dtype=float32_ref>), (<tf.Tensor 'gradients/decoder/conv2d_1/BiasAdd_grad/tuple/control_dependency_1:0' shape=(128,) dtype=float32>, <tf.Variable 'decoder/conv2d_1/bias:0' shape=(128,) dtype=float32_ref>), (<tf.Tensor 'gradients/decoder/conv2d_2/Conv2D_grad/tuple/control_dependency_1:0' shape=(3, 1, 64, 64) dtype=float32>, <tf.Variable 'decoder/conv2d_2/kernel:0' shape=(3, 1, 64, 64) dty ...
# Reach the definition of loss for VAE
# WARNING:tensorflow:From /content/drive/My Drive/afeka/y2/sem1/dl/code/LSTM-VAE/VAE-LSTM-for-anomaly-detection/codes/base.py:126: The name tf.train.Saver is deprecated. Please use tf.compat.v1.train.Saver instead.
#
# WARNING:tensorflow:From /content/drive/My Drive/afeka/y2/sem1/dl/code/LSTM-VAE/VAE-LSTM-for-anomaly-detection/codes/base.py:135: The name tf.global_variables_initializer is deprecated. Please use tf.compat.v1.global_variables_initializer instead.
#
# WARNING:tensorflow:From /content/drive/My Drive/afeka/y2/sem1/dl/code/LSTM-VAE/VAE-LSTM-for-anomaly-detection/codes/base.py:136: The name tf.local_variables_initializer is deprecated. Please use tf.compat.v1.local_variables_initializer instead.
#
# checkpoint_dir at loading: ../experiments/local-results/NAB/PX4-QUAD-HITL/batch-32/NAB-PX4-QUAD-HITL-24-3-6-fixedSigma-0.1/checkpoint/
# No model loaded.
# Saving model...
# Model saved.
# 0/29, test loss: -elbo: 760.8204, recons_loss_weighted: 1465.8684, recons_loss_ls: 29.3174, KL_loss: 7.7500, sigma_regularisor: -55.2620, code_std_dev: [1.534203   0.9369842  0.9763854  0.8803898  0.12479311 0.815048  ]
# Loss on training and val sets:
# train: 623.0981, val: 694.0358
# Current sigma2: 0.0100000
# Already trained for 0.10929824908574422 min; Remaining 3.1696492234865823 min.
# Saving model...
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/training/saver.py:963: remove_checkpoint (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to delete files with this prefix.
# Model saved.
# 1/29, test loss: -elbo: 700.9901, recons_loss_weighted: 1347.8213, recons_loss_ls: 26.9564, KL_loss: 6.9433, sigma_regularisor: -55.2620, code_std_dev: [0.77516985 0.41193807 0.6928018  0.9358243  0.38336635 0.76618356]
# Loss on training and val sets:
# train: 583.3212, val: 592.1400
# Current sigma2: 0.0100000
# Already trained for 0.17381299336751302 min; Remaining 2.4333819071451823 min.
# Saving model...
# Model saved.
# 2/29, test loss: -elbo: 567.8898, recons_loss_weighted: 1074.1680, recons_loss_ls: 21.4834, KL_loss: 10.6697, sigma_regularisor: -55.2620, code_std_dev: [0.81946486 0.19394818 0.5187993  1.3403385  0.5483113  0.8068424 ]
# Loss on training and val sets:
# train: 522.5022, val: 549.7748
# Current sigma2: 0.0100000
# Already trained for 0.23767120440800985 min; Remaining 2.139040839672089 min.
# Saving model...
# Model saved.
# 3/29, test loss: -elbo: 529.2661, recons_loss_weighted: 994.4146, recons_loss_ls: 19.8883, KL_loss: 11.9226, sigma_regularisor: -55.2620, code_std_dev: [0.7587554  0.13129163 0.512214   0.6833751  0.29989848 0.6365493 ]
# Loss on training and val sets:
# train: 469.9757, val: 591.9966
# Current sigma2: 0.0100000
# Already trained for 0.30140730142593386 min; Remaining 1.95914745926857 min.
# Saving model...
# Model saved.
# 4/29, test loss: -elbo: 500.5944, recons_loss_weighted: 928.7928, recons_loss_ls: 18.5759, KL_loss: 16.0618, sigma_regularisor: -55.2620, code_std_dev: [0.8726106  0.02964427 0.6950621  0.35429087 0.13056345 0.46773016]
# Loss on training and val sets:
# train: 444.6460, val: 471.5796
# Current sigma2: 0.0100000
# Already trained for 0.3658046762148539 min; Remaining 1.8290233810742695 min.
# Saving model...
# Model saved.
# 5/29, test loss: -elbo: 437.5039, recons_loss_weighted: 799.2086, recons_loss_ls: 15.9842, KL_loss: 17.7635, sigma_regularisor: -55.2620, code_std_dev: [0.77052015 0.08958749 0.7169464  0.4538216  0.104544   0.36489344]
# Loss on training and val sets:
# train: 399.6635, val: 348.5517
# Current sigma2: 0.0100000
# Already trained for 0.4276400248209635 min; Remaining 1.710560099283854 min.
# Saving model...
# Model saved.
# 6/29, test loss: -elbo: 401.7915, recons_loss_weighted: 724.0131, recons_loss_ls: 14.4803, KL_loss: 19.6488, sigma_regularisor: -55.2620, code_std_dev: [0.38894895 0.0212658  0.6455306  0.44921073 0.09165692 0.21219435]
# Loss on training and val sets:
# train: 359.0108, val: 430.3134
# Current sigma2: 0.0100000
# Already trained for 0.4934617082277934 min; Remaining 1.6213741841770355 min.
# Saving model...
# Model saved.
# 7/29, test loss: -elbo: 384.9774, recons_loss_weighted: 687.5599, recons_loss_ls: 13.7512, KL_loss: 21.0613, sigma_regularisor: -55.2620, code_std_dev: [0.25170627 0.03625206 0.7852755  0.264902   0.09203167 0.12357868]
# Loss on training and val sets:
# train: 329.1922, val: 389.4465
# Current sigma2: 0.0100000
# Already trained for 0.5573542356491089 min; Remaining 1.5327241480350495 min.
# Saving model...
# Model saved.
# 8/29, test loss: -elbo: 361.6869, recons_loss_weighted: 641.2010, recons_loss_ls: 12.8240, KL_loss: 20.9502, sigma_regularisor: -55.2620, code_std_dev: [0.17741404 0.02209096 0.7326368  0.29821503 0.09742968 0.12034273]
# Loss on training and val sets:
# train: 305.7492, val: 380.3910
# Current sigma2: 0.0100000
# Already trained for 0.6221546411514283 min; Remaining 1.451694162686666 min.
# Saving model...
# Model saved.
# 9/29, test loss: -elbo: 357.1219, recons_loss_weighted: 631.0316, recons_loss_ls: 12.6206, KL_loss: 21.4700, sigma_regularisor: -55.2620, code_std_dev: [0.1295272  0.03003597 0.8626688  0.22607212 0.05986762 0.13265933]
# Loss on training and val sets:
# train: 286.6841, val: 377.7793
# Current sigma2: 0.0100000
# Already trained for 0.6857483426729838 min; Remaining 1.3714966853459676 min.
# Saving model...
# Model saved.
# 10/29, test loss: -elbo: 337.2560, recons_loss_weighted: 589.9703, recons_loss_ls: 11.7994, KL_loss: 22.1347, sigma_regularisor: -55.2620, code_std_dev: [0.14192495 0.02855736 0.7842724  0.24753521 0.08125576 0.09874094]
# Loss on training and val sets:
# train: 272.6762, val: 339.7312
# Current sigma2: 0.0100000
# Already trained for 0.7498560269673665 min; Remaining 1.295205864761815 min.
# Saving model...
# Model saved.
# 11/29, test loss: -elbo: 326.9948, recons_loss_weighted: 567.7178, recons_loss_ls: 11.3544, KL_loss: 22.9997, sigma_regularisor: -55.2620, code_std_dev: [0.13389657 0.03158058 0.6882078  0.22198439 0.04344366 0.08334456]
# Loss on training and val sets:
# train: 254.1547, val: 314.7778
# Current sigma2: 0.0100000
# Already trained for 0.8134814778963725 min; Remaining 1.2202222168445587 min.
# Saving model...
# Model saved.
# 12/29, test loss: -elbo: 319.9872, recons_loss_weighted: 552.0906, recons_loss_ls: 11.0418, KL_loss: 23.8058, sigma_regularisor: -55.2620, code_std_dev: [0.17961368 0.03694699 0.75324774 0.20073223 0.05374857 0.11674122]
# Loss on training and val sets:
# train: 242.1135, val: 309.3430
# Current sigma2: 0.0100000
# Already trained for 0.8744533896446228 min; Remaining 1.1435159710737375 min.
# Saving model...
# Model saved.
# 13/29, test loss: -elbo: 308.6952, recons_loss_weighted: 529.0092, recons_loss_ls: 10.5802, KL_loss: 24.0544, sigma_regularisor: -55.2620, code_std_dev: [0.07364518 0.0203696  0.6063032  0.21931982 0.06934712 0.11713223]
# Loss on training and val sets:
# train: 227.1430, val: 253.4190
# Current sigma2: 0.0100000
# Already trained for 0.9398654222488403 min; Remaining 1.0741319111415317 min.
# Saving model...
# Model saved.
# 14/29, test loss: -elbo: 300.6431, recons_loss_weighted: 509.7584, recons_loss_ls: 10.1952, KL_loss: 25.6277, sigma_regularisor: -55.2620, code_std_dev: [0.10383794 0.0270521  0.56624925 0.17780225 0.07364009 0.04429225]
# Loss on training and val sets:
# train: 222.3821, val: 310.5182
# Current sigma2: 0.0100000
# Already trained for 1.0034289240837098 min; Remaining 1.0034289240837098 min.
# Saving model...
# Model saved.
# 15/29, test loss: -elbo: 297.1110, recons_loss_weighted: 502.8799, recons_loss_ls: 10.0576, KL_loss: 25.5348, sigma_regularisor: -55.2620, code_std_dev: [0.09006666 0.0314138  0.5336299  0.2022319  0.07390091 0.07507292]
# Loss on training and val sets:
# train: 208.4194, val: 294.1163
# Current sigma2: 0.0100000
# Already trained for 1.0696571230888368 min; Remaining 0.9359499827027321 min.
# Saving model...
# Model saved.
# 16/29, test loss: -elbo: 300.9789, recons_loss_weighted: 510.4531, recons_loss_ls: 10.2091, KL_loss: 25.6162, sigma_regularisor: -55.2620, code_std_dev: [0.10672691 0.03007778 0.50691324 0.1597676  0.05501476 0.0854819 ]
# Loss on training and val sets:
# train: 203.0550, val: 253.7476
# Current sigma2: 0.0100000
# Already trained for 1.1313321709632873 min; Remaining 0.8651363660307491 min.
# Saving model...
# Model saved.
# 17/29, test loss: -elbo: 283.5415, recons_loss_weighted: 474.6707, recons_loss_ls: 9.4934, KL_loss: 26.0700, sigma_regularisor: -55.2620, code_std_dev: [0.15071586 0.02902235 0.54774904 0.17507644 0.06325383 0.07657348]
# Loss on training and val sets:
# train: 192.6017, val: 257.7547
# Current sigma2: 0.0100000
# Already trained for 1.196828265984853 min; Remaining 0.7978855106565687 min.
# Saving model...
# Model saved.
# 18/29, test loss: -elbo: 278.7249, recons_loss_weighted: 465.3651, recons_loss_ls: 9.3073, KL_loss: 25.9061, sigma_regularisor: -55.2620, code_std_dev: [0.14926651 0.03376509 0.41678983 0.18298009 0.08310661 0.06795353]
# Loss on training and val sets:
# train: 186.6158, val: 281.3935
# Current sigma2: 0.0100000
# Already trained for 1.260943345228831 min; Remaining 0.7300198314482705 min.
# Saving model...
# Model saved.
# 19/29, test loss: -elbo: 271.1845, recons_loss_weighted: 449.0111, recons_loss_ls: 8.9802, KL_loss: 26.5428, sigma_regularisor: -55.2620, code_std_dev: [0.09435438 0.02836296 0.45676512 0.09479929 0.06446835 0.0814483 ]
# Loss on training and val sets:
# train: 181.2470, val: 291.0541
# Current sigma2: 0.0100000
# Already trained for 1.3258755524953207 min; Remaining 0.6629377762476604 min.
# Saving model...
# Model saved.
# 20/29, test loss: -elbo: 273.1499, recons_loss_weighted: 452.4448, recons_loss_ls: 9.0489, KL_loss: 26.7913, sigma_regularisor: -55.2620, code_std_dev: [0.08071976 0.0224478  0.38214597 0.14080997 0.08183371 0.07783604]
# Loss on training and val sets:
# train: 174.0678, val: 245.8864
# Current sigma2: 0.0100000
# Already trained for 1.3889392614364624 min; Remaining 0.5952596834727697 min.
# Saving model...
# Model saved.
# 21/29, test loss: -elbo: 269.3046, recons_loss_weighted: 445.5205, recons_loss_ls: 8.9104, KL_loss: 26.4081, sigma_regularisor: -55.2620, code_std_dev: [0.08908045 0.03019579 0.2946196  0.15598439 0.05299891 0.0937984 ]
# Loss on training and val sets:
# train: 172.7048, val: 246.4333
# Current sigma2: 0.0100000
# Already trained for 1.4543235301971436 min; Remaining 0.5288449200716886 min.
# Saving model...
# Model saved.
# 22/29, test loss: -elbo: 259.5567, recons_loss_weighted: 425.7509, recons_loss_ls: 8.5150, KL_loss: 26.5450, sigma_regularisor: -55.2620, code_std_dev: [0.09129984 0.02531066 0.35177445 0.14066128 0.05586222 0.10387164]
# Loss on training and val sets:
# train: 162.3450, val: 239.3388
# Current sigma2: 0.0100000
# Already trained for 1.521246866385142 min; Remaining 0.4629881767259128 min.
# Saving model...
# Model saved.
# 23/29, test loss: -elbo: 254.9336, recons_loss_weighted: 414.8615, recons_loss_ls: 8.2972, KL_loss: 27.3667, sigma_regularisor: -55.2620, code_std_dev: [0.08860228 0.02707799 0.27592567 0.14311941 0.05987686 0.05775405]
# Loss on training and val sets:
# train: 160.2673, val: 251.8954
# Current sigma2: 0.0100000
# Already trained for 1.5819138566652933 min; Remaining 0.3954784641663233 min.
# Saving model...
# Model saved.
# 24/29, test loss: -elbo: 255.3306, recons_loss_weighted: 417.7648, recons_loss_ls: 8.3553, KL_loss: 26.3120, sigma_regularisor: -55.2620, code_std_dev: [0.09903084 0.03318293 0.354277   0.13514507 0.05671245 0.08988718]
# Loss on training and val sets:
# train: 157.3799, val: 260.3963
# Current sigma2: 0.0100000
# Already trained for 1.6466511885325115 min; Remaining 0.32933023770650227 min.
# Saving model...
# Model saved.
# 25/29, test loss: -elbo: 257.9499, recons_loss_weighted: 420.8795, recons_loss_ls: 8.4176, KL_loss: 27.3740, sigma_regularisor: -55.2620, code_std_dev: [0.1105686  0.03192598 0.34163988 0.09033577 0.04848256 0.06618623]
# Loss on training and val sets:
# train: 151.8698, val: 233.0127
# Current sigma2: 0.0100000
# Already trained for 1.7119161208470663 min; Remaining 0.26337171089954864 min.
# Saving model...
# Model saved.
# 26/29, test loss: -elbo: 255.4570, recons_loss_weighted: 416.5791, recons_loss_ls: 8.3316, KL_loss: 27.0313, sigma_regularisor: -55.2620, code_std_dev: [0.08210827 0.03009127 0.27519628 0.1428841  0.06922804 0.11883952]
# Loss on training and val sets:
# train: 149.5100, val: 209.8038
# Current sigma2: 0.0100000
# Already trained for 1.7787692705790201 min; Remaining 0.19764103006433556 min.
# Saving model...
# Model saved.
# 27/29, test loss: -elbo: 252.4605, recons_loss_weighted: 409.5435, recons_loss_ls: 8.1909, KL_loss: 27.5526, sigma_regularisor: -55.2620, code_std_dev: [0.08093406 0.02470465 0.21966892 0.14956212 0.05850742 0.09540971]
# Loss on training and val sets:
# train: 145.1957, val: 221.5012
# Current sigma2: 0.0100000
# Already trained for 1.8412948290506999 min; Remaining 0.13152105921790713 min.
# Saving model...
# Model saved.
# 28/29, test loss: -elbo: 247.7556, recons_loss_weighted: 401.2363, recons_loss_ls: 8.0247, KL_loss: 27.0012, sigma_regularisor: -55.2620, code_std_dev: [0.07549368 0.02517006 0.26960835 0.12740916 0.06826987 0.09577031]
# Loss on training and val sets:
# train: 141.3957, val: 255.3373
# Current sigma2: 0.0100000
# Already trained for 1.908660630385081 min; Remaining 0.0658158838063821 min.
# Saving model...
# Model saved.
# 29/29, test loss: -elbo: 248.1888, recons_loss_weighted: 401.5600, recons_loss_ls: 8.0312, KL_loss: 27.2726, sigma_regularisor: -55.2620, code_std_dev: [0.08299244 0.02792427 0.3368632  0.11289938 0.04974569 0.05934388]
# Loss on training and val sets:
# train: 138.7445, val: 247.9216
# Current sigma2: 0.0100000
# Already trained for 1.9718372027079265 min; Remaining 0.0 min.

# %%
# load LSTM model
lstm_model = lstmKerasModel(data)
lstm_model.produce_embeddings(config, model_vae, data, sess)
lstm_nn_model = lstm_model.create_lstm_model(config)
lstm_nn_model.summary()   # Display the model's architecture

# checkpoint path
checkpoint_path = config['checkpoint_dir_lstm'] + "cp.ckpt"
checkpoint_dir = os.path.dirname(checkpoint_path)
# Create a callback that saves the model's weights
cp_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path,
                                                 save_weights_only=True,
                                                 verbose=1)
# load weights if possible
lstm_model.load_model(lstm_nn_model, config, checkpoint_path)
# start training
if config['TRAIN_LSTM']:
    if config['num_epochs_lstm'] > 0:
        lstm_model.train(config, lstm_nn_model, cp_callback)

    # make a prediction on the test set using the trained model
    lstm_embedding = lstm_nn_model.predict(lstm_model.x_test, batch_size=config['batch_size_lstm'])
    print(lstm_embedding.shape)

    # visualise the first 10 test sequences
    for i in range(10):
        lstm_model.plot_lstm_embedding_prediction(i, config, model_vae, sess, data, lstm_embedding)
# Out:
# Finish processing the embeddings of the entire dataset.
# The first a few embeddings are
# [[ 5.02436066 -4.43001795  0.68986613 -4.09546328  2.37283254  0.10098826]
#  [-0.40554971  0.73663819  0.66863525  0.31437284  0.27353445 -0.3954441 ]
#  [-0.37921953  0.67072833  0.67547977  0.15524012  0.17634101 -0.29994479]]
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 2, 6)]            0
# _________________________________________________________________
# lstm (LSTM)                  (None, 2, 64)             18176
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 2, 64)             33024
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 2, 6)              1704
# =================================================================
# Total params: 52,904
# Trainable params: 52,904
# Non-trainable params: 0
# _________________________________________________________________
# ../experiments/local-results/NAB/PX4-QUAD-HITL/batch-32/NAB-PX4-QUAD-HITL-24-3-6-fixedSigma-0.1/checkpoint/lstm/checkpoint
# No LSTM model loaded.
# Train on 746 samples, validate on 83 samples
# Epoch 1/100
# 672/746 [==========================>...] - ETA: 0s - loss: 2.6311 - mean_squared_error: 2.6311
# Epoch 00001: saving model to ../experiments/local-results/NAB/PX4-QUAD-HITL/batch-32/NAB-PX4-QUAD-HITL-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 2s 2ms/sample - loss: 2.5826 - mean_squared_error: 2.5826 - val_loss: 2.4492 - val_mean_squared_error: 2.4492
# Epoch 2/100
# 640/746 [========================>.....] - ETA: 0s - loss: 2.5219 - mean_squared_error: 2.5219
# Epoch 00002: saving model to ../experiments/local-results/NAB/PX4-QUAD-HITL/batch-32/NAB-PX4-QUAD-HITL-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 1s 767us/sample - loss: 2.5791 - mean_squared_error: 2.5791 - val_loss: 2.4454 - val_mean_squared_error: 2.4454
# Epoch 3/100
# 672/746 [==========================>...] - ETA: 0s - loss: 2.5592 - mean_squared_error: 2.5592
# Epoch 00003: saving model to ../experiments/local-results/NAB/PX4-QUAD-HITL/batch-32/NAB-PX4-QUAD-HITL-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 463us/sample - loss: 2.5754 - mean_squared_error: 2.5754 - val_loss: 2.4413 - val_mean_squared_error: 2.4413
# Epoch 4/100
# 672/746 [==========================>...] - ETA: 0s - loss: 2.5961 - mean_squared_error: 2.5961
# Epoch 00004: saving model to ../experiments/local-results/NAB/PX4-QUAD-HITL/batch-32/NAB-PX4-QUAD-HITL-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 1s 787us/sample - loss: 2.5713 - mean_squared_error: 2.5713 - val_loss: 2.4367 - val_mean_squared_error: 2.4367
# Epoch 5/100
# 736/746 [============================>.] - ETA: 0s - loss: 2.5451 - mean_squared_error: 2.5451
# Epoch 00005: saving model to ../experiments/local-results/NAB/PX4-QUAD-HITL/batch-32/NAB-PX4-QUAD-HITL-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 538us/sample - loss: 2.5665 - mean_squared_error: 2.5665 - val_loss: 2.4312 - val_mean_squared_error: 2.4312
# Epoch 6/100
# 640/746 [========================>.....] - ETA: 0s - loss: 2.5593 - mean_squared_error: 2.5593
# Epoch 00006: saving model to ../experiments/local-results/NAB/PX4-QUAD-HITL/batch-32/NAB-PX4-QUAD-HITL-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 640us/sample - loss: 2.5604 - mean_squared_error: 2.5604 - val_loss: 2.4247 - val_mean_squared_error: 2.4247
# Epoch 7/100
# 608/746 [=======================>......] - ETA: 0s - loss: 2.5396 - mean_squared_error: 2.5396
# Epoch 00007: saving model to ../experiments/local-results/NAB/PX4-QUAD-HITL/batch-32/NAB-PX4-QUAD-HITL-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 508us/sample - loss: 2.5532 - mean_squared_error: 2.5532 - val_loss: 2.4160 - val_mean_squared_error: 2.4160
# Epoch 8/100
# 736/746 [============================>.] - ETA: 0s - loss: 2.5449 - mean_squared_error: 2.5449
# Epoch 00008: saving model to ../experiments/local-results/NAB/PX4-QUAD-HITL/batch-32/NAB-PX4-QUAD-HITL-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 1s 787us/sample - loss: 2.5442 - mean_squared_error: 2.5442 - val_loss: 2.4060 - val_mean_squared_error: 2.4060
# Epoch 9/100
# 672/746 [==========================>...] - ETA: 0s - loss: 2.5289 - mean_squared_error: 2.5289
# Epoch 00009: saving model to ../experiments/local-results/NAB/PX4-QUAD-HITL/batch-32/NAB-PX4-QUAD-HITL-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 560us/sample - loss: 2.5334 - mean_squared_error: 2.5334 - val_loss: 2.3935 - val_mean_squared_error: 2.3935
# Epoch 10/100
# 672/746 [==========================>...] - ETA: 0s - loss: 2.5381 - mean_squared_error: 2.5381
# Epoch 00010: saving model to ../experiments/local-results/NAB/PX4-QUAD-HITL/batch-32/NAB-PX4-QUAD-HITL-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 638us/sample - loss: 2.5218 - mean_squared_error: 2.5218 - val_loss: 2.3804 - val_mean_squared_error: 2.3804
# Epoch 11/100
# 672/746 [==========================>...] - ETA: 0s - loss: 2.5002 - mean_squared_error: 2.5002
# Epoch 00011: saving model to ../experiments/local-results/NAB/PX4-QUAD-HITL/batch-32/NAB-PX4-QUAD-HITL-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 456us/sample - loss: 2.5092 - mean_squared_error: 2.5092 - val_loss: 2.3664 - val_mean_squared_error: 2.3664
# Epoch 12/100
# 672/746 [==========================>...] - ETA: 0s - loss: 2.5353 - mean_squared_error: 2.5353
# Epoch 00012: saving model to ../experiments/local-results/NAB/PX4-QUAD-HITL/batch-32/NAB-PX4-QUAD-HITL-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 557us/sample - loss: 2.4949 - mean_squared_error: 2.4949 - val_loss: 2.3487 - val_mean_squared_error: 2.3487
# Epoch 13/100
# 672/746 [==========================>...] - ETA: 0s - loss: 2.5083 - mean_squared_error: 2.5083
# Epoch 00013: saving model to ../experiments/local-results/NAB/PX4-QUAD-HITL/batch-32/NAB-PX4-QUAD-HITL-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 1s 681us/sample - loss: 2.4816 - mean_squared_error: 2.4816 - val_loss: 2.3302 - val_mean_squared_error: 2.3302
# Epoch 14/100
# 640/746 [========================>.....] - ETA: 0s - loss: 2.4684 - mean_squared_error: 2.4684
# Epoch 00014: saving model to ../experiments/local-results/NAB/PX4-QUAD-HITL/batch-32/NAB-PX4-QUAD-HITL-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 629us/sample - loss: 2.4660 - mean_squared_error: 2.4660 - val_loss: 2.3151 - val_mean_squared_error: 2.3151
# Epoch 15/100
# 672/746 [==========================>...] - ETA: 0s - loss: 2.4292 - mean_squared_error: 2.4292
# Epoch 00015: saving model to ../experiments/local-results/NAB/PX4-QUAD-HITL/batch-32/NAB-PX4-QUAD-HITL-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 461us/sample - loss: 2.4521 - mean_squared_error: 2.4521 - val_loss: 2.3005 - val_mean_squared_error: 2.3005
# Epoch 16/100
# 640/746 [========================>.....] - ETA: 0s - loss: 2.4215 - mean_squared_error: 2.4215
# Epoch 00016: saving model to ../experiments/local-results/NAB/PX4-QUAD-HITL/batch-32/NAB-PX4-QUAD-HITL-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 632us/sample - loss: 2.4402 - mean_squared_error: 2.4402 - val_loss: 2.2908 - val_mean_squared_error: 2.2908
# Epoch 17/100
# 672/746 [==========================>...] - ETA: 0s - loss: 2.4301 - mean_squared_error: 2.4301
# Epoch 00017: saving model to ../experiments/local-results/NAB/PX4-QUAD-HITL/batch-32/NAB-PX4-QUAD-HITL-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 456us/sample - loss: 2.4308 - mean_squared_error: 2.4308 - val_loss: 2.2822 - val_mean_squared_error: 2.2822
# Epoch 18/100
# 672/746 [==========================>...] - ETA: 0s - loss: 2.4087 - mean_squared_error: 2.4087
# Epoch 00018: saving model to ../experiments/local-results/NAB/PX4-QUAD-HITL/batch-32/NAB-PX4-QUAD-HITL-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 632us/sample - loss: 2.4236 - mean_squared_error: 2.4236 - val_loss: 2.2733 - val_mean_squared_error: 2.2733
# Epoch 19/100
# 672/746 [==========================>...] - ETA: 0s - loss: 2.3933 - mean_squared_error: 2.3933
# Epoch 00019: saving model to ../experiments/local-results/NAB/PX4-QUAD-HITL/batch-32/NAB-PX4-QUAD-HITL-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 463us/sample - loss: 2.4159 - mean_squared_error: 2.4159 - val_loss: 2.2658 - val_mean_squared_error: 2.2658
# Epoch 20/100
# 672/746 [==========================>...] - ETA: 0s - loss: 2.4052 - mean_squared_error: 2.4052
# Epoch 00020: saving model to ../experiments/local-results/NAB/PX4-QUAD-HITL/batch-32/NAB-PX4-QUAD-HITL-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 448us/sample - loss: 2.4083 - mean_squared_error: 2.4083 - val_loss: 2.2590 - val_mean_squared_error: 2.2590
# Epoch 21/100
# 672/746 [==========================>...] - ETA: 0s - loss: 2.4389 - mean_squared_error: 2.4389
# Epoch 00021: saving model to ../experiments/local-results/NAB/PX4-QUAD-HITL/batch-32/NAB-PX4-QUAD-HITL-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 634us/sample - loss: 2.4006 - mean_squared_error: 2.4006 - val_loss: 2.2504 - val_mean_squared_error: 2.2504
# Epoch 22/100
# 608/746 [=======================>......] - ETA: 0s - loss: 2.3892 - mean_squared_error: 2.3892
# Epoch 00022: saving model to ../experiments/local-results/NAB/PX4-QUAD-HITL/batch-32/NAB-PX4-QUAD-HITL-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 480us/sample - loss: 2.3927 - mean_squared_error: 2.3927 - val_loss: 2.2403 - val_mean_squared_error: 2.2403
# Epoch 23/100
# 672/746 [==========================>...] - ETA: 0s - loss: 2.3953 - mean_squared_error: 2.3953
# Epoch 00023: saving model to ../experiments/local-results/NAB/PX4-QUAD-HITL/batch-32/NAB-PX4-QUAD-HITL-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 641us/sample - loss: 2.3843 - mean_squared_error: 2.3843 - val_loss: 2.2318 - val_mean_squared_error: 2.2318
# Epoch 24/100
# 672/746 [==========================>...] - ETA: 0s - loss: 2.3245 - mean_squared_error: 2.3245
# Epoch 00024: saving model to ../experiments/local-results/NAB/PX4-QUAD-HITL/batch-32/NAB-PX4-QUAD-HITL-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 468us/sample - loss: 2.3755 - mean_squared_error: 2.3755 - val_loss: 2.2201 - val_mean_squared_error: 2.2201
# Epoch 25/100
# 672/746 [==========================>...] - ETA: 0s - loss: 2.3623 - mean_squared_error: 2.3623
# Epoch 00025: saving model to ../experiments/local-results/NAB/PX4-QUAD-HITL/batch-32/NAB-PX4-QUAD-HITL-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 648us/sample - loss: 2.3656 - mean_squared_error: 2.3656 - val_loss: 2.2100 - val_mean_squared_error: 2.2100
# Epoch 26/100
# 672/746 [==========================>...] - ETA: 0s - loss: 2.3374 - mean_squared_error: 2.3374
# Epoch 00026: saving model to ../experiments/local-results/NAB/PX4-QUAD-HITL/batch-32/NAB-PX4-QUAD-HITL-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 462us/sample - loss: 2.3550 - mean_squared_error: 2.3550 - val_loss: 2.1967 - val_mean_squared_error: 2.1967
# Epoch 27/100
# 736/746 [============================>.] - ETA: 0s - loss: 2.3397 - mean_squared_error: 2.3397
# Epoch 00027: saving model to ../experiments/local-results/NAB/PX4-QUAD-HITL/batch-32/NAB-PX4-QUAD-HITL-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 1s 729us/sample - loss: 2.3436 - mean_squared_error: 2.3436 - val_loss: 2.1834 - val_mean_squared_error: 2.1834
# Epoch 28/100
# 704/746 [===========================>..] - ETA: 0s - loss: 2.3425 - mean_squared_error: 2.3425
# Epoch 00028: saving model to ../experiments/local-results/NAB/PX4-QUAD-HITL/batch-32/NAB-PX4-QUAD-HITL-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 507us/sample - loss: 2.3314 - mean_squared_error: 2.3314 - val_loss: 2.1659 - val_mean_squared_error: 2.1659
# Epoch 29/100
# 704/746 [===========================>..] - ETA: 0s - loss: 2.2970 - mean_squared_error: 2.2970
# Epoch 00029: saving model to ../experiments/local-results/NAB/PX4-QUAD-HITL/batch-32/NAB-PX4-QUAD-HITL-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 1s 728us/sample - loss: 2.3180 - mean_squared_error: 2.3180 - val_loss: 2.1521 - val_mean_squared_error: 2.1521
# Epoch 30/100
# 704/746 [===========================>..] - ETA: 0s - loss: 2.3037 - mean_squared_error: 2.3037
# Epoch 00030: saving model to ../experiments/local-results/NAB/PX4-QUAD-HITL/batch-32/NAB-PX4-QUAD-HITL-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 531us/sample - loss: 2.3032 - mean_squared_error: 2.3032 - val_loss: 2.1340 - val_mean_squared_error: 2.1340
# Epoch 31/100
# 672/746 [==========================>...] - ETA: 0s - loss: 2.2554 - mean_squared_error: 2.2554
# Epoch 00031: saving model to ../experiments/local-results/NAB/PX4-QUAD-HITL/batch-32/NAB-PX4-QUAD-HITL-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 639us/sample - loss: 2.2876 - mean_squared_error: 2.2876 - val_loss: 2.1167 - val_mean_squared_error: 2.1167
# Epoch 32/100
# 672/746 [==========================>...] - ETA: 0s - loss: 2.2806 - mean_squared_error: 2.2806
# Epoch 00032: saving model to ../experiments/local-results/NAB/PX4-QUAD-HITL/batch-32/NAB-PX4-QUAD-HITL-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 478us/sample - loss: 2.2735 - mean_squared_error: 2.2735 - val_loss: 2.0991 - val_mean_squared_error: 2.0991
# Epoch 33/100
# 640/746 [========================>.....] - ETA: 0s - loss: 2.2643 - mean_squared_error: 2.2643
# Epoch 00033: saving model to ../experiments/local-results/NAB/PX4-QUAD-HITL/batch-32/NAB-PX4-QUAD-HITL-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 652us/sample - loss: 2.2561 - mean_squared_error: 2.2561 - val_loss: 2.0809 - val_mean_squared_error: 2.0809
# Epoch 34/100
# 672/746 [==========================>...] - ETA: 0s - loss: 2.2696 - mean_squared_error: 2.2696
# Epoch 00034: saving model to ../experiments/local-results/NAB/PX4-QUAD-HITL/batch-32/NAB-PX4-QUAD-HITL-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 473us/sample - loss: 2.2405 - mean_squared_error: 2.2405 - val_loss: 2.0649 - val_mean_squared_error: 2.0649
# Epoch 35/100
# 672/746 [==========================>...] - ETA: 0s - loss: 2.2740 - mean_squared_error: 2.2740
# Epoch 00035: saving model to ../experiments/local-results/NAB/PX4-QUAD-HITL/batch-32/NAB-PX4-QUAD-HITL-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 646us/sample - loss: 2.2258 - mean_squared_error: 2.2258 - val_loss: 2.0502 - val_mean_squared_error: 2.0502
# Epoch 36/100
# 672/746 [==========================>...] - ETA: 0s - loss: 2.2090 - mean_squared_error: 2.2090
# Epoch 00036: saving model to ../experiments/local-results/NAB/PX4-QUAD-HITL/batch-32/NAB-PX4-QUAD-HITL-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 472us/sample - loss: 2.2107 - mean_squared_error: 2.2107 - val_loss: 2.0340 - val_mean_squared_error: 2.0340
# Epoch 37/100
# 736/746 [============================>.] - ETA: 0s - loss: 2.1875 - mean_squared_error: 2.1875
# Epoch 00037: saving model to ../experiments/local-results/NAB/PX4-QUAD-HITL/batch-32/NAB-PX4-QUAD-HITL-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 1s 675us/sample - loss: 2.1987 - mean_squared_error: 2.1987 - val_loss: 2.0202 - val_mean_squared_error: 2.0202
# Epoch 38/100
# 672/746 [==========================>...] - ETA: 0s - loss: 2.1601 - mean_squared_error: 2.1601
# Epoch 00038: saving model to ../experiments/local-results/NAB/PX4-QUAD-HITL/batch-32/NAB-PX4-QUAD-HITL-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 470us/sample - loss: 2.1882 - mean_squared_error: 2.1882 - val_loss: 2.0099 - val_mean_squared_error: 2.0099
# Epoch 39/100
# 608/746 [=======================>......] - ETA: 0s - loss: 2.1716 - mean_squared_error: 2.1716
# Epoch 00039: saving model to ../experiments/local-results/NAB/PX4-QUAD-HITL/batch-32/NAB-PX4-QUAD-HITL-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 649us/sample - loss: 2.1765 - mean_squared_error: 2.1765 - val_loss: 2.0014 - val_mean_squared_error: 2.0014
# Epoch 40/100
# 672/746 [==========================>...] - ETA: 0s - loss: 2.1973 - mean_squared_error: 2.1973
# Epoch 00040: saving model to ../experiments/local-results/NAB/PX4-QUAD-HITL/batch-32/NAB-PX4-QUAD-HITL-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 461us/sample - loss: 2.1669 - mean_squared_error: 2.1669 - val_loss: 1.9928 - val_mean_squared_error: 1.9928
# Epoch 41/100
# 640/746 [========================>.....] - ETA: 0s - loss: 2.0829 - mean_squared_error: 2.0829
# Epoch 00041: saving model to ../experiments/local-results/NAB/PX4-QUAD-HITL/batch-32/NAB-PX4-QUAD-HITL-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 652us/sample - loss: 2.1578 - mean_squared_error: 2.1578 - val_loss: 1.9825 - val_mean_squared_error: 1.9825
# Epoch 42/100
# 672/746 [==========================>...] - ETA: 0s - loss: 2.1674 - mean_squared_error: 2.1674
# Epoch 00042: saving model to ../experiments/local-results/NAB/PX4-QUAD-HITL/batch-32/NAB-PX4-QUAD-HITL-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 480us/sample - loss: 2.1487 - mean_squared_error: 2.1487 - val_loss: 1.9765 - val_mean_squared_error: 1.9765
# Epoch 43/100
# 672/746 [==========================>...] - ETA: 0s - loss: 2.1257 - mean_squared_error: 2.1257
# Epoch 00043: saving model to ../experiments/local-results/NAB/PX4-QUAD-HITL/batch-32/NAB-PX4-QUAD-HITL-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 637us/sample - loss: 2.1401 - mean_squared_error: 2.1401 - val_loss: 1.9687 - val_mean_squared_error: 1.9687
# Epoch 44/100
# 672/746 [==========================>...] - ETA: 0s - loss: 2.0791 - mean_squared_error: 2.0791
# Epoch 00044: saving model to ../experiments/local-results/NAB/PX4-QUAD-HITL/batch-32/NAB-PX4-QUAD-HITL-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 455us/sample - loss: 2.1323 - mean_squared_error: 2.1323 - val_loss: 1.9615 - val_mean_squared_error: 1.9615
# Epoch 45/100
# 672/746 [==========================>...] - ETA: 0s - loss: 2.1590 - mean_squared_error: 2.1590
# Epoch 00045: saving model to ../experiments/local-results/NAB/PX4-QUAD-HITL/batch-32/NAB-PX4-QUAD-HITL-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 647us/sample - loss: 2.1248 - mean_squared_error: 2.1248 - val_loss: 1.9562 - val_mean_squared_error: 1.9562
# Epoch 46/100
# 736/746 [============================>.] - ETA: 0s - loss: 2.1161 - mean_squared_error: 2.1161
# Epoch 00046: saving model to ../experiments/local-results/NAB/PX4-QUAD-HITL/batch-32/NAB-PX4-QUAD-HITL-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 627us/sample - loss: 2.1166 - mean_squared_error: 2.1166 - val_loss: 1.9486 - val_mean_squared_error: 1.9486
# Epoch 47/100
# 640/746 [========================>.....] - ETA: 0s - loss: 2.1140 - mean_squared_error: 2.1140
# Epoch 00047: saving model to ../experiments/local-results/NAB/PX4-QUAD-HITL/batch-32/NAB-PX4-QUAD-HITL-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 666us/sample - loss: 2.1092 - mean_squared_error: 2.1092 - val_loss: 1.9431 - val_mean_squared_error: 1.9431
# Epoch 48/100
# 640/746 [========================>.....] - ETA: 0s - loss: 2.1021 - mean_squared_error: 2.1021
# Epoch 00048: saving model to ../experiments/local-results/NAB/PX4-QUAD-HITL/batch-32/NAB-PX4-QUAD-HITL-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 488us/sample - loss: 2.1026 - mean_squared_error: 2.1026 - val_loss: 1.9367 - val_mean_squared_error: 1.9367
# Epoch 49/100
# 640/746 [========================>.....] - ETA: 0s - loss: 2.1243 - mean_squared_error: 2.1243
# Epoch 00049: saving model to ../experiments/local-results/NAB/PX4-QUAD-HITL/batch-32/NAB-PX4-QUAD-HITL-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 1s 688us/sample - loss: 2.0953 - mean_squared_error: 2.0953 - val_loss: 1.9286 - val_mean_squared_error: 1.9286
# Epoch 50/100
# 640/746 [========================>.....] - ETA: 0s - loss: 2.0328 - mean_squared_error: 2.0328
# Epoch 00050: saving model to ../experiments/local-results/NAB/PX4-QUAD-HITL/batch-32/NAB-PX4-QUAD-HITL-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 627us/sample - loss: 2.0883 - mean_squared_error: 2.0883 - val_loss: 1.9265 - val_mean_squared_error: 1.9265
# Epoch 51/100
# 672/746 [==========================>...] - ETA: 0s - loss: 2.1033 - mean_squared_error: 2.1033
# Epoch 00051: saving model to ../experiments/local-results/NAB/PX4-QUAD-HITL/batch-32/NAB-PX4-QUAD-HITL-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 1s 777us/sample - loss: 2.0814 - mean_squared_error: 2.0814 - val_loss: 1.9171 - val_mean_squared_error: 1.9171
# Epoch 52/100
# 736/746 [============================>.] - ETA: 0s - loss: 2.0890 - mean_squared_error: 2.0890
# Epoch 00052: saving model to ../experiments/local-results/NAB/PX4-QUAD-HITL/batch-32/NAB-PX4-QUAD-HITL-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 497us/sample - loss: 2.0747 - mean_squared_error: 2.0747 - val_loss: 1.9136 - val_mean_squared_error: 1.9136
# Epoch 53/100
# 640/746 [========================>.....] - ETA: 0s - loss: 1.9968 - mean_squared_error: 1.9968
# Epoch 00053: saving model to ../experiments/local-results/NAB/PX4-QUAD-HITL/batch-32/NAB-PX4-QUAD-HITL-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 1s 685us/sample - loss: 2.0680 - mean_squared_error: 2.0680 - val_loss: 1.9088 - val_mean_squared_error: 1.9088
# Epoch 54/100
# 672/746 [==========================>...] - ETA: 0s - loss: 2.0514 - mean_squared_error: 2.0514
# Epoch 00054: saving model to ../experiments/local-results/NAB/PX4-QUAD-HITL/batch-32/NAB-PX4-QUAD-HITL-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 468us/sample - loss: 2.0614 - mean_squared_error: 2.0614 - val_loss: 1.9034 - val_mean_squared_error: 1.9034
# Epoch 55/100
# 608/746 [=======================>......] - ETA: 0s - loss: 2.1056 - mean_squared_error: 2.1056
# Epoch 00055: saving model to ../experiments/local-results/NAB/PX4-QUAD-HITL/batch-32/NAB-PX4-QUAD-HITL-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 1s 684us/sample - loss: 2.0556 - mean_squared_error: 2.0556 - val_loss: 1.9006 - val_mean_squared_error: 1.9006
# Epoch 56/100
# 640/746 [========================>.....] - ETA: 0s - loss: 2.0130 - mean_squared_error: 2.0130
# Epoch 00056: saving model to ../experiments/local-results/NAB/PX4-QUAD-HITL/batch-32/NAB-PX4-QUAD-HITL-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 470us/sample - loss: 2.0520 - mean_squared_error: 2.0520 - val_loss: 1.8924 - val_mean_squared_error: 1.8924
# Epoch 57/100
# 608/746 [=======================>......] - ETA: 0s - loss: 2.0821 - mean_squared_error: 2.0821
# Epoch 00057: saving model to ../experiments/local-results/NAB/PX4-QUAD-HITL/batch-32/NAB-PX4-QUAD-HITL-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 646us/sample - loss: 2.0433 - mean_squared_error: 2.0433 - val_loss: 1.8928 - val_mean_squared_error: 1.8928
# Epoch 58/100
# 672/746 [==========================>...] - ETA: 0s - loss: 2.0783 - mean_squared_error: 2.0783
# Epoch 00058: saving model to ../experiments/local-results/NAB/PX4-QUAD-HITL/batch-32/NAB-PX4-QUAD-HITL-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 467us/sample - loss: 2.0372 - mean_squared_error: 2.0372 - val_loss: 1.8853 - val_mean_squared_error: 1.8853
# Epoch 59/100
# 608/746 [=======================>......] - ETA: 0s - loss: 2.0271 - mean_squared_error: 2.0271
# Epoch 00059: saving model to ../experiments/local-results/NAB/PX4-QUAD-HITL/batch-32/NAB-PX4-QUAD-HITL-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 665us/sample - loss: 2.0315 - mean_squared_error: 2.0315 - val_loss: 1.8816 - val_mean_squared_error: 1.8816
# Epoch 60/100
# 640/746 [========================>.....] - ETA: 0s - loss: 2.0163 - mean_squared_error: 2.0163
# Epoch 00060: saving model to ../experiments/local-results/NAB/PX4-QUAD-HITL/batch-32/NAB-PX4-QUAD-HITL-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 629us/sample - loss: 2.0255 - mean_squared_error: 2.0255 - val_loss: 1.8759 - val_mean_squared_error: 1.8759
# Epoch 61/100
# 736/746 [============================>.] - ETA: 0s - loss: 2.0219 - mean_squared_error: 2.0219
# Epoch 00061: saving model to ../experiments/local-results/NAB/PX4-QUAD-HITL/batch-32/NAB-PX4-QUAD-HITL-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 496us/sample - loss: 2.0200 - mean_squared_error: 2.0200 - val_loss: 1.8740 - val_mean_squared_error: 1.8740
# Epoch 62/100
# 736/746 [============================>.] - ETA: 0s - loss: 2.0163 - mean_squared_error: 2.0163
# Epoch 00062: saving model to ../experiments/local-results/NAB/PX4-QUAD-HITL/batch-32/NAB-PX4-QUAD-HITL-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 646us/sample - loss: 2.0141 - mean_squared_error: 2.0141 - val_loss: 1.8680 - val_mean_squared_error: 1.8680
# Epoch 63/100
# 640/746 [========================>.....] - ETA: 0s - loss: 2.0123 - mean_squared_error: 2.0123
# Epoch 00063: saving model to ../experiments/local-results/NAB/PX4-QUAD-HITL/batch-32/NAB-PX4-QUAD-HITL-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 471us/sample - loss: 2.0082 - mean_squared_error: 2.0082 - val_loss: 1.8642 - val_mean_squared_error: 1.8642
# Epoch 64/100
# 736/746 [============================>.] - ETA: 0s - loss: 2.0145 - mean_squared_error: 2.0145
# Epoch 00064: saving model to ../experiments/local-results/NAB/PX4-QUAD-HITL/batch-32/NAB-PX4-QUAD-HITL-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 1s 674us/sample - loss: 2.0036 - mean_squared_error: 2.0036 - val_loss: 1.8625 - val_mean_squared_error: 1.8625
# Epoch 65/100
# 640/746 [========================>.....] - ETA: 0s - loss: 2.0342 - mean_squared_error: 2.0342
# Epoch 00065: saving model to ../experiments/local-results/NAB/PX4-QUAD-HITL/batch-32/NAB-PX4-QUAD-HITL-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 481us/sample - loss: 1.9985 - mean_squared_error: 1.9985 - val_loss: 1.8581 - val_mean_squared_error: 1.8581
# Epoch 66/100
# 640/746 [========================>.....] - ETA: 0s - loss: 1.9968 - mean_squared_error: 1.9968
# Epoch 00066: saving model to ../experiments/local-results/NAB/PX4-QUAD-HITL/batch-32/NAB-PX4-QUAD-HITL-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 663us/sample - loss: 1.9929 - mean_squared_error: 1.9929 - val_loss: 1.8532 - val_mean_squared_error: 1.8532
# Epoch 67/100
# 640/746 [========================>.....] - ETA: 0s - loss: 2.0326 - mean_squared_error: 2.0326
# Epoch 00067: saving model to ../experiments/local-results/NAB/PX4-QUAD-HITL/batch-32/NAB-PX4-QUAD-HITL-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 611us/sample - loss: 1.9873 - mean_squared_error: 1.9873 - val_loss: 1.8506 - val_mean_squared_error: 1.8506
# Epoch 68/100
# 640/746 [========================>.....] - ETA: 0s - loss: 1.9579 - mean_squared_error: 1.9579
# Epoch 00068: saving model to ../experiments/local-results/NAB/PX4-QUAD-HITL/batch-32/NAB-PX4-QUAD-HITL-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 1s 783us/sample - loss: 1.9830 - mean_squared_error: 1.9830 - val_loss: 1.8444 - val_mean_squared_error: 1.8444
# Epoch 69/100
# 672/746 [==========================>...] - ETA: 0s - loss: 1.9889 - mean_squared_error: 1.9889
# Epoch 00069: saving model to ../experiments/local-results/NAB/PX4-QUAD-HITL/batch-32/NAB-PX4-QUAD-HITL-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 491us/sample - loss: 1.9790 - mean_squared_error: 1.9790 - val_loss: 1.8455 - val_mean_squared_error: 1.8455
# Epoch 70/100
# 704/746 [===========================>..] - ETA: 0s - loss: 1.9798 - mean_squared_error: 1.9798
# Epoch 00070: saving model to ../experiments/local-results/NAB/PX4-QUAD-HITL/batch-32/NAB-PX4-QUAD-HITL-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 1s 796us/sample - loss: 1.9723 - mean_squared_error: 1.9723 - val_loss: 1.8388 - val_mean_squared_error: 1.8388
# Epoch 71/100
# 736/746 [============================>.] - ETA: 0s - loss: 1.9670 - mean_squared_error: 1.9670
# Epoch 00071: saving model to ../experiments/local-results/NAB/PX4-QUAD-HITL/batch-32/NAB-PX4-QUAD-HITL-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 627us/sample - loss: 1.9675 - mean_squared_error: 1.9675 - val_loss: 1.8349 - val_mean_squared_error: 1.8349
# Epoch 72/100
# 736/746 [============================>.] - ETA: 0s - loss: 1.9645 - mean_squared_error: 1.9645
# Epoch 00072: saving model to ../experiments/local-results/NAB/PX4-QUAD-HITL/batch-32/NAB-PX4-QUAD-HITL-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 1s 739us/sample - loss: 1.9635 - mean_squared_error: 1.9635 - val_loss: 1.8335 - val_mean_squared_error: 1.8335
# Epoch 73/100
# 608/746 [=======================>......] - ETA: 0s - loss: 1.9772 - mean_squared_error: 1.9772
# Epoch 00073: saving model to ../experiments/local-results/NAB/PX4-QUAD-HITL/batch-32/NAB-PX4-QUAD-HITL-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 493us/sample - loss: 1.9610 - mean_squared_error: 1.9610 - val_loss: 1.8277 - val_mean_squared_error: 1.8277
# Epoch 74/100
# 640/746 [========================>.....] - ETA: 0s - loss: 1.9296 - mean_squared_error: 1.9296
# Epoch 00074: saving model to ../experiments/local-results/NAB/PX4-QUAD-HITL/batch-32/NAB-PX4-QUAD-HITL-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 657us/sample - loss: 1.9541 - mean_squared_error: 1.9541 - val_loss: 1.8241 - val_mean_squared_error: 1.8241
# Epoch 75/100
# 704/746 [===========================>..] - ETA: 0s - loss: 1.9821 - mean_squared_error: 1.9821
# Epoch 00075: saving model to ../experiments/local-results/NAB/PX4-QUAD-HITL/batch-32/NAB-PX4-QUAD-HITL-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 547us/sample - loss: 1.9496 - mean_squared_error: 1.9496 - val_loss: 1.8210 - val_mean_squared_error: 1.8210
# Epoch 76/100
# 640/746 [========================>.....] - ETA: 0s - loss: 1.9225 - mean_squared_error: 1.9225
# Epoch 00076: saving model to ../experiments/local-results/NAB/PX4-QUAD-HITL/batch-32/NAB-PX4-QUAD-HITL-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 1s 688us/sample - loss: 1.9443 - mean_squared_error: 1.9443 - val_loss: 1.8170 - val_mean_squared_error: 1.8170
# Epoch 77/100
# 736/746 [============================>.] - ETA: 0s - loss: 1.9321 - mean_squared_error: 1.9321
# Epoch 00077: saving model to ../experiments/local-results/NAB/PX4-QUAD-HITL/batch-32/NAB-PX4-QUAD-HITL-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 522us/sample - loss: 1.9403 - mean_squared_error: 1.9403 - val_loss: 1.8148 - val_mean_squared_error: 1.8148
# Epoch 78/100
# 640/746 [========================>.....] - ETA: 0s - loss: 1.9481 - mean_squared_error: 1.9481
# Epoch 00078: saving model to ../experiments/local-results/NAB/PX4-QUAD-HITL/batch-32/NAB-PX4-QUAD-HITL-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 637us/sample - loss: 1.9355 - mean_squared_error: 1.9355 - val_loss: 1.8093 - val_mean_squared_error: 1.8093
# Epoch 79/100
# 640/746 [========================>.....] - ETA: 0s - loss: 1.9083 - mean_squared_error: 1.9083
# Epoch 00079: saving model to ../experiments/local-results/NAB/PX4-QUAD-HITL/batch-32/NAB-PX4-QUAD-HITL-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 576us/sample - loss: 1.9323 - mean_squared_error: 1.9323 - val_loss: 1.8061 - val_mean_squared_error: 1.8061
# Epoch 80/100
# 672/746 [==========================>...] - ETA: 0s - loss: 1.9134 - mean_squared_error: 1.9134
# Epoch 00080: saving model to ../experiments/local-results/NAB/PX4-QUAD-HITL/batch-32/NAB-PX4-QUAD-HITL-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 625us/sample - loss: 1.9269 - mean_squared_error: 1.9269 - val_loss: 1.8028 - val_mean_squared_error: 1.8028
# Epoch 81/100
# 736/746 [============================>.] - ETA: 0s - loss: 1.9255 - mean_squared_error: 1.9255
# Epoch 00081: saving model to ../experiments/local-results/NAB/PX4-QUAD-HITL/batch-32/NAB-PX4-QUAD-HITL-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 526us/sample - loss: 1.9225 - mean_squared_error: 1.9225 - val_loss: 1.7999 - val_mean_squared_error: 1.7999
# Epoch 82/100
# 608/746 [=======================>......] - ETA: 0s - loss: 1.9417 - mean_squared_error: 1.9417
# Epoch 00082: saving model to ../experiments/local-results/NAB/PX4-QUAD-HITL/batch-32/NAB-PX4-QUAD-HITL-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 1s 683us/sample - loss: 1.9187 - mean_squared_error: 1.9187 - val_loss: 1.7959 - val_mean_squared_error: 1.7959
# Epoch 83/100
# 640/746 [========================>.....] - ETA: 0s - loss: 1.9145 - mean_squared_error: 1.9145
# Epoch 00083: saving model to ../experiments/local-results/NAB/PX4-QUAD-HITL/batch-32/NAB-PX4-QUAD-HITL-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 487us/sample - loss: 1.9143 - mean_squared_error: 1.9143 - val_loss: 1.7916 - val_mean_squared_error: 1.7916
# Epoch 84/100
# 608/746 [=======================>......] - ETA: 0s - loss: 1.9189 - mean_squared_error: 1.9189
# Epoch 00084: saving model to ../experiments/local-results/NAB/PX4-QUAD-HITL/batch-32/NAB-PX4-QUAD-HITL-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 1s 686us/sample - loss: 1.9109 - mean_squared_error: 1.9109 - val_loss: 1.7889 - val_mean_squared_error: 1.7889
# Epoch 85/100
# 736/746 [============================>.] - ETA: 0s - loss: 1.9207 - mean_squared_error: 1.9207
# Epoch 00085: saving model to ../experiments/local-results/NAB/PX4-QUAD-HITL/batch-32/NAB-PX4-QUAD-HITL-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 666us/sample - loss: 1.9066 - mean_squared_error: 1.9066 - val_loss: 1.7857 - val_mean_squared_error: 1.7857
# Epoch 86/100
# 736/746 [============================>.] - ETA: 0s - loss: 1.8931 - mean_squared_error: 1.8931
# Epoch 00086: saving model to ../experiments/local-results/NAB/PX4-QUAD-HITL/batch-32/NAB-PX4-QUAD-HITL-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 1s 693us/sample - loss: 1.9027 - mean_squared_error: 1.9027 - val_loss: 1.7832 - val_mean_squared_error: 1.7832
# Epoch 87/100
# 672/746 [==========================>...] - ETA: 0s - loss: 1.8988 - mean_squared_error: 1.8988
# Epoch 00087: saving model to ../experiments/local-results/NAB/PX4-QUAD-HITL/batch-32/NAB-PX4-QUAD-HITL-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 652us/sample - loss: 1.8992 - mean_squared_error: 1.8992 - val_loss: 1.7817 - val_mean_squared_error: 1.7817
# Epoch 88/100
# 736/746 [============================>.] - ETA: 0s - loss: 1.9033 - mean_squared_error: 1.9033
# Epoch 00088: saving model to ../experiments/local-results/NAB/PX4-QUAD-HITL/batch-32/NAB-PX4-QUAD-HITL-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 1s 737us/sample - loss: 1.8950 - mean_squared_error: 1.8950 - val_loss: 1.7782 - val_mean_squared_error: 1.7782
# Epoch 89/100
# 672/746 [==========================>...] - ETA: 0s - loss: 1.8771 - mean_squared_error: 1.8771
# Epoch 00089: saving model to ../experiments/local-results/NAB/PX4-QUAD-HITL/batch-32/NAB-PX4-QUAD-HITL-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 478us/sample - loss: 1.8916 - mean_squared_error: 1.8916 - val_loss: 1.7751 - val_mean_squared_error: 1.7751
# Epoch 90/100
# 736/746 [============================>.] - ETA: 0s - loss: 1.8862 - mean_squared_error: 1.8862
# Epoch 00090: saving model to ../experiments/local-results/NAB/PX4-QUAD-HITL/batch-32/NAB-PX4-QUAD-HITL-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 1s 703us/sample - loss: 1.8872 - mean_squared_error: 1.8872 - val_loss: 1.7733 - val_mean_squared_error: 1.7733
# Epoch 91/100
# 672/746 [==========================>...] - ETA: 0s - loss: 1.9046 - mean_squared_error: 1.9046
# Epoch 00091: saving model to ../experiments/local-results/NAB/PX4-QUAD-HITL/batch-32/NAB-PX4-QUAD-HITL-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 1s 680us/sample - loss: 1.8839 - mean_squared_error: 1.8839 - val_loss: 1.7663 - val_mean_squared_error: 1.7663
# Epoch 92/100
# 704/746 [===========================>..] - ETA: 0s - loss: 1.9019 - mean_squared_error: 1.9019
# Epoch 00092: saving model to ../experiments/local-results/NAB/PX4-QUAD-HITL/batch-32/NAB-PX4-QUAD-HITL-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 1s 747us/sample - loss: 1.8813 - mean_squared_error: 1.8813 - val_loss: 1.7648 - val_mean_squared_error: 1.7648
# Epoch 93/100
# 672/746 [==========================>...] - ETA: 0s - loss: 1.8888 - mean_squared_error: 1.8888
# Epoch 00093: saving model to ../experiments/local-results/NAB/PX4-QUAD-HITL/batch-32/NAB-PX4-QUAD-HITL-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 643us/sample - loss: 1.8752 - mean_squared_error: 1.8752 - val_loss: 1.7602 - val_mean_squared_error: 1.7602
# Epoch 94/100
# 640/746 [========================>.....] - ETA: 0s - loss: 1.8860 - mean_squared_error: 1.8860
# Epoch 00094: saving model to ../experiments/local-results/NAB/PX4-QUAD-HITL/batch-32/NAB-PX4-QUAD-HITL-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 668us/sample - loss: 1.8732 - mean_squared_error: 1.8732 - val_loss: 1.7592 - val_mean_squared_error: 1.7592
# Epoch 95/100
# 640/746 [========================>.....] - ETA: 0s - loss: 1.8298 - mean_squared_error: 1.8298
# Epoch 00095: saving model to ../experiments/local-results/NAB/PX4-QUAD-HITL/batch-32/NAB-PX4-QUAD-HITL-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 635us/sample - loss: 1.8694 - mean_squared_error: 1.8694 - val_loss: 1.7547 - val_mean_squared_error: 1.7547
# Epoch 96/100
# 736/746 [============================>.] - ETA: 0s - loss: 1.8531 - mean_squared_error: 1.8531
# Epoch 00096: saving model to ../experiments/local-results/NAB/PX4-QUAD-HITL/batch-32/NAB-PX4-QUAD-HITL-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 1s 755us/sample - loss: 1.8660 - mean_squared_error: 1.8660 - val_loss: 1.7531 - val_mean_squared_error: 1.7531
# Epoch 97/100
# 736/746 [============================>.] - ETA: 0s - loss: 1.8642 - mean_squared_error: 1.8642
# Epoch 00097: saving model to ../experiments/local-results/NAB/PX4-QUAD-HITL/batch-32/NAB-PX4-QUAD-HITL-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 662us/sample - loss: 1.8618 - mean_squared_error: 1.8618 - val_loss: 1.7502 - val_mean_squared_error: 1.7502
# Epoch 98/100
# 608/746 [=======================>......] - ETA: 0s - loss: 1.8831 - mean_squared_error: 1.8831
# Epoch 00098: saving model to ../experiments/local-results/NAB/PX4-QUAD-HITL/batch-32/NAB-PX4-QUAD-HITL-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 667us/sample - loss: 1.8586 - mean_squared_error: 1.8586 - val_loss: 1.7477 - val_mean_squared_error: 1.7477
# Epoch 99/100
# 640/746 [========================>.....] - ETA: 0s - loss: 1.8461 - mean_squared_error: 1.8461
# Epoch 00099: saving model to ../experiments/local-results/NAB/PX4-QUAD-HITL/batch-32/NAB-PX4-QUAD-HITL-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 0s 493us/sample - loss: 1.8552 - mean_squared_error: 1.8552 - val_loss: 1.7441 - val_mean_squared_error: 1.7441
# Epoch 100/100
# 608/746 [=======================>......] - ETA: 0s - loss: 1.8397 - mean_squared_error: 1.8397
# Epoch 00100: saving model to ../experiments/local-results/NAB/PX4-QUAD-HITL/batch-32/NAB-PX4-QUAD-HITL-24-3-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 746/746 [==============================] - 1s 670us/sample - loss: 1.8523 - mean_squared_error: 1.8523 - val_loss: 1.7401 - val_mean_squared_error: 1.7401
# (83, 2, 6)
# Decoded seq from VAE: (3, 24)
# Decoded seq from lstm: (2, 24)
# Decoded seq from VAE: (3, 24)
# Decoded seq from lstm: (2, 24)
# Decoded seq from VAE: (3, 24)
# Decoded seq from lstm: (2, 24)
# Decoded seq from VAE: (3, 24)
# Decoded seq from lstm: (2, 24)
# Decoded seq from VAE: (3, 24)
# Decoded seq from lstm: (2, 24)
# Decoded seq from VAE: (3, 24)
# Decoded seq from lstm: (2, 24)
# Decoded seq from VAE: (3, 24)
# Decoded seq from lstm: (2, 24)
# Decoded seq from VAE: (3, 24)
# Decoded seq from lstm: (2, 24)
# Decoded seq from VAE: (3, 24)
# Decoded seq from lstm: (2, 24)
# Decoded seq from VAE: (3, 24)
# Decoded seq from lstm: (2, 24)

# %%
# load normalised time series
save_dir = '../datasets/' + config['data_dir'] #NAB-known-anomaly/'
dataset = config['dataset']
filename = '{}.npz'.format(dataset)
result = dict(np.load(save_dir+filename, allow_pickle=True))
if dataset == 'machine_temp':
    result['test'] = result['test'][0]
    result['idx_anomaly_test'] = result['idx_anomaly_test'][0]
    result['t_test'] = result['t_test'][0]

# slice into rolling windows and rolling sequences
def slice_rolling_windows_and_sequences(config, time_seq):
    n_sample = len(time_seq)
    print("The given sequence has {} samples".format(n_sample))
    n_vae_win = n_sample - config['l_win'] + 1
    rolling_windows = np.zeros((n_vae_win, config['l_win']))
    for i in range(n_vae_win):
        rolling_windows[i] = time_seq[i:i + config['l_win']]
        sample_m = np.mean(rolling_windows, axis=1)
        sample_std = np.std(rolling_windows, axis=1)

        n_lstm_seq = n_sample - config['l_seq']*config['l_win']+1
        lstm_seq = np.zeros((n_lstm_seq, config['l_seq'], config['l_win']))
    for i in range(n_lstm_seq):
        cur_seq = time_seq[i:i+config['l_seq']*config['l_win']]
        for j in range(config['l_seq']):
            lstm_seq[i,j] = cur_seq[config['l_win']*j:config['l_win']*(j+1)]
    
    return rolling_windows, lstm_seq, sample_m, sample_std

test_windows, test_seq, test_sample_m, test_sample_std = slice_rolling_windows_and_sequences(config, result['test'])
test_windows = np.expand_dims(test_windows, -1)
test_seq = np.expand_dims(test_seq, -1)
print(test_windows.shape)
print(test_seq.shape)
# Out:
# The given sequence has 1113 samples
# (1090, 24, 1)
# (1042, 3, 24, 1)

# %%
# Evaluate ELBO and LSTM prediction error on the validation set
# evaluate some anomaly detection metrics
def evaluate_vae_anomaly_metrics_for_a_window(test_win):
    feed_dict = {model_vae.original_signal: np.expand_dims(test_win, 0),
                 model_vae.is_code_input: False,
                 model_vae.code_input: np.zeros((1, config['code_size']))}

    # VAE reconstruction error
    recons_win_vae = np.squeeze(sess.run(model_vae.decoded, feed_dict=feed_dict))
    test_vae_recons_error = np.sum(np.square(recons_win_vae - test_win))

    # VAE latent embedding likelihood
    vae_code_mean, vae_code_std = sess.run([model_vae.code_mean, model_vae.code_std_dev], feed_dict=feed_dict)
    test_vae_kl = 0.5 * (np.sum(np.square(vae_code_mean)) + \
                            np.sum(np.square(vae_code_std)) - \
                            np.sum(np.log(np.square(vae_code_std))) - config['code_size'])

    # VAE ELBO loss
    sigma2 = 0.0005
    input_dims = model_vae.input_dims
    sigma_regularisor = input_dims/2. * np.log(sigma2) + input_dims * np.pi
    test_vae_elbo = test_vae_recons_error/sigma2 + test_vae_kl + sigma_regularisor
    return test_vae_recons_error, test_vae_kl, test_vae_elbo

def evaluate_lstm_anomaly_metric_for_a_seq(test_seq):
    feed_dict = {model_vae.original_signal: test_seq,
                 model_vae.is_code_input: False,
                 model_vae.code_input: np.zeros((1, config['code_size']))}
    vae_embedding = np.squeeze(sess.run(model_vae.code_mean, feed_dict=feed_dict))
    #print(vae_embedding.shape)
    lstm_embedding = np.squeeze(lstm_nn_model.predict(np.expand_dims(vae_embedding[:config['l_seq']-1], 0), batch_size=1))
    lstm_embedding_error = np.sum(np.square(vae_embedding[1:] - lstm_embedding))
    
    # LSTM prediction error
    feed_dict_lstm = {model_vae.original_signal: np.zeros((config['l_seq'] - 1, config['l_win'], 1)),
                      model_vae.is_code_input: True,
                      model_vae.code_input: lstm_embedding}
    recons_win_lstm = np.squeeze(sess.run(model_vae.decoded, feed_dict=feed_dict_lstm))
    lstm_recons_error = np.sum(np.square(recons_win_lstm - np.squeeze(test_seq[1:])))
    return lstm_recons_error, lstm_embedding_error

n_val_vae = data.val_set_vae['data'].shape[0]
n_val_lstm = data.val_set_lstm['data'].shape[0]

val_vae_recons_error = np.zeros(n_val_vae)
val_vae_kl_error = np.zeros(n_val_vae)
val_vae_elbo_loss = np.zeros(n_val_vae)
for i in range(n_val_vae):
    val_vae_recons_error[i], val_vae_kl_error[i], val_vae_elbo_loss[i] = evaluate_vae_anomaly_metrics_for_a_window(data.val_set_vae['data'][i])

val_lstm_recons_error, val_lstm_embedding_error = np.zeros(n_val_lstm), np.zeros(n_val_lstm)
for i in range(n_val_lstm):
    val_lstm_recons_error[i], val_lstm_embedding_error[i] = evaluate_lstm_anomaly_metric_for_a_seq(data.val_set_lstm['data'][i])

# %%
from scipy.stats import norm
def plot_histogram(test_anomaly_metric, n_bins, title, mean=None, std=None, xlim=None, saveplot=False):
    test_anomaly_list = np.squeeze(np.ndarray.flatten(test_anomaly_metric))
    his = plt.hist(test_anomaly_list, bins=n_bins, density=True)
    if mean is None and std is None:
        mean = np.mean(test_anomaly_list)
        std = np.std(test_anomaly_list)
        legend_label = None
    else:
        legend_label = 1
    x_axis = np.arange(mean-5*std, mean+5*std, std/100)
    plt.plot(x_axis, norm.pdf(x_axis,mean,std))
    plt.title(title)
    plt.xlabel('anomaly score value')
    plt.ylabel('probability density')
    if xlim is not None:
        plt.xlim(0, xlim)
    else:
        plt.xlim(0, np.amax(test_anomaly_list))
    if legend_label is None:
        plt.legend(('Fitted Gaussian', 'histogram'))
    else:
        plt.legend(('normal data distribution','test data distribution (contain anomalies)'))
    if saveplot:
        savefig(config['result_dir']+'reconstruction_error_histogram.pdf')
    else:
        plt.show()
    threshold_25 = np.percentile(test_anomaly_list, 25)
    threshold_75 = np.percentile(test_anomaly_list, 75)
    threshold_1 = np.percentile(test_anomaly_list, 99)
    idx_large_error = np.squeeze(np.argwhere(test_anomaly_metric > threshold_1))
#     print(his[0][-20:])
#     print(his[1][-20:])
    print("25% percentile: {}".format(threshold_25))
    print("75% percentile: {}".format(threshold_75))
#     print("Median: {}".format(np.median(test_anomaly_list)))
#     print("Mean: {}".format(np.mean(test_anomaly_list)))
#     print("Std dev: {}".format(np.std(test_anomaly_list)))
    print("These windows scored the top 1% of anomaly metric ({}): \n{}".format(threshold_1, idx_large_error))
    return mean, std

# %%
# Histogram of VAE ELBO loss - validation set
vae_elbo_m, vae_elbo_std = plot_histogram(val_vae_elbo_loss, 100, 
                                          'VAE ELBO error distribution on the val set', 
                                          mean=None, std=None, xlim=None)
# Out:
# 25% percentile: 12060.107182403228
# 75% percentile: 3542031.3491219417
# These windows scored the top 1% of anomaly metric (8263299.025187218):
# 51

# %%
# Histogram of LSTM reconstruction error - validation set 
#  --> to decide the anomaly detection threshold
lstm_recons_m, lstm_recons_std = plot_histogram(val_lstm_recons_error, 100,  
                                              'LSTM reconstruction error distribution on the val set', 
                                              mean=None, std=None, xlim=None)
# Out:
# 25% percentile: 5.35275223887823
# 75% percentile: 51.5734807352959
# These windows scored the top 1% of anomaly metric (110.19389282069984):
# 32

# %%
# Evaluate the anomaly metrics on the test windows and sequences
n_test_lstm = test_seq.shape[0]

test_lstm_recons_error, test_lstm_embedding_error = np.zeros(n_test_lstm), np.zeros(n_test_lstm)
for i in range(n_test_lstm):
    test_lstm_recons_error[i], test_lstm_embedding_error[i] = evaluate_lstm_anomaly_metric_for_a_seq(test_seq[i])
print("All windows' reconstruction error is computed.")
print("The total number of windows is {}".format(len(test_lstm_recons_error)))
# Out:
# All windows' reconstruction error is computed.
# The total number of windows is 1042

# %%
# Histogram of LSTM reconstruction error - test set 
#  --> to detect anomaly now
_, _ = plot_histogram(test_lstm_recons_error, 100,
                      'LSTM reconstruction error distribution on the test set', 
                      mean=lstm_recons_m, std=lstm_recons_std, xlim=None, saveplot=True)
# Out:
# 25% percentile: 54.463025882096396
# 75% percentile: 216.79348267831466
# These windows scored the top 1% of anomaly metric (255.90989175095035):
# [830 831 832 833 834 835 836 837 838 839 842]

# %%
# Produce the ground truth anomaly indices 
# if result['idx_split'][0] == 0:
#     idx_anomaly_test = result['idx_anomaly_test']
# else:
#     idx_anomaly_test = result['idx_anomaly_test'][0]
idx_anomaly_test = result['idx_anomaly_test']    
anomaly_index_lstm = []
test_labels_lstm = np.zeros(n_test_lstm)
for i in range(len(idx_anomaly_test)):
    idx_start = idx_anomaly_test[i]-(config['l_win']*config['l_seq']-1)
    idx_end = idx_anomaly_test[i]+1
    if idx_start < 0:
        idx_start = 0
    if idx_end > n_test_lstm:
        idx_end = n_test_lstm
    anomaly_index_lstm.append(np.arange(idx_start,idx_end))
    test_labels_lstm[idx_start:idx_end] = 1
    
print(test_labels_lstm.shape)
# Out:
# (1042,)

# %%
def return_anomaly_idx_by_threshold(test_anomaly_metric, threshold):
    test_list = np.squeeze(np.ndarray.flatten(test_anomaly_metric))
    idx_error = np.squeeze(np.argwhere(test_anomaly_metric > threshold))
    
    if len(idx_error.shape) == 0:
        idx_error = np.expand_dims(idx_error, 0)
    
    return list(idx_error)

# %%
def augment_detected_idx(idx_detected_anomaly, anomaly_index):
    n_anomaly = len(anomaly_index)
    idx_detected_anomaly_extended = list(idx_detected_anomaly)
    for i in range(n_anomaly):
        #print(idx_detected_anomaly)
        for j in idx_detected_anomaly:
            if j in anomaly_index[i]:
                in_original_detection = set(idx_detected_anomaly_extended)
                currect_anomaly_win = set(anomaly_index[i])
                idx_detected_anomaly_extended = idx_detected_anomaly_extended + list(currect_anomaly_win - in_original_detection)
                #print(j)
                break
                
    return list(np.sort(idx_detected_anomaly_extended))

# %%
def count_TP_FP_FN(idx_detected_anomaly, anomaly_index, test_labels):
    n_TP = 0
    n_FP = 0
    n_detection = len(idx_detected_anomaly)
    for i in range(n_detection):
        if test_labels[idx_detected_anomaly[i]] == 1:
            n_TP = n_TP + 1
        else:
            n_FP = n_FP + 1
    
    idx_undetected = list(set(np.arange(len(test_labels)))- set(idx_detected_anomaly))
    n_FN = 0
    for i in idx_undetected:
        if test_labels[i] == 1:
            n_FN = n_FN + 1
    
    return n_TP, n_FP, n_FN

# %%
def compute_precision_and_recall(idx_detected_anomaly, anomaly_index, test_labels):
    # compute true positive
    n_TP, n_FP, n_FN = count_TP_FP_FN(idx_detected_anomaly, anomaly_index, test_labels)
    
    if n_TP + n_FP == 0:
        precision = 1
    else:
        precision = n_TP / (n_TP + n_FP)
    recall = n_TP / (n_TP + n_FN)
    if precision + recall == 0:
        F1 = 0
    else:
        F1 = 2* (precision * recall)/(precision + recall)
    
    return precision, recall, F1, n_TP, n_FP, n_FN

# %%
n_threshold = 200
precision = np.zeros(n_threshold)
recall = np.zeros(n_threshold)
F1 = np.zeros(n_threshold)
precision_aug = np.zeros(n_threshold)
recall_aug = np.zeros(n_threshold)
F1_aug = np.zeros(n_threshold)
i = 0
threshold_list = np.linspace(np.amin(test_lstm_recons_error), np.amax(test_lstm_recons_error), n_threshold, endpoint=True)
threshold_list = np.flip(threshold_list)
for threshold in threshold_list:
    #print(threshold_list[i])
    idx_detection_lstm = return_anomaly_idx_by_threshold(test_lstm_recons_error, threshold)
    precision[i], recall[i], F1[i], _, _, _ = compute_precision_and_recall(idx_detection_lstm, 
                                                                           anomaly_index_lstm, 
                                                                           test_labels_lstm)
    # augment the detection using the ground truth labels
    # a method to discount the factor one anomaly appears in multiple consecutive windows
    # introduced in "Unsupervised anomaly detection via variational auto-encoder for seasonal kpis in web applications"
    idx_detection_lstm_augmented = augment_detected_idx(idx_detection_lstm, anomaly_index_lstm)
    precision_aug[i], recall_aug[i], F1_aug[i], _, _, _ = compute_precision_and_recall(idx_detection_lstm_augmented, 
                                                                                       anomaly_index_lstm, 
                                                                                       test_labels_lstm)
    i = i + 1
    #print(precision, recall, F1)

# %%
print("Best F1 score is {}".format(np.amax(F1)))
idx_best_threshold = np.squeeze(np.argwhere(F1 == np.amax(F1)))
print("Best threshold is {}".format(threshold_list[idx_best_threshold]))
print("At this threshold, precision is {}, recall is {}".format(precision[idx_best_threshold], recall[idx_best_threshold]))
average_precision = np.sum(precision[1:] * (recall[1:] - recall[:-1]))
print("Average precision is {}".format(average_precision))

print("\nAugmented detection:")
print("Best F1 score is {}".format(np.amax(F1_aug)))
idx_best_threshold = np.squeeze(np.argwhere(F1_aug == np.amax(F1_aug)))
print("Best threshold is {}".format(threshold_list[idx_best_threshold]))
print("At this threshold, precision is {}, recall is {}".format(precision_aug[idx_best_threshold], 
                                                                recall_aug[idx_best_threshold]))

average_precision_aug = np.sum(precision_aug[1:] * (recall_aug[1:] - recall_aug[:-1]))
print("Average precision is {}".format(average_precision_aug))
# Out:
# Best F1 score is 0.1491891891891892
# Best threshold is 38.08963620080759
# At this threshold, precision is 0.08089097303634232, recall is 0.9583333333333334
# Average precision is 0.049576203814381326
#
# Augmented detection:
# Best F1 score is 0.26373626373626374
# Best threshold is 130.35386199249322
# At this threshold, precision is 0.1518987341772152, recall is 1.0
# Average precision is 0.1518987341772152

# %%
# Now select a threshold
threshold = 130

print("Threshold is {}".format(threshold))
idx_detection = return_anomaly_idx_by_threshold(test_lstm_recons_error, threshold)
idx_detection_augmented = augment_detected_idx(idx_detection, anomaly_index_lstm)
precision, recall, F1, n_TP, n_FP, n_FN = compute_precision_and_recall(idx_detection_augmented, 
                                                                       anomaly_index_lstm, 
                                                                       test_labels_lstm)
print("\nPR evaluation using augmented detection:")
print("Precision: {}".format(precision))
print("Recall: {}".format(recall))
print("F1: {}".format(F1))
print("TP: {}".format(n_TP))
print("FP: {}".format(n_FP))
print("FN: {}".format(n_FN))
# Out:
# Threshold is 130
#
# PR evaluation using augmented detection:
# Precision: 0.15157894736842106
# Recall: 1.0
# F1: 0.26325411334552107
# TP: 72
# FP: 403
# FN: 0

# %%
def slice_detected_indices_into_seq(idx_detection, interval):
    detected_seq = []
    i = 0
    while i < len(idx_detection):
        if i == 0:
            cur_seq = [idx_detection[i]]
            i = i + 1
        else:
            if idx_detection[i] - idx_detection[i-1] > interval:
                detected_seq.append(cur_seq)
                cur_seq = [idx_detection[i]]
            else:
                cur_seq.append(idx_detection[i])
                if i == len(idx_detection) - 1:
                    detected_seq.append(cur_seq)
            i = i + 1
    
    print("Detected {} sequences".format(len(detected_seq)))
    return detected_seq

# %%
def plot_detected_anomalies(idx_detection, interval, dataset, result, detection_method, augmented_flag=1, y_scale=5, y_lim=None):
    detected_seq = slice_detected_indices_into_seq(idx_detection, interval=interval)
    t_test = result['t_test']
    test = result['test']
    idx_anomaly_test = result['idx_anomaly_test']
        
    # plot detected sequences
    fig, axs = plt.subplots(1, 1, figsize=(18, 5), edgecolor='k')
    fig.subplots_adjust(hspace=.4, wspace=.4)
    axs.plot(t_test, test)
    for j in range(len(idx_anomaly_test)):
        if j == 0:
            axs.plot(idx_anomaly_test[j] * np.ones(20), np.linspace(-y_scale, y_scale, 20), 'r--', label='true anomalies')
        else:
            axs.plot(idx_anomaly_test[j] * np.ones(20), np.linspace(-y_scale, y_scale, 20), 'r--')
        
    for i in range(len(detected_seq)):
        for j in detected_seq[i]:
            if j == detected_seq[0][0]:
                axs.plot((j+interval*2) * np.ones(20), np.linspace(-y_scale, -0.8*y_scale, 20), 'g-', label='detected anomalies')
            else:
                axs.plot((j+interval*2) * np.ones(20), np.linspace(-y_scale, -0.8*y_scale, 20), 'g-')
    
    for j in range(len(idx_anomaly_test)):
        axs.plot(idx_anomaly_test[j] * np.ones(20), np.linspace(-y_scale, y_scale, 20), 'r--')

    for i in range(len(detected_seq)):
        interval_x = np.asarray([detected_seq[i][0], detected_seq[i][-1]+interval*2])
        interval_y = np.asarray([y_scale,y_scale])
        if i == 0:
            axs.fill_between(interval_x, interval_y, alpha=0.2, color='y', label='detected anomaly windows')
        else:
            axs.fill_between(interval_x, interval_y, alpha=0.2, color='y')
        interval_y = np.asarray([-y_scale,-y_scale])
        axs.fill_between(interval_x, interval_y, alpha=0.2, color='y')
    axs.grid(True)
    axs.set_xlim(0, len(t_test))
    if y_lim is None:
        axs.set_ylim(-y_scale, y_scale)
    else:
        axs.set_ylim(-y_scale, y_lim)
    axs.set_xlabel("timestamp (every {})".format(result['t_unit']))
    axs.set_ylabel("normalised readings")
    axs.set_title("{} dataset test sequence\n(normalised by train mean {:.4f} and std {:.4f})\n Detection method: {}".format(dataset, 
                                                                                        result['train_m'], 
                                                                                        result['train_std'],
                                                                                        detection_method))
    axs.legend()
    savefig(config['result_dir']+'detected_anomalies_{}_aug_{}.pdf'.format(detection_method, augmented_flag))

# %%
plot_detected_anomalies(idx_detection_augmented, 
                        interval=config['l_win']*config['l_seq']/2, 
                        dataset=dataset, 
                        result=result, 
                        detection_method='lstm reconstruction error',
                        augmented_flag=1,
                        y_scale=5,
                        y_lim=5)
# Out:
# Detected 3 sequences
