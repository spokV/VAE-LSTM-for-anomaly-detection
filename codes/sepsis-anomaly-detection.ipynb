# %%
import tensorflow as tf
import tensorflow_probability as tfp
import numpy as np
import matplotlib.pylab as plt
from matplotlib.pyplot import plot, ion, show, savefig, cla, figure
import random
import time

# %%
import os
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"   # see issue #152
os.environ["CUDA_VISIBLE_DEVICES"]="0"

import tensorflow as tf
from data_loader_sepsis import DataGenerator
from models import VAEmodel, lstmKerasModel
from trainers import vaeTrainer

from utils import process_config, create_dirs, get_args

# %%
from tensorflow.python.client import device_lib

def get_available_gpus():
    local_device_protos = device_lib.list_local_devices()
    return [x.name for x in local_device_protos if x.device_type == 'GPU']

print(get_available_gpus())
# Out:
# []

# %%
# load VAE model
config = process_config('sepsis_config.json')
# create the experiments dirs
create_dirs([config['result_dir'], config['checkpoint_dir']])
# create tensorflow session
sess = tf.Session(config=tf.ConfigProto(log_device_placement=True))
# create your data generator
data = DataGenerator(config)
# create a CNN model
model_vae = VAEmodel(config)
# create a CNN model
trainer_vae = vaeTrainer(sess, model_vae, data, config)
model_vae.load(sess)

# here you train your model
if config['TRAIN_VAE']:
    if config['num_epochs_vae'] > 0:
        trainer_vae.train()
# Out:
# 52, sigma_regularisor: -331.5723, code_std_dev: [0.03976063 0.01608401 0.01385943 0.01983816 0.01421636 0.02389396]
# Loss on training and val sets:
# train: 1887.9881, val: 1970.6861
# Current sigma2: 0.0100000
# Already trained for 1.3090213616689046 min; Remaining 20.508001332812842 min.
# Saving model...
# Model saved.
# 3/49, test loss: -elbo: 2129.4663, recons_loss_weighted: 3931.9824, recons_loss_ls: 78.6397, KL_loss: 42.6579, sigma_regularisor: -331.5723, code_std_dev: [0.01383617 0.01       0.01       0.01164309 0.01490301 0.02850256]
# Loss on training and val sets:
# train: 1878.4664, val: 1898.8957
# Current sigma2: 0.0100000
# Already trained for 1.7512773474057515 min; Remaining 20.13968949516614 min.
# Saving model...
# Model saved.
# 4/49, test loss: -elbo: 2111.3704, recons_loss_weighted: 3897.0137, recons_loss_ls: 77.9403, KL_loss: 42.0464, sigma_regularisor: -331.5723, code_std_dev: [0.01681025 0.01       0.01385282 0.02444519 0.02050141 0.02690149]
# Loss on training and val sets:
# train: 1861.3392, val: 1941.4337
# Current sigma2: 0.0100000
# Already trained for 2.1788273056348166 min; Remaining 19.60944575071335 min.
# Saving model...
# Model saved.
# 5/49, test loss: -elbo: 2111.8909, recons_loss_weighted: 3898.1904, recons_loss_ls: 77.9638, KL_loss: 41.9786, sigma_regularisor: -331.5723, code_std_dev: [0.01067058 0.01       0.01       0.02072325 0.01223991 0.01      ]
# Loss on training and val sets:
# train: 1843.5817, val: 1924.1210
# Current sigma2: 0.0100000
# Already trained for 2.619063369433085 min; Remaining 19.20646470917596 min.
# Saving model...
# Model saved.
# 6/49, test loss: -elbo: 2106.6267, recons_loss_weighted: 3886.9282, recons_loss_ls: 77.7386, KL_loss: 42.3454, sigma_regularisor: -331.5723, code_std_dev: [0.01779364 0.01       0.01232225 0.01370435 0.01       0.01262862]
# Loss on training and val sets:
# train: 1829.2807, val: 1917.3976
# Current sigma2: 0.0100000
# Already trained for 3.053052540620168 min; Remaining 18.75446560666675 min.
# Saving model...
# Model saved.
# 7/49, test loss: -elbo: 2109.0828, recons_loss_weighted: 3891.8511, recons_loss_ls: 77.8370, KL_loss: 42.3400, sigma_regularisor: -331.5723, code_std_dev: [0.02138572 0.01       0.01392409 0.02894707 0.01706464 0.02641834]
# Loss on training and val sets:
# train: 1833.0771, val: 1908.7883
# Current sigma2: 0.0100000
# Already trained for 3.4938485185305277 min; Remaining 18.34270472228527 min.
# Saving model...
# Model saved.
# 8/49, test loss: -elbo: 2101.9529, recons_loss_weighted: 3878.1804, recons_loss_ls: 77.5636, KL_loss: 42.0457, sigma_regularisor: -331.5723, code_std_dev: [0.02240709 0.01       0.01       0.03260064 0.01       0.02168627]
# Loss on training and val sets:
# train: 1817.7029, val: 1923.6650
# Current sigma2: 0.0100000
# Already trained for 3.931328209241231 min; Remaining 17.909384064321166 min.
# Saving model...
# Model saved.
# 9/49, test loss: -elbo: 2095.5852, recons_loss_weighted: 3864.6558, recons_loss_ls: 77.2931, KL_loss: 42.4401, sigma_regularisor: -331.5723, code_std_dev: [0.02491806 0.01       0.01       0.02571662 0.01       0.0127145 ]
# Loss on training and val sets:
# train: 1803.2752, val: 1907.6476
# Current sigma2: 0.0100000
# Already trained for 4.369425197442372 min; Remaining 17.47770078976949 min.
# Saving model...
# Model saved.
# 10/49, test loss: -elbo: 2084.7546, recons_loss_weighted: 3841.6379, recons_loss_ls: 76.8328, KL_loss: 43.1187, sigma_regularisor: -331.5723, code_std_dev: [0.02029473 0.01       0.01180941 0.01986817 0.01       0.01869162]
# Loss on training and val sets:
# train: 1794.6993, val: 1913.3244
# Current sigma2: 0.0100000
# Already trained for 4.80898224512736 min; Remaining 17.050027959997003 min.
# Saving model...
# Model saved.
# 11/49, test loss: -elbo: 2078.5386, recons_loss_weighted: 3829.0073, recons_loss_ls: 76.5802, KL_loss: 43.2178, sigma_regularisor: -331.5723, code_std_dev: [0.01746294 0.01       0.01       0.02696332 0.01       0.01065481]
# Loss on training and val sets:
# train: 1786.3989, val: 1918.5512
# Current sigma2: 0.0100000
# Already trained for 5.2441080411275225 min; Remaining 16.606342130237156 min.
# Saving model...
# Model saved.
# 12/49, test loss: -elbo: 2078.9529, recons_loss_weighted: 3832.3242, recons_loss_ls: 76.6465, KL_loss: 41.9737, sigma_regularisor: -331.5723, code_std_dev: [0.03176946 0.01       0.01       0.03701209 0.01224654 0.01913641]
# Loss on training and val sets:
# train: 1775.7913, val: 1916.5087
# Current sigma2: 0.0100000
# Already trained for 5.691515119870504 min; Remaining 16.198927648862202 min.
# Saving model...
# Model saved.
# 13/49, test loss: -elbo: 2064.3384, recons_loss_weighted: 3801.7683, recons_loss_ls: 76.0354, KL_loss: 42.6372, sigma_regularisor: -331.5723, code_std_dev: [0.02084457 0.01       0.01050108 0.03596967 0.01200269 0.02273756]
# Loss on training and val sets:
# train: 1771.1588, val: 1907.1685
# Current sigma2: 0.0100000
# Already trained for 6.112428935368856 min; Remaining 15.7176744052342 min.
# Saving model...
# Model saved.
# 14/49, test loss: -elbo: 2061.6335, recons_loss_weighted: 3795.4153, recons_loss_ls: 75.9083, KL_loss: 43.1089, sigma_regularisor: -331.5723, code_std_dev: [0.01934939 0.01       0.01       0.03227757 0.01467181 0.01      ]
# Loss on training and val sets:
# train: 1759.0352, val: 1857.8701
# Current sigma2: 0.0100000
# Already trained for 6.542978227138519 min; Remaining 15.266949196656546 min.
# Saving model...
# Model saved.
# 15/49, test loss: -elbo: 2067.8994, recons_loss_weighted: 3808.6050, recons_loss_ls: 76.1721, KL_loss: 42.7799, sigma_regularisor: -331.5723, code_std_dev: [0.02243224 0.01       0.01       0.04167603 0.01729065 0.01987489]
# Loss on training and val sets:
# train: 1749.0255, val: 1829.0874
# Current sigma2: 0.0100000
# Already trained for 6.969394226868947 min; Remaining 14.809962732096514 min.
# Saving model...
# Model saved.
# 16/49, test loss: -elbo: 2053.4990, recons_loss_weighted: 3778.7441, recons_loss_ls: 75.5749, KL_loss: 43.3098, sigma_regularisor: -331.5723, code_std_dev: [0.01073919 0.01       0.01       0.02607547 0.01365999 0.0127656 ]
# Loss on training and val sets:
# train: 1742.2901, val: 1907.9971
# Current sigma2: 0.0100000
# Already trained for 7.394454570611318 min; Remaining 14.353941225304323 min.
# Saving model...
# Model saved.
# 17/49, test loss: -elbo: 2060.1328, recons_loss_weighted: 3792.0754, recons_loss_ls: 75.8415, KL_loss: 43.2781, sigma_regularisor: -331.5723, code_std_dev: [0.01747852 0.01       0.01047562 0.03287507 0.01321627 0.01902998]
# Loss on training and val sets:
# train: 1728.6704, val: 1861.2904
# Current sigma2: 0.0100000
# Already trained for 7.825771113236745 min; Remaining 13.912481979087547 min.
# Saving model...
# Model saved.
# 18/49, test loss: -elbo: 2041.1292, recons_loss_weighted: 3754.6704, recons_loss_ls: 75.0934, KL_loss: 42.9768, sigma_regularisor: -331.5723, code_std_dev: [0.02944192 0.01       0.01       0.04450466 0.01       0.02704425]
# Loss on training and val sets:
# train: 1725.2470, val: 1846.8211
# Current sigma2: 0.0100000
# Already trained for 8.24900987148285 min; Remaining 13.458910842945702 min.
# Saving model...
# Model saved.
# 19/49, test loss: -elbo: 2055.2217, recons_loss_weighted: 3782.6890, recons_loss_ls: 75.6538, KL_loss: 43.0601, sigma_regularisor: -331.5723, code_std_dev: [0.01280733 0.01       0.01214169 0.01045041 0.01       0.01819828]
# Loss on training and val sets:
# train: 1720.1233, val: 1887.2258
# Current sigma2: 0.0100000
# Already trained for 8.677769052982331 min; Remaining 13.016653579473495 min.
# Saving model...
# Model saved.
# 20/49, test loss: -elbo: 2047.7212, recons_loss_weighted: 3767.6877, recons_loss_ls: 75.3538, KL_loss: 43.0603, sigma_regularisor: -331.5723, code_std_dev: [0.02834336 0.01       0.01       0.02312564 0.01       0.02322285]
# Loss on training and val sets:
# train: 1714.9694, val: 1847.3362
# Current sigma2: 0.0100000
# Already trained for 9.096479145685832 min; Remaining 12.56180453451853 min.
# Saving model...
# Model saved.
# 21/49, test loss: -elbo: 2044.2070, recons_loss_weighted: 3759.7524, recons_loss_ls: 75.1951, KL_loss: 43.5136, sigma_regularisor: -331.5723, code_std_dev: [0.0279501  0.01       0.01       0.01356797 0.01       0.02036327]
# Loss on training and val sets:
# train: 1695.5149, val: 1869.4851
# Current sigma2: 0.0100000
# Already trained for 9.522992857297261 min; Remaining 12.120172727469242 min.
# Saving model...
# Model saved.
# 22/49, test loss: -elbo: 2031.6794, recons_loss_weighted: 3733.7292, recons_loss_ls: 74.6746, KL_loss: 43.9978, sigma_regularisor: -331.5723, code_std_dev: [0.02916987 0.01       0.01       0.01199605 0.01       0.01458328]
# Loss on training and val sets:
# train: 1688.9296, val: 1877.0969
# Current sigma2: 0.0100000
# Already trained for 9.960006427764892 min; Remaining 11.692181458680526 min.
# Saving model...
# Model saved.
# 23/49, test loss: -elbo: 2035.9240, recons_loss_weighted: 3742.6870, recons_loss_ls: 74.8537, KL_loss: 43.7633, sigma_regularisor: -331.5723, code_std_dev: [0.03236339 0.01       0.01030511 0.01605096 0.01       0.01004285]
# Loss on training and val sets:
# train: 1693.5317, val: 1870.1724
# Current sigma2: 0.0100000
# Already trained for 10.381094555060068 min; Remaining 11.246185767981741 min.
# Saving model...
# Model saved.
# 24/49, test loss: -elbo: 2040.3990, recons_loss_weighted: 3751.2258, recons_loss_ls: 75.0245, KL_loss: 43.9691, sigma_regularisor: -331.5723, code_std_dev: [0.03904409 0.01       0.01091194 0.0198822  0.01       0.01      ]
# Loss on training and val sets:
# train: 1678.4361, val: 1854.0330
# Current sigma2: 0.0100000
# Already trained for 10.817491622765859 min; Remaining 10.817491622765859 min.
# Saving model...
# Model saved.
# 25/49, test loss: -elbo: 2031.6681, recons_loss_weighted: 3733.7156, recons_loss_ls: 74.6743, KL_loss: 43.9933, sigma_regularisor: -331.5723, code_std_dev: [0.03522985 0.01       0.01       0.02914364 0.01       0.01448428]
# Loss on training and val sets:
# train: 1672.9283, val: 1842.1541
# Current sigma2: 0.0100000
# Already trained for 11.254885097344717 min; Remaining 10.389124705241276 min.
# Saving model...
# Model saved.
# 26/49, test loss: -elbo: 2017.4293, recons_loss_weighted: 3707.7534, recons_loss_ls: 74.1551, KL_loss: 42.7355, sigma_regularisor: -331.5723, code_std_dev: [0.03230704 0.01       0.01112042 0.02140859 0.01       0.02447473]
# Loss on training and val sets:
# train: 1664.7635, val: 1799.2692
# Current sigma2: 0.0100000
# Already trained for 11.704828214645385 min; Remaining 9.970779590253477 min.
# Saving model...
# Model saved.
# 27/49, test loss: -elbo: 2014.4523, recons_loss_weighted: 3699.7781, recons_loss_ls: 73.9956, KL_loss: 43.7462, sigma_regularisor: -331.5723, code_std_dev: [0.02558865 0.01       0.01       0.01785599 0.01       0.0168266 ]
# Loss on training and val sets:
# train: 1663.3315, val: 1855.7981
# Current sigma2: 0.0100000
# Already trained for 12.144235527515411 min; Remaining 9.541899343047824 min.
# Saving model...
# Model saved.
# 28/49, test loss: -elbo: 2022.9807, recons_loss_weighted: 3716.2109, recons_loss_ls: 74.3242, KL_loss: 44.0581, sigma_regularisor: -331.5723, code_std_dev: [0.02929412 0.01       0.01       0.01819629 0.01       0.03102813]
# Loss on training and val sets:
# train: 1653.1075, val: 1828.2864
# Current sigma2: 0.0100000
# Already trained for 12.590952837467194 min; Remaining 9.117586537476244 min.
# Saving model...
# Model saved.
# 29/49, test loss: -elbo: 2006.2869, recons_loss_weighted: 3682.8403, recons_loss_ls: 73.6568, KL_loss: 44.0495, sigma_regularisor: -331.5723, code_std_dev: [0.0281067  0.01       0.01       0.01092411 0.01       0.01787535]
# Loss on training and val sets:
# train: 1652.4225, val: 1856.9895
# Current sigma2: 0.0100000
# Already trained for 13.038103024164835 min; Remaining 8.692068682776556 min.
# Saving model...
# Model saved.
# 30/49, test loss: -elbo: 1999.6580, recons_loss_weighted: 3669.7861, recons_loss_ls: 73.3957, KL_loss: 43.9478, sigma_regularisor: -331.5723, code_std_dev: [0.02313803 0.01       0.01296503 0.01071666 0.01       0.01513582]
# Loss on training and val sets:
# train: 1640.5870, val: 1847.3923
# Current sigma2: 0.0100000
# Already trained for 13.48019598722458 min; Remaining 8.26205560507313 min.
# Saving model...
# Model saved.
# 31/49, test loss: -elbo: 2011.0154, recons_loss_weighted: 3692.3528, recons_loss_ls: 73.8471, KL_loss: 44.0220, sigma_regularisor: -331.5723, code_std_dev: [0.02590203 0.01       0.01246665 0.01       0.01       0.02288737]
# Loss on training and val sets:
# train: 1635.5023, val: 1819.6499
# Current sigma2: 0.0100000
# Already trained for 13.93104437192281 min; Remaining 7.836212459206581 min.
# Saving model...
# Model saved.
# 32/49, test loss: -elbo: 2000.1926, recons_loss_weighted: 3670.2634, recons_loss_ls: 73.4053, KL_loss: 44.2439, sigma_regularisor: -331.5723, code_std_dev: [0.02617353 0.01       0.01       0.0125024  0.01       0.02492045]
# Loss on training and val sets:
# train: 1629.6635, val: 1801.2033
# Current sigma2: 0.0100000
# Already trained for 14.370720783869425 min; Remaining 7.403098585629705 min.
# Saving model...
# Model saved.
# 33/49, test loss: -elbo: 2005.5044, recons_loss_weighted: 3681.3242, recons_loss_ls: 73.6265, KL_loss: 44.0251, sigma_regularisor: -331.5723, code_std_dev: [0.02595223 0.01       0.01       0.02588958 0.01       0.01890656]
# Loss on training and val sets:
# train: 1622.9452, val: 1828.9359
# Current sigma2: 0.0100000
# Already trained for 14.82232920328776 min; Remaining 6.9752137427236525 min.
# Saving model...
# Model saved.
# 34/49, test loss: -elbo: 1998.4082, recons_loss_weighted: 3667.5217, recons_loss_ls: 73.3504, KL_loss: 43.8303, sigma_regularisor: -331.5723, code_std_dev: [0.03666575 0.01       0.01       0.02139893 0.01       0.01891569]
# Loss on training and val sets:
# train: 1616.4980, val: 1810.9717
# Current sigma2: 0.0100000
# Already trained for 15.256642969449361 min; Remaining 6.538561272621155 min.
# Saving model...
# Model saved.
# 35/49, test loss: -elbo: 1987.5889, recons_loss_weighted: 3646.5732, recons_loss_ls: 72.9315, KL_loss: 43.4851, sigma_regularisor: -331.5723, code_std_dev: [0.03977134 0.01       0.01       0.0195858  0.01       0.01358273]
# Loss on training and val sets:
# train: 1614.6348, val: 1850.8544
# Current sigma2: 0.0100000
# Already trained for 15.69301856358846 min; Remaining 6.102840552506624 min.
# Saving model...
# Model saved.
# 36/49, test loss: -elbo: 1998.0635, recons_loss_weighted: 3666.4360, recons_loss_ls: 73.3287, KL_loss: 44.0283, sigma_regularisor: -331.5723, code_std_dev: [0.04060763 0.01       0.01       0.02730914 0.01       0.01381906]
# Loss on training and val sets:
# train: 1608.8967, val: 1796.0450
# Current sigma2: 0.0100000
# Already trained for 16.122900398572288 min; Remaining 5.664802842741613 min.
# Saving model...
# Model saved.
# 37/49, test loss: -elbo: 1988.2211, recons_loss_weighted: 3645.1055, recons_loss_ls: 72.9021, KL_loss: 44.8512, sigma_regularisor: -331.5723, code_std_dev: [0.03239464 0.01       0.01       0.01444234 0.01       0.01829304]
# Loss on training and val sets:
# train: 1603.5290, val: 1806.1756
# Current sigma2: 0.0100000
# Already trained for 16.559904408454894 min; Remaining 5.229443497406809 min.
# Saving model...
# Model saved.
# 38/49, test loss: -elbo: 1978.6716, recons_loss_weighted: 3627.0708, recons_loss_ls: 72.5414, KL_loss: 44.3191, sigma_regularisor: -331.5723, code_std_dev: [0.03711045 0.01       0.01       0.01       0.01       0.02141481]
# Loss on training and val sets:
# train: 1605.0486, val: 1783.2724
# Current sigma2: 0.0100000
# Already trained for 16.993618396917977 min; Remaining 4.793071855540969 min.
# Saving model...
# Model saved.
# 39/49, test loss: -elbo: 1986.3475, recons_loss_weighted: 3643.0220, recons_loss_ls: 72.8604, KL_loss: 44.0194, sigma_regularisor: -331.5723, code_std_dev: [0.04226108 0.01       0.01       0.01458137 0.01       0.02235294]
# Loss on training and val sets:
# train: 1592.5824, val: 1795.8070
# Current sigma2: 0.0100000
# Already trained for 17.437411228815716 min; Remaining 4.359352807203929 min.
# Saving model...
# Model saved.
# 40/49, test loss: -elbo: 1987.5367, recons_loss_weighted: 3645.2104, recons_loss_ls: 72.9042, KL_loss: 44.1144, sigma_regularisor: -331.5723, code_std_dev: [0.03749171 0.01       0.01       0.01795988 0.01       0.02515796]
# Loss on training and val sets:
# train: 1589.0431, val: 1873.9390
# Current sigma2: 0.0100000
# Already trained for 17.877233882745106 min; Remaining 3.9242708523099017 min.
# Saving model...
# Model saved.
# 41/49, test loss: -elbo: 1988.7511, recons_loss_weighted: 3647.7964, recons_loss_ls: 72.9559, KL_loss: 44.0358, sigma_regularisor: -331.5723, code_std_dev: [0.03338314 0.01       0.01       0.01773839 0.01       0.02481601]
# Loss on training and val sets:
# train: 1589.7769, val: 1835.0950
# Current sigma2: 0.0100000
# Already trained for 18.304913608233132 min; Remaining 3.4866502110920257 min.
# Saving model...
# Model saved.
# 42/49, test loss: -elbo: 1971.7926, recons_loss_weighted: 3612.4990, recons_loss_ls: 72.2500, KL_loss: 44.7259, sigma_regularisor: -331.5723, code_std_dev: [0.02780269 0.01       0.01       0.01088542 0.01       0.0155424 ]
# Loss on training and val sets:
# train: 1581.8557, val: 1797.3948
# Current sigma2: 0.0100000
# Already trained for 18.733637603123984 min; Remaining 3.0496619353922765 min.
# Saving model...
# Model saved.
# 43/49, test loss: -elbo: 1981.5505, recons_loss_weighted: 3632.4326, recons_loss_ls: 72.6487, KL_loss: 44.5170, sigma_regularisor: -331.5723, code_std_dev: [0.03894203 0.01       0.01       0.01       0.01       0.02276399]
# Loss on training and val sets:
# train: 1577.7866, val: 1812.0275
# Current sigma2: 0.0100000
# Already trained for 19.15874686638514 min; Remaining 2.6125563908707012 min.
# Saving model...
# Model saved.
# 44/49, test loss: -elbo: 1987.0583, recons_loss_weighted: 3644.1877, recons_loss_ls: 72.8838, KL_loss: 44.1474, sigma_regularisor: -331.5723, code_std_dev: [0.04036279 0.01       0.01       0.0111827  0.01       0.01676964]
# Loss on training and val sets:
# train: 1567.9027, val: 1817.7398
# Current sigma2: 0.0100000
# Already trained for 19.58789069255193 min; Remaining 2.176432299172437 min.
# Saving model...
# Model saved.
# 45/49, test loss: -elbo: 1978.8608, recons_loss_weighted: 3626.3596, recons_loss_ls: 72.5272, KL_loss: 44.8640, sigma_regularisor: -331.5723, code_std_dev: [0.03308266 0.01       0.0101619  0.01       0.01       0.01305331]
# Loss on training and val sets:
# train: 1572.1844, val: 1809.5170
# Current sigma2: 0.0100000
# Already trained for 20.009964048862457 min; Remaining 1.7399968738141267 min.
# Saving model...
# Model saved.
# 46/49, test loss: -elbo: 1963.4122, recons_loss_weighted: 3596.2454, recons_loss_ls: 71.9249, KL_loss: 44.4725, sigma_regularisor: -331.5723, code_std_dev: [0.02270389 0.01       0.01       0.01106461 0.01       0.02261082]
# Loss on training and val sets:
# train: 1561.2472, val: 1792.0238
# Current sigma2: 0.0100000
# Already trained for 20.44067992766698 min; Remaining 1.3047242507021477 min.
# Saving model...
# Model saved.
# 47/49, test loss: -elbo: 1976.0732, recons_loss_weighted: 3621.8105, recons_loss_ls: 72.4362, KL_loss: 44.3509, sigma_regularisor: -331.5723, code_std_dev: [0.03219396 0.01       0.01       0.01027028 0.01       0.01      ]
# Loss on training and val sets:
# train: 1565.6430, val: 1831.3302
# Current sigma2: 0.0100000
# Already trained for 20.87337015469869 min; Remaining 0.8697237564457788 min.
# Saving model...
# Model saved.
# 48/49, test loss: -elbo: 1968.2871, recons_loss_weighted: 3606.9790, recons_loss_ls: 72.1396, KL_loss: 43.9804, sigma_regularisor: -331.5723, code_std_dev: [0.04239547 0.01       0.01061787 0.01574704 0.01       0.0119329 ]
# Loss on training and val sets:
# train: 1558.7634, val: 1827.1844
# Current sigma2: 0.0100000
# Already trained for 21.299748841921488 min; Remaining 0.43468875187594874 min.
# Saving model...
# Model saved.
# 49/49, test loss: -elbo: 1961.9734, recons_loss_weighted: 3593.1028, recons_loss_ls: 71.8621, KL_loss: 44.6050, sigma_regularisor: -331.5723, code_std_dev: [0.03132176 0.01       0.01012757 0.01481045 0.01       0.02079354]
# Loss on training and val sets:
# train: 1549.5658, val: 1800.7673
# Current sigma2: 0.0100000
# Already trained for 21.738209136327107 min; Remaining 0.0 min.

# %%
# load LSTM model
lstm_model = lstmKerasModel(data)
lstm_model.produce_embeddings(config, model_vae, data, sess)
lstm_nn_model = lstm_model.create_lstm_model(config)
lstm_nn_model.summary()   # Display the model's architecture

# checkpoint path
checkpoint_path = config['checkpoint_dir_lstm'] + "cp.ckpt"
checkpoint_dir = os.path.dirname(checkpoint_path)
# Create a callback that saves the model's weights
cp_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path,
                                                 save_weights_only=True,
                                                 verbose=1)
# load weights if possible
lstm_model.load_model(lstm_nn_model, config, checkpoint_path)
# start training
if config['TRAIN_LSTM']:
    if config['num_epochs_lstm'] > 0:
        lstm_model.train(config, lstm_nn_model, cp_callback)

    # make a prediction on the test set using the trained model
    lstm_embedding = lstm_nn_model.predict(lstm_model.x_test, batch_size=config['batch_size_lstm'])
    print(lstm_embedding.shape)

    # visualise the first 10 test sequences
    for i in range(10):
        lstm_model.plot_lstm_embedding_prediction(i, config, model_vae, sess, data, lstm_embedding)
# Out:
# aving model to ../experiments/local-results/SEP/sepsis/batch-32/sepsis-6-channels-24-6-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 880/880 [==============================] - 1s 685us/sample - loss: 1.4336 - mean_squared_error: 1.4336 - val_loss: 1.5833 - val_mean_squared_error: 1.5833
# Epoch 54/100
# 864/880 [============================>.] - ETA: 0s - loss: 1.4219 - mean_squared_error: 1.4219
# Epoch 00054: saving model to ../experiments/local-results/SEP/sepsis/batch-32/sepsis-6-channels-24-6-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 880/880 [==============================] - 1s 685us/sample - loss: 1.4244 - mean_squared_error: 1.4244 - val_loss: 1.5743 - val_mean_squared_error: 1.5743
# Epoch 55/100
# 832/880 [===========================>..] - ETA: 0s - loss: 1.4108 - mean_squared_error: 1.4108
# Epoch 00055: saving model to ../experiments/local-results/SEP/sepsis/batch-32/sepsis-6-channels-24-6-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 880/880 [==============================] - 1s 720us/sample - loss: 1.4137 - mean_squared_error: 1.4137 - val_loss: 1.5637 - val_mean_squared_error: 1.5637
# Epoch 56/100
# 800/880 [==========================>...] - ETA: 0s - loss: 1.4147 - mean_squared_error: 1.4147
# Epoch 00056: saving model to ../experiments/local-results/SEP/sepsis/batch-32/sepsis-6-channels-24-6-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 880/880 [==============================] - 1s 769us/sample - loss: 1.4038 - mean_squared_error: 1.4038 - val_loss: 1.5530 - val_mean_squared_error: 1.5530
# Epoch 57/100
# 864/880 [============================>.] - ETA: 0s - loss: 1.3913 - mean_squared_error: 1.3913
# Epoch 00057: saving model to ../experiments/local-results/SEP/sepsis/batch-32/sepsis-6-channels-24-6-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 880/880 [==============================] - 1s 658us/sample - loss: 1.3937 - mean_squared_error: 1.3937 - val_loss: 1.5441 - val_mean_squared_error: 1.5441
# Epoch 58/100
# 864/880 [============================>.] - ETA: 0s - loss: 1.3843 - mean_squared_error: 1.3843
# Epoch 00058: saving model to ../experiments/local-results/SEP/sepsis/batch-32/sepsis-6-channels-24-6-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 880/880 [==============================] - 1s 718us/sample - loss: 1.3841 - mean_squared_error: 1.3841 - val_loss: 1.5356 - val_mean_squared_error: 1.5356
# Epoch 59/100
# 864/880 [============================>.] - ETA: 0s - loss: 1.3738 - mean_squared_error: 1.3738
# Epoch 00059: saving model to ../experiments/local-results/SEP/sepsis/batch-32/sepsis-6-channels-24-6-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 880/880 [==============================] - 1s 687us/sample - loss: 1.3742 - mean_squared_error: 1.3742 - val_loss: 1.5261 - val_mean_squared_error: 1.5261
# Epoch 60/100
# 864/880 [============================>.] - ETA: 0s - loss: 1.3657 - mean_squared_error: 1.3657
# Epoch 00060: saving model to ../experiments/local-results/SEP/sepsis/batch-32/sepsis-6-channels-24-6-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 880/880 [==============================] - 1s 793us/sample - loss: 1.3647 - mean_squared_error: 1.3647 - val_loss: 1.5165 - val_mean_squared_error: 1.5165
# Epoch 61/100
# 864/880 [============================>.] - ETA: 0s - loss: 1.3620 - mean_squared_error: 1.3620
# Epoch 00061: saving model to ../experiments/local-results/SEP/sepsis/batch-32/sepsis-6-channels-24-6-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 880/880 [==============================] - 1s 737us/sample - loss: 1.3562 - mean_squared_error: 1.3562 - val_loss: 1.5069 - val_mean_squared_error: 1.5069
# Epoch 62/100
# 800/880 [==========================>...] - ETA: 0s - loss: 1.3526 - mean_squared_error: 1.3526
# Epoch 00062: saving model to ../experiments/local-results/SEP/sepsis/batch-32/sepsis-6-channels-24-6-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 880/880 [==============================] - 1s 661us/sample - loss: 1.3466 - mean_squared_error: 1.3466 - val_loss: 1.4993 - val_mean_squared_error: 1.4993
# Epoch 63/100
# 832/880 [===========================>..] - ETA: 0s - loss: 1.3335 - mean_squared_error: 1.3335
# Epoch 00063: saving model to ../experiments/local-results/SEP/sepsis/batch-32/sepsis-6-channels-24-6-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 880/880 [==============================] - 1s 757us/sample - loss: 1.3378 - mean_squared_error: 1.3378 - val_loss: 1.4929 - val_mean_squared_error: 1.4929
# Epoch 64/100
# 864/880 [============================>.] - ETA: 0s - loss: 1.3275 - mean_squared_error: 1.3275
# Epoch 00064: saving model to ../experiments/local-results/SEP/sepsis/batch-32/sepsis-6-channels-24-6-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 880/880 [==============================] - 1s 664us/sample - loss: 1.3291 - mean_squared_error: 1.3291 - val_loss: 1.4818 - val_mean_squared_error: 1.4818
# Epoch 65/100
# 864/880 [============================>.] - ETA: 0s - loss: 1.3211 - mean_squared_error: 1.3211
# Epoch 00065: saving model to ../experiments/local-results/SEP/sepsis/batch-32/sepsis-6-channels-24-6-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 880/880 [==============================] - 1s 712us/sample - loss: 1.3201 - mean_squared_error: 1.3201 - val_loss: 1.4776 - val_mean_squared_error: 1.4776
# Epoch 66/100
# 832/880 [===========================>..] - ETA: 0s - loss: 1.3071 - mean_squared_error: 1.3071
# Epoch 00066: saving model to ../experiments/local-results/SEP/sepsis/batch-32/sepsis-6-channels-24-6-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 880/880 [==============================] - 1s 692us/sample - loss: 1.3115 - mean_squared_error: 1.3115 - val_loss: 1.4697 - val_mean_squared_error: 1.4697
# Epoch 67/100
# 832/880 [===========================>..] - ETA: 0s - loss: 1.3063 - mean_squared_error: 1.3063
# Epoch 00067: saving model to ../experiments/local-results/SEP/sepsis/batch-32/sepsis-6-channels-24-6-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 880/880 [==============================] - 1s 650us/sample - loss: 1.3028 - mean_squared_error: 1.3028 - val_loss: 1.4588 - val_mean_squared_error: 1.4588
# Epoch 68/100
# 832/880 [===========================>..] - ETA: 0s - loss: 1.2932 - mean_squared_error: 1.2932
# Epoch 00068: saving model to ../experiments/local-results/SEP/sepsis/batch-32/sepsis-6-channels-24-6-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 880/880 [==============================] - 1s 628us/sample - loss: 1.2937 - mean_squared_error: 1.2937 - val_loss: 1.4513 - val_mean_squared_error: 1.4513
# Epoch 69/100
# 864/880 [============================>.] - ETA: 0s - loss: 1.2871 - mean_squared_error: 1.2871
# Epoch 00069: saving model to ../experiments/local-results/SEP/sepsis/batch-32/sepsis-6-channels-24-6-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 880/880 [==============================] - 1s 720us/sample - loss: 1.2858 - mean_squared_error: 1.2858 - val_loss: 1.4433 - val_mean_squared_error: 1.4433
# Epoch 70/100
# 864/880 [============================>.] - ETA: 0s - loss: 1.2795 - mean_squared_error: 1.2795
# Epoch 00070: saving model to ../experiments/local-results/SEP/sepsis/batch-32/sepsis-6-channels-24-6-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 880/880 [==============================] - 1s 694us/sample - loss: 1.2774 - mean_squared_error: 1.2774 - val_loss: 1.4389 - val_mean_squared_error: 1.4389
# Epoch 71/100
# 864/880 [============================>.] - ETA: 0s - loss: 1.2713 - mean_squared_error: 1.2713
# Epoch 00071: saving model to ../experiments/local-results/SEP/sepsis/batch-32/sepsis-6-channels-24-6-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 880/880 [==============================] - 1s 743us/sample - loss: 1.2691 - mean_squared_error: 1.2691 - val_loss: 1.4274 - val_mean_squared_error: 1.4274
# Epoch 72/100
# 864/880 [============================>.] - ETA: 0s - loss: 1.2620 - mean_squared_error: 1.2620
# Epoch 00072: saving model to ../experiments/local-results/SEP/sepsis/batch-32/sepsis-6-channels-24-6-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 880/880 [==============================] - 1s 734us/sample - loss: 1.2612 - mean_squared_error: 1.2612 - val_loss: 1.4186 - val_mean_squared_error: 1.4186
# Epoch 73/100
# 800/880 [==========================>...] - ETA: 0s - loss: 1.2528 - mean_squared_error: 1.2528
# Epoch 00073: saving model to ../experiments/local-results/SEP/sepsis/batch-32/sepsis-6-channels-24-6-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 880/880 [==============================] - 1s 695us/sample - loss: 1.2531 - mean_squared_error: 1.2531 - val_loss: 1.4135 - val_mean_squared_error: 1.4135
# Epoch 74/100
# 864/880 [============================>.] - ETA: 0s - loss: 1.2455 - mean_squared_error: 1.2455
# Epoch 00074: saving model to ../experiments/local-results/SEP/sepsis/batch-32/sepsis-6-channels-24-6-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 880/880 [==============================] - 1s 740us/sample - loss: 1.2451 - mean_squared_error: 1.2451 - val_loss: 1.4059 - val_mean_squared_error: 1.4059
# Epoch 75/100
# 800/880 [==========================>...] - ETA: 0s - loss: 1.2305 - mean_squared_error: 1.2305
# Epoch 00075: saving model to ../experiments/local-results/SEP/sepsis/batch-32/sepsis-6-channels-24-6-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 880/880 [==============================] - 1s 649us/sample - loss: 1.2374 - mean_squared_error: 1.2374 - val_loss: 1.4017 - val_mean_squared_error: 1.4017
# Epoch 76/100
# 800/880 [==========================>...] - ETA: 0s - loss: 1.2302 - mean_squared_error: 1.2302
# Epoch 00076: saving model to ../experiments/local-results/SEP/sepsis/batch-32/sepsis-6-channels-24-6-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 880/880 [==============================] - 1s 721us/sample - loss: 1.2298 - mean_squared_error: 1.2298 - val_loss: 1.3900 - val_mean_squared_error: 1.3900
# Epoch 77/100
# 864/880 [============================>.] - ETA: 0s - loss: 1.2223 - mean_squared_error: 1.2223
# Epoch 00077: saving model to ../experiments/local-results/SEP/sepsis/batch-32/sepsis-6-channels-24-6-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 880/880 [==============================] - 1s 710us/sample - loss: 1.2219 - mean_squared_error: 1.2219 - val_loss: 1.3851 - val_mean_squared_error: 1.3851
# Epoch 78/100
# 864/880 [============================>.] - ETA: 0s - loss: 1.2166 - mean_squared_error: 1.2166
# Epoch 00078: saving model to ../experiments/local-results/SEP/sepsis/batch-32/sepsis-6-channels-24-6-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 880/880 [==============================] - 1s 723us/sample - loss: 1.2140 - mean_squared_error: 1.2140 - val_loss: 1.3780 - val_mean_squared_error: 1.3780
# Epoch 79/100
# 800/880 [==========================>...] - ETA: 0s - loss: 1.2069 - mean_squared_error: 1.2069
# Epoch 00079: saving model to ../experiments/local-results/SEP/sepsis/batch-32/sepsis-6-channels-24-6-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 880/880 [==============================] - 1s 672us/sample - loss: 1.2069 - mean_squared_error: 1.2069 - val_loss: 1.3714 - val_mean_squared_error: 1.3714
# Epoch 80/100
# 832/880 [===========================>..] - ETA: 0s - loss: 1.2017 - mean_squared_error: 1.2017
# Epoch 00080: saving model to ../experiments/local-results/SEP/sepsis/batch-32/sepsis-6-channels-24-6-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 880/880 [==============================] - 1s 727us/sample - loss: 1.1999 - mean_squared_error: 1.1999 - val_loss: 1.3667 - val_mean_squared_error: 1.3667
# Epoch 81/100
# 832/880 [===========================>..] - ETA: 0s - loss: 1.1888 - mean_squared_error: 1.1888
# Epoch 00081: saving model to ../experiments/local-results/SEP/sepsis/batch-32/sepsis-6-channels-24-6-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 880/880 [==============================] - 1s 752us/sample - loss: 1.1926 - mean_squared_error: 1.1926 - val_loss: 1.3577 - val_mean_squared_error: 1.3577
# Epoch 82/100
# 832/880 [===========================>..] - ETA: 0s - loss: 1.1854 - mean_squared_error: 1.1854
# Epoch 00082: saving model to ../experiments/local-results/SEP/sepsis/batch-32/sepsis-6-channels-24-6-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 880/880 [==============================] - 1s 661us/sample - loss: 1.1850 - mean_squared_error: 1.1850 - val_loss: 1.3523 - val_mean_squared_error: 1.3523
# Epoch 83/100
# 832/880 [===========================>..] - ETA: 0s - loss: 1.1769 - mean_squared_error: 1.1769
# Epoch 00083: saving model to ../experiments/local-results/SEP/sepsis/batch-32/sepsis-6-channels-24-6-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 880/880 [==============================] - 1s 762us/sample - loss: 1.1777 - mean_squared_error: 1.1777 - val_loss: 1.3464 - val_mean_squared_error: 1.3464
# Epoch 84/100
# 832/880 [===========================>..] - ETA: 0s - loss: 1.1763 - mean_squared_error: 1.1763
# Epoch 00084: saving model to ../experiments/local-results/SEP/sepsis/batch-32/sepsis-6-channels-24-6-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 880/880 [==============================] - 1s 696us/sample - loss: 1.1709 - mean_squared_error: 1.1709 - val_loss: 1.3393 - val_mean_squared_error: 1.3393
# Epoch 85/100
# 832/880 [===========================>..] - ETA: 0s - loss: 1.1652 - mean_squared_error: 1.1652
# Epoch 00085: saving model to ../experiments/local-results/SEP/sepsis/batch-32/sepsis-6-channels-24-6-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 880/880 [==============================] - 1s 705us/sample - loss: 1.1639 - mean_squared_error: 1.1639 - val_loss: 1.3326 - val_mean_squared_error: 1.3326
# Epoch 86/100
# 864/880 [============================>.] - ETA: 0s - loss: 1.1559 - mean_squared_error: 1.1559
# Epoch 00086: saving model to ../experiments/local-results/SEP/sepsis/batch-32/sepsis-6-channels-24-6-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 880/880 [==============================] - 1s 710us/sample - loss: 1.1572 - mean_squared_error: 1.1572 - val_loss: 1.3265 - val_mean_squared_error: 1.3265
# Epoch 87/100
# 864/880 [============================>.] - ETA: 0s - loss: 1.1518 - mean_squared_error: 1.1518
# Epoch 00087: saving model to ../experiments/local-results/SEP/sepsis/batch-32/sepsis-6-channels-24-6-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 880/880 [==============================] - 1s 733us/sample - loss: 1.1504 - mean_squared_error: 1.1504 - val_loss: 1.3208 - val_mean_squared_error: 1.3208
# Epoch 88/100
# 800/880 [==========================>...] - ETA: 0s - loss: 1.1377 - mean_squared_error: 1.1377
# Epoch 00088: saving model to ../experiments/local-results/SEP/sepsis/batch-32/sepsis-6-channels-24-6-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 880/880 [==============================] - 1s 761us/sample - loss: 1.1434 - mean_squared_error: 1.1434 - val_loss: 1.3134 - val_mean_squared_error: 1.3134
# Epoch 89/100
# 832/880 [===========================>..] - ETA: 0s - loss: 1.1370 - mean_squared_error: 1.1370
# Epoch 00089: saving model to ../experiments/local-results/SEP/sepsis/batch-32/sepsis-6-channels-24-6-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 880/880 [==============================] - 1s 734us/sample - loss: 1.1370 - mean_squared_error: 1.1370 - val_loss: 1.3076 - val_mean_squared_error: 1.3076
# Epoch 90/100
# 864/880 [============================>.] - ETA: 0s - loss: 1.1280 - mean_squared_error: 1.1280
# Epoch 00090: saving model to ../experiments/local-results/SEP/sepsis/batch-32/sepsis-6-channels-24-6-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 880/880 [==============================] - 1s 690us/sample - loss: 1.1302 - mean_squared_error: 1.1302 - val_loss: 1.3009 - val_mean_squared_error: 1.3009
# Epoch 91/100
# 832/880 [===========================>..] - ETA: 0s - loss: 1.1285 - mean_squared_error: 1.1285
# Epoch 00091: saving model to ../experiments/local-results/SEP/sepsis/batch-32/sepsis-6-channels-24-6-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 880/880 [==============================] - 1s 726us/sample - loss: 1.1238 - mean_squared_error: 1.1238 - val_loss: 1.2968 - val_mean_squared_error: 1.2968
# Epoch 92/100
# 864/880 [============================>.] - ETA: 0s - loss: 1.1148 - mean_squared_error: 1.1148
# Epoch 00092: saving model to ../experiments/local-results/SEP/sepsis/batch-32/sepsis-6-channels-24-6-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 880/880 [==============================] - 1s 684us/sample - loss: 1.1174 - mean_squared_error: 1.1174 - val_loss: 1.2881 - val_mean_squared_error: 1.2881
# Epoch 93/100
# 800/880 [==========================>...] - ETA: 0s - loss: 1.1107 - mean_squared_error: 1.1107
# Epoch 00093: saving model to ../experiments/local-results/SEP/sepsis/batch-32/sepsis-6-channels-24-6-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 880/880 [==============================] - 1s 602us/sample - loss: 1.1111 - mean_squared_error: 1.1111 - val_loss: 1.2843 - val_mean_squared_error: 1.2843
# Epoch 94/100
# 864/880 [============================>.] - ETA: 0s - loss: 1.1006 - mean_squared_error: 1.1006
# Epoch 00094: saving model to ../experiments/local-results/SEP/sepsis/batch-32/sepsis-6-channels-24-6-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 880/880 [==============================] - 1s 717us/sample - loss: 1.1044 - mean_squared_error: 1.1044 - val_loss: 1.2782 - val_mean_squared_error: 1.2782
# Epoch 95/100
# 864/880 [============================>.] - ETA: 0s - loss: 1.0982 - mean_squared_error: 1.0982
# Epoch 00095: saving model to ../experiments/local-results/SEP/sepsis/batch-32/sepsis-6-channels-24-6-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 880/880 [==============================] - 1s 643us/sample - loss: 1.0980 - mean_squared_error: 1.0980 - val_loss: 1.2734 - val_mean_squared_error: 1.2734
# Epoch 96/100
# 832/880 [===========================>..] - ETA: 0s - loss: 1.0996 - mean_squared_error: 1.0996
# Epoch 00096: saving model to ../experiments/local-results/SEP/sepsis/batch-32/sepsis-6-channels-24-6-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 880/880 [==============================] - 1s 628us/sample - loss: 1.0920 - mean_squared_error: 1.0920 - val_loss: 1.2660 - val_mean_squared_error: 1.2660
# Epoch 97/100
# 864/880 [============================>.] - ETA: 0s - loss: 1.0882 - mean_squared_error: 1.0882
# Epoch 00097: saving model to ../experiments/local-results/SEP/sepsis/batch-32/sepsis-6-channels-24-6-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 880/880 [==============================] - 1s 629us/sample - loss: 1.0858 - mean_squared_error: 1.0858 - val_loss: 1.2632 - val_mean_squared_error: 1.2632
# Epoch 98/100
# 864/880 [============================>.] - ETA: 0s - loss: 1.0809 - mean_squared_error: 1.0809
# Epoch 00098: saving model to ../experiments/local-results/SEP/sepsis/batch-32/sepsis-6-channels-24-6-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 880/880 [==============================] - 1s 627us/sample - loss: 1.0800 - mean_squared_error: 1.0800 - val_loss: 1.2557 - val_mean_squared_error: 1.2557
# Epoch 99/100
# 800/880 [==========================>...] - ETA: 0s - loss: 1.0807 - mean_squared_error: 1.0807
# Epoch 00099: saving model to ../experiments/local-results/SEP/sepsis/batch-32/sepsis-6-channels-24-6-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 880/880 [==============================] - 1s 714us/sample - loss: 1.0737 - mean_squared_error: 1.0737 - val_loss: 1.2515 - val_mean_squared_error: 1.2515
# Epoch 100/100
# 832/880 [===========================>..] - ETA: 0s - loss: 1.0681 - mean_squared_error: 1.0681
# Epoch 00100: saving model to ../experiments/local-results/SEP/sepsis/batch-32/sepsis-6-channels-24-6-6-fixedSigma-0.1/checkpoint/lstm/cp.ckpt
# 880/880 [==============================] - 1s 710us/sample - loss: 1.0678 - mean_squared_error: 1.0678 - val_loss: 1.2462 - val_mean_squared_error: 1.2462
# (98, 5, 6)
# Decoded seq from VAE: (6, 24, 6)
# Decoded seq from lstm: (5, 24, 6)
# Decoded seq from VAE: (6, 24, 6)
# Decoded seq from lstm: (5, 24, 6)
# Decoded seq from VAE: (6, 24, 6)
# Decoded seq from lstm: (5, 24, 6)
# Decoded seq from VAE: (6, 24, 6)
# Decoded seq from lstm: (5, 24, 6)
# Decoded seq from VAE: (6, 24, 6)
# Decoded seq from lstm: (5, 24, 6)
# Decoded seq from VAE: (6, 24, 6)
# Decoded seq from lstm: (5, 24, 6)
# Decoded seq from VAE: (6, 24, 6)
# Decoded seq from lstm: (5, 24, 6)
# Decoded seq from VAE: (6, 24, 6)
# Decoded seq from lstm: (5, 24, 6)
# Decoded seq from VAE: (6, 24, 6)
# Decoded seq from lstm: (5, 24, 6)
# Decoded seq from VAE: (6, 24, 6)
# Decoded seq from lstm: (5, 24, 6)

# %%
# load normalised time series
save_dir = '../datasets/' + config['data_dir'] #NAB-known-anomaly/'
dataset = config['dataset']
file_name = config['filename']
filename = '{}.npz'.format(file_name)
result = dict(np.load(save_dir+filename, allow_pickle=True))
"""
#if dataset == 'machine_temp':
result['test'] = result['test'][0]
result['idx_anomaly_test'] = result['idx_anomaly_test'][0]
#result['t_test'] = result['t_test'][0]
t_test = np.linspace(0, result['test'].shape[0] - 1, result['test'].shape[0])
"""
print(result['test'].shape)
# slice into rolling windows and rolling sequences
def slice_rolling_windows_and_sequences(config, time_seq):
    n_sample = len(time_seq)
    print("The given sequence has {} samples".format(n_sample))
    n_vae_win = n_sample - config['l_win'] + 1
    if config['n_channel'] == 1:
        rolling_windows = np.zeros((n_vae_win, config['l_win']))
    else:
        rolling_windows = np.zeros((n_vae_win, config['l_win'], config['n_channel']), dtype=float)
    for i in range(n_vae_win):
        rolling_windows[i] = time_seq[i:i + config['l_win']]
        sample_m = np.mean(rolling_windows, axis=1)
        sample_std = np.std(rolling_windows, axis=1)

        n_lstm_seq = n_sample - config['l_seq']*config['l_win']+1
        if config['n_channel'] == 1:
            lstm_seq = np.zeros((n_lstm_seq, config['l_seq'], config['l_win']))
        else:
            lstm_seq = np.zeros((n_lstm_seq, config['l_seq'], config['l_win'], config['n_channel']), dtype=float)
    for i in range(n_lstm_seq):
        cur_seq = time_seq[i:i+config['l_seq']*config['l_win']]
        for j in range(config['l_seq']):
            lstm_seq[i,j] = cur_seq[config['l_win']*j:config['l_win']*(j+1)]
    
    return rolling_windows, lstm_seq, sample_m, sample_std

test_windows, test_seq, test_sample_m, test_sample_std = slice_rolling_windows_and_sequences(config, result['test'])
if config['n_channel'] == 1:
    test_windows = np.expand_dims(test_windows, -1)
    test_seq = np.expand_dims(test_seq, -1)
else:
    test_windows = test_windows
    test_seq = test_seq
print(test_windows.shape)
print(test_seq.shape)
# Out:
# (1122, 6)
# The given sequence has 1122 samples
# (1099, 24, 6)
# (979, 6, 24, 6)

# %%
# Evaluate ELBO and LSTM prediction error on the validation set
# evaluate some anomaly detection metrics
def evaluate_vae_anomaly_metrics_for_a_window(test_win):
    feed_dict = {model_vae.original_signal: np.expand_dims(test_win, 0),
                 model_vae.is_code_input: False,
                 model_vae.code_input: np.zeros((1, config['code_size']))}

    # VAE reconstruction error
    recons_win_vae = np.squeeze(sess.run(model_vae.decoded, feed_dict=feed_dict))
    test_vae_recons_error = np.sum(np.square(recons_win_vae - test_win))

    # VAE latent embedding likelihood
    vae_code_mean, vae_code_std = sess.run([model_vae.code_mean, model_vae.code_std_dev], feed_dict=feed_dict)
    test_vae_kl = 0.5 * (np.sum(np.square(vae_code_mean)) + \
                            np.sum(np.square(vae_code_std)) - \
                            np.sum(np.log(np.square(vae_code_std))) - config['code_size'])

    # VAE ELBO loss
    sigma2 = 0.0005
    input_dims = model_vae.input_dims
    sigma_regularisor = input_dims/2. * np.log(sigma2) + input_dims * np.pi
    test_vae_elbo = test_vae_recons_error/sigma2 + test_vae_kl + sigma_regularisor
    return test_vae_recons_error, test_vae_kl, test_vae_elbo

def evaluate_lstm_anomaly_metric_for_a_seq(test_seq):
    feed_dict = {model_vae.original_signal: test_seq,
                 model_vae.is_code_input: False,
                 model_vae.code_input: np.zeros((1, config['code_size']))}
    vae_embedding = np.squeeze(sess.run(model_vae.code_mean, feed_dict=feed_dict))
    #print(vae_embedding.shape)
    lstm_embedding = np.squeeze(lstm_nn_model.predict(np.expand_dims(vae_embedding[:config['l_seq']-1], 0), batch_size=1))
    lstm_embedding_error = np.sum(np.square(vae_embedding[1:] - lstm_embedding))
    
    # LSTM prediction error
    feed_dict_lstm = {model_vae.original_signal: np.zeros((config['l_seq'] - 1, config['l_win'], test_seq.shape[2])),
                      model_vae.is_code_input: True,
                      model_vae.code_input: lstm_embedding}
    recons_win_lstm = np.squeeze(sess.run(model_vae.decoded, feed_dict=feed_dict_lstm))
    lstm_recons_error = np.sum(np.square(recons_win_lstm - np.squeeze(test_seq[1:])))
    return lstm_recons_error, lstm_embedding_error

n_val_vae = data.val_set_vae['data'].shape[0]
n_val_lstm = data.val_set_lstm['data'].shape[0]

val_vae_recons_error = np.zeros(n_val_vae)
val_vae_kl_error = np.zeros(n_val_vae)
val_vae_elbo_loss = np.zeros(n_val_vae)
for i in range(n_val_vae):
    val_vae_recons_error[i], val_vae_kl_error[i], val_vae_elbo_loss[i] = evaluate_vae_anomaly_metrics_for_a_window(data.val_set_vae['data'][i])

val_lstm_recons_error, val_lstm_embedding_error = np.zeros(n_val_lstm), np.zeros(n_val_lstm)
for i in range(n_val_lstm):
    val_lstm_recons_error[i], val_lstm_embedding_error[i] = evaluate_lstm_anomaly_metric_for_a_seq(data.val_set_lstm['data'][i])

# %%
from scipy.stats import norm
def plot_histogram(test_anomaly_metric, n_bins, title, mean=None, std=None, xlim=None, saveplot=False):
    test_anomaly_list = np.squeeze(np.ndarray.flatten(test_anomaly_metric))
    his = plt.hist(test_anomaly_list, bins=n_bins, density=True)
    if mean is None and std is None:
        mean = np.mean(test_anomaly_list)
        std = np.std(test_anomaly_list)
        legend_label = None
    else:
        legend_label = 1
    x_axis = np.arange(mean-5*std, mean+5*std, std/100)
    plt.plot(x_axis, norm.pdf(x_axis,mean,std))
    plt.title(title)
    plt.xlabel('anomaly score value')
    plt.ylabel('probability density')
    if xlim is not None:
        plt.xlim(0, xlim)
    else:
        plt.xlim(0, np.amax(test_anomaly_list))
    if legend_label is None:
        plt.legend(('Fitted Gaussian', 'histogram'))
    else:
        plt.legend(('normal data distribution','test data distribution (contain anomalies)'))
    if saveplot:
        savefig(config['result_dir']+'reconstruction_error_histogram.pdf')
    else:
        plt.show()
    threshold_25 = np.percentile(test_anomaly_list, 25)
    threshold_75 = np.percentile(test_anomaly_list, 75)
    threshold_1 = np.percentile(test_anomaly_list, 99)
    idx_large_error = np.squeeze(np.argwhere(test_anomaly_metric > threshold_1))
#     print(his[0][-20:])
#     print(his[1][-20:])
    print("25% percentile: {}".format(threshold_25))
    print("75% percentile: {}".format(threshold_75))
#     print("Median: {}".format(np.median(test_anomaly_list)))
#     print("Mean: {}".format(np.mean(test_anomaly_list)))
#     print("Std dev: {}".format(np.std(test_anomaly_list)))
    print("These windows scored the top 1% of anomaly metric ({}): \n{}".format(threshold_1, idx_large_error))
    return mean, std

# %%
# Histogram of VAE ELBO loss - validation set
vae_elbo_m, vae_elbo_std = plot_histogram(val_vae_elbo_loss, 100, 
                                          'VAE ELBO error distribution on the val set', 
                                          mean=None, std=None, xlim=None)
# Out:
# 25% percentile: 104523.37206625644
# 75% percentile: 149419.73299315677
# These windows scored the top 1% of anomaly metric (289769.6621625257):
# [0 1]

# %%
# Histogram of LSTM reconstruction error - validation set 
#  --> to decide the anomaly detection threshold
lstm_recons_m, lstm_recons_std = plot_histogram(val_lstm_recons_error, 100,  
                                              'LSTM reconstruction error distribution on the val set', 
                                              mean=None, std=None, xlim=None)
# Out:
# 25% percentile: 350.1316776686282
# 75% percentile: 432.21392658961247
# These windows scored the top 1% of anomaly metric (527.1528263837579):
# 48

# %%
# Evaluate the anomaly metrics on the test windows and sequences
n_test_lstm = test_seq.shape[0]

test_lstm_recons_error, test_lstm_embedding_error = np.zeros(n_test_lstm), np.zeros(n_test_lstm)
for i in range(n_test_lstm):
    test_lstm_recons_error[i], test_lstm_embedding_error[i] = evaluate_lstm_anomaly_metric_for_a_seq(test_seq[i])
print("All windows' reconstruction error is computed.")
print("The total number of windows is {}".format(len(test_lstm_recons_error)))
# Out:
# All windows' reconstruction error is computed.
# The total number of windows is 979

# %%
# Histogram of LSTM reconstruction error - test set 
#  --> to detect anomaly now
_, _ = plot_histogram(test_lstm_recons_error, 100,
                      'LSTM reconstruction error distribution on the test set', 
                      mean=lstm_recons_m, std=lstm_recons_std, xlim=None, saveplot=True)
# Out:
# 25% percentile: 819.1965306813798
# 75% percentile: 1083.9374995610578
# These windows scored the top 1% of anomaly metric (1440.0227186220452):
# [533 534 535 555 556 557 558 559 906 907]

# %%
# Produce the ground truth anomaly indices 
# if result['idx_split'][0] == 0:
#     idx_anomaly_test = result['idx_anomaly_test']
# else:
#     idx_anomaly_test = result['idx_anomaly_test'][0]
idx_anomaly_test = result['idx_anomaly_test']    
anomaly_index_lstm = []
test_labels_lstm = np.zeros(n_test_lstm)
for i in range(len(idx_anomaly_test)):
    idx_start = idx_anomaly_test[i]-(config['l_win']*config['l_seq']-1)
    idx_end = idx_anomaly_test[i]+1
    if idx_start < 0:
        idx_start = 0
    if idx_end > n_test_lstm:
        idx_end = n_test_lstm
    anomaly_index_lstm.append(np.arange(idx_start,idx_end))
    test_labels_lstm[idx_start:idx_end] = 1
    
print(test_labels_lstm.shape)
# Out:
# (979,)

# %%
def return_anomaly_idx_by_threshold(test_anomaly_metric, threshold):
    test_list = np.squeeze(np.ndarray.flatten(test_anomaly_metric))
    idx_error = np.squeeze(np.argwhere(test_anomaly_metric > threshold))
    
    if len(idx_error.shape) == 0:
        idx_error = np.expand_dims(idx_error, 0)
    
    return list(idx_error)

# %%
def augment_detected_idx(idx_detected_anomaly, anomaly_index):
    n_anomaly = len(anomaly_index)
    idx_detected_anomaly_extended = list(idx_detected_anomaly)
    for i in range(n_anomaly):
        #print(idx_detected_anomaly)
        for j in idx_detected_anomaly:
            if j in anomaly_index[i]:
                in_original_detection = set(idx_detected_anomaly_extended)
                currect_anomaly_win = set(anomaly_index[i])
                idx_detected_anomaly_extended = idx_detected_anomaly_extended + list(currect_anomaly_win - in_original_detection)
                #print(j)
                break
                
    return list(np.sort(idx_detected_anomaly_extended))

# %%
def count_TP_FP_FN(idx_detected_anomaly, anomaly_index, test_labels):
    n_TP = 0
    n_FP = 0
    n_detection = len(idx_detected_anomaly)
    for i in range(n_detection):
        if test_labels[idx_detected_anomaly[i]] == 1:
            n_TP = n_TP + 1
        else:
            n_FP = n_FP + 1
    
    idx_undetected = list(set(np.arange(len(test_labels)))- set(idx_detected_anomaly))
    n_FN = 0
    for i in idx_undetected:
        if test_labels[i] == 1:
            n_FN = n_FN + 1
    
    return n_TP, n_FP, n_FN

# %%
def compute_precision_and_recall(idx_detected_anomaly, anomaly_index, test_labels):
    # compute true positive
    n_TP, n_FP, n_FN = count_TP_FP_FN(idx_detected_anomaly, anomaly_index, test_labels)
    
    if n_TP + n_FP == 0:
        precision = 1
    else:
        precision = n_TP / (n_TP + n_FP)
    recall = n_TP / (n_TP + n_FN)
    if precision + recall == 0:
        F1 = 0
    else:
        F1 = 2* (precision * recall)/(precision + recall)
    
    return precision, recall, F1, n_TP, n_FP, n_FN

# %%
n_threshold = 200
precision = np.zeros(n_threshold)
recall = np.zeros(n_threshold)
F1 = np.zeros(n_threshold)
precision_aug = np.zeros(n_threshold)
recall_aug = np.zeros(n_threshold)
F1_aug = np.zeros(n_threshold)
i = 0
threshold_list = np.linspace(np.amin(test_lstm_recons_error), np.amax(test_lstm_recons_error), n_threshold, endpoint=True)
threshold_list = np.flip(threshold_list)
for threshold in threshold_list:
    #print(threshold_list[i])
    idx_detection_lstm = return_anomaly_idx_by_threshold(test_lstm_recons_error, threshold)
    precision[i], recall[i], F1[i], _, _, _ = compute_precision_and_recall(idx_detection_lstm, 
                                                                           anomaly_index_lstm, 
                                                                           test_labels_lstm)
    # augment the detection using the ground truth labels
    # a method to discount the factor one anomaly appears in multiple consecutive windows
    # introduced in "Unsupervised anomaly detection via variational auto-encoder for seasonal kpis in web applications"
    idx_detection_lstm_augmented = augment_detected_idx(idx_detection_lstm, anomaly_index_lstm)
    precision_aug[i], recall_aug[i], F1_aug[i], _, _, _ = compute_precision_and_recall(idx_detection_lstm_augmented, 
                                                                                       anomaly_index_lstm, 
                                                                                       test_labels_lstm)
    i = i + 1
    #print(precision, recall, F1)

# %%
print("Best F1 score is {}".format(np.amax(F1)))
idx_best_threshold = np.squeeze(np.argwhere(F1 == np.amax(F1)))
print("Best threshold is {}".format(threshold_list[idx_best_threshold]))
print("At this threshold, precision is {}, recall is {}".format(precision[idx_best_threshold], recall[idx_best_threshold]))
average_precision = np.sum(precision[1:] * (recall[1:] - recall[:-1]))
print("Average precision is {}".format(average_precision))

print("\nAugmented detection:")
print("Best F1 score is {}".format(np.amax(F1_aug)))
idx_best_threshold = np.squeeze(np.argwhere(F1_aug == np.amax(F1_aug)))
print("Best threshold is {}".format(threshold_list[idx_best_threshold]))
print("At this threshold, precision is {}, recall is {}".format(precision_aug[idx_best_threshold], 
                                                                recall_aug[idx_best_threshold]))

average_precision_aug = np.sum(precision_aug[1:] * (recall_aug[1:] - recall_aug[:-1]))
print("Average precision is {}".format(average_precision_aug))
# Out:
# Best F1 score is 0.9389312977099238
# Best threshold is 666.9185252901589
# At this threshold, precision is 0.8876288659793814, recall is 0.9965277777777778
# Average precision is 0.9479128010836652
#
# Augmented detection:
# Best F1 score is 0.9891242129364625
# Best threshold is 998.913908244488
# At this threshold, precision is 0.9784824462061155, recall is 1.0
# Average precision is 0.9961825806090173

# %%
# Now select a threshold
print(idx_best_threshold.ndim)
if idx_best_threshold.ndim > 0:
    threshold = threshold_list[idx_best_threshold[0]]
else:
    threshold = threshold_list[idx_best_threshold]

print("Threshold is {}".format(threshold))
idx_detection = return_anomaly_idx_by_threshold(test_lstm_recons_error, threshold)
idx_detection_augmented = augment_detected_idx(idx_detection, anomaly_index_lstm)
precision, recall, F1, n_TP, n_FP, n_FN = compute_precision_and_recall(idx_detection_augmented, 
                                                                       anomaly_index_lstm, 
                                                                       test_labels_lstm)
print("\nPR evaluation using augmented detection:")
print("Precision: {}".format(precision))
print("Recall: {}".format(recall))
print("F1: {}".format(F1))
print("TP: {}".format(n_TP))
print("FP: {}".format(n_FP))
print("FN: {}".format(n_FN))
# Out:
# 0
# Threshold is 998.913908244488
#
# PR evaluation using augmented detection:
# Precision: 0.9784824462061155
# Recall: 1.0
# F1: 0.9891242129364625
# TP: 864
# FP: 19
# FN: 0

# %%
def slice_detected_indices_into_seq(idx_detection, interval):
    detected_seq = []
    i = 0
    while i < len(idx_detection):
        if i == 0:
            cur_seq = [idx_detection[i]]
            i = i + 1
        else:
            if idx_detection[i] - idx_detection[i-1] > interval:
                detected_seq.append(cur_seq)
                cur_seq = [idx_detection[i]]
            else:
                cur_seq.append(idx_detection[i])
                if i == len(idx_detection) - 1:
                    detected_seq.append(cur_seq)
            i = i + 1
    
    print("Detected {} sequences".format(len(detected_seq)))
    return detected_seq

# %%
def plot_detected_anomalies(idx_detection, interval, dataset, result, detection_method, augmented_flag=1, y_scale=5, y_lim=None):
    detected_seq = slice_detected_indices_into_seq(idx_detection, interval=interval)
    t_test = result['t_test']
    test = result['test']
    idx_anomaly_test = result['idx_anomaly_test']
        
    # plot detected sequences
    fig, axs = plt.subplots(1, 1, figsize=(18, 5), edgecolor='k')
    fig.subplots_adjust(hspace=.4, wspace=.4)
    axs.plot(t_test, test)
    for j in range(len(idx_anomaly_test)):
        if j == 0:
            axs.plot(idx_anomaly_test[j] * np.ones(20), np.linspace(-y_scale, y_scale, 20), 'r--', label='true anomalies')
        else:
            axs.plot(idx_anomaly_test[j] * np.ones(20), np.linspace(-y_scale, y_scale, 20), 'r--')
        
    for i in range(len(detected_seq)):
        for j in detected_seq[i]:
            if j == detected_seq[0][0]:
                axs.plot((j+interval*2) * np.ones(20), np.linspace(-y_scale, -0.8*y_scale, 20), 'g-', label='detected anomalies')
            else:
                axs.plot((j+interval*2) * np.ones(20), np.linspace(-y_scale, -0.8*y_scale, 20), 'g-')
    
    for j in range(len(idx_anomaly_test)):
        axs.plot(idx_anomaly_test[j] * np.ones(20), np.linspace(-y_scale, y_scale, 20), 'r--')

    for i in range(len(detected_seq)):
        interval_x = np.asarray([detected_seq[i][0], detected_seq[i][-1]+interval*2])
        interval_y = np.asarray([y_scale,y_scale])
        if i == 0:
            axs.fill_between(interval_x, interval_y, alpha=0.2, color='y', label='detected anomaly windows')
        else:
            axs.fill_between(interval_x, interval_y, alpha=0.2, color='y')
        interval_y = np.asarray([-y_scale,-y_scale])
        axs.fill_between(interval_x, interval_y, alpha=0.2, color='y')
    axs.grid(True)
    axs.set_xlim(0, len(t_test))
    if y_lim is None:
        axs.set_ylim(-y_scale, y_scale)
    else:
        axs.set_ylim(-y_scale, y_lim)
    axs.set_xlabel("timestamp (every {})".format(result['t_unit']))
    axs.set_ylabel("normalised readings")
    #axs.set_title("{} dataset test sequence\n(normalised by train mean {:.4f} and std {:.4f})\n Detection method: {}".format(dataset, 
    #                                                                                    result['train_m'], 
    #                                                                                    result['train_std'],
    #                                                                                    detection_method))
    axs.set_title("{} dataset test sequence\n Detection method: {}".format(dataset, detection_method))
    axs.legend()
    savefig(config['result_dir']+'detected_anomalies_{}_aug_{}.pdf'.format(detection_method, augmented_flag))

# %%
plot_detected_anomalies(idx_detection_augmented, 
                        interval=config['l_win']*config['l_seq']/2, 
                        dataset=dataset, 
                        result=result, 
                        detection_method='lstm reconstruction error',
                        augmented_flag=1,
                        y_scale=5,
                        y_lim=5)
# Out:
# Detected 1 sequences
